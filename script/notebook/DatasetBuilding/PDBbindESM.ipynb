# %% [markdown]
# # ESM for Protein Residue Embedding

# %% [markdown]
# ## Protein Construction

# %%
import pickle
import torch
from tqdm import tqdm
from torchdrug import utils, transforms, data, models, layers

# %%
protein_pkl = '../../../data/dta-datasets/PDBbind/gearnet_Protein.pkl'
with utils.smart_open(protein_pkl, "rb") as fin:
    output_list = pickle.load(fin)

# %%
output_list
# Out:
# [PackedProtein(batch_size=1, num_atoms=[1161], num_bonds=[23749], num_residues=[1161]),
#  PackedProtein(batch_size=1, num_atoms=[501], num_bonds=[9852], num_residues=[501]),
#  PackedProtein(batch_size=1, num_atoms=[165], num_bonds=[3709], num_residues=[165]),
#  PackedProtein(batch_size=1, num_atoms=[852], num_bonds=[19860], num_residues=[852]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5615], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[611], num_bonds=[14390], num_residues=[611]),
#  PackedProtein(batch_size=1, num_atoms=[939], num_bonds=[20431], num_residues=[939]),
#  PackedProtein(batch_size=1, num_atoms=[295], num_bonds=[6629], num_residues=[295]),
#  PackedProtein(batch_size=1, num_atoms=[296], num_bonds=[6538], num_residues=[296]),
#  PackedProtein(batch_size=1, num_atoms=[1017], num_bonds=[23912], num_residues=[1017]),
#  PackedProtein(batch_size=1, num_atoms=[364], num_bonds=[7158], num_residues=[364]),
#  PackedProtein(batch_size=1, num_atoms=[430], num_bonds=[7629], num_residues=[430]),
#  PackedProtein(batch_size=1, num_atoms=[244], num_bonds=[4891], num_residues=[244]),
#  PackedProtein(batch_size=1, num_atoms=[244], num_bonds=[4882], num_residues=[244]),
#  PackedProtein(batch_size=1, num_atoms=[509], num_bonds=[10824], num_residues=[509]),
#  PackedProtein(batch_size=1, num_atoms=[652], num_bonds=[12512], num_residues=[652]),
#  PackedProtein(batch_size=1, num_atoms=[165], num_bonds=[3233], num_residues=[165]),
#  PackedProtein(batch_size=1, num_atoms=[301], num_bonds=[5884], num_residues=[301]),
#  PackedProtein(batch_size=1, num_atoms=[1078], num_bonds=[24632], num_residues=[1078]),
#  PackedProtein(batch_size=1, num_atoms=[557], num_bonds=[12134], num_residues=[557]),
#  PackedProtein(batch_size=1, num_atoms=[939], num_bonds=[21263], num_residues=[939]),
#  PackedProtein(batch_size=1, num_atoms=[942], num_bonds=[21516], num_residues=[942]),
#  PackedProtein(batch_size=1, num_atoms=[1377], num_bonds=[29382], num_residues=[1377]),
#  PackedProtein(batch_size=1, num_atoms=[721], num_bonds=[15357], num_residues=[721]),
#  PackedProtein(batch_size=1, num_atoms=[1242], num_bonds=[30937], num_residues=[1242]),
#  PackedProtein(batch_size=1, num_atoms=[504], num_bonds=[10392], num_residues=[504]),
#  PackedProtein(batch_size=1, num_atoms=[608], num_bonds=[13321], num_residues=[608]),
#  PackedProtein(batch_size=1, num_atoms=[439], num_bonds=[8580], num_residues=[439]),
#  PackedProtein(batch_size=1, num_atoms=[172], num_bonds=[3833], num_residues=[172]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5238], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5196], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5185], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[865], num_bonds=[19609], num_residues=[865]),
#  PackedProtein(batch_size=1, num_atoms=[458], num_bonds=[10504], num_residues=[458]),
#  PackedProtein(batch_size=1, num_atoms=[2220], num_bonds=[48542], num_residues=[2220]),
#  PackedProtein(batch_size=1, num_atoms=[960], num_bonds=[22017], num_residues=[960]),
#  PackedProtein(batch_size=1, num_atoms=[988], num_bonds=[21779], num_residues=[988]),
#  PackedProtein(batch_size=1, num_atoms=[105], num_bonds=[2024], num_residues=[105]),
#  PackedProtein(batch_size=1, num_atoms=[105], num_bonds=[2004], num_residues=[105]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2036], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7704], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[471], num_bonds=[10850], num_residues=[471]),
#  PackedProtein(batch_size=1, num_atoms=[656], num_bonds=[14002], num_residues=[656]),
#  PackedProtein(batch_size=1, num_atoms=[429], num_bonds=[7472], num_residues=[429]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5254], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[301], num_bonds=[6024], num_residues=[301]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5225], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[1473], num_bonds=[32399], num_residues=[1473]),
#  PackedProtein(batch_size=1, num_atoms=[559], num_bonds=[12131], num_residues=[559]),
#  PackedProtein(batch_size=1, num_atoms=[1078], num_bonds=[24640], num_residues=[1078]),
#  PackedProtein(batch_size=1, num_atoms=[346], num_bonds=[7484], num_residues=[346]),
#  PackedProtein(batch_size=1, num_atoms=[525], num_bonds=[11486], num_residues=[525]),
#  PackedProtein(batch_size=1, num_atoms=[744], num_bonds=[15577], num_residues=[744]),
#  PackedProtein(batch_size=1, num_atoms=[1025], num_bonds=[23873], num_residues=[1025]),
#  PackedProtein(batch_size=1, num_atoms=[498], num_bonds=[10377], num_residues=[498]),
#  PackedProtein(batch_size=1, num_atoms=[894], num_bonds=[19858], num_residues=[894]),
#  PackedProtein(batch_size=1, num_atoms=[346], num_bonds=[7499], num_residues=[346]),
#  PackedProtein(batch_size=1, num_atoms=[390], num_bonds=[8464], num_residues=[390]),
#  PackedProtein(batch_size=1, num_atoms=[244], num_bonds=[4862], num_residues=[244]),
#  PackedProtein(batch_size=1, num_atoms=[165], num_bonds=[3720], num_residues=[165]),
#  PackedProtein(batch_size=1, num_atoms=[392], num_bonds=[8391], num_residues=[392]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5642], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[922], num_bonds=[19254], num_residues=[922]),
#  PackedProtein(batch_size=1, num_atoms=[454], num_bonds=[9521], num_residues=[454]),
#  PackedProtein(batch_size=1, num_atoms=[414], num_bonds=[9383], num_residues=[414]),
#  PackedProtein(batch_size=1, num_atoms=[1509], num_bonds=[33178], num_residues=[1509]),
#  PackedProtein(batch_size=1, num_atoms=[445], num_bonds=[9391], num_residues=[445]),
#  PackedProtein(batch_size=1, num_atoms=[130], num_bonds=[1956], num_residues=[130]),
#  PackedProtein(batch_size=1, num_atoms=[758], num_bonds=[16676], num_residues=[758]),
#  PackedProtein(batch_size=1, num_atoms=[282], num_bonds=[4946], num_residues=[282]),
#  PackedProtein(batch_size=1, num_atoms=[430], num_bonds=[9258], num_residues=[430]),
#  PackedProtein(batch_size=1, num_atoms=[545], num_bonds=[11075], num_residues=[545]),
#  PackedProtein(batch_size=1, num_atoms=[317], num_bonds=[6706], num_residues=[317]),
#  PackedProtein(batch_size=1, num_atoms=[324], num_bonds=[6789], num_residues=[324]),
#  PackedProtein(batch_size=1, num_atoms=[388], num_bonds=[8612], num_residues=[388]),
#  PackedProtein(batch_size=1, num_atoms=[352], num_bonds=[7536], num_residues=[352]),
#  PackedProtein(batch_size=1, num_atoms=[465], num_bonds=[10595], num_residues=[465]),
#  PackedProtein(batch_size=1, num_atoms=[138], num_bonds=[3183], num_residues=[138]),
#  PackedProtein(batch_size=1, num_atoms=[1298], num_bonds=[27316], num_residues=[1298]),
#  PackedProtein(batch_size=1, num_atoms=[276], num_bonds=[5675], num_residues=[276]),
#  PackedProtein(batch_size=1, num_atoms=[497], num_bonds=[10833], num_residues=[497]),
#  PackedProtein(batch_size=1, num_atoms=[130], num_bonds=[1971], num_residues=[130]),
#  PackedProtein(batch_size=1, num_atoms=[301], num_bonds=[5901], num_residues=[301]),
#  PackedProtein(batch_size=1, num_atoms=[153], num_bonds=[3437], num_residues=[153]),
#  PackedProtein(batch_size=1, num_atoms=[591], num_bonds=[13204], num_residues=[591]),
#  PackedProtein(batch_size=1, num_atoms=[1449], num_bonds=[31629], num_residues=[1449]),
#  PackedProtein(batch_size=1, num_atoms=[4032], num_bonds=[80016], num_residues=[4032]),
#  PackedProtein(batch_size=1, num_atoms=[155], num_bonds=[3492], num_residues=[155]),
#  PackedProtein(batch_size=1, num_atoms=[318], num_bonds=[7257], num_residues=[318]),
#  PackedProtein(batch_size=1, num_atoms=[278], num_bonds=[5320], num_residues=[278]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5268], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[1263], num_bonds=[31765], num_residues=[1263]),
#  PackedProtein(batch_size=1, num_atoms=[448], num_bonds=[10673], num_residues=[448]),
#  PackedProtein(batch_size=1, num_atoms=[307], num_bonds=[6055], num_residues=[307]),
#  PackedProtein(batch_size=1, num_atoms=[271], num_bonds=[5282], num_residues=[271]),
#  PackedProtein(batch_size=1, num_atoms=[578], num_bonds=[11060], num_residues=[578]),
#  PackedProtein(batch_size=1, num_atoms=[299], num_bonds=[5715], num_residues=[299]),
#  PackedProtein(batch_size=1, num_atoms=[515], num_bonds=[11096], num_residues=[515]),
#  PackedProtein(batch_size=1, num_atoms=[239], num_bonds=[5574], num_residues=[239]),
#  PackedProtein(batch_size=1, num_atoms=[635], num_bonds=[13094], num_residues=[635]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5240], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[16375], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[305], num_bonds=[6917], num_residues=[305]),
#  PackedProtein(batch_size=1, num_atoms=[275], num_bonds=[5908], num_residues=[275]),
#  PackedProtein(batch_size=1, num_atoms=[150], num_bonds=[3179], num_residues=[150]),
#  PackedProtein(batch_size=1, num_atoms=[278], num_bonds=[6049], num_residues=[278]),
#  PackedProtein(batch_size=1, num_atoms=[515], num_bonds=[11046], num_residues=[515]),
#  PackedProtein(batch_size=1, num_atoms=[514], num_bonds=[10911], num_residues=[514]),
#  PackedProtein(batch_size=1, num_atoms=[1473], num_bonds=[32297], num_residues=[1473]),
#  PackedProtein(batch_size=1, num_atoms=[2100], num_bonds=[49530], num_residues=[2100]),
#  PackedProtein(batch_size=1, num_atoms=[847], num_bonds=[19548], num_residues=[847]),
#  PackedProtein(batch_size=1, num_atoms=[150], num_bonds=[3185], num_residues=[150]),
#  PackedProtein(batch_size=1, num_atoms=[534], num_bonds=[10462], num_residues=[534]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5234], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[445], num_bonds=[10385], num_residues=[445]),
#  PackedProtein(batch_size=1, num_atoms=[463], num_bonds=[8970], num_residues=[463]),
#  PackedProtein(batch_size=1, num_atoms=[493], num_bonds=[10290], num_residues=[493]),
#  PackedProtein(batch_size=1, num_atoms=[487], num_bonds=[8868], num_residues=[487]),
#  PackedProtein(batch_size=1, num_atoms=[487], num_bonds=[8972], num_residues=[487]),
#  PackedProtein(batch_size=1, num_atoms=[4044], num_bonds=[94536], num_residues=[4044]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5217], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[1556], num_bonds=[42080], num_residues=[1556]),
#  PackedProtein(batch_size=1, num_atoms=[163], num_bonds=[3355], num_residues=[163]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7739], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[212], num_bonds=[4295], num_residues=[212]),
#  PackedProtein(batch_size=1, num_atoms=[1602], num_bonds=[36458], num_residues=[1602]),
#  PackedProtein(batch_size=1, num_atoms=[263], num_bonds=[5652], num_residues=[263]),
#  PackedProtein(batch_size=1, num_atoms=[2598], num_bonds=[59406], num_residues=[2598]),
#  PackedProtein(batch_size=1, num_atoms=[894], num_bonds=[19645], num_residues=[894]),
#  PackedProtein(batch_size=1, num_atoms=[325], num_bonds=[6502], num_residues=[325]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5193], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[355], num_bonds=[7653], num_residues=[355]),
#  PackedProtein(batch_size=1, num_atoms=[130], num_bonds=[1965], num_residues=[130]),
#  PackedProtein(batch_size=1, num_atoms=[130], num_bonds=[1960], num_residues=[130]),
#  PackedProtein(batch_size=1, num_atoms=[426], num_bonds=[7798], num_residues=[426]),
#  PackedProtein(batch_size=1, num_atoms=[330], num_bonds=[7453], num_residues=[330]),
#  PackedProtein(batch_size=1, num_atoms=[140], num_bonds=[2124], num_residues=[140]),
#  PackedProtein(batch_size=1, num_atoms=[164], num_bonds=[3697], num_residues=[164]),
#  PackedProtein(batch_size=1, num_atoms=[544], num_bonds=[11034], num_residues=[544]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5207], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[390], num_bonds=[8491], num_residues=[390]),
#  PackedProtein(batch_size=1, num_atoms=[363], num_bonds=[6633], num_residues=[363]),
#  PackedProtein(batch_size=1, num_atoms=[497], num_bonds=[10793], num_residues=[497]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5686], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[544], num_bonds=[11081], num_residues=[544]),
#  PackedProtein(batch_size=1, num_atoms=[306], num_bonds=[6908], num_residues=[306]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5190], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[278], num_bonds=[6057], num_residues=[278]),
#  PackedProtein(batch_size=1, num_atoms=[210], num_bonds=[4258], num_residues=[210]),
#  PackedProtein(batch_size=1, num_atoms=[425], num_bonds=[7768], num_residues=[425]),
#  PackedProtein(batch_size=1, num_atoms=[272], num_bonds=[5330], num_residues=[272]),
#  PackedProtein(batch_size=1, num_atoms=[338], num_bonds=[7589], num_residues=[338]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5269], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[555], num_bonds=[13548], num_residues=[555]),
#  PackedProtein(batch_size=1, num_atoms=[698], num_bonds=[14885], num_residues=[698]),
#  PackedProtein(batch_size=1, num_atoms=[208], num_bonds=[4100], num_residues=[208]),
#  PackedProtein(batch_size=1, num_atoms=[341], num_bonds=[8495], num_residues=[341]),
#  PackedProtein(batch_size=1, num_atoms=[651], num_bonds=[11665], num_residues=[651]),
#  PackedProtein(batch_size=1, num_atoms=[260], num_bonds=[4927], num_residues=[260]),
#  PackedProtein(batch_size=1, num_atoms=[628], num_bonds=[13508], num_residues=[628]),
#  PackedProtein(batch_size=1, num_atoms=[528], num_bonds=[10124], num_residues=[528]),
#  PackedProtein(batch_size=1, num_atoms=[1014], num_bonds=[22741], num_residues=[1014]),
#  PackedProtein(batch_size=1, num_atoms=[794], num_bonds=[18090], num_residues=[794]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7646], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[164], num_bonds=[3717], num_residues=[164]),
#  PackedProtein(batch_size=1, num_atoms=[1616], num_bonds=[32794], num_residues=[1616]),
#  PackedProtein(batch_size=1, num_atoms=[488], num_bonds=[9013], num_residues=[488]),
#  PackedProtein(batch_size=1, num_atoms=[740], num_bonds=[15265], num_residues=[740]),
#  PackedProtein(batch_size=1, num_atoms=[437], num_bonds=[9294], num_residues=[437]),
#  PackedProtein(batch_size=1, num_atoms=[438], num_bonds=[9309], num_residues=[438]),
#  PackedProtein(batch_size=1, num_atoms=[550], num_bonds=[12808], num_residues=[550]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5283], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[334], num_bonds=[7639], num_residues=[334]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5671], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[346], num_bonds=[7446], num_residues=[346]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[830], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[875], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[164], num_bonds=[3707], num_residues=[164]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[16402], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[498], num_bonds=[10385], num_residues=[498]),
#  PackedProtein(batch_size=1, num_atoms=[109], num_bonds=[1627], num_residues=[109]),
#  PackedProtein(batch_size=1, num_atoms=[457], num_bonds=[8636], num_residues=[457]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7627], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[330], num_bonds=[7444], num_residues=[330]),
#  PackedProtein(batch_size=1, num_atoms=[437], num_bonds=[8417], num_residues=[437]),
#  PackedProtein(batch_size=1, num_atoms=[1010], num_bonds=[24408], num_residues=[1010]),
#  PackedProtein(batch_size=1, num_atoms=[328], num_bonds=[6541], num_residues=[328]),
#  PackedProtein(batch_size=1, num_atoms=[1618], num_bonds=[32480], num_residues=[1618]),
#  PackedProtein(batch_size=1, num_atoms=[496], num_bonds=[11870], num_residues=[496]),
#  PackedProtein(batch_size=1, num_atoms=[306], num_bonds=[5851], num_residues=[306]),
#  PackedProtein(batch_size=1, num_atoms=[301], num_bonds=[5749], num_residues=[301]),
#  PackedProtein(batch_size=1, num_atoms=[1025], num_bonds=[24082], num_residues=[1025]),
#  PackedProtein(batch_size=1, num_atoms=[341], num_bonds=[6758], num_residues=[341]),
#  PackedProtein(batch_size=1, num_atoms=[150], num_bonds=[3184], num_residues=[150]),
#  PackedProtein(batch_size=1, num_atoms=[390], num_bonds=[8467], num_residues=[390]),
#  PackedProtein(batch_size=1, num_atoms=[993], num_bonds=[21393], num_residues=[993]),
#  PackedProtein(batch_size=1, num_atoms=[312], num_bonds=[7053], num_residues=[312]),
#  PackedProtein(batch_size=1, num_atoms=[336], num_bonds=[6296], num_residues=[336]),
#  PackedProtein(batch_size=1, num_atoms=[208], num_bonds=[3895], num_residues=[208]),
#  PackedProtein(batch_size=1, num_atoms=[147], num_bonds=[2705], num_residues=[147]),
#  PackedProtein(batch_size=1, num_atoms=[504], num_bonds=[9815], num_residues=[504]),
#  PackedProtein(batch_size=1, num_atoms=[1724], num_bonds=[40972], num_residues=[1724]),
#  PackedProtein(batch_size=1, num_atoms=[326], num_bonds=[6630], num_residues=[326]),
#  PackedProtein(batch_size=1, num_atoms=[353], num_bonds=[6143], num_residues=[353]),
#  PackedProtein(batch_size=1, num_atoms=[619], num_bonds=[11376], num_residues=[619]),
#  PackedProtein(batch_size=1, num_atoms=[616], num_bonds=[11344], num_residues=[616]),
#  PackedProtein(batch_size=1, num_atoms=[767], num_bonds=[18259], num_residues=[767]),
#  PackedProtein(batch_size=1, num_atoms=[678], num_bonds=[17155], num_residues=[678]),
#  PackedProtein(batch_size=1, num_atoms=[127], num_bonds=[2042], num_residues=[127]),
#  PackedProtein(batch_size=1, num_atoms=[381], num_bonds=[7235], num_residues=[381]),
#  PackedProtein(batch_size=1, num_atoms=[764], num_bonds=[16267], num_residues=[764]),
#  PackedProtein(batch_size=1, num_atoms=[172], num_bonds=[3927], num_residues=[172]),
#  PackedProtein(batch_size=1, num_atoms=[275], num_bonds=[5284], num_residues=[275]),
#  PackedProtein(batch_size=1, num_atoms=[4044], num_bonds=[94950], num_residues=[4044]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[16314], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[461], num_bonds=[9722], num_residues=[461]),
#  PackedProtein(batch_size=1, num_atoms=[156], num_bonds=[2909], num_residues=[156]),
#  PackedProtein(batch_size=1, num_atoms=[320], num_bonds=[7269], num_residues=[320]),
#  PackedProtein(batch_size=1, num_atoms=[390], num_bonds=[8481], num_residues=[390]),
#  PackedProtein(batch_size=1, num_atoms=[688], num_bonds=[15437], num_residues=[688]),
#  PackedProtein(batch_size=1, num_atoms=[898], num_bonds=[22290], num_residues=[898]),
#  PackedProtein(batch_size=1, num_atoms=[283], num_bonds=[5459], num_residues=[283]),
#  PackedProtein(batch_size=1, num_atoms=[334], num_bonds=[6229], num_residues=[334]),
#  PackedProtein(batch_size=1, num_atoms=[150], num_bonds=[3179], num_residues=[150]),
#  PackedProtein(batch_size=1, num_atoms=[418], num_bonds=[8991], num_residues=[418]),
#  PackedProtein(batch_size=1, num_atoms=[1509], num_bonds=[33196], num_residues=[1509]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5282], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[306], num_bonds=[5782], num_residues=[306]),
#  PackedProtein(batch_size=1, num_atoms=[2382], num_bonds=[50643], num_residues=[2382]),
#  PackedProtein(batch_size=1, num_atoms=[1014], num_bonds=[22689], num_residues=[1014]),
#  PackedProtein(batch_size=1, num_atoms=[2102], num_bonds=[49519], num_residues=[2102]),
#  PackedProtein(batch_size=1, num_atoms=[607], num_bonds=[12628], num_residues=[607]),
#  PackedProtein(batch_size=1, num_atoms=[232], num_bonds=[4964], num_residues=[232]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[16329], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[570], num_bonds=[11535], num_residues=[570]),
#  PackedProtein(batch_size=1, num_atoms=[337], num_bonds=[6369], num_residues=[337]),
#  PackedProtein(batch_size=1, num_atoms=[258], num_bonds=[5687], num_residues=[258]),
#  PackedProtein(batch_size=1, num_atoms=[288], num_bonds=[5506], num_residues=[288]),
#  PackedProtein(batch_size=1, num_atoms=[1556], num_bonds=[41118], num_residues=[1556]),
#  PackedProtein(batch_size=1, num_atoms=[692], num_bonds=[15310], num_residues=[692]),
#  PackedProtein(batch_size=1, num_atoms=[692], num_bonds=[15111], num_residues=[692]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2033], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[551], num_bonds=[12795], num_residues=[551]),
#  PackedProtein(batch_size=1, num_atoms=[497], num_bonds=[10461], num_residues=[497]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[16307], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[357], num_bonds=[7665], num_residues=[357]),
#  PackedProtein(batch_size=1, num_atoms=[274], num_bonds=[5352], num_residues=[274]),
#  PackedProtein(batch_size=1, num_atoms=[1868], num_bonds=[42869], num_residues=[1868]),
#  PackedProtein(batch_size=1, num_atoms=[4044], num_bonds=[94625], num_residues=[4044]),
#  PackedProtein(batch_size=1, num_atoms=[303], num_bonds=[6514], num_residues=[303]),
#  PackedProtein(batch_size=1, num_atoms=[246], num_bonds=[5656], num_residues=[246]),
#  PackedProtein(batch_size=1, num_atoms=[2598], num_bonds=[59782], num_residues=[2598]),
#  PackedProtein(batch_size=1, num_atoms=[892], num_bonds=[19516], num_residues=[892]),
#  PackedProtein(batch_size=1, num_atoms=[1287], num_bonds=[28023], num_residues=[1287]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5640], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[147], num_bonds=[2697], num_residues=[147]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5706], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[254], num_bonds=[5545], num_residues=[254]),
#  PackedProtein(batch_size=1, num_atoms=[178], num_bonds=[3268], num_residues=[178]),
#  PackedProtein(batch_size=1, num_atoms=[124], num_bonds=[1799], num_residues=[124]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[1795], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[1789], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[252], num_bonds=[4265], num_residues=[252]),
#  PackedProtein(batch_size=1, num_atoms=[210], num_bonds=[4225], num_residues=[210]),
#  PackedProtein(batch_size=1, num_atoms=[332], num_bonds=[6638], num_residues=[332]),
#  PackedProtein(batch_size=1, num_atoms=[1724], num_bonds=[40064], num_residues=[1724]),
#  PackedProtein(batch_size=1, num_atoms=[179], num_bonds=[3255], num_residues=[179]),
#  PackedProtein(batch_size=1, num_atoms=[961], num_bonds=[22219], num_residues=[961]),
#  PackedProtein(batch_size=1, num_atoms=[2100], num_bonds=[49511], num_residues=[2100]),
#  PackedProtein(batch_size=1, num_atoms=[197], num_bonds=[4021], num_residues=[197]),
#  PackedProtein(batch_size=1, num_atoms=[124], num_bonds=[2479], num_residues=[124]),
#  PackedProtein(batch_size=1, num_atoms=[1666], num_bonds=[40456], num_residues=[1666]),
#  PackedProtein(batch_size=1, num_atoms=[525], num_bonds=[11515], num_residues=[525]),
#  PackedProtein(batch_size=1, num_atoms=[307], num_bonds=[6787], num_residues=[307]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7689], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[728], num_bonds=[16175], num_residues=[728]),
#  PackedProtein(batch_size=1, num_atoms=[330], num_bonds=[7461], num_residues=[330]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2030], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[262], num_bonds=[5642], num_residues=[262]),
#  PackedProtein(batch_size=1, num_atoms=[678], num_bonds=[17123], num_residues=[678]),
#  PackedProtein(batch_size=1, num_atoms=[4060], num_bonds=[94551], num_residues=[4060]),
#  PackedProtein(batch_size=1, num_atoms=[138], num_bonds=[2891], num_residues=[138]),
#  PackedProtein(batch_size=1, num_atoms=[105], num_bonds=[2052], num_residues=[105]),
#  PackedProtein(batch_size=1, num_atoms=[2100], num_bonds=[51180], num_residues=[2100]),
#  PackedProtein(batch_size=1, num_atoms=[1314], num_bonds=[30150], num_residues=[1314]),
#  PackedProtein(batch_size=1, num_atoms=[263], num_bonds=[5666], num_residues=[263]),
#  PackedProtein(batch_size=1, num_atoms=[1152], num_bonds=[24472], num_residues=[1152]),
#  PackedProtein(batch_size=1, num_atoms=[283], num_bonds=[5528], num_residues=[283]),
#  PackedProtein(batch_size=1, num_atoms=[644], num_bonds=[14934], num_residues=[644]),
#  PackedProtein(batch_size=1, num_atoms=[544], num_bonds=[11060], num_residues=[544]),
#  PackedProtein(batch_size=1, num_atoms=[208], num_bonds=[4048], num_residues=[208]),
#  PackedProtein(batch_size=1, num_atoms=[124], num_bonds=[2463], num_residues=[124]),
#  PackedProtein(batch_size=1, num_atoms=[1618], num_bonds=[32560], num_residues=[1618]),
#  PackedProtein(batch_size=1, num_atoms=[2598], num_bonds=[59569], num_residues=[2598]),
#  PackedProtein(batch_size=1, num_atoms=[262], num_bonds=[5745], num_residues=[262]),
#  PackedProtein(batch_size=1, num_atoms=[426], num_bonds=[7856], num_residues=[426]),
#  PackedProtein(batch_size=1, num_atoms=[329], num_bonds=[7450], num_residues=[329]),
#  PackedProtein(batch_size=1, num_atoms=[389], num_bonds=[8814], num_residues=[389]),
#  PackedProtein(batch_size=1, num_atoms=[105], num_bonds=[2002], num_residues=[105]),
#  PackedProtein(batch_size=1, num_atoms=[1488], num_bonds=[28261], num_residues=[1488]),
#  PackedProtein(batch_size=1, num_atoms=[426], num_bonds=[7770], num_residues=[426]),
#  PackedProtein(batch_size=1, num_atoms=[528], num_bonds=[10174], num_residues=[528]),
#  PackedProtein(batch_size=1, num_atoms=[426], num_bonds=[7837], num_residues=[426]),
#  PackedProtein(batch_size=1, num_atoms=[265], num_bonds=[4951], num_residues=[265]),
#  PackedProtein(batch_size=1, num_atoms=[238], num_bonds=[4843], num_residues=[238]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2056], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[338], num_bonds=[6790], num_residues=[338]),
#  PackedProtein(batch_size=1, num_atoms=[942], num_bonds=[21137], num_residues=[942]),
#  PackedProtein(batch_size=1, num_atoms=[1032], num_bonds=[22924], num_residues=[1032]),
#  PackedProtein(batch_size=1, num_atoms=[274], num_bonds=[5365], num_residues=[274]),
#  PackedProtein(batch_size=1, num_atoms=[866], num_bonds=[17906], num_residues=[866]),
#  PackedProtein(batch_size=1, num_atoms=[1624], num_bonds=[32828], num_residues=[1624]),
#  PackedProtein(batch_size=1, num_atoms=[942], num_bonds=[21301], num_residues=[942]),
#  PackedProtein(batch_size=1, num_atoms=[414], num_bonds=[9374], num_residues=[414]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[1113], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2001], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[536], num_bonds=[12966], num_residues=[536]),
#  PackedProtein(batch_size=1, num_atoms=[1620], num_bonds=[32732], num_residues=[1620]),
#  PackedProtein(batch_size=1, num_atoms=[304], num_bonds=[5800], num_residues=[304]),
#  PackedProtein(batch_size=1, num_atoms=[564], num_bonds=[11341], num_residues=[564]),
#  PackedProtein(batch_size=1, num_atoms=[335], num_bonds=[6275], num_residues=[335]),
#  PackedProtein(batch_size=1, num_atoms=[307], num_bonds=[6914], num_residues=[307]),
#  PackedProtein(batch_size=1, num_atoms=[492], num_bonds=[9549], num_residues=[492]),
#  PackedProtein(batch_size=1, num_atoms=[792], num_bonds=[17054], num_residues=[792]),
#  PackedProtein(batch_size=1, num_atoms=[223], num_bonds=[5204], num_residues=[223]),
#  PackedProtein(batch_size=1, num_atoms=[497], num_bonds=[11163], num_residues=[497]),
#  PackedProtein(batch_size=1, num_atoms=[98], num_bonds=[1788], num_residues=[98]),
#  PackedProtein(batch_size=1, num_atoms=[330], num_bonds=[7467], num_residues=[330]),
#  PackedProtein(batch_size=1, num_atoms=[344], num_bonds=[7208], num_residues=[344]),
#  PackedProtein(batch_size=1, num_atoms=[371], num_bonds=[8130], num_residues=[371]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[886], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[152], num_bonds=[2661], num_residues=[152]),
#  PackedProtein(batch_size=1, num_atoms=[426], num_bonds=[7957], num_residues=[426]),
#  PackedProtein(batch_size=1, num_atoms=[329], num_bonds=[7452], num_residues=[329]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5230], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5163], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5147], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5170], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2027], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[554], num_bonds=[11085], num_residues=[554]),
#  PackedProtein(batch_size=1, num_atoms=[1620], num_bonds=[33050], num_residues=[1620]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7659], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[245], num_bonds=[4390], num_residues=[245]),
#  PackedProtein(batch_size=1, num_atoms=[764], num_bonds=[16223], num_residues=[764]),
#  PackedProtein(batch_size=1, num_atoms=[262], num_bonds=[5646], num_residues=[262]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5200], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[438], num_bonds=[9381], num_residues=[438]),
#  PackedProtein(batch_size=1, num_atoms=[593], num_bonds=[13695], num_residues=[593]),
#  PackedProtein(batch_size=1, num_atoms=[492], num_bonds=[10300], num_residues=[492]),
#  PackedProtein(batch_size=1, num_atoms=[1653], num_bonds=[38532], num_residues=[1653]),
#  PackedProtein(batch_size=1, num_atoms=[496], num_bonds=[10587], num_residues=[496]),
#  PackedProtein(batch_size=1, num_atoms=[854], num_bonds=[20697], num_residues=[854]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7681], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[939], num_bonds=[21212], num_residues=[939]),
#  PackedProtein(batch_size=1, num_atoms=[4060], num_bonds=[94944], num_residues=[4060]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5664], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[147], num_bonds=[2707], num_residues=[147]),
#  PackedProtein(batch_size=1, num_atoms=[621], num_bonds=[11415], num_residues=[621]),
#  PackedProtein(batch_size=1, num_atoms=[156], num_bonds=[2902], num_residues=[156]),
#  PackedProtein(batch_size=1, num_atoms=[156], num_bonds=[2904], num_residues=[156]),
#  PackedProtein(batch_size=1, num_atoms=[430], num_bonds=[7572], num_residues=[430]),
#  PackedProtein(batch_size=1, num_atoms=[542], num_bonds=[11524], num_residues=[542]),
#  PackedProtein(batch_size=1, num_atoms=[267], num_bonds=[5134], num_residues=[267]),
#  PackedProtein(batch_size=1, num_atoms=[416], num_bonds=[8530], num_residues=[416]),
#  PackedProtein(batch_size=1, num_atoms=[291], num_bonds=[6644], num_residues=[291]),
#  PackedProtein(batch_size=1, num_atoms=[284], num_bonds=[5467], num_residues=[284]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5218], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[390], num_bonds=[8467], num_residues=[390]),
#  PackedProtein(batch_size=1, num_atoms=[265], num_bonds=[4965], num_residues=[265]),
#  PackedProtein(batch_size=1, num_atoms=[287], num_bonds=[5755], num_residues=[287]),
#  PackedProtein(batch_size=1, num_atoms=[447], num_bonds=[9506], num_residues=[447]),
#  PackedProtein(batch_size=1, num_atoms=[395], num_bonds=[9886], num_residues=[395]),
#  PackedProtein(batch_size=1, num_atoms=[239], num_bonds=[5601], num_residues=[239]),
#  PackedProtein(batch_size=1, num_atoms=[532], num_bonds=[12287], num_residues=[532]),
#  PackedProtein(batch_size=1, num_atoms=[188], num_bonds=[3294], num_residues=[188]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[16307], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[124], num_bonds=[1873], num_residues=[124]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7776], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[522], num_bonds=[10418], num_residues=[522]),
#  PackedProtein(batch_size=1, num_atoms=[524], num_bonds=[10584], num_residues=[524]),
#  PackedProtein(batch_size=1, num_atoms=[864], num_bonds=[20968], num_residues=[864]),
#  PackedProtein(batch_size=1, num_atoms=[407], num_bonds=[8928], num_residues=[407]),
#  PackedProtein(batch_size=1, num_atoms=[105], num_bonds=[1978], num_residues=[105]),
#  PackedProtein(batch_size=1, num_atoms=[316], num_bonds=[6084], num_residues=[316]),
#  PackedProtein(batch_size=1, num_atoms=[212], num_bonds=[4279], num_residues=[212]),
#  PackedProtein(batch_size=1, num_atoms=[498], num_bonds=[9829], num_residues=[498]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5261], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[85], num_bonds=[1600], num_residues=[85]),
#  PackedProtein(batch_size=1, num_atoms=[246], num_bonds=[4099], num_residues=[246]),
#  PackedProtein(batch_size=1, num_atoms=[522], num_bonds=[11400], num_residues=[522]),
#  PackedProtein(batch_size=1, num_atoms=[792], num_bonds=[16696], num_residues=[792]),
#  PackedProtein(batch_size=1, num_atoms=[993], num_bonds=[21944], num_residues=[993]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[1678], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[4032], num_bonds=[80232], num_residues=[4032]),
#  PackedProtein(batch_size=1, num_atoms=[4032], num_bonds=[80304], num_residues=[4032]),
#  PackedProtein(batch_size=1, num_atoms=[427], num_bonds=[9875], num_residues=[427]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5276], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[1329], num_bonds=[27916], num_residues=[1329]),
#  PackedProtein(batch_size=1, num_atoms=[2658], num_bonds=[57024], num_residues=[2658]),
#  PackedProtein(batch_size=1, num_atoms=[463], num_bonds=[9687], num_residues=[463]),
#  PackedProtein(batch_size=1, num_atoms=[320], num_bonds=[7270], num_residues=[320]),
#  PackedProtein(batch_size=1, num_atoms=[764], num_bonds=[16295], num_residues=[764]),
#  PackedProtein(batch_size=1, num_atoms=[296], num_bonds=[6083], num_residues=[296]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2048], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[115], num_bonds=[1734], num_residues=[115]),
#  PackedProtein(batch_size=1, num_atoms=[1314], num_bonds=[29433], num_residues=[1314]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5669], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5685], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[642], num_bonds=[15234], num_residues=[642]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[827], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[505], num_bonds=[9596], num_residues=[505]),
#  PackedProtein(batch_size=1, num_atoms=[264], num_bonds=[5029], num_residues=[264]),
#  PackedProtein(batch_size=1, num_atoms=[540], num_bonds=[11463], num_residues=[540]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5253], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[546], num_bonds=[10562], num_residues=[546]),
#  PackedProtein(batch_size=1, num_atoms=[515], num_bonds=[11187], num_residues=[515]),
#  PackedProtein(batch_size=1, num_atoms=[672], num_bonds=[14083], num_residues=[672]),
#  PackedProtein(batch_size=1, num_atoms=[126], num_bonds=[2007], num_residues=[126]),
#  PackedProtein(batch_size=1, num_atoms=[1509], num_bonds=[33118], num_residues=[1509]),
#  PackedProtein(batch_size=1, num_atoms=[380], num_bonds=[8495], num_residues=[380]),
#  PackedProtein(batch_size=1, num_atoms=[511], num_bonds=[10040], num_residues=[511]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5261], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[4324], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[213], num_bonds=[4331], num_residues=[213]),
#  PackedProtein(batch_size=1, num_atoms=[493], num_bonds=[9635], num_residues=[493]),
#  PackedProtein(batch_size=1, num_atoms=[492], num_bonds=[9587], num_residues=[492]),
#  PackedProtein(batch_size=1, num_atoms=[471], num_bonds=[10777], num_residues=[471]),
#  PackedProtein(batch_size=1, num_atoms=[1371], num_bonds=[29119], num_residues=[1371]),
#  PackedProtein(batch_size=1, num_atoms=[537], num_bonds=[11177], num_residues=[537]),
#  PackedProtein(batch_size=1, num_atoms=[267], num_bonds=[5141], num_residues=[267]),
#  PackedProtein(batch_size=1, num_atoms=[296], num_bonds=[6276], num_residues=[296]),
#  PackedProtein(batch_size=1, num_atoms=[515], num_bonds=[11140], num_residues=[515]),
#  PackedProtein(batch_size=1, num_atoms=[361], num_bonds=[7377], num_residues=[361]),
#  PackedProtein(batch_size=1, num_atoms=[2728], num_bonds=[62496], num_residues=[2728]),
#  PackedProtein(batch_size=1, num_atoms=[2772], num_bonds=[58905], num_residues=[2772]),
#  PackedProtein(batch_size=1, num_atoms=[1072], num_bonds=[23254], num_residues=[1072]),
#  PackedProtein(batch_size=1, num_atoms=[90], num_bonds=[1368], num_residues=[90]),
#  PackedProtein(batch_size=1, num_atoms=[377], num_bonds=[8455], num_residues=[377]),
#  PackedProtein(batch_size=1, num_atoms=[1016], num_bonds=[22804], num_residues=[1016]),
#  PackedProtein(batch_size=1, num_atoms=[378], num_bonds=[8501], num_residues=[378]),
#  PackedProtein(batch_size=1, num_atoms=[370], num_bonds=[8270], num_residues=[370]),
#  PackedProtein(batch_size=1, num_atoms=[606], num_bonds=[12604], num_residues=[606]),
#  PackedProtein(batch_size=1, num_atoms=[606], num_bonds=[12664], num_residues=[606]),
#  PackedProtein(batch_size=1, num_atoms=[607], num_bonds=[12465], num_residues=[607]),
#  PackedProtein(batch_size=1, num_atoms=[607], num_bonds=[12523], num_residues=[607]),
#  PackedProtein(batch_size=1, num_atoms=[180], num_bonds=[3100], num_residues=[180]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7749], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[379], num_bonds=[8509], num_residues=[379]),
#  PackedProtein(batch_size=1, num_atoms=[1535], num_bonds=[30644], num_residues=[1535]),
#  PackedProtein(batch_size=1, num_atoms=[924], num_bonds=[20434], num_residues=[924]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5681], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5692], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5701], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[1872], num_bonds=[37276], num_residues=[1872]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7737], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[351], num_bonds=[7528], num_residues=[351]),
#  PackedProtein(batch_size=1, num_atoms=[711], num_bonds=[15678], num_residues=[711]),
#  PackedProtein(batch_size=1, num_atoms=[812], num_bonds=[16398], num_residues=[812]),
#  PackedProtein(batch_size=1, num_atoms=[838], num_bonds=[16974], num_residues=[838]),
#  PackedProtein(batch_size=1, num_atoms=[806], num_bonds=[16434], num_residues=[806]),
#  PackedProtein(batch_size=1, num_atoms=[410], num_bonds=[7716], num_residues=[410]),
#  PackedProtein(batch_size=1, num_atoms=[195], num_bonds=[3999], num_residues=[195]),
#  PackedProtein(batch_size=1, num_atoms=[228], num_bonds=[5253], num_residues=[228]),
#  PackedProtein(batch_size=1, num_atoms=[251], num_bonds=[5866], num_residues=[251]),
#  PackedProtein(batch_size=1, num_atoms=[1350], num_bonds=[31592], num_residues=[1350]),
#  PackedProtein(batch_size=1, num_atoms=[188], num_bonds=[3293], num_residues=[188]),
#  PackedProtein(batch_size=1, num_atoms=[547], num_bonds=[10558], num_residues=[547]),
#  PackedProtein(batch_size=1, num_atoms=[613], num_bonds=[13171], num_residues=[613]),
#  PackedProtein(batch_size=1, num_atoms=[1069], num_bonds=[22763], num_residues=[1069]),
#  PackedProtein(batch_size=1, num_atoms=[233], num_bonds=[4711], num_residues=[233]),
#  PackedProtein(batch_size=1, num_atoms=[438], num_bonds=[9332], num_residues=[438]),
#  PackedProtein(batch_size=1, num_atoms=[157], num_bonds=[3101], num_residues=[157]),
#  PackedProtein(batch_size=1, num_atoms=[1557], num_bonds=[41971], num_residues=[1557]),
#  PackedProtein(batch_size=1, num_atoms=[214], num_bonds=[4301], num_residues=[214]),
#  PackedProtein(batch_size=1, num_atoms=[2856], num_bonds=[66104], num_residues=[2856]),
#  PackedProtein(batch_size=1, num_atoms=[188], num_bonds=[4281], num_residues=[188]),
#  PackedProtein(batch_size=1, num_atoms=[261], num_bonds=[4905], num_residues=[261]),
#  PackedProtein(batch_size=1, num_atoms=[125], num_bonds=[2578], num_residues=[125]),
#  PackedProtein(batch_size=1, num_atoms=[514], num_bonds=[10253], num_residues=[514]),
#  PackedProtein(batch_size=1, num_atoms=[370], num_bonds=[7899], num_residues=[370]),
#  PackedProtein(batch_size=1, num_atoms=[522], num_bonds=[10242], num_residues=[522]),
#  PackedProtein(batch_size=1, num_atoms=[472], num_bonds=[11000], num_residues=[472]),
#  PackedProtein(batch_size=1, num_atoms=[185], num_bonds=[3285], num_residues=[185]),
#  PackedProtein(batch_size=1, num_atoms=[314], num_bonds=[7002], num_residues=[314]),
#  PackedProtein(batch_size=1, num_atoms=[258], num_bonds=[5099], num_residues=[258]),
#  PackedProtein(batch_size=1, num_atoms=[320], num_bonds=[7294], num_residues=[320]),
#  PackedProtein(batch_size=1, num_atoms=[510], num_bonds=[11323], num_residues=[510]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1296], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[558], num_bonds=[11280], num_residues=[558]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7714], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[617], num_bonds=[11365], num_residues=[617]),
#  PackedProtein(batch_size=1, num_atoms=[502], num_bonds=[9943], num_residues=[502]),
#  PackedProtein(batch_size=1, num_atoms=[493], num_bonds=[9680], num_residues=[493]),
#  PackedProtein(batch_size=1, num_atoms=[410], num_bonds=[8528], num_residues=[410]),
#  PackedProtein(batch_size=1, num_atoms=[383], num_bonds=[9255], num_residues=[383]),
#  PackedProtein(batch_size=1, num_atoms=[121], num_bonds=[2120], num_residues=[121]),
#  PackedProtein(batch_size=1, num_atoms=[1270], num_bonds=[29532], num_residues=[1270]),
#  PackedProtein(batch_size=1, num_atoms=[607], num_bonds=[12618], num_residues=[607]),
#  PackedProtein(batch_size=1, num_atoms=[828], num_bonds=[16778], num_residues=[828]),
#  PackedProtein(batch_size=1, num_atoms=[265], num_bonds=[4969], num_residues=[265]),
#  PackedProtein(batch_size=1, num_atoms=[528], num_bonds=[10416], num_residues=[528]),
#  PackedProtein(batch_size=1, num_atoms=[297], num_bonds=[5854], num_residues=[297]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5186], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[301], num_bonds=[5746], num_residues=[301]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7675], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[620], num_bonds=[11453], num_residues=[620]),
#  PackedProtein(batch_size=1, num_atoms=[659], num_bonds=[15731], num_residues=[659]),
#  PackedProtein(batch_size=1, num_atoms=[228], num_bonds=[5257], num_residues=[228]),
#  PackedProtein(batch_size=1, num_atoms=[227], num_bonds=[4546], num_residues=[227]),
#  PackedProtein(batch_size=1, num_atoms=[343], num_bonds=[7403], num_residues=[343]),
#  PackedProtein(batch_size=1, num_atoms=[390], num_bonds=[8467], num_residues=[390]),
#  PackedProtein(batch_size=1, num_atoms=[592], num_bonds=[13229], num_residues=[592]),
#  PackedProtein(batch_size=1, num_atoms=[425], num_bonds=[8953], num_residues=[425]),
#  PackedProtein(batch_size=1, num_atoms=[248], num_bonds=[5041], num_residues=[248]),
#  PackedProtein(batch_size=1, num_atoms=[337], num_bonds=[6310], num_residues=[337]),
#  PackedProtein(batch_size=1, num_atoms=[884], num_bonds=[19523], num_residues=[884]),
#  PackedProtein(batch_size=1, num_atoms=[276], num_bonds=[6073], num_residues=[276]),
#  PackedProtein(batch_size=1, num_atoms=[792], num_bonds=[16676], num_residues=[792]),
#  PackedProtein(batch_size=1, num_atoms=[398], num_bonds=[7867], num_residues=[398]),
#  PackedProtein(batch_size=1, num_atoms=[394], num_bonds=[8629], num_residues=[394]),
#  PackedProtein(batch_size=1, num_atoms=[461], num_bonds=[9783], num_residues=[461]),
#  PackedProtein(batch_size=1, num_atoms=[446], num_bonds=[9509], num_residues=[446]),
#  PackedProtein(batch_size=1, num_atoms=[274], num_bonds=[5343], num_residues=[274]),
#  PackedProtein(batch_size=1, num_atoms=[698], num_bonds=[13648], num_residues=[698]),
#  PackedProtein(batch_size=1, num_atoms=[607], num_bonds=[12616], num_residues=[607]),
#  PackedProtein(batch_size=1, num_atoms=[161], num_bonds=[3242], num_residues=[161]),
#  PackedProtein(batch_size=1, num_atoms=[271], num_bonds=[5377], num_residues=[271]),
#  PackedProtein(batch_size=1, num_atoms=[177], num_bonds=[3414], num_residues=[177]),
#  PackedProtein(batch_size=1, num_atoms=[162], num_bonds=[3320], num_residues=[162]),
#  PackedProtein(batch_size=1, num_atoms=[1212], num_bonds=[25115], num_residues=[1212]),
#  PackedProtein(batch_size=1, num_atoms=[129], num_bonds=[2480], num_residues=[129]),
#  PackedProtein(batch_size=1, num_atoms=[273], num_bonds=[4494], num_residues=[273]),
#  PackedProtein(batch_size=1, num_atoms=[87], num_bonds=[1218], num_residues=[87]),
#  PackedProtein(batch_size=1, num_atoms=[95], num_bonds=[1600], num_residues=[95]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[992], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[334], num_bonds=[6747], num_residues=[334]),
#  PackedProtein(batch_size=1, num_atoms=[656], num_bonds=[15615], num_residues=[656]),
#  PackedProtein(batch_size=1, num_atoms=[606], num_bonds=[12590], num_residues=[606]),
#  PackedProtein(batch_size=1, num_atoms=[604], num_bonds=[13102], num_residues=[604]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5663], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5608], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[267], num_bonds=[5082], num_residues=[267]),
#  PackedProtein(batch_size=1, num_atoms=[136], num_bonds=[2899], num_residues=[136]),
#  PackedProtein(batch_size=1, num_atoms=[461], num_bonds=[9728], num_residues=[461]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5281], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[993], num_bonds=[22143], num_residues=[993]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5262], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[394], num_bonds=[8783], num_residues=[394]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[2409], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5634], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[489], num_bonds=[11572], num_residues=[489]),
#  PackedProtein(batch_size=1, num_atoms=[138], num_bonds=[2938], num_residues=[138]),
#  PackedProtein(batch_size=1, num_atoms=[493], num_bonds=[9628], num_residues=[493]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5702], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[904], num_bonds=[21901], num_residues=[904]),
#  PackedProtein(batch_size=1, num_atoms=[133], num_bonds=[2409], num_residues=[133]),
#  PackedProtein(batch_size=1, num_atoms=[297], num_bonds=[5595], num_residues=[297]),
#  PackedProtein(batch_size=1, num_atoms=[281], num_bonds=[6183], num_residues=[281]),
#  PackedProtein(batch_size=1, num_atoms=[1209], num_bonds=[25379], num_residues=[1209]),
#  PackedProtein(batch_size=1, num_atoms=[245], num_bonds=[5695], num_residues=[245]),
# ...
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1132], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[166], num_bonds=[3237], num_residues=[166]),
#  PackedProtein(batch_size=1, num_atoms=[1602], num_bonds=[36952], num_residues=[1602]),
#  PackedProtein(batch_size=1, num_atoms=[373], num_bonds=[8680], num_residues=[373]),
#  PackedProtein(batch_size=1, num_atoms=[1317], num_bonds=[30203], num_residues=[1317]),
#  PackedProtein(batch_size=1, num_atoms=[1318], num_bonds=[30240], num_residues=[1318]),
#  PackedProtein(batch_size=1, num_atoms=[314], num_bonds=[7339], num_residues=[314]),
#  PackedProtein(batch_size=1, num_atoms=[475], num_bonds=[9461], num_residues=[475]),
#  PackedProtein(batch_size=1, num_atoms=[376], num_bonds=[6903], num_residues=[376]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[1796], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[241], num_bonds=[5707], num_residues=[241]),
#  PackedProtein(batch_size=1, num_atoms=[363], num_bonds=[6633], num_residues=[363]),
#  PackedProtein(batch_size=1, num_atoms=[472], num_bonds=[11041], num_residues=[472]),
#  PackedProtein(batch_size=1, num_atoms=[299], num_bonds=[5688], num_residues=[299]),
#  PackedProtein(batch_size=1, num_atoms=[636], num_bonds=[12464], num_residues=[636]),
#  PackedProtein(batch_size=1, num_atoms=[378], num_bonds=[7804], num_residues=[378]),
#  PackedProtein(batch_size=1, num_atoms=[480], num_bonds=[11367], num_residues=[480]),
#  PackedProtein(batch_size=1, num_atoms=[113], num_bonds=[2181], num_residues=[113]),
#  PackedProtein(batch_size=1, num_atoms=[181], num_bonds=[3781], num_residues=[181]),
#  PackedProtein(batch_size=1, num_atoms=[229], num_bonds=[5012], num_residues=[229]),
#  PackedProtein(batch_size=1, num_atoms=[437], num_bonds=[9322], num_residues=[437]),
#  PackedProtein(batch_size=1, num_atoms=[437], num_bonds=[9309], num_residues=[437]),
#  PackedProtein(batch_size=1, num_atoms=[119], num_bonds=[2332], num_residues=[119]),
#  PackedProtein(batch_size=1, num_atoms=[1015], num_bonds=[22951], num_residues=[1015]),
#  PackedProtein(batch_size=1, num_atoms=[469], num_bonds=[11242], num_residues=[469]),
#  PackedProtein(batch_size=1, num_atoms=[145], num_bonds=[2856], num_residues=[145]),
#  PackedProtein(batch_size=1, num_atoms=[220], num_bonds=[4504], num_residues=[220]),
#  PackedProtein(batch_size=1, num_atoms=[99], num_bonds=[1896], num_residues=[99]),
#  PackedProtein(batch_size=1, num_atoms=[119], num_bonds=[2117], num_residues=[119]),
#  PackedProtein(batch_size=1, num_atoms=[998], num_bonds=[22276], num_residues=[998]),
#  PackedProtein(batch_size=1, num_atoms=[515], num_bonds=[11199], num_residues=[515]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[607], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[1646], num_bonds=[33246], num_residues=[1646]),
#  PackedProtein(batch_size=1, num_atoms=[1662], num_bonds=[33844], num_residues=[1662]),
#  PackedProtein(batch_size=1, num_atoms=[1662], num_bonds=[33790], num_residues=[1662]),
#  PackedProtein(batch_size=1, num_atoms=[458], num_bonds=[11064], num_residues=[458]),
#  PackedProtein(batch_size=1, num_atoms=[879], num_bonds=[19677], num_residues=[879]),
#  PackedProtein(batch_size=1, num_atoms=[258], num_bonds=[5013], num_residues=[258]),
#  PackedProtein(batch_size=1, num_atoms=[133], num_bonds=[2575], num_residues=[133]),
#  PackedProtein(batch_size=1, num_atoms=[405], num_bonds=[8267], num_residues=[405]),
#  PackedProtein(batch_size=1, num_atoms=[565], num_bonds=[11385], num_residues=[565]),
#  PackedProtein(batch_size=1, num_atoms=[562], num_bonds=[11359], num_residues=[562]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[2399], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[771], num_bonds=[18351], num_residues=[771]),
#  PackedProtein(batch_size=1, num_atoms=[914], num_bonds=[19238], num_residues=[914]),
#  PackedProtein(batch_size=1, num_atoms=[258], num_bonds=[5696], num_residues=[258]),
#  PackedProtein(batch_size=1, num_atoms=[208], num_bonds=[4081], num_residues=[208]),
#  PackedProtein(batch_size=1, num_atoms=[117], num_bonds=[2553], num_residues=[117]),
#  PackedProtein(batch_size=1, num_atoms=[581], num_bonds=[8111], num_residues=[581]),
#  PackedProtein(batch_size=1, num_atoms=[581], num_bonds=[8622], num_residues=[581]),
#  PackedProtein(batch_size=1, num_atoms=[210], num_bonds=[4073], num_residues=[210]),
#  PackedProtein(batch_size=1, num_atoms=[2111], num_bonds=[47515], num_residues=[2111]),
#  PackedProtein(batch_size=1, num_atoms=[1653], num_bonds=[38603], num_residues=[1653]),
#  PackedProtein(batch_size=1, num_atoms=[338], num_bonds=[5943], num_residues=[338]),
#  PackedProtein(batch_size=1, num_atoms=[4032], num_bonds=[79872], num_residues=[4032]),
#  PackedProtein(batch_size=1, num_atoms=[4032], num_bonds=[79272], num_residues=[4032]),
#  PackedProtein(batch_size=1, num_atoms=[525], num_bonds=[10870], num_residues=[525]),
#  PackedProtein(batch_size=1, num_atoms=[182], num_bonds=[3226], num_residues=[182]),
#  PackedProtein(batch_size=1, num_atoms=[337], num_bonds=[6277], num_residues=[337]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[1048], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[121], num_bonds=[1942], num_residues=[121]),
#  PackedProtein(batch_size=1, num_atoms=[708], num_bonds=[15827], num_residues=[708]),
#  PackedProtein(batch_size=1, num_atoms=[218], num_bonds=[3969], num_residues=[218]),
#  PackedProtein(batch_size=1, num_atoms=[72], num_bonds=[869], num_residues=[72]),
#  PackedProtein(batch_size=1, num_atoms=[225], num_bonds=[4560], num_residues=[225]),
#  PackedProtein(batch_size=1, num_atoms=[222], num_bonds=[4558], num_residues=[222]),
#  PackedProtein(batch_size=1, num_atoms=[265], num_bonds=[4997], num_residues=[265]),
#  PackedProtein(batch_size=1, num_atoms=[87], num_bonds=[1261], num_residues=[87]),
#  PackedProtein(batch_size=1, num_atoms=[1568], num_bonds=[41810], num_residues=[1568]),
#  PackedProtein(batch_size=1, num_atoms=[416], num_bonds=[7353], num_residues=[416]),
#  PackedProtein(batch_size=1, num_atoms=[976], num_bonds=[19527], num_residues=[976]),
#  PackedProtein(batch_size=1, num_atoms=[4216], num_bonds=[91968], num_residues=[4216]),
#  PackedProtein(batch_size=1, num_atoms=[2736], num_bonds=[57931], num_residues=[2736]),
#  PackedProtein(batch_size=1, num_atoms=[357], num_bonds=[8043], num_residues=[357]),
#  PackedProtein(batch_size=1, num_atoms=[238], num_bonds=[5543], num_residues=[238]),
#  PackedProtein(batch_size=1, num_atoms=[993], num_bonds=[21257], num_residues=[993]),
#  PackedProtein(batch_size=1, num_atoms=[681], num_bonds=[12971], num_residues=[681]),
#  PackedProtein(batch_size=1, num_atoms=[124], num_bonds=[2467], num_residues=[124]),
#  PackedProtein(batch_size=1, num_atoms=[426], num_bonds=[9245], num_residues=[426]),
#  PackedProtein(batch_size=1, num_atoms=[1557], num_bonds=[42336], num_residues=[1557]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5672], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[214], num_bonds=[4041], num_residues=[214]),
#  PackedProtein(batch_size=1, num_atoms=[506], num_bonds=[9195], num_residues=[506]),
#  PackedProtein(batch_size=1, num_atoms=[188], num_bonds=[3299], num_residues=[188]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[6208], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[240], num_bonds=[5569], num_residues=[240]),
#  PackedProtein(batch_size=1, num_atoms=[83], num_bonds=[1190], num_residues=[83]),
#  PackedProtein(batch_size=1, num_atoms=[684], num_bonds=[13536], num_residues=[684]),
#  PackedProtein(batch_size=1, num_atoms=[4216], num_bonds=[92136], num_residues=[4216]),
#  PackedProtein(batch_size=1, num_atoms=[145], num_bonds=[2875], num_residues=[145]),
#  PackedProtein(batch_size=1, num_atoms=[211], num_bonds=[4125], num_residues=[211]),
#  PackedProtein(batch_size=1, num_atoms=[327], num_bonds=[6244], num_residues=[327]),
#  PackedProtein(batch_size=1, num_atoms=[348], num_bonds=[7331], num_residues=[348]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5673], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[154], num_bonds=[3509], num_residues=[154]),
#  PackedProtein(batch_size=1, num_atoms=[900], num_bonds=[19582], num_residues=[900]),
#  PackedProtein(batch_size=1, num_atoms=[606], num_bonds=[12613], num_residues=[606]),
#  PackedProtein(batch_size=1, num_atoms=[386], num_bonds=[6616], num_residues=[386]),
#  PackedProtein(batch_size=1, num_atoms=[267], num_bonds=[5016], num_residues=[267]),
#  PackedProtein(batch_size=1, num_atoms=[498], num_bonds=[10351], num_residues=[498]),
#  PackedProtein(batch_size=1, num_atoms=[268], num_bonds=[5157], num_residues=[268]),
#  PackedProtein(batch_size=1, num_atoms=[998], num_bonds=[22272], num_residues=[998]),
#  PackedProtein(batch_size=1, num_atoms=[998], num_bonds=[22250], num_residues=[998]),
#  PackedProtein(batch_size=1, num_atoms=[111], num_bonds=[2217], num_residues=[111]),
#  PackedProtein(batch_size=1, num_atoms=[898], num_bonds=[22255], num_residues=[898]),
#  PackedProtein(batch_size=1, num_atoms=[637], num_bonds=[13473], num_residues=[637]),
#  PackedProtein(batch_size=1, num_atoms=[115], num_bonds=[2479], num_residues=[115]),
#  PackedProtein(batch_size=1, num_atoms=[1014], num_bonds=[22819], num_residues=[1014]),
#  PackedProtein(batch_size=1, num_atoms=[792], num_bonds=[16970], num_residues=[792]),
#  PackedProtein(batch_size=1, num_atoms=[1088], num_bonds=[23772], num_residues=[1088]),
#  PackedProtein(batch_size=1, num_atoms=[431], num_bonds=[8985], num_residues=[431]),
#  PackedProtein(batch_size=1, num_atoms=[230], num_bonds=[5611], num_residues=[230]),
#  PackedProtein(batch_size=1, num_atoms=[476], num_bonds=[9958], num_residues=[476]),
#  PackedProtein(batch_size=1, num_atoms=[285], num_bonds=[6045], num_residues=[285]),
#  PackedProtein(batch_size=1, num_atoms=[570], num_bonds=[12611], num_residues=[570]),
#  PackedProtein(batch_size=1, num_atoms=[560], num_bonds=[12587], num_residues=[560]),
#  PackedProtein(batch_size=1, num_atoms=[500], num_bonds=[11114], num_residues=[500]),
#  PackedProtein(batch_size=1, num_atoms=[130], num_bonds=[1957], num_residues=[130]),
#  PackedProtein(batch_size=1, num_atoms=[840], num_bonds=[21221], num_residues=[840]),
#  PackedProtein(batch_size=1, num_atoms=[88], num_bonds=[1091], num_residues=[88]),
#  PackedProtein(batch_size=1, num_atoms=[377], num_bonds=[7694], num_residues=[377]),
#  PackedProtein(batch_size=1, num_atoms=[660], num_bonds=[15388], num_residues=[660]),
#  PackedProtein(batch_size=1, num_atoms=[4044], num_bonds=[94723], num_residues=[4044]),
#  PackedProtein(batch_size=1, num_atoms=[104], num_bonds=[2064], num_residues=[104]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5699], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[578], num_bonds=[12002], num_residues=[578]),
#  PackedProtein(batch_size=1, num_atoms=[332], num_bonds=[5862], num_residues=[332]),
#  PackedProtein(batch_size=1, num_atoms=[183], num_bonds=[3431], num_residues=[183]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[1796], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[242], num_bonds=[4861], num_residues=[242]),
#  PackedProtein(batch_size=1, num_atoms=[670], num_bonds=[12224], num_residues=[670]),
#  PackedProtein(batch_size=1, num_atoms=[1644], num_bonds=[38669], num_residues=[1644]),
#  PackedProtein(batch_size=1, num_atoms=[220], num_bonds=[4529], num_residues=[220]),
#  PackedProtein(batch_size=1, num_atoms=[219], num_bonds=[4950], num_residues=[219]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[2412], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[472], num_bonds=[9994], num_residues=[472]),
#  PackedProtein(batch_size=1, num_atoms=[546], num_bonds=[10455], num_residues=[546]),
#  PackedProtein(batch_size=1, num_atoms=[930], num_bonds=[19358], num_residues=[930]),
#  PackedProtein(batch_size=1, num_atoms=[369], num_bonds=[9076], num_residues=[369]),
#  PackedProtein(batch_size=1, num_atoms=[374], num_bonds=[7180], num_residues=[374]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5201], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[189], num_bonds=[3319], num_residues=[189]),
#  PackedProtein(batch_size=1, num_atoms=[328], num_bonds=[6737], num_residues=[328]),
#  PackedProtein(batch_size=1, num_atoms=[330], num_bonds=[5824], num_residues=[330]),
#  PackedProtein(batch_size=1, num_atoms=[188], num_bonds=[3319], num_residues=[188]),
#  PackedProtein(batch_size=1, num_atoms=[448], num_bonds=[8700], num_residues=[448]),
#  PackedProtein(batch_size=1, num_atoms=[3168], num_bonds=[65814], num_residues=[3168]),
#  PackedProtein(batch_size=1, num_atoms=[138], num_bonds=[2856], num_residues=[138]),
#  PackedProtein(batch_size=1, num_atoms=[209], num_bonds=[4087], num_residues=[209]),
#  PackedProtein(batch_size=1, num_atoms=[485], num_bonds=[9871], num_residues=[485]),
#  PackedProtein(batch_size=1, num_atoms=[713], num_bonds=[15735], num_residues=[713]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5261], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[1658], num_bonds=[34354], num_residues=[1658]),
#  PackedProtein(batch_size=1, num_atoms=[566], num_bonds=[11473], num_residues=[566]),
#  PackedProtein(batch_size=1, num_atoms=[674], num_bonds=[15042], num_residues=[674]),
#  PackedProtein(batch_size=1, num_atoms=[284], num_bonds=[5903], num_residues=[284]),
#  PackedProtein(batch_size=1, num_atoms=[495], num_bonds=[10487], num_residues=[495]),
#  PackedProtein(batch_size=1, num_atoms=[275], num_bonds=[6113], num_residues=[275]),
#  PackedProtein(batch_size=1, num_atoms=[672], num_bonds=[14332], num_residues=[672]),
#  PackedProtein(batch_size=1, num_atoms=[462], num_bonds=[8914], num_residues=[462]),
#  PackedProtein(batch_size=1, num_atoms=[542], num_bonds=[11146], num_residues=[542]),
#  PackedProtein(batch_size=1, num_atoms=[1016], num_bonds=[23071], num_residues=[1016]),
#  PackedProtein(batch_size=1, num_atoms=[1620], num_bonds=[32760], num_residues=[1620]),
#  PackedProtein(batch_size=1, num_atoms=[829], num_bonds=[19365], num_residues=[829]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5661], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[337], num_bonds=[6403], num_residues=[337]),
#  PackedProtein(batch_size=1, num_atoms=[268], num_bonds=[5191], num_residues=[268]),
#  PackedProtein(batch_size=1, num_atoms=[559], num_bonds=[12294], num_residues=[559]),
#  PackedProtein(batch_size=1, num_atoms=[325], num_bonds=[6257], num_residues=[325]),
#  PackedProtein(batch_size=1, num_atoms=[244], num_bonds=[5598], num_residues=[244]),
#  PackedProtein(batch_size=1, num_atoms=[692], num_bonds=[13451], num_residues=[692]),
#  PackedProtein(batch_size=1, num_atoms=[184], num_bonds=[3803], num_residues=[184]),
#  PackedProtein(batch_size=1, num_atoms=[240], num_bonds=[5588], num_residues=[240]),
#  PackedProtein(batch_size=1, num_atoms=[331], num_bonds=[7401], num_residues=[331]),
#  PackedProtein(batch_size=1, num_atoms=[138], num_bonds=[2897], num_residues=[138]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[17209], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[107], num_bonds=[2145], num_residues=[107]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[607], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[515], num_bonds=[10889], num_residues=[515]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2025], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[1088], num_bonds=[23796], num_residues=[1088]),
#  PackedProtein(batch_size=1, num_atoms=[490], num_bonds=[10437], num_residues=[490]),
#  PackedProtein(batch_size=1, num_atoms=[1094], num_bonds=[22466], num_residues=[1094]),
#  PackedProtein(batch_size=1, num_atoms=[1094], num_bonds=[22444], num_residues=[1094]),
#  PackedProtein(batch_size=1, num_atoms=[807], num_bonds=[20536], num_residues=[807]),
#  PackedProtein(batch_size=1, num_atoms=[807], num_bonds=[20580], num_residues=[807]),
#  ...]

# %%
len(output_list)
# Out:
# 19404

# %%
protein_within_1022_list = []
indexes = range(len(output_list))   # len(transform_list)
indexes = tqdm(indexes, "ESM Combining ...")
for index in indexes: 
    curProtein = output_list[index]
    curLength = curProtein.num_residue.tolist()
    if curLength <= 1022:
        protein_within_1022_list.append(curProtein)
    elif curLength <= 2044:
        mask1 = list(range(1022))
        mask2 = list(range(1022, curLength))
        part1 = curProtein.residue_mask(mask1, compact=True)
        part2 = curProtein.residue_mask(mask2, compact=True)
        graph = data.Protein.pack([part1, part2])
        protein_within_1022_list.append(graph)
    elif curLength <= 3066:
        mask1 = list(range(1022))
        mask2 = list(range(1022, 2044))
        mask3 = list(range(2044, curLength))
        part1 = curProtein.residue_mask(mask1, compact=True)
        part2 = curProtein.residue_mask(mask2, compact=True)
        part3 = curProtein.residue_mask(mask3, compact=True)
        graph = data.Protein.pack([part1, part2, part3])
        protein_within_1022_list.append(graph)
    elif curLength <= 4088:
        mask1 = list(range(1022))
        mask2 = list(range(1022, 2044))
        mask3 = list(range(2044, 3066))
        mask4 = list(range(3066, curLength))
        part1 = curProtein.residue_mask(mask1, compact=True)
        part2 = curProtein.residue_mask(mask2, compact=True)
        part3 = curProtein.residue_mask(mask3, compact=True)
        part4 = curProtein.residue_mask(mask4, compact=True)
        graph = data.Protein.pack([part1, part2, part3, part4])
        protein_within_1022_list.append(graph)
    elif curLength <= 5110:
        mask1 = list(range(1022))
        mask2 = list(range(1022, 2044))
        mask3 = list(range(2044, 3066))
        mask4 = list(range(2044, 4088))
        mask5 = list(range(4088, curLength))
        part1 = curProtein.residue_mask(mask1, compact=True)
        part2 = curProtein.residue_mask(mask2, compact=True)
        part3 = curProtein.residue_mask(mask3, compact=True)
        part4 = curProtein.residue_mask(mask4, compact=True)
        part5 = curProtein.residue_mask(mask5, compact=True)
        graph = data.Protein.pack([part1, part2, part3, part4, part5])
        protein_within_1022_list.append(graph)
    else :
        raise ValueError("Error with too long residue")
# Out:
# ESM Combining ...: 100%|██████████| 19404/19404 [30:52<00:00, 10.47it/s]

# %%
drug_pkl = '../../../data/dta-datasets/PDBbind/protein_for_esm.pkl'
with utils.smart_open(drug_pkl, "wb") as fout:
    pickle.dump(protein_within_1022_list, fout)

# %% [markdown]
# #### 1022 Length Limit Protein Construction

# %%
import pickle
import torch
from tqdm import tqdm
from torchdrug import utils, transforms, data, models, layers

# %%
protein_pkl = '../../../data/dta-datasets/PDBbind/protein_for_esm.pkl'
with utils.smart_open(protein_pkl, "rb") as fin:
    protein_within_1022_list = pickle.load(fin)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Code\CurrentWork\Demo\DTA_Work\script\notebook\DatasetBuilding\PDBbindESM.ipynb Cell 4' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000003?line=0'>1</a> protein_pkl = '../../../data/dta-datasets/PDBbind/protein_for_esm.pkl'
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000003?line=1'>2</a> with utils.smart_open(protein_pkl, "rb") as fin:
# ----> <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000003?line=2'>3</a>     protein_within_1022_list = pickle.load(fin)
#
# File d:\miniconda3\envs\torchdrug\lib\site-packages\torch\storage.py:239, in _load_from_bytes(b)
#     235     @property
#     236     def is_cuda(self):
#     237         return self.device.type == 'cuda'
# --> 239 def _load_from_bytes(b):
#     240     return torch.load(io.BytesIO(b))
#     243 _StorageBase.type = _type  # type: ignore[assignment]
#
# KeyboardInterrupt:

# %%
list1 = protein_within_1022_list[5000:10000]
list1
# Out:
# [PackedProtein(batch_size=2, num_atoms=[1022, 139], num_bonds=[20059, 2123], num_residues=[1022, 139]),
#  PackedProtein(batch_size=1, num_atoms=[501], num_bonds=[9852], num_residues=[501]),
#  PackedProtein(batch_size=1, num_atoms=[165], num_bonds=[3709], num_residues=[165]),
#  PackedProtein(batch_size=1, num_atoms=[852], num_bonds=[19860], num_residues=[852]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5615], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[611], num_bonds=[14390], num_residues=[611]),
#  PackedProtein(batch_size=1, num_atoms=[939], num_bonds=[20431], num_residues=[939]),
#  PackedProtein(batch_size=1, num_atoms=[295], num_bonds=[6629], num_residues=[295]),
#  PackedProtein(batch_size=1, num_atoms=[296], num_bonds=[6538], num_residues=[296]),
#  PackedProtein(batch_size=1, num_atoms=[1017], num_bonds=[23912], num_residues=[1017]),
#  PackedProtein(batch_size=1, num_atoms=[364], num_bonds=[7158], num_residues=[364]),
#  PackedProtein(batch_size=1, num_atoms=[430], num_bonds=[7629], num_residues=[430]),
#  PackedProtein(batch_size=1, num_atoms=[244], num_bonds=[4891], num_residues=[244]),
#  PackedProtein(batch_size=1, num_atoms=[244], num_bonds=[4882], num_residues=[244]),
#  PackedProtein(batch_size=1, num_atoms=[509], num_bonds=[10824], num_residues=[509]),
#  PackedProtein(batch_size=1, num_atoms=[652], num_bonds=[12512], num_residues=[652]),
#  PackedProtein(batch_size=1, num_atoms=[165], num_bonds=[3233], num_residues=[165]),
#  PackedProtein(batch_size=1, num_atoms=[301], num_bonds=[5884], num_residues=[301]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 56], num_bonds=[22306, 485], num_residues=[1022, 56]),
#  PackedProtein(batch_size=1, num_atoms=[557], num_bonds=[12134], num_residues=[557]),
#  PackedProtein(batch_size=1, num_atoms=[939], num_bonds=[21263], num_residues=[939]),
#  PackedProtein(batch_size=1, num_atoms=[942], num_bonds=[21516], num_residues=[942]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 355], num_bonds=[20706, 6505], num_residues=[1022, 355]),
#  PackedProtein(batch_size=1, num_atoms=[721], num_bonds=[15357], num_residues=[721]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 220], num_bonds=[24553, 4581], num_residues=[1022, 220]),
#  PackedProtein(batch_size=1, num_atoms=[504], num_bonds=[10392], num_residues=[504]),
#  PackedProtein(batch_size=1, num_atoms=[608], num_bonds=[13321], num_residues=[608]),
#  PackedProtein(batch_size=1, num_atoms=[439], num_bonds=[8580], num_residues=[439]),
#  PackedProtein(batch_size=1, num_atoms=[172], num_bonds=[3833], num_residues=[172]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5238], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5196], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5185], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[865], num_bonds=[19609], num_residues=[865]),
#  PackedProtein(batch_size=1, num_atoms=[458], num_bonds=[10504], num_residues=[458]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 176], num_bonds=[21607, 20240, 3035], num_residues=[1022, 1022, 176]),
#  PackedProtein(batch_size=1, num_atoms=[960], num_bonds=[22017], num_residues=[960]),
#  PackedProtein(batch_size=1, num_atoms=[988], num_bonds=[21779], num_residues=[988]),
#  PackedProtein(batch_size=1, num_atoms=[105], num_bonds=[2024], num_residues=[105]),
#  PackedProtein(batch_size=1, num_atoms=[105], num_bonds=[2004], num_residues=[105]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2036], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7704], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[471], num_bonds=[10850], num_residues=[471]),
#  PackedProtein(batch_size=1, num_atoms=[656], num_bonds=[14002], num_residues=[656]),
#  PackedProtein(batch_size=1, num_atoms=[429], num_bonds=[7472], num_residues=[429]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5254], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[301], num_bonds=[6024], num_residues=[301]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5225], num_residues=[224]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 451], num_bonds=[21283, 8474], num_residues=[1022, 451]),
#  PackedProtein(batch_size=1, num_atoms=[559], num_bonds=[12131], num_residues=[559]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 56], num_bonds=[22301, 486], num_residues=[1022, 56]),
#  PackedProtein(batch_size=1, num_atoms=[346], num_bonds=[7484], num_residues=[346]),
#  PackedProtein(batch_size=1, num_atoms=[525], num_bonds=[11486], num_residues=[525]),
#  PackedProtein(batch_size=1, num_atoms=[744], num_bonds=[15577], num_residues=[744]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 3], num_bonds=[23730, 9], num_residues=[1022, 3]),
#  PackedProtein(batch_size=1, num_atoms=[498], num_bonds=[10377], num_residues=[498]),
#  PackedProtein(batch_size=1, num_atoms=[894], num_bonds=[19858], num_residues=[894]),
#  PackedProtein(batch_size=1, num_atoms=[346], num_bonds=[7499], num_residues=[346]),
#  PackedProtein(batch_size=1, num_atoms=[390], num_bonds=[8464], num_residues=[390]),
#  PackedProtein(batch_size=1, num_atoms=[244], num_bonds=[4862], num_residues=[244]),
#  PackedProtein(batch_size=1, num_atoms=[165], num_bonds=[3720], num_residues=[165]),
#  PackedProtein(batch_size=1, num_atoms=[392], num_bonds=[8391], num_residues=[392]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5642], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[922], num_bonds=[19254], num_residues=[922]),
#  PackedProtein(batch_size=1, num_atoms=[454], num_bonds=[9521], num_residues=[454]),
#  PackedProtein(batch_size=1, num_atoms=[414], num_bonds=[9383], num_residues=[414]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 487], num_bonds=[21383, 9768], num_residues=[1022, 487]),
#  PackedProtein(batch_size=1, num_atoms=[445], num_bonds=[9391], num_residues=[445]),
#  PackedProtein(batch_size=1, num_atoms=[130], num_bonds=[1956], num_residues=[130]),
#  PackedProtein(batch_size=1, num_atoms=[758], num_bonds=[16676], num_residues=[758]),
#  PackedProtein(batch_size=1, num_atoms=[282], num_bonds=[4946], num_residues=[282]),
#  PackedProtein(batch_size=1, num_atoms=[430], num_bonds=[9258], num_residues=[430]),
#  PackedProtein(batch_size=1, num_atoms=[545], num_bonds=[11075], num_residues=[545]),
#  PackedProtein(batch_size=1, num_atoms=[317], num_bonds=[6706], num_residues=[317]),
#  PackedProtein(batch_size=1, num_atoms=[324], num_bonds=[6789], num_residues=[324]),
#  PackedProtein(batch_size=1, num_atoms=[388], num_bonds=[8612], num_residues=[388]),
#  PackedProtein(batch_size=1, num_atoms=[352], num_bonds=[7536], num_residues=[352]),
#  PackedProtein(batch_size=1, num_atoms=[465], num_bonds=[10595], num_residues=[465]),
#  PackedProtein(batch_size=1, num_atoms=[138], num_bonds=[3183], num_residues=[138]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 276], num_bonds=[20691, 5187], num_residues=[1022, 276]),
#  PackedProtein(batch_size=1, num_atoms=[276], num_bonds=[5675], num_residues=[276]),
#  PackedProtein(batch_size=1, num_atoms=[497], num_bonds=[10833], num_residues=[497]),
#  PackedProtein(batch_size=1, num_atoms=[130], num_bonds=[1971], num_residues=[130]),
#  PackedProtein(batch_size=1, num_atoms=[301], num_bonds=[5901], num_residues=[301]),
#  PackedProtein(batch_size=1, num_atoms=[153], num_bonds=[3437], num_residues=[153]),
#  PackedProtein(batch_size=1, num_atoms=[591], num_bonds=[13204], num_residues=[591]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 427], num_bonds=[20933, 7624], num_residues=[1022, 427]),
#  PackedProtein(batch_size=4, num_atoms=[1022, 1022, 1022, 966], num_bonds=[16489, 16256, 15858, 15146], num_residues=[1022, 1022, 1022, 966]),
#  PackedProtein(batch_size=1, num_atoms=[155], num_bonds=[3492], num_residues=[155]),
#  PackedProtein(batch_size=1, num_atoms=[318], num_bonds=[7257], num_residues=[318]),
#  PackedProtein(batch_size=1, num_atoms=[278], num_bonds=[5320], num_residues=[278]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5268], num_residues=[224]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 241], num_bonds=[24785, 5132], num_residues=[1022, 241]),
#  PackedProtein(batch_size=1, num_atoms=[448], num_bonds=[10673], num_residues=[448]),
#  PackedProtein(batch_size=1, num_atoms=[307], num_bonds=[6055], num_residues=[307]),
#  PackedProtein(batch_size=1, num_atoms=[271], num_bonds=[5282], num_residues=[271]),
#  PackedProtein(batch_size=1, num_atoms=[578], num_bonds=[11060], num_residues=[578]),
#  PackedProtein(batch_size=1, num_atoms=[299], num_bonds=[5715], num_residues=[299]),
#  PackedProtein(batch_size=1, num_atoms=[515], num_bonds=[11096], num_residues=[515]),
#  PackedProtein(batch_size=1, num_atoms=[239], num_bonds=[5574], num_residues=[239]),
#  PackedProtein(batch_size=1, num_atoms=[635], num_bonds=[13094], num_residues=[635]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5240], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[16375], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[305], num_bonds=[6917], num_residues=[305]),
#  PackedProtein(batch_size=1, num_atoms=[275], num_bonds=[5908], num_residues=[275]),
#  PackedProtein(batch_size=1, num_atoms=[150], num_bonds=[3179], num_residues=[150]),
#  PackedProtein(batch_size=1, num_atoms=[278], num_bonds=[6049], num_residues=[278]),
#  PackedProtein(batch_size=1, num_atoms=[515], num_bonds=[11046], num_residues=[515]),
#  PackedProtein(batch_size=1, num_atoms=[514], num_bonds=[10911], num_residues=[514]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 451], num_bonds=[21214, 8441], num_residues=[1022, 451]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 56], num_bonds=[22368, 21992, 608], num_residues=[1022, 1022, 56]),
#  PackedProtein(batch_size=1, num_atoms=[847], num_bonds=[19548], num_residues=[847]),
#  PackedProtein(batch_size=1, num_atoms=[150], num_bonds=[3185], num_residues=[150]),
#  PackedProtein(batch_size=1, num_atoms=[534], num_bonds=[10462], num_residues=[534]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5234], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[445], num_bonds=[10385], num_residues=[445]),
#  PackedProtein(batch_size=1, num_atoms=[463], num_bonds=[8970], num_residues=[463]),
#  PackedProtein(batch_size=1, num_atoms=[493], num_bonds=[10290], num_residues=[493]),
#  PackedProtein(batch_size=1, num_atoms=[487], num_bonds=[8868], num_residues=[487]),
#  PackedProtein(batch_size=1, num_atoms=[487], num_bonds=[8972], num_residues=[487]),
#  PackedProtein(batch_size=4, num_atoms=[1022, 1022, 1022, 978], num_bonds=[22923, 22684, 22277, 21732], num_residues=[1022, 1022, 1022, 978]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5217], num_residues=[224]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 534], num_bonds=[25652, 12122], num_residues=[1022, 534]),
#  PackedProtein(batch_size=1, num_atoms=[163], num_bonds=[3355], num_residues=[163]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7739], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[212], num_bonds=[4295], num_residues=[212]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 580], num_bonds=[21636, 11561], num_residues=[1022, 580]),
#  PackedProtein(batch_size=1, num_atoms=[263], num_bonds=[5652], num_residues=[263]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 554], num_bonds=[22032, 20670, 11194], num_residues=[1022, 1022, 554]),
#  PackedProtein(batch_size=1, num_atoms=[894], num_bonds=[19645], num_residues=[894]),
#  PackedProtein(batch_size=1, num_atoms=[325], num_bonds=[6502], num_residues=[325]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5193], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[355], num_bonds=[7653], num_residues=[355]),
#  PackedProtein(batch_size=1, num_atoms=[130], num_bonds=[1965], num_residues=[130]),
#  PackedProtein(batch_size=1, num_atoms=[130], num_bonds=[1960], num_residues=[130]),
#  PackedProtein(batch_size=1, num_atoms=[426], num_bonds=[7798], num_residues=[426]),
#  PackedProtein(batch_size=1, num_atoms=[330], num_bonds=[7453], num_residues=[330]),
#  PackedProtein(batch_size=1, num_atoms=[140], num_bonds=[2124], num_residues=[140]),
#  PackedProtein(batch_size=1, num_atoms=[164], num_bonds=[3697], num_residues=[164]),
#  PackedProtein(batch_size=1, num_atoms=[544], num_bonds=[11034], num_residues=[544]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5207], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[390], num_bonds=[8491], num_residues=[390]),
#  PackedProtein(batch_size=1, num_atoms=[363], num_bonds=[6633], num_residues=[363]),
#  PackedProtein(batch_size=1, num_atoms=[497], num_bonds=[10793], num_residues=[497]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5686], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[544], num_bonds=[11081], num_residues=[544]),
#  PackedProtein(batch_size=1, num_atoms=[306], num_bonds=[6908], num_residues=[306]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5190], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[278], num_bonds=[6057], num_residues=[278]),
#  PackedProtein(batch_size=1, num_atoms=[210], num_bonds=[4258], num_residues=[210]),
#  PackedProtein(batch_size=1, num_atoms=[425], num_bonds=[7768], num_residues=[425]),
#  PackedProtein(batch_size=1, num_atoms=[272], num_bonds=[5330], num_residues=[272]),
#  PackedProtein(batch_size=1, num_atoms=[338], num_bonds=[7589], num_residues=[338]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5269], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[555], num_bonds=[13548], num_residues=[555]),
#  PackedProtein(batch_size=1, num_atoms=[698], num_bonds=[14885], num_residues=[698]),
#  PackedProtein(batch_size=1, num_atoms=[208], num_bonds=[4100], num_residues=[208]),
#  PackedProtein(batch_size=1, num_atoms=[341], num_bonds=[8495], num_residues=[341]),
#  PackedProtein(batch_size=1, num_atoms=[651], num_bonds=[11665], num_residues=[651]),
#  PackedProtein(batch_size=1, num_atoms=[260], num_bonds=[4927], num_residues=[260]),
#  PackedProtein(batch_size=1, num_atoms=[628], num_bonds=[13508], num_residues=[628]),
#  PackedProtein(batch_size=1, num_atoms=[528], num_bonds=[10124], num_residues=[528]),
#  PackedProtein(batch_size=1, num_atoms=[1014], num_bonds=[22741], num_residues=[1014]),
#  PackedProtein(batch_size=1, num_atoms=[794], num_bonds=[18090], num_residues=[794]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7646], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[164], num_bonds=[3717], num_residues=[164]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 594], num_bonds=[19658, 10674], num_residues=[1022, 594]),
#  PackedProtein(batch_size=1, num_atoms=[488], num_bonds=[9013], num_residues=[488]),
#  PackedProtein(batch_size=1, num_atoms=[740], num_bonds=[15265], num_residues=[740]),
#  PackedProtein(batch_size=1, num_atoms=[437], num_bonds=[9294], num_residues=[437]),
#  PackedProtein(batch_size=1, num_atoms=[438], num_bonds=[9309], num_residues=[438]),
#  PackedProtein(batch_size=1, num_atoms=[550], num_bonds=[12808], num_residues=[550]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5283], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[334], num_bonds=[7639], num_residues=[334]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5671], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[346], num_bonds=[7446], num_residues=[346]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[830], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[875], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[164], num_bonds=[3707], num_residues=[164]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[16402], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[498], num_bonds=[10385], num_residues=[498]),
#  PackedProtein(batch_size=1, num_atoms=[109], num_bonds=[1627], num_residues=[109]),
#  PackedProtein(batch_size=1, num_atoms=[457], num_bonds=[8636], num_residues=[457]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7627], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[330], num_bonds=[7444], num_residues=[330]),
#  PackedProtein(batch_size=1, num_atoms=[437], num_bonds=[8417], num_residues=[437]),
#  PackedProtein(batch_size=1, num_atoms=[1010], num_bonds=[24408], num_residues=[1010]),
#  PackedProtein(batch_size=1, num_atoms=[328], num_bonds=[6541], num_residues=[328]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 596], num_bonds=[19436, 10597], num_residues=[1022, 596]),
#  PackedProtein(batch_size=1, num_atoms=[496], num_bonds=[11870], num_residues=[496]),
#  PackedProtein(batch_size=1, num_atoms=[306], num_bonds=[5851], num_residues=[306]),
#  PackedProtein(batch_size=1, num_atoms=[301], num_bonds=[5749], num_residues=[301]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 3], num_bonds=[23939, 9], num_residues=[1022, 3]),
#  PackedProtein(batch_size=1, num_atoms=[341], num_bonds=[6758], num_residues=[341]),
#  PackedProtein(batch_size=1, num_atoms=[150], num_bonds=[3184], num_residues=[150]),
#  PackedProtein(batch_size=1, num_atoms=[390], num_bonds=[8467], num_residues=[390]),
#  PackedProtein(batch_size=1, num_atoms=[993], num_bonds=[21393], num_residues=[993]),
#  PackedProtein(batch_size=1, num_atoms=[312], num_bonds=[7053], num_residues=[312]),
#  PackedProtein(batch_size=1, num_atoms=[336], num_bonds=[6296], num_residues=[336]),
#  PackedProtein(batch_size=1, num_atoms=[208], num_bonds=[3895], num_residues=[208]),
#  PackedProtein(batch_size=1, num_atoms=[147], num_bonds=[2705], num_residues=[147]),
#  PackedProtein(batch_size=1, num_atoms=[504], num_bonds=[9815], num_residues=[504]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 702], num_bonds=[21616, 13708], num_residues=[1022, 702]),
#  PackedProtein(batch_size=1, num_atoms=[326], num_bonds=[6630], num_residues=[326]),
#  PackedProtein(batch_size=1, num_atoms=[353], num_bonds=[6143], num_residues=[353]),
#  PackedProtein(batch_size=1, num_atoms=[619], num_bonds=[11376], num_residues=[619]),
#  PackedProtein(batch_size=1, num_atoms=[616], num_bonds=[11344], num_residues=[616]),
#  PackedProtein(batch_size=1, num_atoms=[767], num_bonds=[18259], num_residues=[767]),
#  PackedProtein(batch_size=1, num_atoms=[678], num_bonds=[17155], num_residues=[678]),
#  PackedProtein(batch_size=1, num_atoms=[127], num_bonds=[2042], num_residues=[127]),
#  PackedProtein(batch_size=1, num_atoms=[381], num_bonds=[7235], num_residues=[381]),
#  PackedProtein(batch_size=1, num_atoms=[764], num_bonds=[16267], num_residues=[764]),
#  PackedProtein(batch_size=1, num_atoms=[172], num_bonds=[3927], num_residues=[172]),
#  PackedProtein(batch_size=1, num_atoms=[275], num_bonds=[5284], num_residues=[275]),
#  PackedProtein(batch_size=4, num_atoms=[1022, 1022, 1022, 978], num_bonds=[23046, 22748, 22410, 21834], num_residues=[1022, 1022, 1022, 978]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[16314], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[461], num_bonds=[9722], num_residues=[461]),
#  PackedProtein(batch_size=1, num_atoms=[156], num_bonds=[2909], num_residues=[156]),
#  PackedProtein(batch_size=1, num_atoms=[320], num_bonds=[7269], num_residues=[320]),
#  PackedProtein(batch_size=1, num_atoms=[390], num_bonds=[8481], num_residues=[390]),
#  PackedProtein(batch_size=1, num_atoms=[688], num_bonds=[15437], num_residues=[688]),
#  PackedProtein(batch_size=1, num_atoms=[898], num_bonds=[22290], num_residues=[898]),
#  PackedProtein(batch_size=1, num_atoms=[283], num_bonds=[5459], num_residues=[283]),
#  PackedProtein(batch_size=1, num_atoms=[334], num_bonds=[6229], num_residues=[334]),
#  PackedProtein(batch_size=1, num_atoms=[150], num_bonds=[3179], num_residues=[150]),
#  PackedProtein(batch_size=1, num_atoms=[418], num_bonds=[8991], num_residues=[418]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 487], num_bonds=[21406, 9762], num_residues=[1022, 487]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5282], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[306], num_bonds=[5782], num_residues=[306]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 338], num_bonds=[21555, 18726, 5131], num_residues=[1022, 1022, 338]),
#  PackedProtein(batch_size=1, num_atoms=[1014], num_bonds=[22689], num_residues=[1014]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 58], num_bonds=[22364, 21980, 626], num_residues=[1022, 1022, 58]),
#  PackedProtein(batch_size=1, num_atoms=[607], num_bonds=[12628], num_residues=[607]),
#  PackedProtein(batch_size=1, num_atoms=[232], num_bonds=[4964], num_residues=[232]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[16329], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[570], num_bonds=[11535], num_residues=[570]),
#  PackedProtein(batch_size=1, num_atoms=[337], num_bonds=[6369], num_residues=[337]),
#  PackedProtein(batch_size=1, num_atoms=[258], num_bonds=[5687], num_residues=[258]),
#  PackedProtein(batch_size=1, num_atoms=[288], num_bonds=[5506], num_residues=[288]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 534], num_bonds=[25099, 11852], num_residues=[1022, 534]),
#  PackedProtein(batch_size=1, num_atoms=[692], num_bonds=[15310], num_residues=[692]),
#  PackedProtein(batch_size=1, num_atoms=[692], num_bonds=[15111], num_residues=[692]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2033], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[551], num_bonds=[12795], num_residues=[551]),
#  PackedProtein(batch_size=1, num_atoms=[497], num_bonds=[10461], num_residues=[497]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[16307], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[357], num_bonds=[7665], num_residues=[357]),
#  PackedProtein(batch_size=1, num_atoms=[274], num_bonds=[5352], num_residues=[274]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 846], num_bonds=[21386, 17715], num_residues=[1022, 846]),
#  PackedProtein(batch_size=4, num_atoms=[1022, 1022, 1022, 978], num_bonds=[22991, 22715, 22319, 21766], num_residues=[1022, 1022, 1022, 978]),
#  PackedProtein(batch_size=1, num_atoms=[303], num_bonds=[6514], num_residues=[303]),
#  PackedProtein(batch_size=1, num_atoms=[246], num_bonds=[5656], num_residues=[246]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 554], num_bonds=[22210, 20758, 11263], num_residues=[1022, 1022, 554]),
#  PackedProtein(batch_size=1, num_atoms=[892], num_bonds=[19516], num_residues=[892]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 265], num_bonds=[21116, 4266], num_residues=[1022, 265]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5640], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[147], num_bonds=[2697], num_residues=[147]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5706], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[254], num_bonds=[5545], num_residues=[254]),
#  PackedProtein(batch_size=1, num_atoms=[178], num_bonds=[3268], num_residues=[178]),
#  PackedProtein(batch_size=1, num_atoms=[124], num_bonds=[1799], num_residues=[124]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[1795], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[1789], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[252], num_bonds=[4265], num_residues=[252]),
#  PackedProtein(batch_size=1, num_atoms=[210], num_bonds=[4225], num_residues=[210]),
#  PackedProtein(batch_size=1, num_atoms=[332], num_bonds=[6638], num_residues=[332]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 702], num_bonds=[21189, 13392], num_residues=[1022, 702]),
#  PackedProtein(batch_size=1, num_atoms=[179], num_bonds=[3255], num_residues=[179]),
#  PackedProtein(batch_size=1, num_atoms=[961], num_bonds=[22219], num_residues=[961]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 56], num_bonds=[22371, 21995, 607], num_residues=[1022, 1022, 56]),
#  PackedProtein(batch_size=1, num_atoms=[197], num_bonds=[4021], num_residues=[197]),
#  PackedProtein(batch_size=1, num_atoms=[124], num_bonds=[2479], num_residues=[124]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 644], num_bonds=[22970, 12852], num_residues=[1022, 644]),
#  PackedProtein(batch_size=1, num_atoms=[525], num_bonds=[11515], num_residues=[525]),
#  PackedProtein(batch_size=1, num_atoms=[307], num_bonds=[6787], num_residues=[307]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7689], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[728], num_bonds=[16175], num_residues=[728]),
#  PackedProtein(batch_size=1, num_atoms=[330], num_bonds=[7461], num_residues=[330]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2030], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[262], num_bonds=[5642], num_residues=[262]),
#  PackedProtein(batch_size=1, num_atoms=[678], num_bonds=[17123], num_residues=[678]),
#  PackedProtein(batch_size=4, num_atoms=[1022, 1022, 1022, 994], num_bonds=[22871, 22901, 22644, 22213], num_residues=[1022, 1022, 1022, 994]),
#  PackedProtein(batch_size=1, num_atoms=[138], num_bonds=[2891], num_residues=[138]),
#  PackedProtein(batch_size=1, num_atoms=[105], num_bonds=[2052], num_residues=[105]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 56], num_bonds=[23569, 22904, 650], num_residues=[1022, 1022, 56]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 292], num_bonds=[22180, 5561], num_residues=[1022, 292]),
#  PackedProtein(batch_size=1, num_atoms=[263], num_bonds=[5666], num_residues=[263]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 130], num_bonds=[21024, 2022], num_residues=[1022, 130]),
#  PackedProtein(batch_size=1, num_atoms=[283], num_bonds=[5528], num_residues=[283]),
#  PackedProtein(batch_size=1, num_atoms=[644], num_bonds=[14934], num_residues=[644]),
#  PackedProtein(batch_size=1, num_atoms=[544], num_bonds=[11060], num_residues=[544]),
#  PackedProtein(batch_size=1, num_atoms=[208], num_bonds=[4048], num_residues=[208]),
#  PackedProtein(batch_size=1, num_atoms=[124], num_bonds=[2463], num_residues=[124]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 596], num_bonds=[19477, 10617], num_residues=[1022, 596]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 554], num_bonds=[22119, 20685, 11232], num_residues=[1022, 1022, 554]),
#  PackedProtein(batch_size=1, num_atoms=[262], num_bonds=[5745], num_residues=[262]),
#  PackedProtein(batch_size=1, num_atoms=[426], num_bonds=[7856], num_residues=[426]),
#  PackedProtein(batch_size=1, num_atoms=[329], num_bonds=[7450], num_residues=[329]),
#  PackedProtein(batch_size=1, num_atoms=[389], num_bonds=[8814], num_residues=[389]),
#  PackedProtein(batch_size=1, num_atoms=[105], num_bonds=[2002], num_residues=[105]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 466], num_bonds=[18749, 8438], num_residues=[1022, 466]),
#  PackedProtein(batch_size=1, num_atoms=[426], num_bonds=[7770], num_residues=[426]),
#  PackedProtein(batch_size=1, num_atoms=[528], num_bonds=[10174], num_residues=[528]),
#  PackedProtein(batch_size=1, num_atoms=[426], num_bonds=[7837], num_residues=[426]),
#  PackedProtein(batch_size=1, num_atoms=[265], num_bonds=[4951], num_residues=[265]),
#  PackedProtein(batch_size=1, num_atoms=[238], num_bonds=[4843], num_residues=[238]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2056], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[338], num_bonds=[6790], num_residues=[338]),
#  PackedProtein(batch_size=1, num_atoms=[942], num_bonds=[21137], num_residues=[942]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 10], num_bonds=[22648, 73], num_residues=[1022, 10]),
#  PackedProtein(batch_size=1, num_atoms=[274], num_bonds=[5365], num_residues=[274]),
#  PackedProtein(batch_size=1, num_atoms=[866], num_bonds=[17906], num_residues=[866]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 602], num_bonds=[19535, 10798], num_residues=[1022, 602]),
#  PackedProtein(batch_size=1, num_atoms=[942], num_bonds=[21301], num_residues=[942]),
#  PackedProtein(batch_size=1, num_atoms=[414], num_bonds=[9374], num_residues=[414]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[1113], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2001], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[536], num_bonds=[12966], num_residues=[536]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 598], num_bonds=[19539, 10704], num_residues=[1022, 598]),
#  PackedProtein(batch_size=1, num_atoms=[304], num_bonds=[5800], num_residues=[304]),
#  PackedProtein(batch_size=1, num_atoms=[564], num_bonds=[11341], num_residues=[564]),
#  PackedProtein(batch_size=1, num_atoms=[335], num_bonds=[6275], num_residues=[335]),
#  PackedProtein(batch_size=1, num_atoms=[307], num_bonds=[6914], num_residues=[307]),
#  PackedProtein(batch_size=1, num_atoms=[492], num_bonds=[9549], num_residues=[492]),
#  PackedProtein(batch_size=1, num_atoms=[792], num_bonds=[17054], num_residues=[792]),
#  PackedProtein(batch_size=1, num_atoms=[223], num_bonds=[5204], num_residues=[223]),
#  PackedProtein(batch_size=1, num_atoms=[497], num_bonds=[11163], num_residues=[497]),
#  PackedProtein(batch_size=1, num_atoms=[98], num_bonds=[1788], num_residues=[98]),
#  PackedProtein(batch_size=1, num_atoms=[330], num_bonds=[7467], num_residues=[330]),
#  PackedProtein(batch_size=1, num_atoms=[344], num_bonds=[7208], num_residues=[344]),
#  PackedProtein(batch_size=1, num_atoms=[371], num_bonds=[8130], num_residues=[371]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[886], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[152], num_bonds=[2661], num_residues=[152]),
#  PackedProtein(batch_size=1, num_atoms=[426], num_bonds=[7957], num_residues=[426]),
#  PackedProtein(batch_size=1, num_atoms=[329], num_bonds=[7452], num_residues=[329]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5230], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5163], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5147], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5170], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2027], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[554], num_bonds=[11085], num_residues=[554]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 598], num_bonds=[19734, 10816], num_residues=[1022, 598]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7659], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[245], num_bonds=[4390], num_residues=[245]),
#  PackedProtein(batch_size=1, num_atoms=[764], num_bonds=[16223], num_residues=[764]),
#  PackedProtein(batch_size=1, num_atoms=[262], num_bonds=[5646], num_residues=[262]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5200], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[438], num_bonds=[9381], num_residues=[438]),
#  PackedProtein(batch_size=1, num_atoms=[593], num_bonds=[13695], num_residues=[593]),
#  PackedProtein(batch_size=1, num_atoms=[492], num_bonds=[10300], num_residues=[492]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 631], num_bonds=[22023, 12968], num_residues=[1022, 631]),
#  PackedProtein(batch_size=1, num_atoms=[496], num_bonds=[10587], num_residues=[496]),
#  PackedProtein(batch_size=1, num_atoms=[854], num_bonds=[20697], num_residues=[854]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7681], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[939], num_bonds=[21212], num_residues=[939]),
#  PackedProtein(batch_size=4, num_atoms=[1022, 1022, 1022, 994], num_bonds=[23002, 22966, 22715, 22340], num_residues=[1022, 1022, 1022, 994]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5664], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[147], num_bonds=[2707], num_residues=[147]),
#  PackedProtein(batch_size=1, num_atoms=[621], num_bonds=[11415], num_residues=[621]),
#  PackedProtein(batch_size=1, num_atoms=[156], num_bonds=[2902], num_residues=[156]),
#  PackedProtein(batch_size=1, num_atoms=[156], num_bonds=[2904], num_residues=[156]),
#  PackedProtein(batch_size=1, num_atoms=[430], num_bonds=[7572], num_residues=[430]),
#  PackedProtein(batch_size=1, num_atoms=[542], num_bonds=[11524], num_residues=[542]),
#  PackedProtein(batch_size=1, num_atoms=[267], num_bonds=[5134], num_residues=[267]),
#  PackedProtein(batch_size=1, num_atoms=[416], num_bonds=[8530], num_residues=[416]),
#  PackedProtein(batch_size=1, num_atoms=[291], num_bonds=[6644], num_residues=[291]),
#  PackedProtein(batch_size=1, num_atoms=[284], num_bonds=[5467], num_residues=[284]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5218], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[390], num_bonds=[8467], num_residues=[390]),
#  PackedProtein(batch_size=1, num_atoms=[265], num_bonds=[4965], num_residues=[265]),
#  PackedProtein(batch_size=1, num_atoms=[287], num_bonds=[5755], num_residues=[287]),
#  PackedProtein(batch_size=1, num_atoms=[447], num_bonds=[9506], num_residues=[447]),
#  PackedProtein(batch_size=1, num_atoms=[395], num_bonds=[9886], num_residues=[395]),
#  PackedProtein(batch_size=1, num_atoms=[239], num_bonds=[5601], num_residues=[239]),
#  PackedProtein(batch_size=1, num_atoms=[532], num_bonds=[12287], num_residues=[532]),
#  PackedProtein(batch_size=1, num_atoms=[188], num_bonds=[3294], num_residues=[188]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[16307], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[124], num_bonds=[1873], num_residues=[124]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7776], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[522], num_bonds=[10418], num_residues=[522]),
#  PackedProtein(batch_size=1, num_atoms=[524], num_bonds=[10584], num_residues=[524]),
#  PackedProtein(batch_size=1, num_atoms=[864], num_bonds=[20968], num_residues=[864]),
#  PackedProtein(batch_size=1, num_atoms=[407], num_bonds=[8928], num_residues=[407]),
#  PackedProtein(batch_size=1, num_atoms=[105], num_bonds=[1978], num_residues=[105]),
#  PackedProtein(batch_size=1, num_atoms=[316], num_bonds=[6084], num_residues=[316]),
#  PackedProtein(batch_size=1, num_atoms=[212], num_bonds=[4279], num_residues=[212]),
#  PackedProtein(batch_size=1, num_atoms=[498], num_bonds=[9829], num_residues=[498]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5261], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[85], num_bonds=[1600], num_residues=[85]),
#  PackedProtein(batch_size=1, num_atoms=[246], num_bonds=[4099], num_residues=[246]),
#  PackedProtein(batch_size=1, num_atoms=[522], num_bonds=[11400], num_residues=[522]),
#  PackedProtein(batch_size=1, num_atoms=[792], num_bonds=[16696], num_residues=[792]),
#  PackedProtein(batch_size=1, num_atoms=[993], num_bonds=[21944], num_residues=[993]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[1678], num_residues=[106]),
#  PackedProtein(batch_size=4, num_atoms=[1022, 1022, 1022, 966], num_bonds=[16560, 16320, 15914, 15198], num_residues=[1022, 1022, 1022, 966]),
#  PackedProtein(batch_size=4, num_atoms=[1022, 1022, 1022, 966], num_bonds=[16576, 16335, 15931, 15220], num_residues=[1022, 1022, 1022, 966]),
#  PackedProtein(batch_size=1, num_atoms=[427], num_bonds=[9875], num_residues=[427]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5276], num_residues=[224]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 307], num_bonds=[20590, 5582], num_residues=[1022, 307]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 614], num_bonds=[21187, 20532, 11890], num_residues=[1022, 1022, 614]),
#  PackedProtein(batch_size=1, num_atoms=[463], num_bonds=[9687], num_residues=[463]),
#  PackedProtein(batch_size=1, num_atoms=[320], num_bonds=[7270], num_residues=[320]),
#  PackedProtein(batch_size=1, num_atoms=[764], num_bonds=[16295], num_residues=[764]),
#  PackedProtein(batch_size=1, num_atoms=[296], num_bonds=[6083], num_residues=[296]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2048], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[115], num_bonds=[1734], num_residues=[115]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 292], num_bonds=[21657, 5399], num_residues=[1022, 292]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5669], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5685], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[642], num_bonds=[15234], num_residues=[642]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[827], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[505], num_bonds=[9596], num_residues=[505]),
#  PackedProtein(batch_size=1, num_atoms=[264], num_bonds=[5029], num_residues=[264]),
#  PackedProtein(batch_size=1, num_atoms=[540], num_bonds=[11463], num_residues=[540]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5253], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[546], num_bonds=[10562], num_residues=[546]),
#  PackedProtein(batch_size=1, num_atoms=[515], num_bonds=[11187], num_residues=[515]),
#  PackedProtein(batch_size=1, num_atoms=[672], num_bonds=[14083], num_residues=[672]),
#  PackedProtein(batch_size=1, num_atoms=[126], num_bonds=[2007], num_residues=[126]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 487], num_bonds=[21360, 9748], num_residues=[1022, 487]),
#  PackedProtein(batch_size=1, num_atoms=[380], num_bonds=[8495], num_residues=[380]),
#  PackedProtein(batch_size=1, num_atoms=[511], num_bonds=[10040], num_residues=[511]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5261], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[4324], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[213], num_bonds=[4331], num_residues=[213]),
#  PackedProtein(batch_size=1, num_atoms=[493], num_bonds=[9635], num_residues=[493]),
#  PackedProtein(batch_size=1, num_atoms=[492], num_bonds=[9587], num_residues=[492]),
#  PackedProtein(batch_size=1, num_atoms=[471], num_bonds=[10777], num_residues=[471]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 349], num_bonds=[20636, 6341], num_residues=[1022, 349]),
#  PackedProtein(batch_size=1, num_atoms=[537], num_bonds=[11177], num_residues=[537]),
#  PackedProtein(batch_size=1, num_atoms=[267], num_bonds=[5141], num_residues=[267]),
#  PackedProtein(batch_size=1, num_atoms=[296], num_bonds=[6276], num_residues=[296]),
#  PackedProtein(batch_size=1, num_atoms=[515], num_bonds=[11140], num_residues=[515]),
#  PackedProtein(batch_size=1, num_atoms=[361], num_bonds=[7377], num_residues=[361]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 684], num_bonds=[19660, 21250, 13026], num_residues=[1022, 1022, 684]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 728], num_bonds=[20078, 19664, 13667], num_residues=[1022, 1022, 728]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 50], num_bonds=[21964, 555], num_residues=[1022, 50]),
#  PackedProtein(batch_size=1, num_atoms=[90], num_bonds=[1368], num_residues=[90]),
#  PackedProtein(batch_size=1, num_atoms=[377], num_bonds=[8455], num_residues=[377]),
#  PackedProtein(batch_size=1, num_atoms=[1016], num_bonds=[22804], num_residues=[1016]),
#  PackedProtein(batch_size=1, num_atoms=[378], num_bonds=[8501], num_residues=[378]),
#  PackedProtein(batch_size=1, num_atoms=[370], num_bonds=[8270], num_residues=[370]),
#  PackedProtein(batch_size=1, num_atoms=[606], num_bonds=[12604], num_residues=[606]),
#  PackedProtein(batch_size=1, num_atoms=[606], num_bonds=[12664], num_residues=[606]),
#  PackedProtein(batch_size=1, num_atoms=[607], num_bonds=[12465], num_residues=[607]),
#  PackedProtein(batch_size=1, num_atoms=[607], num_bonds=[12523], num_residues=[607]),
#  PackedProtein(batch_size=1, num_atoms=[180], num_bonds=[3100], num_residues=[180]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7749], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[379], num_bonds=[8509], num_residues=[379]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 513], num_bonds=[19547, 8961], num_residues=[1022, 513]),
#  PackedProtein(batch_size=1, num_atoms=[924], num_bonds=[20434], num_residues=[924]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5681], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5692], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5701], num_residues=[298]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 850], num_bonds=[18860, 15585], num_residues=[1022, 850]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7737], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[351], num_bonds=[7528], num_residues=[351]),
#  PackedProtein(batch_size=1, num_atoms=[711], num_bonds=[15678], num_residues=[711]),
#  PackedProtein(batch_size=1, num_atoms=[812], num_bonds=[16398], num_residues=[812]),
#  PackedProtein(batch_size=1, num_atoms=[838], num_bonds=[16974], num_residues=[838]),
#  PackedProtein(batch_size=1, num_atoms=[806], num_bonds=[16434], num_residues=[806]),
#  PackedProtein(batch_size=1, num_atoms=[410], num_bonds=[7716], num_residues=[410]),
#  PackedProtein(batch_size=1, num_atoms=[195], num_bonds=[3999], num_residues=[195]),
#  PackedProtein(batch_size=1, num_atoms=[228], num_bonds=[5253], num_residues=[228]),
#  PackedProtein(batch_size=1, num_atoms=[251], num_bonds=[5866], num_residues=[251]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 328], num_bonds=[22410, 6651], num_residues=[1022, 328]),
#  PackedProtein(batch_size=1, num_atoms=[188], num_bonds=[3293], num_residues=[188]),
#  PackedProtein(batch_size=1, num_atoms=[547], num_bonds=[10558], num_residues=[547]),
#  PackedProtein(batch_size=1, num_atoms=[613], num_bonds=[13171], num_residues=[613]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 47], num_bonds=[21664, 536], num_residues=[1022, 47]),
#  PackedProtein(batch_size=1, num_atoms=[233], num_bonds=[4711], num_residues=[233]),
#  PackedProtein(batch_size=1, num_atoms=[438], num_bonds=[9332], num_residues=[438]),
#  PackedProtein(batch_size=1, num_atoms=[157], num_bonds=[3101], num_residues=[157]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 535], num_bonds=[26066, 12553], num_residues=[1022, 535]),
#  PackedProtein(batch_size=1, num_atoms=[214], num_bonds=[4301], num_residues=[214]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 812], num_bonds=[21870, 21493, 17339], num_residues=[1022, 1022, 812]),
#  PackedProtein(batch_size=1, num_atoms=[188], num_bonds=[4281], num_residues=[188]),
#  PackedProtein(batch_size=1, num_atoms=[261], num_bonds=[4905], num_residues=[261]),
#  PackedProtein(batch_size=1, num_atoms=[125], num_bonds=[2578], num_residues=[125]),
#  PackedProtein(batch_size=1, num_atoms=[514], num_bonds=[10253], num_residues=[514]),
#  PackedProtein(batch_size=1, num_atoms=[370], num_bonds=[7899], num_residues=[370]),
#  PackedProtein(batch_size=1, num_atoms=[522], num_bonds=[10242], num_residues=[522]),
#  PackedProtein(batch_size=1, num_atoms=[472], num_bonds=[11000], num_residues=[472]),
#  PackedProtein(batch_size=1, num_atoms=[185], num_bonds=[3285], num_residues=[185]),
#  PackedProtein(batch_size=1, num_atoms=[314], num_bonds=[7002], num_residues=[314]),
#  PackedProtein(batch_size=1, num_atoms=[258], num_bonds=[5099], num_residues=[258]),
#  PackedProtein(batch_size=1, num_atoms=[320], num_bonds=[7294], num_residues=[320]),
#  PackedProtein(batch_size=1, num_atoms=[510], num_bonds=[11323], num_residues=[510]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1296], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[558], num_bonds=[11280], num_residues=[558]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7714], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[617], num_bonds=[11365], num_residues=[617]),
#  PackedProtein(batch_size=1, num_atoms=[502], num_bonds=[9943], num_residues=[502]),
#  PackedProtein(batch_size=1, num_atoms=[493], num_bonds=[9680], num_residues=[493]),
#  PackedProtein(batch_size=1, num_atoms=[410], num_bonds=[8528], num_residues=[410]),
#  PackedProtein(batch_size=1, num_atoms=[383], num_bonds=[9255], num_residues=[383]),
#  PackedProtein(batch_size=1, num_atoms=[121], num_bonds=[2120], num_residues=[121]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 248], num_bonds=[22865, 4800], num_residues=[1022, 248]),
#  PackedProtein(batch_size=1, num_atoms=[607], num_bonds=[12618], num_residues=[607]),
#  PackedProtein(batch_size=1, num_atoms=[828], num_bonds=[16778], num_residues=[828]),
#  PackedProtein(batch_size=1, num_atoms=[265], num_bonds=[4969], num_residues=[265]),
#  PackedProtein(batch_size=1, num_atoms=[528], num_bonds=[10416], num_residues=[528]),
#  PackedProtein(batch_size=1, num_atoms=[297], num_bonds=[5854], num_residues=[297]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5186], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[301], num_bonds=[5746], num_residues=[301]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7675], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[620], num_bonds=[11453], num_residues=[620]),
#  PackedProtein(batch_size=1, num_atoms=[659], num_bonds=[15731], num_residues=[659]),
#  PackedProtein(batch_size=1, num_atoms=[228], num_bonds=[5257], num_residues=[228]),
#  PackedProtein(batch_size=1, num_atoms=[227], num_bonds=[4546], num_residues=[227]),
#  PackedProtein(batch_size=1, num_atoms=[343], num_bonds=[7403], num_residues=[343]),
#  PackedProtein(batch_size=1, num_atoms=[390], num_bonds=[8467], num_residues=[390]),
#  PackedProtein(batch_size=1, num_atoms=[592], num_bonds=[13229], num_residues=[592]),
#  PackedProtein(batch_size=1, num_atoms=[425], num_bonds=[8953], num_residues=[425]),
#  PackedProtein(batch_size=1, num_atoms=[248], num_bonds=[5041], num_residues=[248]),
#  PackedProtein(batch_size=1, num_atoms=[337], num_bonds=[6310], num_residues=[337]),
#  PackedProtein(batch_size=1, num_atoms=[884], num_bonds=[19523], num_residues=[884]),
#  PackedProtein(batch_size=1, num_atoms=[276], num_bonds=[6073], num_residues=[276]),
#  PackedProtein(batch_size=1, num_atoms=[792], num_bonds=[16676], num_residues=[792]),
#  PackedProtein(batch_size=1, num_atoms=[398], num_bonds=[7867], num_residues=[398]),
#  PackedProtein(batch_size=1, num_atoms=[394], num_bonds=[8629], num_residues=[394]),
#  PackedProtein(batch_size=1, num_atoms=[461], num_bonds=[9783], num_residues=[461]),
#  PackedProtein(batch_size=1, num_atoms=[446], num_bonds=[9509], num_residues=[446]),
#  PackedProtein(batch_size=1, num_atoms=[274], num_bonds=[5343], num_residues=[274]),
#  PackedProtein(batch_size=1, num_atoms=[698], num_bonds=[13648], num_residues=[698]),
#  PackedProtein(batch_size=1, num_atoms=[607], num_bonds=[12616], num_residues=[607]),
#  PackedProtein(batch_size=1, num_atoms=[161], num_bonds=[3242], num_residues=[161]),
#  PackedProtein(batch_size=1, num_atoms=[271], num_bonds=[5377], num_residues=[271]),
#  PackedProtein(batch_size=1, num_atoms=[177], num_bonds=[3414], num_residues=[177]),
#  PackedProtein(batch_size=1, num_atoms=[162], num_bonds=[3320], num_residues=[162]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 190], num_bonds=[19938, 2755], num_residues=[1022, 190]),
#  PackedProtein(batch_size=1, num_atoms=[129], num_bonds=[2480], num_residues=[129]),
#  PackedProtein(batch_size=1, num_atoms=[273], num_bonds=[4494], num_residues=[273]),
#  PackedProtein(batch_size=1, num_atoms=[87], num_bonds=[1218], num_residues=[87]),
#  PackedProtein(batch_size=1, num_atoms=[95], num_bonds=[1600], num_residues=[95]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[992], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[334], num_bonds=[6747], num_residues=[334]),
#  PackedProtein(batch_size=1, num_atoms=[656], num_bonds=[15615], num_residues=[656]),
#  PackedProtein(batch_size=1, num_atoms=[606], num_bonds=[12590], num_residues=[606]),
#  PackedProtein(batch_size=1, num_atoms=[604], num_bonds=[13102], num_residues=[604]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5663], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5608], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[267], num_bonds=[5082], num_residues=[267]),
# ...
#  PackedProtein(batch_size=1, num_atoms=[475], num_bonds=[9461], num_residues=[475]),
#  PackedProtein(batch_size=1, num_atoms=[376], num_bonds=[6903], num_residues=[376]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[1796], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[241], num_bonds=[5707], num_residues=[241]),
#  PackedProtein(batch_size=1, num_atoms=[363], num_bonds=[6633], num_residues=[363]),
#  PackedProtein(batch_size=1, num_atoms=[472], num_bonds=[11041], num_residues=[472]),
#  PackedProtein(batch_size=1, num_atoms=[299], num_bonds=[5688], num_residues=[299]),
#  PackedProtein(batch_size=1, num_atoms=[636], num_bonds=[12464], num_residues=[636]),
#  PackedProtein(batch_size=1, num_atoms=[378], num_bonds=[7804], num_residues=[378]),
#  PackedProtein(batch_size=1, num_atoms=[480], num_bonds=[11367], num_residues=[480]),
#  PackedProtein(batch_size=1, num_atoms=[113], num_bonds=[2181], num_residues=[113]),
#  PackedProtein(batch_size=1, num_atoms=[181], num_bonds=[3781], num_residues=[181]),
#  PackedProtein(batch_size=1, num_atoms=[229], num_bonds=[5012], num_residues=[229]),
#  PackedProtein(batch_size=1, num_atoms=[437], num_bonds=[9322], num_residues=[437]),
#  PackedProtein(batch_size=1, num_atoms=[437], num_bonds=[9309], num_residues=[437]),
#  PackedProtein(batch_size=1, num_atoms=[119], num_bonds=[2332], num_residues=[119]),
#  PackedProtein(batch_size=1, num_atoms=[1015], num_bonds=[22951], num_residues=[1015]),
#  PackedProtein(batch_size=1, num_atoms=[469], num_bonds=[11242], num_residues=[469]),
#  PackedProtein(batch_size=1, num_atoms=[145], num_bonds=[2856], num_residues=[145]),
#  PackedProtein(batch_size=1, num_atoms=[220], num_bonds=[4504], num_residues=[220]),
#  PackedProtein(batch_size=1, num_atoms=[99], num_bonds=[1896], num_residues=[99]),
#  PackedProtein(batch_size=1, num_atoms=[119], num_bonds=[2117], num_residues=[119]),
#  PackedProtein(batch_size=1, num_atoms=[998], num_bonds=[22276], num_residues=[998]),
#  PackedProtein(batch_size=1, num_atoms=[515], num_bonds=[11199], num_residues=[515]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[607], num_residues=[40]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 624], num_bonds=[19682, 11260], num_residues=[1022, 624]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 640], num_bonds=[19766, 11572], num_residues=[1022, 640]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 640], num_bonds=[19741, 11576], num_residues=[1022, 640]),
#  PackedProtein(batch_size=1, num_atoms=[458], num_bonds=[11064], num_residues=[458]),
#  PackedProtein(batch_size=1, num_atoms=[879], num_bonds=[19677], num_residues=[879]),
#  PackedProtein(batch_size=1, num_atoms=[258], num_bonds=[5013], num_residues=[258]),
#  PackedProtein(batch_size=1, num_atoms=[133], num_bonds=[2575], num_residues=[133]),
#  PackedProtein(batch_size=1, num_atoms=[405], num_bonds=[8267], num_residues=[405]),
#  PackedProtein(batch_size=1, num_atoms=[565], num_bonds=[11385], num_residues=[565]),
#  PackedProtein(batch_size=1, num_atoms=[562], num_bonds=[11359], num_residues=[562]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[2399], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[771], num_bonds=[18351], num_residues=[771]),
#  PackedProtein(batch_size=1, num_atoms=[914], num_bonds=[19238], num_residues=[914]),
#  PackedProtein(batch_size=1, num_atoms=[258], num_bonds=[5696], num_residues=[258]),
#  PackedProtein(batch_size=1, num_atoms=[208], num_bonds=[4081], num_residues=[208]),
#  PackedProtein(batch_size=1, num_atoms=[117], num_bonds=[2553], num_residues=[117]),
#  PackedProtein(batch_size=1, num_atoms=[581], num_bonds=[8111], num_residues=[581]),
#  PackedProtein(batch_size=1, num_atoms=[581], num_bonds=[8622], num_residues=[581]),
#  PackedProtein(batch_size=1, num_atoms=[210], num_bonds=[4073], num_residues=[210]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 67], num_bonds=[22048, 21720, 935], num_residues=[1022, 1022, 67]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 631], num_bonds=[22079, 12978], num_residues=[1022, 631]),
#  PackedProtein(batch_size=1, num_atoms=[338], num_bonds=[5943], num_residues=[338]),
#  PackedProtein(batch_size=4, num_atoms=[1022, 1022, 1022, 966], num_bonds=[16494, 16258, 15855, 15139], num_residues=[1022, 1022, 1022, 966]),
#  PackedProtein(batch_size=4, num_atoms=[1022, 1022, 1022, 966], num_bonds=[16386, 16154, 15751, 15046], num_residues=[1022, 1022, 1022, 966]),
#  PackedProtein(batch_size=1, num_atoms=[525], num_bonds=[10870], num_residues=[525]),
#  PackedProtein(batch_size=1, num_atoms=[182], num_bonds=[3226], num_residues=[182]),
#  PackedProtein(batch_size=1, num_atoms=[337], num_bonds=[6277], num_residues=[337]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[1048], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[121], num_bonds=[1942], num_residues=[121]),
#  PackedProtein(batch_size=1, num_atoms=[708], num_bonds=[15827], num_residues=[708]),
#  PackedProtein(batch_size=1, num_atoms=[218], num_bonds=[3969], num_residues=[218]),
#  PackedProtein(batch_size=1, num_atoms=[72], num_bonds=[869], num_residues=[72]),
#  PackedProtein(batch_size=1, num_atoms=[225], num_bonds=[4560], num_residues=[225]),
#  PackedProtein(batch_size=1, num_atoms=[222], num_bonds=[4558], num_residues=[222]),
#  PackedProtein(batch_size=1, num_atoms=[265], num_bonds=[4997], num_residues=[265]),
#  PackedProtein(batch_size=1, num_atoms=[87], num_bonds=[1261], num_residues=[87]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 546], num_bonds=[25501, 12488], num_residues=[1022, 546]),
#  PackedProtein(batch_size=1, num_atoms=[416], num_bonds=[7353], num_residues=[416]),
#  PackedProtein(batch_size=1, num_atoms=[976], num_bonds=[19527], num_residues=[976]),
#  PackedProtein(batch_size=5, num_atoms=[1022, 1022, 1022, 2044, 128], num_bonds=[21645, 21232, 20935, 42905, 1884], num_residues=[1022, 1022, 1022, 2044, 128]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 692], num_bonds=[19955, 19321, 13065], num_residues=[1022, 1022, 692]),
#  PackedProtein(batch_size=1, num_atoms=[357], num_bonds=[8043], num_residues=[357]),
#  PackedProtein(batch_size=1, num_atoms=[238], num_bonds=[5543], num_residues=[238]),
#  PackedProtein(batch_size=1, num_atoms=[993], num_bonds=[21257], num_residues=[993]),
#  PackedProtein(batch_size=1, num_atoms=[681], num_bonds=[12971], num_residues=[681]),
#  PackedProtein(batch_size=1, num_atoms=[124], num_bonds=[2467], num_residues=[124]),
#  PackedProtein(batch_size=1, num_atoms=[426], num_bonds=[9245], num_residues=[426]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 535], num_bonds=[25834, 12175], num_residues=[1022, 535]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5672], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[214], num_bonds=[4041], num_residues=[214]),
#  PackedProtein(batch_size=1, num_atoms=[506], num_bonds=[9195], num_residues=[506]),
#  PackedProtein(batch_size=1, num_atoms=[188], num_bonds=[3299], num_residues=[188]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[6208], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[240], num_bonds=[5569], num_residues=[240]),
#  PackedProtein(batch_size=1, num_atoms=[83], num_bonds=[1190], num_residues=[83]),
#  PackedProtein(batch_size=1, num_atoms=[684], num_bonds=[13536], num_residues=[684]),
#  PackedProtein(batch_size=5, num_atoms=[1022, 1022, 1022, 2044, 128], num_bonds=[21699, 21285, 20997, 43022, 1892], num_residues=[1022, 1022, 1022, 2044, 128]),
#  PackedProtein(batch_size=1, num_atoms=[145], num_bonds=[2875], num_residues=[145]),
#  PackedProtein(batch_size=1, num_atoms=[211], num_bonds=[4125], num_residues=[211]),
#  PackedProtein(batch_size=1, num_atoms=[327], num_bonds=[6244], num_residues=[327]),
#  PackedProtein(batch_size=1, num_atoms=[348], num_bonds=[7331], num_residues=[348]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5673], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[154], num_bonds=[3509], num_residues=[154]),
#  PackedProtein(batch_size=1, num_atoms=[900], num_bonds=[19582], num_residues=[900]),
#  PackedProtein(batch_size=1, num_atoms=[606], num_bonds=[12613], num_residues=[606]),
#  PackedProtein(batch_size=1, num_atoms=[386], num_bonds=[6616], num_residues=[386]),
#  PackedProtein(batch_size=1, num_atoms=[267], num_bonds=[5016], num_residues=[267]),
#  PackedProtein(batch_size=1, num_atoms=[498], num_bonds=[10351], num_residues=[498]),
#  PackedProtein(batch_size=1, num_atoms=[268], num_bonds=[5157], num_residues=[268]),
#  PackedProtein(batch_size=1, num_atoms=[998], num_bonds=[22272], num_residues=[998]),
#  PackedProtein(batch_size=1, num_atoms=[998], num_bonds=[22250], num_residues=[998]),
#  PackedProtein(batch_size=1, num_atoms=[111], num_bonds=[2217], num_residues=[111]),
#  PackedProtein(batch_size=1, num_atoms=[898], num_bonds=[22255], num_residues=[898]),
#  PackedProtein(batch_size=1, num_atoms=[637], num_bonds=[13473], num_residues=[637]),
#  PackedProtein(batch_size=1, num_atoms=[115], num_bonds=[2479], num_residues=[115]),
#  PackedProtein(batch_size=1, num_atoms=[1014], num_bonds=[22819], num_residues=[1014]),
#  PackedProtein(batch_size=1, num_atoms=[792], num_bonds=[16970], num_residues=[792]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 66], num_bonds=[21707, 728], num_residues=[1022, 66]),
#  PackedProtein(batch_size=1, num_atoms=[431], num_bonds=[8985], num_residues=[431]),
#  PackedProtein(batch_size=1, num_atoms=[230], num_bonds=[5611], num_residues=[230]),
#  PackedProtein(batch_size=1, num_atoms=[476], num_bonds=[9958], num_residues=[476]),
#  PackedProtein(batch_size=1, num_atoms=[285], num_bonds=[6045], num_residues=[285]),
#  PackedProtein(batch_size=1, num_atoms=[570], num_bonds=[12611], num_residues=[570]),
#  PackedProtein(batch_size=1, num_atoms=[560], num_bonds=[12587], num_residues=[560]),
#  PackedProtein(batch_size=1, num_atoms=[500], num_bonds=[11114], num_residues=[500]),
#  PackedProtein(batch_size=1, num_atoms=[130], num_bonds=[1957], num_residues=[130]),
#  PackedProtein(batch_size=1, num_atoms=[840], num_bonds=[21221], num_residues=[840]),
#  PackedProtein(batch_size=1, num_atoms=[88], num_bonds=[1091], num_residues=[88]),
#  PackedProtein(batch_size=1, num_atoms=[377], num_bonds=[7694], num_residues=[377]),
#  PackedProtein(batch_size=1, num_atoms=[660], num_bonds=[15388], num_residues=[660]),
#  PackedProtein(batch_size=4, num_atoms=[1022, 1022, 1022, 978], num_bonds=[22972, 22709, 22338, 21805], num_residues=[1022, 1022, 1022, 978]),
#  PackedProtein(batch_size=1, num_atoms=[104], num_bonds=[2064], num_residues=[104]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5699], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[578], num_bonds=[12002], num_residues=[578]),
#  PackedProtein(batch_size=1, num_atoms=[332], num_bonds=[5862], num_residues=[332]),
#  PackedProtein(batch_size=1, num_atoms=[183], num_bonds=[3431], num_residues=[183]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[1796], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[242], num_bonds=[4861], num_residues=[242]),
#  PackedProtein(batch_size=1, num_atoms=[670], num_bonds=[12224], num_residues=[670]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 622], num_bonds=[23081, 12864], num_residues=[1022, 622]),
#  PackedProtein(batch_size=1, num_atoms=[220], num_bonds=[4529], num_residues=[220]),
#  PackedProtein(batch_size=1, num_atoms=[219], num_bonds=[4950], num_residues=[219]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[2412], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[472], num_bonds=[9994], num_residues=[472]),
#  PackedProtein(batch_size=1, num_atoms=[546], num_bonds=[10455], num_residues=[546]),
#  PackedProtein(batch_size=1, num_atoms=[930], num_bonds=[19358], num_residues=[930]),
#  PackedProtein(batch_size=1, num_atoms=[369], num_bonds=[9076], num_residues=[369]),
#  PackedProtein(batch_size=1, num_atoms=[374], num_bonds=[7180], num_residues=[374]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5201], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[189], num_bonds=[3319], num_residues=[189]),
#  PackedProtein(batch_size=1, num_atoms=[328], num_bonds=[6737], num_residues=[328]),
#  PackedProtein(batch_size=1, num_atoms=[330], num_bonds=[5824], num_residues=[330]),
#  PackedProtein(batch_size=1, num_atoms=[188], num_bonds=[3319], num_residues=[188]),
#  PackedProtein(batch_size=1, num_atoms=[448], num_bonds=[8700], num_residues=[448]),
#  PackedProtein(batch_size=4, num_atoms=[1022, 1022, 1022, 102], num_bonds=[20558, 19178, 19439, 1088], num_residues=[1022, 1022, 1022, 102]),
#  PackedProtein(batch_size=1, num_atoms=[138], num_bonds=[2856], num_residues=[138]),
#  PackedProtein(batch_size=1, num_atoms=[209], num_bonds=[4087], num_residues=[209]),
#  PackedProtein(batch_size=1, num_atoms=[485], num_bonds=[9871], num_residues=[485]),
#  PackedProtein(batch_size=1, num_atoms=[713], num_bonds=[15735], num_residues=[713]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5261], num_residues=[256]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 636], num_bonds=[20061, 11610], num_residues=[1022, 636]),
#  PackedProtein(batch_size=1, num_atoms=[566], num_bonds=[11473], num_residues=[566]),
#  PackedProtein(batch_size=1, num_atoms=[674], num_bonds=[15042], num_residues=[674]),
#  PackedProtein(batch_size=1, num_atoms=[284], num_bonds=[5903], num_residues=[284]),
#  PackedProtein(batch_size=1, num_atoms=[495], num_bonds=[10487], num_residues=[495]),
#  PackedProtein(batch_size=1, num_atoms=[275], num_bonds=[6113], num_residues=[275]),
#  PackedProtein(batch_size=1, num_atoms=[672], num_bonds=[14332], num_residues=[672]),
#  PackedProtein(batch_size=1, num_atoms=[462], num_bonds=[8914], num_residues=[462]),
#  PackedProtein(batch_size=1, num_atoms=[542], num_bonds=[11146], num_residues=[542]),
#  PackedProtein(batch_size=1, num_atoms=[1016], num_bonds=[23071], num_residues=[1016]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 598], num_bonds=[19547, 10743], num_residues=[1022, 598]),
#  PackedProtein(batch_size=1, num_atoms=[829], num_bonds=[19365], num_residues=[829]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5661], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[337], num_bonds=[6403], num_residues=[337]),
#  PackedProtein(batch_size=1, num_atoms=[268], num_bonds=[5191], num_residues=[268]),
#  PackedProtein(batch_size=1, num_atoms=[559], num_bonds=[12294], num_residues=[559]),
#  PackedProtein(batch_size=1, num_atoms=[325], num_bonds=[6257], num_residues=[325]),
#  PackedProtein(batch_size=1, num_atoms=[244], num_bonds=[5598], num_residues=[244]),
#  PackedProtein(batch_size=1, num_atoms=[692], num_bonds=[13451], num_residues=[692]),
#  PackedProtein(batch_size=1, num_atoms=[184], num_bonds=[3803], num_residues=[184]),
#  PackedProtein(batch_size=1, num_atoms=[240], num_bonds=[5588], num_residues=[240]),
#  PackedProtein(batch_size=1, num_atoms=[331], num_bonds=[7401], num_residues=[331]),
#  PackedProtein(batch_size=1, num_atoms=[138], num_bonds=[2897], num_residues=[138]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[17209], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[107], num_bonds=[2145], num_residues=[107]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[607], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[515], num_bonds=[10889], num_residues=[515]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2025], num_residues=[106]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 66], num_bonds=[21723, 731], num_residues=[1022, 66]),
#  PackedProtein(batch_size=1, num_atoms=[490], num_bonds=[10437], num_residues=[490]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 72], num_bonds=[20482, 969], num_residues=[1022, 72]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 72], num_bonds=[20495, 962], num_residues=[1022, 72]),
#  PackedProtein(batch_size=1, num_atoms=[807], num_bonds=[20536], num_residues=[807]),
#  PackedProtein(batch_size=1, num_atoms=[807], num_bonds=[20580], num_residues=[807]),
#  ...]

# %%
len(list1)
# Out:
# 5000

# %%
drug_pkl = '../../../data/dta-datasets/PDBbind/esm/protein_5000.pkl'
with utils.smart_open(drug_pkl, "wb") as fout:
    pickle.dump(list1, fout)

# %% [markdown]
# ***

# %% [markdown]
# #### ESM for each Protein

# %%
import pickle
import torch
from tqdm import tqdm
from torchdrug import utils, transforms, data, models, layers

# %%
protein_pkl = '../../../data/dta-datasets/PDBbind/esm/protein_5000.pkl'
with utils.smart_open(protein_pkl, "rb") as fin:
    protein_within_1022_list = pickle.load(fin)

# %%
sequence_model = models.ESM(path="../../../result/model_pth/ESM/", model="ESM-2_650M")

# %%
def esmProcess(esmModel, curProtein, pklName):
    """
    curProtein: list of packedProtein 
    pklName: the pkl name to store the protein
    """
    output = esmModel(curProtein, curProtein.residue_feature)
    curProtein.residue_feature = output['residue_feature']
    curProtein.mol_feature = output['graph_feature']
    protein_pkl = '../../../data/dta-datasets/PDBbind/esm/gearnetesm_' + pklName + '.pkl'
    with utils.smart_open(protein_pkl, "wb") as fout:
        pickle.dump(curProtein, fout)

# %%
protein_within_1022_list
# Out:
# [PackedProtein(batch_size=2, num_atoms=[1022, 139], num_bonds=[20059, 2123], num_residues=[1022, 139]),
#  PackedProtein(batch_size=1, num_atoms=[501], num_bonds=[9852], num_residues=[501]),
#  PackedProtein(batch_size=1, num_atoms=[165], num_bonds=[3709], num_residues=[165]),
#  PackedProtein(batch_size=1, num_atoms=[852], num_bonds=[19860], num_residues=[852]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5615], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[611], num_bonds=[14390], num_residues=[611]),
#  PackedProtein(batch_size=1, num_atoms=[939], num_bonds=[20431], num_residues=[939]),
#  PackedProtein(batch_size=1, num_atoms=[295], num_bonds=[6629], num_residues=[295]),
#  PackedProtein(batch_size=1, num_atoms=[296], num_bonds=[6538], num_residues=[296]),
#  PackedProtein(batch_size=1, num_atoms=[1017], num_bonds=[23912], num_residues=[1017]),
#  PackedProtein(batch_size=1, num_atoms=[364], num_bonds=[7158], num_residues=[364]),
#  PackedProtein(batch_size=1, num_atoms=[430], num_bonds=[7629], num_residues=[430]),
#  PackedProtein(batch_size=1, num_atoms=[244], num_bonds=[4891], num_residues=[244]),
#  PackedProtein(batch_size=1, num_atoms=[244], num_bonds=[4882], num_residues=[244]),
#  PackedProtein(batch_size=1, num_atoms=[509], num_bonds=[10824], num_residues=[509]),
#  PackedProtein(batch_size=1, num_atoms=[652], num_bonds=[12512], num_residues=[652]),
#  PackedProtein(batch_size=1, num_atoms=[165], num_bonds=[3233], num_residues=[165]),
#  PackedProtein(batch_size=1, num_atoms=[301], num_bonds=[5884], num_residues=[301]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 56], num_bonds=[22306, 485], num_residues=[1022, 56]),
#  PackedProtein(batch_size=1, num_atoms=[557], num_bonds=[12134], num_residues=[557]),
#  PackedProtein(batch_size=1, num_atoms=[939], num_bonds=[21263], num_residues=[939]),
#  PackedProtein(batch_size=1, num_atoms=[942], num_bonds=[21516], num_residues=[942]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 355], num_bonds=[20706, 6505], num_residues=[1022, 355]),
#  PackedProtein(batch_size=1, num_atoms=[721], num_bonds=[15357], num_residues=[721]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 220], num_bonds=[24553, 4581], num_residues=[1022, 220]),
#  PackedProtein(batch_size=1, num_atoms=[504], num_bonds=[10392], num_residues=[504]),
#  PackedProtein(batch_size=1, num_atoms=[608], num_bonds=[13321], num_residues=[608]),
#  PackedProtein(batch_size=1, num_atoms=[439], num_bonds=[8580], num_residues=[439]),
#  PackedProtein(batch_size=1, num_atoms=[172], num_bonds=[3833], num_residues=[172]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5238], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5196], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5185], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[865], num_bonds=[19609], num_residues=[865]),
#  PackedProtein(batch_size=1, num_atoms=[458], num_bonds=[10504], num_residues=[458]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 176], num_bonds=[21607, 20240, 3035], num_residues=[1022, 1022, 176]),
#  PackedProtein(batch_size=1, num_atoms=[960], num_bonds=[22017], num_residues=[960]),
#  PackedProtein(batch_size=1, num_atoms=[988], num_bonds=[21779], num_residues=[988]),
#  PackedProtein(batch_size=1, num_atoms=[105], num_bonds=[2024], num_residues=[105]),
#  PackedProtein(batch_size=1, num_atoms=[105], num_bonds=[2004], num_residues=[105]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2036], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7704], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[471], num_bonds=[10850], num_residues=[471]),
#  PackedProtein(batch_size=1, num_atoms=[656], num_bonds=[14002], num_residues=[656]),
#  PackedProtein(batch_size=1, num_atoms=[429], num_bonds=[7472], num_residues=[429]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5254], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[301], num_bonds=[6024], num_residues=[301]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5225], num_residues=[224]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 451], num_bonds=[21283, 8474], num_residues=[1022, 451]),
#  PackedProtein(batch_size=1, num_atoms=[559], num_bonds=[12131], num_residues=[559]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 56], num_bonds=[22301, 486], num_residues=[1022, 56]),
#  PackedProtein(batch_size=1, num_atoms=[346], num_bonds=[7484], num_residues=[346]),
#  PackedProtein(batch_size=1, num_atoms=[525], num_bonds=[11486], num_residues=[525]),
#  PackedProtein(batch_size=1, num_atoms=[744], num_bonds=[15577], num_residues=[744]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 3], num_bonds=[23730, 9], num_residues=[1022, 3]),
#  PackedProtein(batch_size=1, num_atoms=[498], num_bonds=[10377], num_residues=[498]),
#  PackedProtein(batch_size=1, num_atoms=[894], num_bonds=[19858], num_residues=[894]),
#  PackedProtein(batch_size=1, num_atoms=[346], num_bonds=[7499], num_residues=[346]),
#  PackedProtein(batch_size=1, num_atoms=[390], num_bonds=[8464], num_residues=[390]),
#  PackedProtein(batch_size=1, num_atoms=[244], num_bonds=[4862], num_residues=[244]),
#  PackedProtein(batch_size=1, num_atoms=[165], num_bonds=[3720], num_residues=[165]),
#  PackedProtein(batch_size=1, num_atoms=[392], num_bonds=[8391], num_residues=[392]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5642], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[922], num_bonds=[19254], num_residues=[922]),
#  PackedProtein(batch_size=1, num_atoms=[454], num_bonds=[9521], num_residues=[454]),
#  PackedProtein(batch_size=1, num_atoms=[414], num_bonds=[9383], num_residues=[414]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 487], num_bonds=[21383, 9768], num_residues=[1022, 487]),
#  PackedProtein(batch_size=1, num_atoms=[445], num_bonds=[9391], num_residues=[445]),
#  PackedProtein(batch_size=1, num_atoms=[130], num_bonds=[1956], num_residues=[130]),
#  PackedProtein(batch_size=1, num_atoms=[758], num_bonds=[16676], num_residues=[758]),
#  PackedProtein(batch_size=1, num_atoms=[282], num_bonds=[4946], num_residues=[282]),
#  PackedProtein(batch_size=1, num_atoms=[430], num_bonds=[9258], num_residues=[430]),
#  PackedProtein(batch_size=1, num_atoms=[545], num_bonds=[11075], num_residues=[545]),
#  PackedProtein(batch_size=1, num_atoms=[317], num_bonds=[6706], num_residues=[317]),
#  PackedProtein(batch_size=1, num_atoms=[324], num_bonds=[6789], num_residues=[324]),
#  PackedProtein(batch_size=1, num_atoms=[388], num_bonds=[8612], num_residues=[388]),
#  PackedProtein(batch_size=1, num_atoms=[352], num_bonds=[7536], num_residues=[352]),
#  PackedProtein(batch_size=1, num_atoms=[465], num_bonds=[10595], num_residues=[465]),
#  PackedProtein(batch_size=1, num_atoms=[138], num_bonds=[3183], num_residues=[138]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 276], num_bonds=[20691, 5187], num_residues=[1022, 276]),
#  PackedProtein(batch_size=1, num_atoms=[276], num_bonds=[5675], num_residues=[276]),
#  PackedProtein(batch_size=1, num_atoms=[497], num_bonds=[10833], num_residues=[497]),
#  PackedProtein(batch_size=1, num_atoms=[130], num_bonds=[1971], num_residues=[130]),
#  PackedProtein(batch_size=1, num_atoms=[301], num_bonds=[5901], num_residues=[301]),
#  PackedProtein(batch_size=1, num_atoms=[153], num_bonds=[3437], num_residues=[153]),
#  PackedProtein(batch_size=1, num_atoms=[591], num_bonds=[13204], num_residues=[591]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 427], num_bonds=[20933, 7624], num_residues=[1022, 427]),
#  PackedProtein(batch_size=4, num_atoms=[1022, 1022, 1022, 966], num_bonds=[16489, 16256, 15858, 15146], num_residues=[1022, 1022, 1022, 966]),
#  PackedProtein(batch_size=1, num_atoms=[155], num_bonds=[3492], num_residues=[155]),
#  PackedProtein(batch_size=1, num_atoms=[318], num_bonds=[7257], num_residues=[318]),
#  PackedProtein(batch_size=1, num_atoms=[278], num_bonds=[5320], num_residues=[278]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5268], num_residues=[224]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 241], num_bonds=[24785, 5132], num_residues=[1022, 241]),
#  PackedProtein(batch_size=1, num_atoms=[448], num_bonds=[10673], num_residues=[448]),
#  PackedProtein(batch_size=1, num_atoms=[307], num_bonds=[6055], num_residues=[307]),
#  PackedProtein(batch_size=1, num_atoms=[271], num_bonds=[5282], num_residues=[271]),
#  PackedProtein(batch_size=1, num_atoms=[578], num_bonds=[11060], num_residues=[578]),
#  PackedProtein(batch_size=1, num_atoms=[299], num_bonds=[5715], num_residues=[299]),
#  PackedProtein(batch_size=1, num_atoms=[515], num_bonds=[11096], num_residues=[515]),
#  PackedProtein(batch_size=1, num_atoms=[239], num_bonds=[5574], num_residues=[239]),
#  PackedProtein(batch_size=1, num_atoms=[635], num_bonds=[13094], num_residues=[635]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5240], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[16375], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[305], num_bonds=[6917], num_residues=[305]),
#  PackedProtein(batch_size=1, num_atoms=[275], num_bonds=[5908], num_residues=[275]),
#  PackedProtein(batch_size=1, num_atoms=[150], num_bonds=[3179], num_residues=[150]),
#  PackedProtein(batch_size=1, num_atoms=[278], num_bonds=[6049], num_residues=[278]),
#  PackedProtein(batch_size=1, num_atoms=[515], num_bonds=[11046], num_residues=[515]),
#  PackedProtein(batch_size=1, num_atoms=[514], num_bonds=[10911], num_residues=[514]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 451], num_bonds=[21214, 8441], num_residues=[1022, 451]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 56], num_bonds=[22368, 21992, 608], num_residues=[1022, 1022, 56]),
#  PackedProtein(batch_size=1, num_atoms=[847], num_bonds=[19548], num_residues=[847]),
#  PackedProtein(batch_size=1, num_atoms=[150], num_bonds=[3185], num_residues=[150]),
#  PackedProtein(batch_size=1, num_atoms=[534], num_bonds=[10462], num_residues=[534]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5234], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[445], num_bonds=[10385], num_residues=[445]),
#  PackedProtein(batch_size=1, num_atoms=[463], num_bonds=[8970], num_residues=[463]),
#  PackedProtein(batch_size=1, num_atoms=[493], num_bonds=[10290], num_residues=[493]),
#  PackedProtein(batch_size=1, num_atoms=[487], num_bonds=[8868], num_residues=[487]),
#  PackedProtein(batch_size=1, num_atoms=[487], num_bonds=[8972], num_residues=[487]),
#  PackedProtein(batch_size=4, num_atoms=[1022, 1022, 1022, 978], num_bonds=[22923, 22684, 22277, 21732], num_residues=[1022, 1022, 1022, 978]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5217], num_residues=[224]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 534], num_bonds=[25652, 12122], num_residues=[1022, 534]),
#  PackedProtein(batch_size=1, num_atoms=[163], num_bonds=[3355], num_residues=[163]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7739], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[212], num_bonds=[4295], num_residues=[212]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 580], num_bonds=[21636, 11561], num_residues=[1022, 580]),
#  PackedProtein(batch_size=1, num_atoms=[263], num_bonds=[5652], num_residues=[263]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 554], num_bonds=[22032, 20670, 11194], num_residues=[1022, 1022, 554]),
#  PackedProtein(batch_size=1, num_atoms=[894], num_bonds=[19645], num_residues=[894]),
#  PackedProtein(batch_size=1, num_atoms=[325], num_bonds=[6502], num_residues=[325]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5193], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[355], num_bonds=[7653], num_residues=[355]),
#  PackedProtein(batch_size=1, num_atoms=[130], num_bonds=[1965], num_residues=[130]),
#  PackedProtein(batch_size=1, num_atoms=[130], num_bonds=[1960], num_residues=[130]),
#  PackedProtein(batch_size=1, num_atoms=[426], num_bonds=[7798], num_residues=[426]),
#  PackedProtein(batch_size=1, num_atoms=[330], num_bonds=[7453], num_residues=[330]),
#  PackedProtein(batch_size=1, num_atoms=[140], num_bonds=[2124], num_residues=[140]),
#  PackedProtein(batch_size=1, num_atoms=[164], num_bonds=[3697], num_residues=[164]),
#  PackedProtein(batch_size=1, num_atoms=[544], num_bonds=[11034], num_residues=[544]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5207], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[390], num_bonds=[8491], num_residues=[390]),
#  PackedProtein(batch_size=1, num_atoms=[363], num_bonds=[6633], num_residues=[363]),
#  PackedProtein(batch_size=1, num_atoms=[497], num_bonds=[10793], num_residues=[497]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5686], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[544], num_bonds=[11081], num_residues=[544]),
#  PackedProtein(batch_size=1, num_atoms=[306], num_bonds=[6908], num_residues=[306]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5190], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[278], num_bonds=[6057], num_residues=[278]),
#  PackedProtein(batch_size=1, num_atoms=[210], num_bonds=[4258], num_residues=[210]),
#  PackedProtein(batch_size=1, num_atoms=[425], num_bonds=[7768], num_residues=[425]),
#  PackedProtein(batch_size=1, num_atoms=[272], num_bonds=[5330], num_residues=[272]),
#  PackedProtein(batch_size=1, num_atoms=[338], num_bonds=[7589], num_residues=[338]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5269], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[555], num_bonds=[13548], num_residues=[555]),
#  PackedProtein(batch_size=1, num_atoms=[698], num_bonds=[14885], num_residues=[698]),
#  PackedProtein(batch_size=1, num_atoms=[208], num_bonds=[4100], num_residues=[208]),
#  PackedProtein(batch_size=1, num_atoms=[341], num_bonds=[8495], num_residues=[341]),
#  PackedProtein(batch_size=1, num_atoms=[651], num_bonds=[11665], num_residues=[651]),
#  PackedProtein(batch_size=1, num_atoms=[260], num_bonds=[4927], num_residues=[260]),
#  PackedProtein(batch_size=1, num_atoms=[628], num_bonds=[13508], num_residues=[628]),
#  PackedProtein(batch_size=1, num_atoms=[528], num_bonds=[10124], num_residues=[528]),
#  PackedProtein(batch_size=1, num_atoms=[1014], num_bonds=[22741], num_residues=[1014]),
#  PackedProtein(batch_size=1, num_atoms=[794], num_bonds=[18090], num_residues=[794]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7646], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[164], num_bonds=[3717], num_residues=[164]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 594], num_bonds=[19658, 10674], num_residues=[1022, 594]),
#  PackedProtein(batch_size=1, num_atoms=[488], num_bonds=[9013], num_residues=[488]),
#  PackedProtein(batch_size=1, num_atoms=[740], num_bonds=[15265], num_residues=[740]),
#  PackedProtein(batch_size=1, num_atoms=[437], num_bonds=[9294], num_residues=[437]),
#  PackedProtein(batch_size=1, num_atoms=[438], num_bonds=[9309], num_residues=[438]),
#  PackedProtein(batch_size=1, num_atoms=[550], num_bonds=[12808], num_residues=[550]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5283], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[334], num_bonds=[7639], num_residues=[334]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5671], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[346], num_bonds=[7446], num_residues=[346]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[830], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[875], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[164], num_bonds=[3707], num_residues=[164]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[16402], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[498], num_bonds=[10385], num_residues=[498]),
#  PackedProtein(batch_size=1, num_atoms=[109], num_bonds=[1627], num_residues=[109]),
#  PackedProtein(batch_size=1, num_atoms=[457], num_bonds=[8636], num_residues=[457]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7627], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[330], num_bonds=[7444], num_residues=[330]),
#  PackedProtein(batch_size=1, num_atoms=[437], num_bonds=[8417], num_residues=[437]),
#  PackedProtein(batch_size=1, num_atoms=[1010], num_bonds=[24408], num_residues=[1010]),
#  PackedProtein(batch_size=1, num_atoms=[328], num_bonds=[6541], num_residues=[328]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 596], num_bonds=[19436, 10597], num_residues=[1022, 596]),
#  PackedProtein(batch_size=1, num_atoms=[496], num_bonds=[11870], num_residues=[496]),
#  PackedProtein(batch_size=1, num_atoms=[306], num_bonds=[5851], num_residues=[306]),
#  PackedProtein(batch_size=1, num_atoms=[301], num_bonds=[5749], num_residues=[301]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 3], num_bonds=[23939, 9], num_residues=[1022, 3]),
#  PackedProtein(batch_size=1, num_atoms=[341], num_bonds=[6758], num_residues=[341]),
#  PackedProtein(batch_size=1, num_atoms=[150], num_bonds=[3184], num_residues=[150]),
#  PackedProtein(batch_size=1, num_atoms=[390], num_bonds=[8467], num_residues=[390]),
#  PackedProtein(batch_size=1, num_atoms=[993], num_bonds=[21393], num_residues=[993]),
#  PackedProtein(batch_size=1, num_atoms=[312], num_bonds=[7053], num_residues=[312]),
#  PackedProtein(batch_size=1, num_atoms=[336], num_bonds=[6296], num_residues=[336]),
#  PackedProtein(batch_size=1, num_atoms=[208], num_bonds=[3895], num_residues=[208]),
#  PackedProtein(batch_size=1, num_atoms=[147], num_bonds=[2705], num_residues=[147]),
#  PackedProtein(batch_size=1, num_atoms=[504], num_bonds=[9815], num_residues=[504]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 702], num_bonds=[21616, 13708], num_residues=[1022, 702]),
#  PackedProtein(batch_size=1, num_atoms=[326], num_bonds=[6630], num_residues=[326]),
#  PackedProtein(batch_size=1, num_atoms=[353], num_bonds=[6143], num_residues=[353]),
#  PackedProtein(batch_size=1, num_atoms=[619], num_bonds=[11376], num_residues=[619]),
#  PackedProtein(batch_size=1, num_atoms=[616], num_bonds=[11344], num_residues=[616]),
#  PackedProtein(batch_size=1, num_atoms=[767], num_bonds=[18259], num_residues=[767]),
#  PackedProtein(batch_size=1, num_atoms=[678], num_bonds=[17155], num_residues=[678]),
#  PackedProtein(batch_size=1, num_atoms=[127], num_bonds=[2042], num_residues=[127]),
#  PackedProtein(batch_size=1, num_atoms=[381], num_bonds=[7235], num_residues=[381]),
#  PackedProtein(batch_size=1, num_atoms=[764], num_bonds=[16267], num_residues=[764]),
#  PackedProtein(batch_size=1, num_atoms=[172], num_bonds=[3927], num_residues=[172]),
#  PackedProtein(batch_size=1, num_atoms=[275], num_bonds=[5284], num_residues=[275]),
#  PackedProtein(batch_size=4, num_atoms=[1022, 1022, 1022, 978], num_bonds=[23046, 22748, 22410, 21834], num_residues=[1022, 1022, 1022, 978]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[16314], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[461], num_bonds=[9722], num_residues=[461]),
#  PackedProtein(batch_size=1, num_atoms=[156], num_bonds=[2909], num_residues=[156]),
#  PackedProtein(batch_size=1, num_atoms=[320], num_bonds=[7269], num_residues=[320]),
#  PackedProtein(batch_size=1, num_atoms=[390], num_bonds=[8481], num_residues=[390]),
#  PackedProtein(batch_size=1, num_atoms=[688], num_bonds=[15437], num_residues=[688]),
#  PackedProtein(batch_size=1, num_atoms=[898], num_bonds=[22290], num_residues=[898]),
#  PackedProtein(batch_size=1, num_atoms=[283], num_bonds=[5459], num_residues=[283]),
#  PackedProtein(batch_size=1, num_atoms=[334], num_bonds=[6229], num_residues=[334]),
#  PackedProtein(batch_size=1, num_atoms=[150], num_bonds=[3179], num_residues=[150]),
#  PackedProtein(batch_size=1, num_atoms=[418], num_bonds=[8991], num_residues=[418]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 487], num_bonds=[21406, 9762], num_residues=[1022, 487]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5282], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[306], num_bonds=[5782], num_residues=[306]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 338], num_bonds=[21555, 18726, 5131], num_residues=[1022, 1022, 338]),
#  PackedProtein(batch_size=1, num_atoms=[1014], num_bonds=[22689], num_residues=[1014]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 58], num_bonds=[22364, 21980, 626], num_residues=[1022, 1022, 58]),
#  PackedProtein(batch_size=1, num_atoms=[607], num_bonds=[12628], num_residues=[607]),
#  PackedProtein(batch_size=1, num_atoms=[232], num_bonds=[4964], num_residues=[232]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[16329], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[570], num_bonds=[11535], num_residues=[570]),
#  PackedProtein(batch_size=1, num_atoms=[337], num_bonds=[6369], num_residues=[337]),
#  PackedProtein(batch_size=1, num_atoms=[258], num_bonds=[5687], num_residues=[258]),
#  PackedProtein(batch_size=1, num_atoms=[288], num_bonds=[5506], num_residues=[288]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 534], num_bonds=[25099, 11852], num_residues=[1022, 534]),
#  PackedProtein(batch_size=1, num_atoms=[692], num_bonds=[15310], num_residues=[692]),
#  PackedProtein(batch_size=1, num_atoms=[692], num_bonds=[15111], num_residues=[692]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2033], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[551], num_bonds=[12795], num_residues=[551]),
#  PackedProtein(batch_size=1, num_atoms=[497], num_bonds=[10461], num_residues=[497]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[16307], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[357], num_bonds=[7665], num_residues=[357]),
#  PackedProtein(batch_size=1, num_atoms=[274], num_bonds=[5352], num_residues=[274]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 846], num_bonds=[21386, 17715], num_residues=[1022, 846]),
#  PackedProtein(batch_size=4, num_atoms=[1022, 1022, 1022, 978], num_bonds=[22991, 22715, 22319, 21766], num_residues=[1022, 1022, 1022, 978]),
#  PackedProtein(batch_size=1, num_atoms=[303], num_bonds=[6514], num_residues=[303]),
#  PackedProtein(batch_size=1, num_atoms=[246], num_bonds=[5656], num_residues=[246]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 554], num_bonds=[22210, 20758, 11263], num_residues=[1022, 1022, 554]),
#  PackedProtein(batch_size=1, num_atoms=[892], num_bonds=[19516], num_residues=[892]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 265], num_bonds=[21116, 4266], num_residues=[1022, 265]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5640], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[147], num_bonds=[2697], num_residues=[147]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5706], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[254], num_bonds=[5545], num_residues=[254]),
#  PackedProtein(batch_size=1, num_atoms=[178], num_bonds=[3268], num_residues=[178]),
#  PackedProtein(batch_size=1, num_atoms=[124], num_bonds=[1799], num_residues=[124]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[1795], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[1789], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[252], num_bonds=[4265], num_residues=[252]),
#  PackedProtein(batch_size=1, num_atoms=[210], num_bonds=[4225], num_residues=[210]),
#  PackedProtein(batch_size=1, num_atoms=[332], num_bonds=[6638], num_residues=[332]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 702], num_bonds=[21189, 13392], num_residues=[1022, 702]),
#  PackedProtein(batch_size=1, num_atoms=[179], num_bonds=[3255], num_residues=[179]),
#  PackedProtein(batch_size=1, num_atoms=[961], num_bonds=[22219], num_residues=[961]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 56], num_bonds=[22371, 21995, 607], num_residues=[1022, 1022, 56]),
#  PackedProtein(batch_size=1, num_atoms=[197], num_bonds=[4021], num_residues=[197]),
#  PackedProtein(batch_size=1, num_atoms=[124], num_bonds=[2479], num_residues=[124]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 644], num_bonds=[22970, 12852], num_residues=[1022, 644]),
#  PackedProtein(batch_size=1, num_atoms=[525], num_bonds=[11515], num_residues=[525]),
#  PackedProtein(batch_size=1, num_atoms=[307], num_bonds=[6787], num_residues=[307]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7689], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[728], num_bonds=[16175], num_residues=[728]),
#  PackedProtein(batch_size=1, num_atoms=[330], num_bonds=[7461], num_residues=[330]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2030], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[262], num_bonds=[5642], num_residues=[262]),
#  PackedProtein(batch_size=1, num_atoms=[678], num_bonds=[17123], num_residues=[678]),
#  PackedProtein(batch_size=4, num_atoms=[1022, 1022, 1022, 994], num_bonds=[22871, 22901, 22644, 22213], num_residues=[1022, 1022, 1022, 994]),
#  PackedProtein(batch_size=1, num_atoms=[138], num_bonds=[2891], num_residues=[138]),
#  PackedProtein(batch_size=1, num_atoms=[105], num_bonds=[2052], num_residues=[105]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 56], num_bonds=[23569, 22904, 650], num_residues=[1022, 1022, 56]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 292], num_bonds=[22180, 5561], num_residues=[1022, 292]),
#  PackedProtein(batch_size=1, num_atoms=[263], num_bonds=[5666], num_residues=[263]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 130], num_bonds=[21024, 2022], num_residues=[1022, 130]),
#  PackedProtein(batch_size=1, num_atoms=[283], num_bonds=[5528], num_residues=[283]),
#  PackedProtein(batch_size=1, num_atoms=[644], num_bonds=[14934], num_residues=[644]),
#  PackedProtein(batch_size=1, num_atoms=[544], num_bonds=[11060], num_residues=[544]),
#  PackedProtein(batch_size=1, num_atoms=[208], num_bonds=[4048], num_residues=[208]),
#  PackedProtein(batch_size=1, num_atoms=[124], num_bonds=[2463], num_residues=[124]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 596], num_bonds=[19477, 10617], num_residues=[1022, 596]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 554], num_bonds=[22119, 20685, 11232], num_residues=[1022, 1022, 554]),
#  PackedProtein(batch_size=1, num_atoms=[262], num_bonds=[5745], num_residues=[262]),
#  PackedProtein(batch_size=1, num_atoms=[426], num_bonds=[7856], num_residues=[426]),
#  PackedProtein(batch_size=1, num_atoms=[329], num_bonds=[7450], num_residues=[329]),
#  PackedProtein(batch_size=1, num_atoms=[389], num_bonds=[8814], num_residues=[389]),
#  PackedProtein(batch_size=1, num_atoms=[105], num_bonds=[2002], num_residues=[105]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 466], num_bonds=[18749, 8438], num_residues=[1022, 466]),
#  PackedProtein(batch_size=1, num_atoms=[426], num_bonds=[7770], num_residues=[426]),
#  PackedProtein(batch_size=1, num_atoms=[528], num_bonds=[10174], num_residues=[528]),
#  PackedProtein(batch_size=1, num_atoms=[426], num_bonds=[7837], num_residues=[426]),
#  PackedProtein(batch_size=1, num_atoms=[265], num_bonds=[4951], num_residues=[265]),
#  PackedProtein(batch_size=1, num_atoms=[238], num_bonds=[4843], num_residues=[238]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2056], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[338], num_bonds=[6790], num_residues=[338]),
#  PackedProtein(batch_size=1, num_atoms=[942], num_bonds=[21137], num_residues=[942]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 10], num_bonds=[22648, 73], num_residues=[1022, 10]),
#  PackedProtein(batch_size=1, num_atoms=[274], num_bonds=[5365], num_residues=[274]),
#  PackedProtein(batch_size=1, num_atoms=[866], num_bonds=[17906], num_residues=[866]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 602], num_bonds=[19535, 10798], num_residues=[1022, 602]),
#  PackedProtein(batch_size=1, num_atoms=[942], num_bonds=[21301], num_residues=[942]),
#  PackedProtein(batch_size=1, num_atoms=[414], num_bonds=[9374], num_residues=[414]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[1113], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2001], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[536], num_bonds=[12966], num_residues=[536]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 598], num_bonds=[19539, 10704], num_residues=[1022, 598]),
#  PackedProtein(batch_size=1, num_atoms=[304], num_bonds=[5800], num_residues=[304]),
#  PackedProtein(batch_size=1, num_atoms=[564], num_bonds=[11341], num_residues=[564]),
#  PackedProtein(batch_size=1, num_atoms=[335], num_bonds=[6275], num_residues=[335]),
#  PackedProtein(batch_size=1, num_atoms=[307], num_bonds=[6914], num_residues=[307]),
#  PackedProtein(batch_size=1, num_atoms=[492], num_bonds=[9549], num_residues=[492]),
#  PackedProtein(batch_size=1, num_atoms=[792], num_bonds=[17054], num_residues=[792]),
#  PackedProtein(batch_size=1, num_atoms=[223], num_bonds=[5204], num_residues=[223]),
#  PackedProtein(batch_size=1, num_atoms=[497], num_bonds=[11163], num_residues=[497]),
#  PackedProtein(batch_size=1, num_atoms=[98], num_bonds=[1788], num_residues=[98]),
#  PackedProtein(batch_size=1, num_atoms=[330], num_bonds=[7467], num_residues=[330]),
#  PackedProtein(batch_size=1, num_atoms=[344], num_bonds=[7208], num_residues=[344]),
#  PackedProtein(batch_size=1, num_atoms=[371], num_bonds=[8130], num_residues=[371]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[886], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[152], num_bonds=[2661], num_residues=[152]),
#  PackedProtein(batch_size=1, num_atoms=[426], num_bonds=[7957], num_residues=[426]),
#  PackedProtein(batch_size=1, num_atoms=[329], num_bonds=[7452], num_residues=[329]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5230], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5163], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5147], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5170], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2027], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[554], num_bonds=[11085], num_residues=[554]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 598], num_bonds=[19734, 10816], num_residues=[1022, 598]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7659], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[245], num_bonds=[4390], num_residues=[245]),
#  PackedProtein(batch_size=1, num_atoms=[764], num_bonds=[16223], num_residues=[764]),
#  PackedProtein(batch_size=1, num_atoms=[262], num_bonds=[5646], num_residues=[262]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5200], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[438], num_bonds=[9381], num_residues=[438]),
#  PackedProtein(batch_size=1, num_atoms=[593], num_bonds=[13695], num_residues=[593]),
#  PackedProtein(batch_size=1, num_atoms=[492], num_bonds=[10300], num_residues=[492]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 631], num_bonds=[22023, 12968], num_residues=[1022, 631]),
#  PackedProtein(batch_size=1, num_atoms=[496], num_bonds=[10587], num_residues=[496]),
#  PackedProtein(batch_size=1, num_atoms=[854], num_bonds=[20697], num_residues=[854]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7681], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[939], num_bonds=[21212], num_residues=[939]),
#  PackedProtein(batch_size=4, num_atoms=[1022, 1022, 1022, 994], num_bonds=[23002, 22966, 22715, 22340], num_residues=[1022, 1022, 1022, 994]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5664], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[147], num_bonds=[2707], num_residues=[147]),
#  PackedProtein(batch_size=1, num_atoms=[621], num_bonds=[11415], num_residues=[621]),
#  PackedProtein(batch_size=1, num_atoms=[156], num_bonds=[2902], num_residues=[156]),
#  PackedProtein(batch_size=1, num_atoms=[156], num_bonds=[2904], num_residues=[156]),
#  PackedProtein(batch_size=1, num_atoms=[430], num_bonds=[7572], num_residues=[430]),
#  PackedProtein(batch_size=1, num_atoms=[542], num_bonds=[11524], num_residues=[542]),
#  PackedProtein(batch_size=1, num_atoms=[267], num_bonds=[5134], num_residues=[267]),
#  PackedProtein(batch_size=1, num_atoms=[416], num_bonds=[8530], num_residues=[416]),
#  PackedProtein(batch_size=1, num_atoms=[291], num_bonds=[6644], num_residues=[291]),
#  PackedProtein(batch_size=1, num_atoms=[284], num_bonds=[5467], num_residues=[284]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5218], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[390], num_bonds=[8467], num_residues=[390]),
#  PackedProtein(batch_size=1, num_atoms=[265], num_bonds=[4965], num_residues=[265]),
#  PackedProtein(batch_size=1, num_atoms=[287], num_bonds=[5755], num_residues=[287]),
#  PackedProtein(batch_size=1, num_atoms=[447], num_bonds=[9506], num_residues=[447]),
#  PackedProtein(batch_size=1, num_atoms=[395], num_bonds=[9886], num_residues=[395]),
#  PackedProtein(batch_size=1, num_atoms=[239], num_bonds=[5601], num_residues=[239]),
#  PackedProtein(batch_size=1, num_atoms=[532], num_bonds=[12287], num_residues=[532]),
#  PackedProtein(batch_size=1, num_atoms=[188], num_bonds=[3294], num_residues=[188]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[16307], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[124], num_bonds=[1873], num_residues=[124]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7776], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[522], num_bonds=[10418], num_residues=[522]),
#  PackedProtein(batch_size=1, num_atoms=[524], num_bonds=[10584], num_residues=[524]),
#  PackedProtein(batch_size=1, num_atoms=[864], num_bonds=[20968], num_residues=[864]),
#  PackedProtein(batch_size=1, num_atoms=[407], num_bonds=[8928], num_residues=[407]),
#  PackedProtein(batch_size=1, num_atoms=[105], num_bonds=[1978], num_residues=[105]),
#  PackedProtein(batch_size=1, num_atoms=[316], num_bonds=[6084], num_residues=[316]),
#  PackedProtein(batch_size=1, num_atoms=[212], num_bonds=[4279], num_residues=[212]),
#  PackedProtein(batch_size=1, num_atoms=[498], num_bonds=[9829], num_residues=[498]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5261], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[85], num_bonds=[1600], num_residues=[85]),
#  PackedProtein(batch_size=1, num_atoms=[246], num_bonds=[4099], num_residues=[246]),
#  PackedProtein(batch_size=1, num_atoms=[522], num_bonds=[11400], num_residues=[522]),
#  PackedProtein(batch_size=1, num_atoms=[792], num_bonds=[16696], num_residues=[792]),
#  PackedProtein(batch_size=1, num_atoms=[993], num_bonds=[21944], num_residues=[993]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[1678], num_residues=[106]),
#  PackedProtein(batch_size=4, num_atoms=[1022, 1022, 1022, 966], num_bonds=[16560, 16320, 15914, 15198], num_residues=[1022, 1022, 1022, 966]),
#  PackedProtein(batch_size=4, num_atoms=[1022, 1022, 1022, 966], num_bonds=[16576, 16335, 15931, 15220], num_residues=[1022, 1022, 1022, 966]),
#  PackedProtein(batch_size=1, num_atoms=[427], num_bonds=[9875], num_residues=[427]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5276], num_residues=[224]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 307], num_bonds=[20590, 5582], num_residues=[1022, 307]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 614], num_bonds=[21187, 20532, 11890], num_residues=[1022, 1022, 614]),
#  PackedProtein(batch_size=1, num_atoms=[463], num_bonds=[9687], num_residues=[463]),
#  PackedProtein(batch_size=1, num_atoms=[320], num_bonds=[7270], num_residues=[320]),
#  PackedProtein(batch_size=1, num_atoms=[764], num_bonds=[16295], num_residues=[764]),
#  PackedProtein(batch_size=1, num_atoms=[296], num_bonds=[6083], num_residues=[296]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2048], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[115], num_bonds=[1734], num_residues=[115]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 292], num_bonds=[21657, 5399], num_residues=[1022, 292]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5669], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5685], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[642], num_bonds=[15234], num_residues=[642]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[827], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[505], num_bonds=[9596], num_residues=[505]),
#  PackedProtein(batch_size=1, num_atoms=[264], num_bonds=[5029], num_residues=[264]),
#  PackedProtein(batch_size=1, num_atoms=[540], num_bonds=[11463], num_residues=[540]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5253], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[546], num_bonds=[10562], num_residues=[546]),
#  PackedProtein(batch_size=1, num_atoms=[515], num_bonds=[11187], num_residues=[515]),
#  PackedProtein(batch_size=1, num_atoms=[672], num_bonds=[14083], num_residues=[672]),
#  PackedProtein(batch_size=1, num_atoms=[126], num_bonds=[2007], num_residues=[126]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 487], num_bonds=[21360, 9748], num_residues=[1022, 487]),
#  PackedProtein(batch_size=1, num_atoms=[380], num_bonds=[8495], num_residues=[380]),
#  PackedProtein(batch_size=1, num_atoms=[511], num_bonds=[10040], num_residues=[511]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5261], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[4324], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[213], num_bonds=[4331], num_residues=[213]),
#  PackedProtein(batch_size=1, num_atoms=[493], num_bonds=[9635], num_residues=[493]),
#  PackedProtein(batch_size=1, num_atoms=[492], num_bonds=[9587], num_residues=[492]),
#  PackedProtein(batch_size=1, num_atoms=[471], num_bonds=[10777], num_residues=[471]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 349], num_bonds=[20636, 6341], num_residues=[1022, 349]),
#  PackedProtein(batch_size=1, num_atoms=[537], num_bonds=[11177], num_residues=[537]),
#  PackedProtein(batch_size=1, num_atoms=[267], num_bonds=[5141], num_residues=[267]),
#  PackedProtein(batch_size=1, num_atoms=[296], num_bonds=[6276], num_residues=[296]),
#  PackedProtein(batch_size=1, num_atoms=[515], num_bonds=[11140], num_residues=[515]),
#  PackedProtein(batch_size=1, num_atoms=[361], num_bonds=[7377], num_residues=[361]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 684], num_bonds=[19660, 21250, 13026], num_residues=[1022, 1022, 684]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 728], num_bonds=[20078, 19664, 13667], num_residues=[1022, 1022, 728]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 50], num_bonds=[21964, 555], num_residues=[1022, 50]),
#  PackedProtein(batch_size=1, num_atoms=[90], num_bonds=[1368], num_residues=[90]),
#  PackedProtein(batch_size=1, num_atoms=[377], num_bonds=[8455], num_residues=[377]),
#  PackedProtein(batch_size=1, num_atoms=[1016], num_bonds=[22804], num_residues=[1016]),
#  PackedProtein(batch_size=1, num_atoms=[378], num_bonds=[8501], num_residues=[378]),
#  PackedProtein(batch_size=1, num_atoms=[370], num_bonds=[8270], num_residues=[370]),
#  PackedProtein(batch_size=1, num_atoms=[606], num_bonds=[12604], num_residues=[606]),
#  PackedProtein(batch_size=1, num_atoms=[606], num_bonds=[12664], num_residues=[606]),
#  PackedProtein(batch_size=1, num_atoms=[607], num_bonds=[12465], num_residues=[607]),
#  PackedProtein(batch_size=1, num_atoms=[607], num_bonds=[12523], num_residues=[607]),
#  PackedProtein(batch_size=1, num_atoms=[180], num_bonds=[3100], num_residues=[180]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7749], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[379], num_bonds=[8509], num_residues=[379]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 513], num_bonds=[19547, 8961], num_residues=[1022, 513]),
#  PackedProtein(batch_size=1, num_atoms=[924], num_bonds=[20434], num_residues=[924]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5681], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5692], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5701], num_residues=[298]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 850], num_bonds=[18860, 15585], num_residues=[1022, 850]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7737], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[351], num_bonds=[7528], num_residues=[351]),
#  PackedProtein(batch_size=1, num_atoms=[711], num_bonds=[15678], num_residues=[711]),
#  PackedProtein(batch_size=1, num_atoms=[812], num_bonds=[16398], num_residues=[812]),
#  PackedProtein(batch_size=1, num_atoms=[838], num_bonds=[16974], num_residues=[838]),
#  PackedProtein(batch_size=1, num_atoms=[806], num_bonds=[16434], num_residues=[806]),
#  PackedProtein(batch_size=1, num_atoms=[410], num_bonds=[7716], num_residues=[410]),
#  PackedProtein(batch_size=1, num_atoms=[195], num_bonds=[3999], num_residues=[195]),
#  PackedProtein(batch_size=1, num_atoms=[228], num_bonds=[5253], num_residues=[228]),
#  PackedProtein(batch_size=1, num_atoms=[251], num_bonds=[5866], num_residues=[251]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 328], num_bonds=[22410, 6651], num_residues=[1022, 328]),
#  PackedProtein(batch_size=1, num_atoms=[188], num_bonds=[3293], num_residues=[188]),
#  PackedProtein(batch_size=1, num_atoms=[547], num_bonds=[10558], num_residues=[547]),
#  PackedProtein(batch_size=1, num_atoms=[613], num_bonds=[13171], num_residues=[613]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 47], num_bonds=[21664, 536], num_residues=[1022, 47]),
#  PackedProtein(batch_size=1, num_atoms=[233], num_bonds=[4711], num_residues=[233]),
#  PackedProtein(batch_size=1, num_atoms=[438], num_bonds=[9332], num_residues=[438]),
#  PackedProtein(batch_size=1, num_atoms=[157], num_bonds=[3101], num_residues=[157]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 535], num_bonds=[26066, 12553], num_residues=[1022, 535]),
#  PackedProtein(batch_size=1, num_atoms=[214], num_bonds=[4301], num_residues=[214]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 812], num_bonds=[21870, 21493, 17339], num_residues=[1022, 1022, 812]),
#  PackedProtein(batch_size=1, num_atoms=[188], num_bonds=[4281], num_residues=[188]),
#  PackedProtein(batch_size=1, num_atoms=[261], num_bonds=[4905], num_residues=[261]),
#  PackedProtein(batch_size=1, num_atoms=[125], num_bonds=[2578], num_residues=[125]),
#  PackedProtein(batch_size=1, num_atoms=[514], num_bonds=[10253], num_residues=[514]),
#  PackedProtein(batch_size=1, num_atoms=[370], num_bonds=[7899], num_residues=[370]),
#  PackedProtein(batch_size=1, num_atoms=[522], num_bonds=[10242], num_residues=[522]),
#  PackedProtein(batch_size=1, num_atoms=[472], num_bonds=[11000], num_residues=[472]),
#  PackedProtein(batch_size=1, num_atoms=[185], num_bonds=[3285], num_residues=[185]),
#  PackedProtein(batch_size=1, num_atoms=[314], num_bonds=[7002], num_residues=[314]),
#  PackedProtein(batch_size=1, num_atoms=[258], num_bonds=[5099], num_residues=[258]),
#  PackedProtein(batch_size=1, num_atoms=[320], num_bonds=[7294], num_residues=[320]),
#  PackedProtein(batch_size=1, num_atoms=[510], num_bonds=[11323], num_residues=[510]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1296], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[558], num_bonds=[11280], num_residues=[558]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7714], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[617], num_bonds=[11365], num_residues=[617]),
#  PackedProtein(batch_size=1, num_atoms=[502], num_bonds=[9943], num_residues=[502]),
#  PackedProtein(batch_size=1, num_atoms=[493], num_bonds=[9680], num_residues=[493]),
#  PackedProtein(batch_size=1, num_atoms=[410], num_bonds=[8528], num_residues=[410]),
#  PackedProtein(batch_size=1, num_atoms=[383], num_bonds=[9255], num_residues=[383]),
#  PackedProtein(batch_size=1, num_atoms=[121], num_bonds=[2120], num_residues=[121]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 248], num_bonds=[22865, 4800], num_residues=[1022, 248]),
#  PackedProtein(batch_size=1, num_atoms=[607], num_bonds=[12618], num_residues=[607]),
#  PackedProtein(batch_size=1, num_atoms=[828], num_bonds=[16778], num_residues=[828]),
#  PackedProtein(batch_size=1, num_atoms=[265], num_bonds=[4969], num_residues=[265]),
#  PackedProtein(batch_size=1, num_atoms=[528], num_bonds=[10416], num_residues=[528]),
#  PackedProtein(batch_size=1, num_atoms=[297], num_bonds=[5854], num_residues=[297]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5186], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[301], num_bonds=[5746], num_residues=[301]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7675], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[620], num_bonds=[11453], num_residues=[620]),
#  PackedProtein(batch_size=1, num_atoms=[659], num_bonds=[15731], num_residues=[659]),
#  PackedProtein(batch_size=1, num_atoms=[228], num_bonds=[5257], num_residues=[228]),
#  PackedProtein(batch_size=1, num_atoms=[227], num_bonds=[4546], num_residues=[227]),
#  PackedProtein(batch_size=1, num_atoms=[343], num_bonds=[7403], num_residues=[343]),
#  PackedProtein(batch_size=1, num_atoms=[390], num_bonds=[8467], num_residues=[390]),
#  PackedProtein(batch_size=1, num_atoms=[592], num_bonds=[13229], num_residues=[592]),
#  PackedProtein(batch_size=1, num_atoms=[425], num_bonds=[8953], num_residues=[425]),
#  PackedProtein(batch_size=1, num_atoms=[248], num_bonds=[5041], num_residues=[248]),
#  PackedProtein(batch_size=1, num_atoms=[337], num_bonds=[6310], num_residues=[337]),
#  PackedProtein(batch_size=1, num_atoms=[884], num_bonds=[19523], num_residues=[884]),
#  PackedProtein(batch_size=1, num_atoms=[276], num_bonds=[6073], num_residues=[276]),
#  PackedProtein(batch_size=1, num_atoms=[792], num_bonds=[16676], num_residues=[792]),
#  PackedProtein(batch_size=1, num_atoms=[398], num_bonds=[7867], num_residues=[398]),
#  PackedProtein(batch_size=1, num_atoms=[394], num_bonds=[8629], num_residues=[394]),
#  PackedProtein(batch_size=1, num_atoms=[461], num_bonds=[9783], num_residues=[461]),
#  PackedProtein(batch_size=1, num_atoms=[446], num_bonds=[9509], num_residues=[446]),
#  PackedProtein(batch_size=1, num_atoms=[274], num_bonds=[5343], num_residues=[274]),
#  PackedProtein(batch_size=1, num_atoms=[698], num_bonds=[13648], num_residues=[698]),
#  PackedProtein(batch_size=1, num_atoms=[607], num_bonds=[12616], num_residues=[607]),
#  PackedProtein(batch_size=1, num_atoms=[161], num_bonds=[3242], num_residues=[161]),
#  PackedProtein(batch_size=1, num_atoms=[271], num_bonds=[5377], num_residues=[271]),
#  PackedProtein(batch_size=1, num_atoms=[177], num_bonds=[3414], num_residues=[177]),
#  PackedProtein(batch_size=1, num_atoms=[162], num_bonds=[3320], num_residues=[162]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 190], num_bonds=[19938, 2755], num_residues=[1022, 190]),
#  PackedProtein(batch_size=1, num_atoms=[129], num_bonds=[2480], num_residues=[129]),
#  PackedProtein(batch_size=1, num_atoms=[273], num_bonds=[4494], num_residues=[273]),
#  PackedProtein(batch_size=1, num_atoms=[87], num_bonds=[1218], num_residues=[87]),
#  PackedProtein(batch_size=1, num_atoms=[95], num_bonds=[1600], num_residues=[95]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[992], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[334], num_bonds=[6747], num_residues=[334]),
#  PackedProtein(batch_size=1, num_atoms=[656], num_bonds=[15615], num_residues=[656]),
#  PackedProtein(batch_size=1, num_atoms=[606], num_bonds=[12590], num_residues=[606]),
#  PackedProtein(batch_size=1, num_atoms=[604], num_bonds=[13102], num_residues=[604]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5663], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5608], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[267], num_bonds=[5082], num_residues=[267]),
# ...
#  PackedProtein(batch_size=1, num_atoms=[475], num_bonds=[9461], num_residues=[475]),
#  PackedProtein(batch_size=1, num_atoms=[376], num_bonds=[6903], num_residues=[376]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[1796], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[241], num_bonds=[5707], num_residues=[241]),
#  PackedProtein(batch_size=1, num_atoms=[363], num_bonds=[6633], num_residues=[363]),
#  PackedProtein(batch_size=1, num_atoms=[472], num_bonds=[11041], num_residues=[472]),
#  PackedProtein(batch_size=1, num_atoms=[299], num_bonds=[5688], num_residues=[299]),
#  PackedProtein(batch_size=1, num_atoms=[636], num_bonds=[12464], num_residues=[636]),
#  PackedProtein(batch_size=1, num_atoms=[378], num_bonds=[7804], num_residues=[378]),
#  PackedProtein(batch_size=1, num_atoms=[480], num_bonds=[11367], num_residues=[480]),
#  PackedProtein(batch_size=1, num_atoms=[113], num_bonds=[2181], num_residues=[113]),
#  PackedProtein(batch_size=1, num_atoms=[181], num_bonds=[3781], num_residues=[181]),
#  PackedProtein(batch_size=1, num_atoms=[229], num_bonds=[5012], num_residues=[229]),
#  PackedProtein(batch_size=1, num_atoms=[437], num_bonds=[9322], num_residues=[437]),
#  PackedProtein(batch_size=1, num_atoms=[437], num_bonds=[9309], num_residues=[437]),
#  PackedProtein(batch_size=1, num_atoms=[119], num_bonds=[2332], num_residues=[119]),
#  PackedProtein(batch_size=1, num_atoms=[1015], num_bonds=[22951], num_residues=[1015]),
#  PackedProtein(batch_size=1, num_atoms=[469], num_bonds=[11242], num_residues=[469]),
#  PackedProtein(batch_size=1, num_atoms=[145], num_bonds=[2856], num_residues=[145]),
#  PackedProtein(batch_size=1, num_atoms=[220], num_bonds=[4504], num_residues=[220]),
#  PackedProtein(batch_size=1, num_atoms=[99], num_bonds=[1896], num_residues=[99]),
#  PackedProtein(batch_size=1, num_atoms=[119], num_bonds=[2117], num_residues=[119]),
#  PackedProtein(batch_size=1, num_atoms=[998], num_bonds=[22276], num_residues=[998]),
#  PackedProtein(batch_size=1, num_atoms=[515], num_bonds=[11199], num_residues=[515]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[607], num_residues=[40]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 624], num_bonds=[19682, 11260], num_residues=[1022, 624]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 640], num_bonds=[19766, 11572], num_residues=[1022, 640]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 640], num_bonds=[19741, 11576], num_residues=[1022, 640]),
#  PackedProtein(batch_size=1, num_atoms=[458], num_bonds=[11064], num_residues=[458]),
#  PackedProtein(batch_size=1, num_atoms=[879], num_bonds=[19677], num_residues=[879]),
#  PackedProtein(batch_size=1, num_atoms=[258], num_bonds=[5013], num_residues=[258]),
#  PackedProtein(batch_size=1, num_atoms=[133], num_bonds=[2575], num_residues=[133]),
#  PackedProtein(batch_size=1, num_atoms=[405], num_bonds=[8267], num_residues=[405]),
#  PackedProtein(batch_size=1, num_atoms=[565], num_bonds=[11385], num_residues=[565]),
#  PackedProtein(batch_size=1, num_atoms=[562], num_bonds=[11359], num_residues=[562]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[2399], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[771], num_bonds=[18351], num_residues=[771]),
#  PackedProtein(batch_size=1, num_atoms=[914], num_bonds=[19238], num_residues=[914]),
#  PackedProtein(batch_size=1, num_atoms=[258], num_bonds=[5696], num_residues=[258]),
#  PackedProtein(batch_size=1, num_atoms=[208], num_bonds=[4081], num_residues=[208]),
#  PackedProtein(batch_size=1, num_atoms=[117], num_bonds=[2553], num_residues=[117]),
#  PackedProtein(batch_size=1, num_atoms=[581], num_bonds=[8111], num_residues=[581]),
#  PackedProtein(batch_size=1, num_atoms=[581], num_bonds=[8622], num_residues=[581]),
#  PackedProtein(batch_size=1, num_atoms=[210], num_bonds=[4073], num_residues=[210]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 67], num_bonds=[22048, 21720, 935], num_residues=[1022, 1022, 67]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 631], num_bonds=[22079, 12978], num_residues=[1022, 631]),
#  PackedProtein(batch_size=1, num_atoms=[338], num_bonds=[5943], num_residues=[338]),
#  PackedProtein(batch_size=4, num_atoms=[1022, 1022, 1022, 966], num_bonds=[16494, 16258, 15855, 15139], num_residues=[1022, 1022, 1022, 966]),
#  PackedProtein(batch_size=4, num_atoms=[1022, 1022, 1022, 966], num_bonds=[16386, 16154, 15751, 15046], num_residues=[1022, 1022, 1022, 966]),
#  PackedProtein(batch_size=1, num_atoms=[525], num_bonds=[10870], num_residues=[525]),
#  PackedProtein(batch_size=1, num_atoms=[182], num_bonds=[3226], num_residues=[182]),
#  PackedProtein(batch_size=1, num_atoms=[337], num_bonds=[6277], num_residues=[337]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[1048], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[121], num_bonds=[1942], num_residues=[121]),
#  PackedProtein(batch_size=1, num_atoms=[708], num_bonds=[15827], num_residues=[708]),
#  PackedProtein(batch_size=1, num_atoms=[218], num_bonds=[3969], num_residues=[218]),
#  PackedProtein(batch_size=1, num_atoms=[72], num_bonds=[869], num_residues=[72]),
#  PackedProtein(batch_size=1, num_atoms=[225], num_bonds=[4560], num_residues=[225]),
#  PackedProtein(batch_size=1, num_atoms=[222], num_bonds=[4558], num_residues=[222]),
#  PackedProtein(batch_size=1, num_atoms=[265], num_bonds=[4997], num_residues=[265]),
#  PackedProtein(batch_size=1, num_atoms=[87], num_bonds=[1261], num_residues=[87]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 546], num_bonds=[25501, 12488], num_residues=[1022, 546]),
#  PackedProtein(batch_size=1, num_atoms=[416], num_bonds=[7353], num_residues=[416]),
#  PackedProtein(batch_size=1, num_atoms=[976], num_bonds=[19527], num_residues=[976]),
#  PackedProtein(batch_size=5, num_atoms=[1022, 1022, 1022, 2044, 128], num_bonds=[21645, 21232, 20935, 42905, 1884], num_residues=[1022, 1022, 1022, 2044, 128]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 692], num_bonds=[19955, 19321, 13065], num_residues=[1022, 1022, 692]),
#  PackedProtein(batch_size=1, num_atoms=[357], num_bonds=[8043], num_residues=[357]),
#  PackedProtein(batch_size=1, num_atoms=[238], num_bonds=[5543], num_residues=[238]),
#  PackedProtein(batch_size=1, num_atoms=[993], num_bonds=[21257], num_residues=[993]),
#  PackedProtein(batch_size=1, num_atoms=[681], num_bonds=[12971], num_residues=[681]),
#  PackedProtein(batch_size=1, num_atoms=[124], num_bonds=[2467], num_residues=[124]),
#  PackedProtein(batch_size=1, num_atoms=[426], num_bonds=[9245], num_residues=[426]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 535], num_bonds=[25834, 12175], num_residues=[1022, 535]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5672], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[214], num_bonds=[4041], num_residues=[214]),
#  PackedProtein(batch_size=1, num_atoms=[506], num_bonds=[9195], num_residues=[506]),
#  PackedProtein(batch_size=1, num_atoms=[188], num_bonds=[3299], num_residues=[188]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[6208], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[240], num_bonds=[5569], num_residues=[240]),
#  PackedProtein(batch_size=1, num_atoms=[83], num_bonds=[1190], num_residues=[83]),
#  PackedProtein(batch_size=1, num_atoms=[684], num_bonds=[13536], num_residues=[684]),
#  PackedProtein(batch_size=5, num_atoms=[1022, 1022, 1022, 2044, 128], num_bonds=[21699, 21285, 20997, 43022, 1892], num_residues=[1022, 1022, 1022, 2044, 128]),
#  PackedProtein(batch_size=1, num_atoms=[145], num_bonds=[2875], num_residues=[145]),
#  PackedProtein(batch_size=1, num_atoms=[211], num_bonds=[4125], num_residues=[211]),
#  PackedProtein(batch_size=1, num_atoms=[327], num_bonds=[6244], num_residues=[327]),
#  PackedProtein(batch_size=1, num_atoms=[348], num_bonds=[7331], num_residues=[348]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5673], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[154], num_bonds=[3509], num_residues=[154]),
#  PackedProtein(batch_size=1, num_atoms=[900], num_bonds=[19582], num_residues=[900]),
#  PackedProtein(batch_size=1, num_atoms=[606], num_bonds=[12613], num_residues=[606]),
#  PackedProtein(batch_size=1, num_atoms=[386], num_bonds=[6616], num_residues=[386]),
#  PackedProtein(batch_size=1, num_atoms=[267], num_bonds=[5016], num_residues=[267]),
#  PackedProtein(batch_size=1, num_atoms=[498], num_bonds=[10351], num_residues=[498]),
#  PackedProtein(batch_size=1, num_atoms=[268], num_bonds=[5157], num_residues=[268]),
#  PackedProtein(batch_size=1, num_atoms=[998], num_bonds=[22272], num_residues=[998]),
#  PackedProtein(batch_size=1, num_atoms=[998], num_bonds=[22250], num_residues=[998]),
#  PackedProtein(batch_size=1, num_atoms=[111], num_bonds=[2217], num_residues=[111]),
#  PackedProtein(batch_size=1, num_atoms=[898], num_bonds=[22255], num_residues=[898]),
#  PackedProtein(batch_size=1, num_atoms=[637], num_bonds=[13473], num_residues=[637]),
#  PackedProtein(batch_size=1, num_atoms=[115], num_bonds=[2479], num_residues=[115]),
#  PackedProtein(batch_size=1, num_atoms=[1014], num_bonds=[22819], num_residues=[1014]),
#  PackedProtein(batch_size=1, num_atoms=[792], num_bonds=[16970], num_residues=[792]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 66], num_bonds=[21707, 728], num_residues=[1022, 66]),
#  PackedProtein(batch_size=1, num_atoms=[431], num_bonds=[8985], num_residues=[431]),
#  PackedProtein(batch_size=1, num_atoms=[230], num_bonds=[5611], num_residues=[230]),
#  PackedProtein(batch_size=1, num_atoms=[476], num_bonds=[9958], num_residues=[476]),
#  PackedProtein(batch_size=1, num_atoms=[285], num_bonds=[6045], num_residues=[285]),
#  PackedProtein(batch_size=1, num_atoms=[570], num_bonds=[12611], num_residues=[570]),
#  PackedProtein(batch_size=1, num_atoms=[560], num_bonds=[12587], num_residues=[560]),
#  PackedProtein(batch_size=1, num_atoms=[500], num_bonds=[11114], num_residues=[500]),
#  PackedProtein(batch_size=1, num_atoms=[130], num_bonds=[1957], num_residues=[130]),
#  PackedProtein(batch_size=1, num_atoms=[840], num_bonds=[21221], num_residues=[840]),
#  PackedProtein(batch_size=1, num_atoms=[88], num_bonds=[1091], num_residues=[88]),
#  PackedProtein(batch_size=1, num_atoms=[377], num_bonds=[7694], num_residues=[377]),
#  PackedProtein(batch_size=1, num_atoms=[660], num_bonds=[15388], num_residues=[660]),
#  PackedProtein(batch_size=4, num_atoms=[1022, 1022, 1022, 978], num_bonds=[22972, 22709, 22338, 21805], num_residues=[1022, 1022, 1022, 978]),
#  PackedProtein(batch_size=1, num_atoms=[104], num_bonds=[2064], num_residues=[104]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5699], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[578], num_bonds=[12002], num_residues=[578]),
#  PackedProtein(batch_size=1, num_atoms=[332], num_bonds=[5862], num_residues=[332]),
#  PackedProtein(batch_size=1, num_atoms=[183], num_bonds=[3431], num_residues=[183]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[1796], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[242], num_bonds=[4861], num_residues=[242]),
#  PackedProtein(batch_size=1, num_atoms=[670], num_bonds=[12224], num_residues=[670]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 622], num_bonds=[23081, 12864], num_residues=[1022, 622]),
#  PackedProtein(batch_size=1, num_atoms=[220], num_bonds=[4529], num_residues=[220]),
#  PackedProtein(batch_size=1, num_atoms=[219], num_bonds=[4950], num_residues=[219]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[2412], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[472], num_bonds=[9994], num_residues=[472]),
#  PackedProtein(batch_size=1, num_atoms=[546], num_bonds=[10455], num_residues=[546]),
#  PackedProtein(batch_size=1, num_atoms=[930], num_bonds=[19358], num_residues=[930]),
#  PackedProtein(batch_size=1, num_atoms=[369], num_bonds=[9076], num_residues=[369]),
#  PackedProtein(batch_size=1, num_atoms=[374], num_bonds=[7180], num_residues=[374]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5201], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[189], num_bonds=[3319], num_residues=[189]),
#  PackedProtein(batch_size=1, num_atoms=[328], num_bonds=[6737], num_residues=[328]),
#  PackedProtein(batch_size=1, num_atoms=[330], num_bonds=[5824], num_residues=[330]),
#  PackedProtein(batch_size=1, num_atoms=[188], num_bonds=[3319], num_residues=[188]),
#  PackedProtein(batch_size=1, num_atoms=[448], num_bonds=[8700], num_residues=[448]),
#  PackedProtein(batch_size=4, num_atoms=[1022, 1022, 1022, 102], num_bonds=[20558, 19178, 19439, 1088], num_residues=[1022, 1022, 1022, 102]),
#  PackedProtein(batch_size=1, num_atoms=[138], num_bonds=[2856], num_residues=[138]),
#  PackedProtein(batch_size=1, num_atoms=[209], num_bonds=[4087], num_residues=[209]),
#  PackedProtein(batch_size=1, num_atoms=[485], num_bonds=[9871], num_residues=[485]),
#  PackedProtein(batch_size=1, num_atoms=[713], num_bonds=[15735], num_residues=[713]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5261], num_residues=[256]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 636], num_bonds=[20061, 11610], num_residues=[1022, 636]),
#  PackedProtein(batch_size=1, num_atoms=[566], num_bonds=[11473], num_residues=[566]),
#  PackedProtein(batch_size=1, num_atoms=[674], num_bonds=[15042], num_residues=[674]),
#  PackedProtein(batch_size=1, num_atoms=[284], num_bonds=[5903], num_residues=[284]),
#  PackedProtein(batch_size=1, num_atoms=[495], num_bonds=[10487], num_residues=[495]),
#  PackedProtein(batch_size=1, num_atoms=[275], num_bonds=[6113], num_residues=[275]),
#  PackedProtein(batch_size=1, num_atoms=[672], num_bonds=[14332], num_residues=[672]),
#  PackedProtein(batch_size=1, num_atoms=[462], num_bonds=[8914], num_residues=[462]),
#  PackedProtein(batch_size=1, num_atoms=[542], num_bonds=[11146], num_residues=[542]),
#  PackedProtein(batch_size=1, num_atoms=[1016], num_bonds=[23071], num_residues=[1016]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 598], num_bonds=[19547, 10743], num_residues=[1022, 598]),
#  PackedProtein(batch_size=1, num_atoms=[829], num_bonds=[19365], num_residues=[829]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5661], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[337], num_bonds=[6403], num_residues=[337]),
#  PackedProtein(batch_size=1, num_atoms=[268], num_bonds=[5191], num_residues=[268]),
#  PackedProtein(batch_size=1, num_atoms=[559], num_bonds=[12294], num_residues=[559]),
#  PackedProtein(batch_size=1, num_atoms=[325], num_bonds=[6257], num_residues=[325]),
#  PackedProtein(batch_size=1, num_atoms=[244], num_bonds=[5598], num_residues=[244]),
#  PackedProtein(batch_size=1, num_atoms=[692], num_bonds=[13451], num_residues=[692]),
#  PackedProtein(batch_size=1, num_atoms=[184], num_bonds=[3803], num_residues=[184]),
#  PackedProtein(batch_size=1, num_atoms=[240], num_bonds=[5588], num_residues=[240]),
#  PackedProtein(batch_size=1, num_atoms=[331], num_bonds=[7401], num_residues=[331]),
#  PackedProtein(batch_size=1, num_atoms=[138], num_bonds=[2897], num_residues=[138]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[17209], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[107], num_bonds=[2145], num_residues=[107]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[607], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[515], num_bonds=[10889], num_residues=[515]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2025], num_residues=[106]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 66], num_bonds=[21723, 731], num_residues=[1022, 66]),
#  PackedProtein(batch_size=1, num_atoms=[490], num_bonds=[10437], num_residues=[490]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 72], num_bonds=[20482, 969], num_residues=[1022, 72]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 72], num_bonds=[20495, 962], num_residues=[1022, 72]),
#  PackedProtein(batch_size=1, num_atoms=[807], num_bonds=[20536], num_residues=[807]),
#  PackedProtein(batch_size=1, num_atoms=[807], num_bonds=[20580], num_residues=[807]),
#  ...]

# %%
len(protein_within_1022_list)
# Out:
# 5000

# %%
indexes = range(528, 600)   # len(transform_list)
indexes = tqdm(indexes, "ESM Computing ......")
for index in indexes:
    curProtein = protein_within_1022_list[index]
    if curProtein.batch_size == 1:
        esmProcess(sequence_model, curProtein, str(index))
    else:
        for i in range(curProtein.batch_size):
            protein = data.Protein.pack([curProtein[i]])
            esmProcess(sequence_model, protein, str(index) + '-' + str(i))
# Out:
# ESM Computing ......:  29%|██▉       | 29/100 [02:19<05:42,  4.82s/it]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# d:\Code\CurrentWork\Demo\DTA_Work\script\notebook\DatasetBuilding\PDBbindESM.ipynb Cell 23' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000020?line=7'>8</a> for i in range(curProtein.batch_size):
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000020?line=8'>9</a>     protein = data.Protein.pack([curProtein[i]])
# ---> <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000020?line=9'>10</a>     esmProcess(sequence_model, protein, str(index) + '-' + str(i))
#
# d:\Code\CurrentWork\Demo\DTA_Work\script\notebook\DatasetBuilding\PDBbindESM.ipynb Cell 6' in esmProcess(esmModel, curProtein, pklName)
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000005?line=0'>1</a> def esmProcess(esmModel, curProtein, pklName):
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000005?line=1'>2</a>     """
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000005?line=2'>3</a>     curProtein: list of packedProtein
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000005?line=3'>4</a>     pklName: the pkl name to store the protein
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000005?line=4'>5</a>     """
# ----> <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000005?line=5'>6</a>     output = esmModel(curProtein, curProtein.residue_feature)
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000005?line=6'>7</a>     curProtein.residue_feature = output['residue_feature']
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000005?line=7'>8</a>     curProtein.mol_feature = output['graph_feature']
#
# File d:\miniconda3\envs\torchdrug\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File d:\miniconda3\envs\torchdrug\lib\site-packages\torchdrug\models\esm.py:139, in EvolutionaryScaleModeling.forward(self, graph, input, all_loss, metric)
#     136     input, size_ext = functional._extend(input, size_ext, eos, torch.ones_like(size_ext))
#     137 input = functional.variadic_to_padded(input, size_ext, value=self.alphabet.padding_idx)[0]  # (batch_size, max_residues)
# --> 139 output = self.model(input, repr_layers=[33])
#     140 residue_feature = output["representations"][33]
#     141 # output = self.model(input, repr_layers=[12])  # for esm2-35M contains 12 layers
#     142 # residue_feature = output["representations"][12]
#
# File d:\miniconda3\envs\torchdrug\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File d:\miniconda3\envs\torchdrug\lib\site-packages\esm\model\esm2.py:112, in ESM2.forward(self, tokens, repr_layers, need_head_weights, return_contacts)
#     109     padding_mask = None
#     111 for layer_idx, layer in enumerate(self.layers):
# --> 112     x, attn = layer(
#     113         x,
#     114         self_attn_padding_mask=padding_mask,
#     115         need_head_weights=need_head_weights,
#     116     )
#     117     if (layer_idx + 1) in repr_layers:
#     118         hidden_representations[layer_idx + 1] = x.transpose(0, 1)
#
# File d:\miniconda3\envs\torchdrug\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File d:\miniconda3\envs\torchdrug\lib\site-packages\esm\modules.py:138, in TransformerLayer.forward(self, x, self_attn_mask, self_attn_padding_mask, need_head_weights)
#     136 residual = x
#     137 x = self.final_layer_norm(x)
# --> 138 x = gelu(self.fc1(x))
#     139 x = self.fc2(x)
#     140 x = residual + x
#
# File d:\miniconda3\envs\torchdrug\lib\site-packages\esm\modules.py:24, in gelu(x)
#      17 def gelu(x):
#      18     """Implementation of the gelu activation function.
#      19
#      20     For information: OpenAI GPT's gelu is slightly different
#      21     (and gives slightly different results):
#      22     0.5 * x * (1 + torch.tanh(math.sqrt(2 / math.pi) * (x + 0.044715 * torch.pow(x, 3))))
#      23     """
# ---> 24     return x * 0.5 * (1.0 + torch.erf(x / math.sqrt(2.0)))
#
# RuntimeError: [enforce fail at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\c10\core\impl\alloc_cpu.cpp:72] data. DefaultCPUAllocator: not enough memory: you tried to allocate 20971520 bytes.

# %% [markdown]
# Read all pkl and aggreate into the new list

# %%
import pickle
import torch
from tqdm import tqdm
from torchdrug import utils, transforms, data, models, layers

# %%
protein_pkl = '../../../data/dta-datasets/PDBbind/gearnet_pocket_Protein.pkl'
with utils.smart_open(protein_pkl, "rb") as fin:
    output_list = pickle.load(fin)

# %%
len(output_list)
# Out:
# 9018

# %%
output_list
# Out:
# [PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[501], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[22], num_bonds=[246], num_residues=[22]),
#  PackedProtein(batch_size=1, num_atoms=[29], num_bonds=[347], num_residues=[29]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[713], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[73], num_bonds=[1106], num_residues=[73]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[588], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[73], num_bonds=[1131], num_residues=[73]),
#  PackedProtein(batch_size=1, num_atoms=[34], num_bonds=[552], num_residues=[34]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[340], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[834], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[653], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[632], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[594], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[821], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[876], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[16], num_bonds=[174], num_residues=[16]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[710], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[604], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[626], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[503], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[705], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[779], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[704], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[566], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[685], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[725], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[610], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[715], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[848], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[766], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[637], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[830], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[785], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[689], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[675], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[885], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[554], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1030], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[1193], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[683], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[769], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[772], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[721], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[527], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[784], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[927], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[521], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[705], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[482], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[606], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[779], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[497], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[863], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1080], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[690], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[707], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[759], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[698], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[819], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[595], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[851], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[762], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[735], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[78], num_bonds=[1493], num_residues=[78]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[534], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[625], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[650], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[685], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[609], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[632], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[648], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[630], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[639], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[650], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[646], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[364], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[544], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[590], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[522], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[581], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[799], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[590], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[447], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[803], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[604], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[644], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[708], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[494], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[736], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[725], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[1007], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[932], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[840], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[770], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[782], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[510], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[829], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[857], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[999], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[805], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[757], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[879], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[717], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[573], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[864], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[784], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[934], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[779], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[975], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[909], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[751], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[785], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[776], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[853], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[730], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[784], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[937], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[980], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[748], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1010], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[108], num_bonds=[1641], num_residues=[108]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1000], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[746], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[543], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[636], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[701], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[694], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[585], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[399], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[540], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[479], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[72], num_bonds=[1082], num_residues=[72]),
#  PackedProtein(batch_size=1, num_atoms=[21], num_bonds=[225], num_residues=[21]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[895], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[759], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[709], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[567], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[555], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[805], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[860], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[705], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[807], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[635], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[670], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[947], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[92], num_bonds=[1313], num_residues=[92]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[801], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[736], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[586], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[610], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1142], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[801], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[733], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[876], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[751], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[731], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[762], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[701], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[1053], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[74], num_bonds=[1147], num_residues=[74]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[737], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[19], num_bonds=[217], num_residues=[19]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[614], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[494], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[553], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[25], num_bonds=[293], num_residues=[25]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[636], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[729], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[536], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[799], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[839], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[839], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[664], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[580], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[887], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[949], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1281], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[721], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1229], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1285], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[561], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[528], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[784], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1089], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[993], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[572], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[594], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[956], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[792], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[932], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1102], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[1014], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1159], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[581], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[728], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[937], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[919], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[748], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[532], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[466], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[114], num_bonds=[2303], num_residues=[114]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1025], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[1022], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1086], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1046], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[985], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[118], num_bonds=[2421], num_residues=[118]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[974], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[112], num_bonds=[2239], num_residues=[112]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[515], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[881], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[1150], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[23], num_bonds=[328], num_residues=[23]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[1042], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[935], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[885], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[647], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[950], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[881], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[926], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[74], num_bonds=[1170], num_residues=[74]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[977], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[722], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[630], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[693], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[637], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[674], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[910], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[105], num_bonds=[1777], num_residues=[105]),
#  PackedProtein(batch_size=1, num_atoms=[116], num_bonds=[2325], num_residues=[116]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[499], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[888], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[879], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[538], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[692], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[30], num_bonds=[439], num_residues=[30]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[543], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[444], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1088], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1313], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[914], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[871], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1179], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[794], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[707], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1058], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1052], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1059], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1089], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[650], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[663], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[738], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[572], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[668], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[827], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[726], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[1157], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[640], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[521], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[697], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[823], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[940], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[950], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1005], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1103], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[761], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[956], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[780], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[592], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[679], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[591], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[580], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[565], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[88], num_bonds=[1535], num_residues=[88]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[978], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[985], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1241], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[803], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[941], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[859], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[802], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[730], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[642], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[996], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[904], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[813], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1243], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1129], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[773], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[775], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[663], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[722], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[813], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1047], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[561], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[668], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[850], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1183], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[886], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[617], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[618], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[738], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[626], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[779], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[660], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[1249], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[744], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[859], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[862], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[916], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1074], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[903], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[454], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[623], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[560], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[627], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[879], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[656], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[982], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[597], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[616], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[744], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[664], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[725], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[759], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[879], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[814], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[734], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[689], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1031], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[649], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[755], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[17], num_bonds=[195], num_residues=[17]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[597], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[567], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[518], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[646], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[645], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1012], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[592], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[724], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[12], num_bonds=[111], num_residues=[12]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1107], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[950], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[651], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[985], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[691], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[719], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[615], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[701], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[870], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[860], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[911], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[847], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[745], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[915], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[747], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1102], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[1040], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[80], num_bonds=[1395], num_residues=[80]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[710], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1072], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[649], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[660], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[654], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[662], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[774], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[565], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[778], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[477], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[607], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[18], num_bonds=[242], num_residues=[18]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1096], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[73], num_bonds=[1164], num_residues=[73]),
#  PackedProtein(batch_size=1, num_atoms=[28], num_bonds=[307], num_residues=[28]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[570], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1061], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[597], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[719], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[512], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[682], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1007], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[108], num_bonds=[1722], num_residues=[108]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1259], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[844], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[756], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[913], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[813], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[520], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[22], num_bonds=[282], num_residues=[22]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[890], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[834], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[78], num_bonds=[1201], num_residues=[78]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[886], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[1048], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[489], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[823], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1184], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[798], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[759], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[597], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[883], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[904], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[802], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[719], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[864], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[785], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[529], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1236], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[631], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[636], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[626], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[557], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[704], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[602], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[697], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[1012], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[1022], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[1044], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[24], num_bonds=[362], num_residues=[24]),
#  PackedProtein(batch_size=1, num_atoms=[24], num_bonds=[369], num_residues=[24]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[900], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[871], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[517], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[73], num_bonds=[1205], num_residues=[73]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[409], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[456], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[86], num_bonds=[1216], num_residues=[86]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[1101], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1235], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[72], num_bonds=[1331], num_residues=[72]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[970], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[1067], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1086], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[983], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[1185], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1086], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1130], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1163], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[72], num_bonds=[1342], num_residues=[72]),
#  PackedProtein(batch_size=1, num_atoms=[29], num_bonds=[333], num_residues=[29]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[940], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[841], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[718], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1074], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[24], num_bonds=[261], num_residues=[24]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[707], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[840], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[719], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[990], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[695], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[576], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1171], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[872], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[910], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[511], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[660], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[796], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[92], num_bonds=[1691], num_residues=[92]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[947], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[873], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[81], num_bonds=[1284], num_residues=[81]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[852], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1070], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[464], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1455], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[869], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[805], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[880], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[693], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[25], num_bonds=[385], num_residues=[25]),
#  PackedProtein(batch_size=1, num_atoms=[26], num_bonds=[405], num_residues=[26]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1200], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[908], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[909], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[579], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[658], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[799], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[796], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[719], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[710], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[984], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[781], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[495], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[878], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[611], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[924], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[782], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[938], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[90], num_bonds=[1689], num_residues=[90]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[561], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[655], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[555], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[729], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[612], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[648], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[816], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[946], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[698], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[671], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[735], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[821], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[565], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[467], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1366], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[521], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[831], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[959], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1529], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[488], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[505], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[623], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[683], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[909], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[438], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[882], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[615], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[798], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1174], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[590], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[664], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[962], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[756], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[854], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1187], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1026], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[1032], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1088], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[880], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1120], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[1052], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[726], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[651], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[653], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[896], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[795], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[820], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[817], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[753], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[848], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[806], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[904], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[885], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[753], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[806], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[857], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[860], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[843], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[85], num_bonds=[1636], num_residues=[85]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[621], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1267], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[724], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[674], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[950], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[730], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[780], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1038], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[1281], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[81], num_bonds=[1525], num_residues=[81]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[999], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[113], num_bonds=[1764], num_residues=[113]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1236], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[811], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[816], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[790], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1524], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[555], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[615], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[666], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[646], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[755], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[721], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[492], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[476], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[650], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[258], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[284], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[650], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[622], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[1060], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1040], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[546], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[465], num_residues=[35]),
# ...
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[310], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[16], num_bonds=[186], num_residues=[16]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[479], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[763], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[663], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[693], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[500], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[662], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[746], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[877], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[925], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[30], num_bonds=[434], num_residues=[30]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[783], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[839], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[818], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[29], num_bonds=[415], num_residues=[29]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[773], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[799], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[850], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[544], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[729], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[888], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[857], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[581], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[779], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[773], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[858], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[729], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[894], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[349], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[956], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[885], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[752], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[867], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[895], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[861], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[870], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[853], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[982], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[1202], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1063], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[1010], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[899], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[30], num_bonds=[407], num_residues=[30]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[636], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[932], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[697], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[588], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[804], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[535], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[694], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[820], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[767], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[994], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[728], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[875], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[912], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[924], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1268], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1002], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[1226], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[921], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[955], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[642], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[748], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[918], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[630], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[698], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[440], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[535], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[679], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[650], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[582], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[630], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[637], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[34], num_bonds=[550], num_residues=[34]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[828], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[499], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[451], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[935], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[723], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1156], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1083], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[910], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[31], num_bonds=[432], num_residues=[31]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[386], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[564], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[996], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[605], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[904], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[686], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1082], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[919], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1396], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[814], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1087], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[87], num_bonds=[1325], num_residues=[87]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1111], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[871], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[871], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[999], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[944], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1042], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1019], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[837], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[953], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[1187], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1137], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[26], num_bonds=[394], num_residues=[26]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[764], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[844], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[585], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[813], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[922], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1097], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[116], num_bonds=[2444], num_residues=[116]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[868], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[741], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[854], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[977], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[847], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1105], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[632], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[781], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[795], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[792], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[851], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[798], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[698], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[453], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[836], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[768], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[650], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[26], num_bonds=[367], num_residues=[26]),
#  PackedProtein(batch_size=1, num_atoms=[28], num_bonds=[392], num_residues=[28]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[644], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[583], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[21], num_bonds=[249], num_residues=[21]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[550], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[23], num_bonds=[290], num_residues=[23]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[966], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[640], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[870], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[479], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[826], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[313], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[74], num_bonds=[1129], num_residues=[74]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[876], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[675], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[23], num_bonds=[334], num_residues=[23]),
#  PackedProtein(batch_size=1, num_atoms=[16], num_bonds=[208], num_residues=[16]),
#  PackedProtein(batch_size=1, num_atoms=[25], num_bonds=[361], num_residues=[25]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[765], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[819], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1005], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[23], num_bonds=[314], num_residues=[23]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[905], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1090], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[548], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[773], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[519], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[608], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1013], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[604], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[651], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[794], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1148], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[74], num_bonds=[1282], num_residues=[74]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1096], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[1214], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[542], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[809], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[977], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[801], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1028], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[931], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[835], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[890], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[88], num_bonds=[1729], num_residues=[88]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[551], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[81], num_bonds=[1573], num_residues=[81]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1082], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[946], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[563], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[675], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[655], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[558], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[566], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[891], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[866], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[630], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1097], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[776], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[28], num_bonds=[343], num_residues=[28]),
#  ...]

# %%
indexes = range(len(output_list)) # len(output_list)
indexes = tqdm(indexes, "ESM Combining ...")
for index in indexes: 
    # read each esm protein from pkl file
    curProtein = output_list[index]
    protein_pkl = '../../../data/dta-datasets/PDBbind/esm/gearnetesm_'+str(index)+'.pkl'
    with utils.smart_open(protein_pkl, "rb") as fin:
        output_protein = pickle.load(fin)
    output_list[index].residue_feature = output_protein.residue_feature
# Out:
# ESM Combining ...: 100%|██████████| 9018/9018 [02:35<00:00, 57.88it/s]

# %%
output_list[8866].residue_feature.shape
# Out:
# torch.Size([29, 1280])

# %%
len(output_list)
# Out:
# 9018

# %%
protein_pkl = '../../../data/dta-datasets/PDBbind/gearnetesm_pocket_Protein.pkl'
with utils.smart_open(protein_pkl, "wb") as fout:
    pickle.dump(output_list, fout)

# %% [markdown]
# ## Pocket Construction

# %% [markdown]
# #### GearNet Construction

# %%
import pickle
import torch
from tqdm import tqdm
from torchdrug import utils, transforms, data, models, layers
# Out:
# No CUDA runtime is found, using CUDA_HOME='C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.7'

# %%
protein_pkl = '../../../data/dta-datasets/PDBbind/gearnet_pocket_Protein.pkl'
with utils.smart_open(protein_pkl, "rb") as fin:
    output_list = pickle.load(fin)

# %%
len(output_list)
# Out:
# 19404

# %%
sequence_model = models.ESM(path="../../../result/model_pth/ESM/", model="ESM-2_650M")

# %%
def esmProcess(esmModel, curProtein, pklName):
    """
    curProtein: list of packedProtein 
    pklName: the pkl name to store the protein
    """
    output = esmModel(curProtein, curProtein.residue_feature)
    curProtein.residue_feature = output['residue_feature']
    curProtein.mol_feature = output['graph_feature']
    protein_pkl = '../../../data/dta-datasets/PDBbind/esm/gearnetesm_' + pklName + '.pkl'
    with utils.smart_open(protein_pkl, "wb") as fout:
        pickle.dump(curProtein, fout)

# %%
indexes = range(19000, len(output_list))   # len(output_list)
indexes = tqdm(indexes, "ESM Computing ......")
for index in indexes:
    curProtein = output_list[index]
    esmProcess(sequence_model, curProtein, str(index))
# Out:
# ESM Computing ......: 100%|██████████| 404/404 [20:06<00:00,  2.99s/it]

# %% [markdown]
# Read all pkl and aggreate into the new list

# %%
import pickle
import torch
from tqdm import tqdm
from torchdrug import utils, transforms, data, models, layers
# Out:
# No CUDA runtime is found, using CUDA_HOME='C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.7'

# %%
protein_pkl = '../../../data/dta-datasets/PDBbind/gearnet_pocket_Protein.pkl'
with utils.smart_open(protein_pkl, "rb") as fin:
    output_list = pickle.load(fin)

# %%
len(output_list)
# Out:
# 19404

# %%
indexes = range(len(output_list)) # len(output_list)
indexes = tqdm(indexes, "ESM Combining ...")
for index in indexes: 
    # read each esm protein from pkl file
    protein_pkl = '../../../data/dta-datasets/PDBbind/esm/gearnetesm_'+str(index)+'.pkl'
    with utils.smart_open(protein_pkl, "rb") as fin:
        output_protein = pickle.load(fin)
    output_list[index].residue_feature = output_protein.residue_feature
# Out:
# ESM Combining ...: 100%|██████████| 19404/19404 [12:44<00:00, 25.39it/s]

# %%
output_list[0].residue_feature.shape
# Out:
# torch.Size([49, 1280])

# %%
len(output_list)
# Out:
# 19404

# %%
protein_pkl = '../../../data/dta-datasets/PDBbind/gearnetesm_pocket_Protein.pkl'
with utils.smart_open(protein_pkl, "wb") as fout:
    pickle.dump(output_list, fout)

# %% [markdown]
# ***

# %%
import pickle
import torch
from tqdm import tqdm
from torchdrug import utils, transforms, data, models, layers

# %%
protein_pkl = '../../../data/dta-datasets/PDBbind/gearnet_Protein.pkl'
with utils.smart_open(protein_pkl, "rb") as fin:
    output_list = pickle.load(fin)

# %%
output_list
# Out:
# [PackedProtein(batch_size=1, num_atoms=[1161], num_bonds=[23749], num_residues=[1161]),
#  PackedProtein(batch_size=1, num_atoms=[501], num_bonds=[9852], num_residues=[501]),
#  PackedProtein(batch_size=1, num_atoms=[165], num_bonds=[3709], num_residues=[165]),
#  PackedProtein(batch_size=1, num_atoms=[852], num_bonds=[19860], num_residues=[852]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5615], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[611], num_bonds=[14390], num_residues=[611]),
#  PackedProtein(batch_size=1, num_atoms=[939], num_bonds=[20431], num_residues=[939]),
#  PackedProtein(batch_size=1, num_atoms=[295], num_bonds=[6629], num_residues=[295]),
#  PackedProtein(batch_size=1, num_atoms=[296], num_bonds=[6538], num_residues=[296]),
#  PackedProtein(batch_size=1, num_atoms=[1017], num_bonds=[23912], num_residues=[1017]),
#  PackedProtein(batch_size=1, num_atoms=[364], num_bonds=[7158], num_residues=[364]),
#  PackedProtein(batch_size=1, num_atoms=[430], num_bonds=[7629], num_residues=[430]),
#  PackedProtein(batch_size=1, num_atoms=[244], num_bonds=[4891], num_residues=[244]),
#  PackedProtein(batch_size=1, num_atoms=[244], num_bonds=[4882], num_residues=[244]),
#  PackedProtein(batch_size=1, num_atoms=[509], num_bonds=[10824], num_residues=[509]),
#  PackedProtein(batch_size=1, num_atoms=[652], num_bonds=[12512], num_residues=[652]),
#  PackedProtein(batch_size=1, num_atoms=[165], num_bonds=[3233], num_residues=[165]),
#  PackedProtein(batch_size=1, num_atoms=[301], num_bonds=[5884], num_residues=[301]),
#  PackedProtein(batch_size=1, num_atoms=[1078], num_bonds=[24632], num_residues=[1078]),
#  PackedProtein(batch_size=1, num_atoms=[557], num_bonds=[12134], num_residues=[557]),
#  PackedProtein(batch_size=1, num_atoms=[939], num_bonds=[21263], num_residues=[939]),
#  PackedProtein(batch_size=1, num_atoms=[942], num_bonds=[21516], num_residues=[942]),
#  PackedProtein(batch_size=1, num_atoms=[1377], num_bonds=[29382], num_residues=[1377]),
#  PackedProtein(batch_size=1, num_atoms=[721], num_bonds=[15357], num_residues=[721]),
#  PackedProtein(batch_size=1, num_atoms=[1242], num_bonds=[30937], num_residues=[1242]),
#  PackedProtein(batch_size=1, num_atoms=[504], num_bonds=[10392], num_residues=[504]),
#  PackedProtein(batch_size=1, num_atoms=[608], num_bonds=[13321], num_residues=[608]),
#  PackedProtein(batch_size=1, num_atoms=[439], num_bonds=[8580], num_residues=[439]),
#  PackedProtein(batch_size=1, num_atoms=[172], num_bonds=[3833], num_residues=[172]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5238], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5196], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5185], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[865], num_bonds=[19609], num_residues=[865]),
#  PackedProtein(batch_size=1, num_atoms=[458], num_bonds=[10504], num_residues=[458]),
#  PackedProtein(batch_size=1, num_atoms=[2220], num_bonds=[48542], num_residues=[2220]),
#  PackedProtein(batch_size=1, num_atoms=[960], num_bonds=[22017], num_residues=[960]),
#  PackedProtein(batch_size=1, num_atoms=[988], num_bonds=[21779], num_residues=[988]),
#  PackedProtein(batch_size=1, num_atoms=[105], num_bonds=[2024], num_residues=[105]),
#  PackedProtein(batch_size=1, num_atoms=[105], num_bonds=[2004], num_residues=[105]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2036], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7704], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[471], num_bonds=[10850], num_residues=[471]),
#  PackedProtein(batch_size=1, num_atoms=[656], num_bonds=[14002], num_residues=[656]),
#  PackedProtein(batch_size=1, num_atoms=[429], num_bonds=[7472], num_residues=[429]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5254], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[301], num_bonds=[6024], num_residues=[301]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5225], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[1473], num_bonds=[32399], num_residues=[1473]),
#  PackedProtein(batch_size=1, num_atoms=[559], num_bonds=[12131], num_residues=[559]),
#  PackedProtein(batch_size=1, num_atoms=[1078], num_bonds=[24640], num_residues=[1078]),
#  PackedProtein(batch_size=1, num_atoms=[346], num_bonds=[7484], num_residues=[346]),
#  PackedProtein(batch_size=1, num_atoms=[525], num_bonds=[11486], num_residues=[525]),
#  PackedProtein(batch_size=1, num_atoms=[744], num_bonds=[15577], num_residues=[744]),
#  PackedProtein(batch_size=1, num_atoms=[1025], num_bonds=[23873], num_residues=[1025]),
#  PackedProtein(batch_size=1, num_atoms=[498], num_bonds=[10377], num_residues=[498]),
#  PackedProtein(batch_size=1, num_atoms=[894], num_bonds=[19858], num_residues=[894]),
#  PackedProtein(batch_size=1, num_atoms=[346], num_bonds=[7499], num_residues=[346]),
#  PackedProtein(batch_size=1, num_atoms=[390], num_bonds=[8464], num_residues=[390]),
#  PackedProtein(batch_size=1, num_atoms=[244], num_bonds=[4862], num_residues=[244]),
#  PackedProtein(batch_size=1, num_atoms=[165], num_bonds=[3720], num_residues=[165]),
#  PackedProtein(batch_size=1, num_atoms=[392], num_bonds=[8391], num_residues=[392]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5642], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[922], num_bonds=[19254], num_residues=[922]),
#  PackedProtein(batch_size=1, num_atoms=[454], num_bonds=[9521], num_residues=[454]),
#  PackedProtein(batch_size=1, num_atoms=[414], num_bonds=[9383], num_residues=[414]),
#  PackedProtein(batch_size=1, num_atoms=[1509], num_bonds=[33178], num_residues=[1509]),
#  PackedProtein(batch_size=1, num_atoms=[445], num_bonds=[9391], num_residues=[445]),
#  PackedProtein(batch_size=1, num_atoms=[130], num_bonds=[1956], num_residues=[130]),
#  PackedProtein(batch_size=1, num_atoms=[758], num_bonds=[16676], num_residues=[758]),
#  PackedProtein(batch_size=1, num_atoms=[282], num_bonds=[4946], num_residues=[282]),
#  PackedProtein(batch_size=1, num_atoms=[430], num_bonds=[9258], num_residues=[430]),
#  PackedProtein(batch_size=1, num_atoms=[545], num_bonds=[11075], num_residues=[545]),
#  PackedProtein(batch_size=1, num_atoms=[317], num_bonds=[6706], num_residues=[317]),
#  PackedProtein(batch_size=1, num_atoms=[324], num_bonds=[6789], num_residues=[324]),
#  PackedProtein(batch_size=1, num_atoms=[388], num_bonds=[8612], num_residues=[388]),
#  PackedProtein(batch_size=1, num_atoms=[352], num_bonds=[7536], num_residues=[352]),
#  PackedProtein(batch_size=1, num_atoms=[465], num_bonds=[10595], num_residues=[465]),
#  PackedProtein(batch_size=1, num_atoms=[138], num_bonds=[3183], num_residues=[138]),
#  PackedProtein(batch_size=1, num_atoms=[1298], num_bonds=[27316], num_residues=[1298]),
#  PackedProtein(batch_size=1, num_atoms=[276], num_bonds=[5675], num_residues=[276]),
#  PackedProtein(batch_size=1, num_atoms=[497], num_bonds=[10833], num_residues=[497]),
#  PackedProtein(batch_size=1, num_atoms=[130], num_bonds=[1971], num_residues=[130]),
#  PackedProtein(batch_size=1, num_atoms=[301], num_bonds=[5901], num_residues=[301]),
#  PackedProtein(batch_size=1, num_atoms=[153], num_bonds=[3437], num_residues=[153]),
#  PackedProtein(batch_size=1, num_atoms=[591], num_bonds=[13204], num_residues=[591]),
#  PackedProtein(batch_size=1, num_atoms=[1449], num_bonds=[31629], num_residues=[1449]),
#  PackedProtein(batch_size=1, num_atoms=[4032], num_bonds=[80016], num_residues=[4032]),
#  PackedProtein(batch_size=1, num_atoms=[155], num_bonds=[3492], num_residues=[155]),
#  PackedProtein(batch_size=1, num_atoms=[318], num_bonds=[7257], num_residues=[318]),
#  PackedProtein(batch_size=1, num_atoms=[278], num_bonds=[5320], num_residues=[278]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5268], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[1263], num_bonds=[31765], num_residues=[1263]),
#  PackedProtein(batch_size=1, num_atoms=[448], num_bonds=[10673], num_residues=[448]),
#  PackedProtein(batch_size=1, num_atoms=[307], num_bonds=[6055], num_residues=[307]),
#  PackedProtein(batch_size=1, num_atoms=[271], num_bonds=[5282], num_residues=[271]),
#  PackedProtein(batch_size=1, num_atoms=[578], num_bonds=[11060], num_residues=[578]),
#  PackedProtein(batch_size=1, num_atoms=[299], num_bonds=[5715], num_residues=[299]),
#  PackedProtein(batch_size=1, num_atoms=[515], num_bonds=[11096], num_residues=[515]),
#  PackedProtein(batch_size=1, num_atoms=[239], num_bonds=[5574], num_residues=[239]),
#  PackedProtein(batch_size=1, num_atoms=[635], num_bonds=[13094], num_residues=[635]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5240], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[16375], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[305], num_bonds=[6917], num_residues=[305]),
#  PackedProtein(batch_size=1, num_atoms=[275], num_bonds=[5908], num_residues=[275]),
#  PackedProtein(batch_size=1, num_atoms=[150], num_bonds=[3179], num_residues=[150]),
#  PackedProtein(batch_size=1, num_atoms=[278], num_bonds=[6049], num_residues=[278]),
#  PackedProtein(batch_size=1, num_atoms=[515], num_bonds=[11046], num_residues=[515]),
#  PackedProtein(batch_size=1, num_atoms=[514], num_bonds=[10911], num_residues=[514]),
#  PackedProtein(batch_size=1, num_atoms=[1473], num_bonds=[32297], num_residues=[1473]),
#  PackedProtein(batch_size=1, num_atoms=[2100], num_bonds=[49530], num_residues=[2100]),
#  PackedProtein(batch_size=1, num_atoms=[847], num_bonds=[19548], num_residues=[847]),
#  PackedProtein(batch_size=1, num_atoms=[150], num_bonds=[3185], num_residues=[150]),
#  PackedProtein(batch_size=1, num_atoms=[534], num_bonds=[10462], num_residues=[534]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5234], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[445], num_bonds=[10385], num_residues=[445]),
#  PackedProtein(batch_size=1, num_atoms=[463], num_bonds=[8970], num_residues=[463]),
#  PackedProtein(batch_size=1, num_atoms=[493], num_bonds=[10290], num_residues=[493]),
#  PackedProtein(batch_size=1, num_atoms=[487], num_bonds=[8868], num_residues=[487]),
#  PackedProtein(batch_size=1, num_atoms=[487], num_bonds=[8972], num_residues=[487]),
#  PackedProtein(batch_size=1, num_atoms=[4044], num_bonds=[94536], num_residues=[4044]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5217], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[1556], num_bonds=[42080], num_residues=[1556]),
#  PackedProtein(batch_size=1, num_atoms=[163], num_bonds=[3355], num_residues=[163]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7739], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[212], num_bonds=[4295], num_residues=[212]),
#  PackedProtein(batch_size=1, num_atoms=[1602], num_bonds=[36458], num_residues=[1602]),
#  PackedProtein(batch_size=1, num_atoms=[263], num_bonds=[5652], num_residues=[263]),
#  PackedProtein(batch_size=1, num_atoms=[2598], num_bonds=[59406], num_residues=[2598]),
#  PackedProtein(batch_size=1, num_atoms=[894], num_bonds=[19645], num_residues=[894]),
#  PackedProtein(batch_size=1, num_atoms=[325], num_bonds=[6502], num_residues=[325]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5193], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[355], num_bonds=[7653], num_residues=[355]),
#  PackedProtein(batch_size=1, num_atoms=[130], num_bonds=[1965], num_residues=[130]),
#  PackedProtein(batch_size=1, num_atoms=[130], num_bonds=[1960], num_residues=[130]),
#  PackedProtein(batch_size=1, num_atoms=[426], num_bonds=[7798], num_residues=[426]),
#  PackedProtein(batch_size=1, num_atoms=[330], num_bonds=[7453], num_residues=[330]),
#  PackedProtein(batch_size=1, num_atoms=[140], num_bonds=[2124], num_residues=[140]),
#  PackedProtein(batch_size=1, num_atoms=[164], num_bonds=[3697], num_residues=[164]),
#  PackedProtein(batch_size=1, num_atoms=[544], num_bonds=[11034], num_residues=[544]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5207], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[390], num_bonds=[8491], num_residues=[390]),
#  PackedProtein(batch_size=1, num_atoms=[363], num_bonds=[6633], num_residues=[363]),
#  PackedProtein(batch_size=1, num_atoms=[497], num_bonds=[10793], num_residues=[497]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5686], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[544], num_bonds=[11081], num_residues=[544]),
#  PackedProtein(batch_size=1, num_atoms=[306], num_bonds=[6908], num_residues=[306]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5190], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[278], num_bonds=[6057], num_residues=[278]),
#  PackedProtein(batch_size=1, num_atoms=[210], num_bonds=[4258], num_residues=[210]),
#  PackedProtein(batch_size=1, num_atoms=[425], num_bonds=[7768], num_residues=[425]),
#  PackedProtein(batch_size=1, num_atoms=[272], num_bonds=[5330], num_residues=[272]),
#  PackedProtein(batch_size=1, num_atoms=[338], num_bonds=[7589], num_residues=[338]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5269], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[555], num_bonds=[13548], num_residues=[555]),
#  PackedProtein(batch_size=1, num_atoms=[698], num_bonds=[14885], num_residues=[698]),
#  PackedProtein(batch_size=1, num_atoms=[208], num_bonds=[4100], num_residues=[208]),
#  PackedProtein(batch_size=1, num_atoms=[341], num_bonds=[8495], num_residues=[341]),
#  PackedProtein(batch_size=1, num_atoms=[651], num_bonds=[11665], num_residues=[651]),
#  PackedProtein(batch_size=1, num_atoms=[260], num_bonds=[4927], num_residues=[260]),
#  PackedProtein(batch_size=1, num_atoms=[628], num_bonds=[13508], num_residues=[628]),
#  PackedProtein(batch_size=1, num_atoms=[528], num_bonds=[10124], num_residues=[528]),
#  PackedProtein(batch_size=1, num_atoms=[1014], num_bonds=[22741], num_residues=[1014]),
#  PackedProtein(batch_size=1, num_atoms=[794], num_bonds=[18090], num_residues=[794]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7646], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[164], num_bonds=[3717], num_residues=[164]),
#  PackedProtein(batch_size=1, num_atoms=[1616], num_bonds=[32794], num_residues=[1616]),
#  PackedProtein(batch_size=1, num_atoms=[488], num_bonds=[9013], num_residues=[488]),
#  PackedProtein(batch_size=1, num_atoms=[740], num_bonds=[15265], num_residues=[740]),
#  PackedProtein(batch_size=1, num_atoms=[437], num_bonds=[9294], num_residues=[437]),
#  PackedProtein(batch_size=1, num_atoms=[438], num_bonds=[9309], num_residues=[438]),
#  PackedProtein(batch_size=1, num_atoms=[550], num_bonds=[12808], num_residues=[550]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5283], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[334], num_bonds=[7639], num_residues=[334]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5671], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[346], num_bonds=[7446], num_residues=[346]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[830], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[875], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[164], num_bonds=[3707], num_residues=[164]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[16402], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[498], num_bonds=[10385], num_residues=[498]),
#  PackedProtein(batch_size=1, num_atoms=[109], num_bonds=[1627], num_residues=[109]),
#  PackedProtein(batch_size=1, num_atoms=[457], num_bonds=[8636], num_residues=[457]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7627], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[330], num_bonds=[7444], num_residues=[330]),
#  PackedProtein(batch_size=1, num_atoms=[437], num_bonds=[8417], num_residues=[437]),
#  PackedProtein(batch_size=1, num_atoms=[1010], num_bonds=[24408], num_residues=[1010]),
#  PackedProtein(batch_size=1, num_atoms=[328], num_bonds=[6541], num_residues=[328]),
#  PackedProtein(batch_size=1, num_atoms=[1618], num_bonds=[32480], num_residues=[1618]),
#  PackedProtein(batch_size=1, num_atoms=[496], num_bonds=[11870], num_residues=[496]),
#  PackedProtein(batch_size=1, num_atoms=[306], num_bonds=[5851], num_residues=[306]),
#  PackedProtein(batch_size=1, num_atoms=[301], num_bonds=[5749], num_residues=[301]),
#  PackedProtein(batch_size=1, num_atoms=[1025], num_bonds=[24082], num_residues=[1025]),
#  PackedProtein(batch_size=1, num_atoms=[341], num_bonds=[6758], num_residues=[341]),
#  PackedProtein(batch_size=1, num_atoms=[150], num_bonds=[3184], num_residues=[150]),
#  PackedProtein(batch_size=1, num_atoms=[390], num_bonds=[8467], num_residues=[390]),
#  PackedProtein(batch_size=1, num_atoms=[993], num_bonds=[21393], num_residues=[993]),
#  PackedProtein(batch_size=1, num_atoms=[312], num_bonds=[7053], num_residues=[312]),
#  PackedProtein(batch_size=1, num_atoms=[336], num_bonds=[6296], num_residues=[336]),
#  PackedProtein(batch_size=1, num_atoms=[208], num_bonds=[3895], num_residues=[208]),
#  PackedProtein(batch_size=1, num_atoms=[147], num_bonds=[2705], num_residues=[147]),
#  PackedProtein(batch_size=1, num_atoms=[504], num_bonds=[9815], num_residues=[504]),
#  PackedProtein(batch_size=1, num_atoms=[1724], num_bonds=[40972], num_residues=[1724]),
#  PackedProtein(batch_size=1, num_atoms=[326], num_bonds=[6630], num_residues=[326]),
#  PackedProtein(batch_size=1, num_atoms=[353], num_bonds=[6143], num_residues=[353]),
#  PackedProtein(batch_size=1, num_atoms=[619], num_bonds=[11376], num_residues=[619]),
#  PackedProtein(batch_size=1, num_atoms=[616], num_bonds=[11344], num_residues=[616]),
#  PackedProtein(batch_size=1, num_atoms=[767], num_bonds=[18259], num_residues=[767]),
#  PackedProtein(batch_size=1, num_atoms=[678], num_bonds=[17155], num_residues=[678]),
#  PackedProtein(batch_size=1, num_atoms=[127], num_bonds=[2042], num_residues=[127]),
#  PackedProtein(batch_size=1, num_atoms=[381], num_bonds=[7235], num_residues=[381]),
#  PackedProtein(batch_size=1, num_atoms=[764], num_bonds=[16267], num_residues=[764]),
#  PackedProtein(batch_size=1, num_atoms=[172], num_bonds=[3927], num_residues=[172]),
#  PackedProtein(batch_size=1, num_atoms=[275], num_bonds=[5284], num_residues=[275]),
#  PackedProtein(batch_size=1, num_atoms=[4044], num_bonds=[94950], num_residues=[4044]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[16314], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[461], num_bonds=[9722], num_residues=[461]),
#  PackedProtein(batch_size=1, num_atoms=[156], num_bonds=[2909], num_residues=[156]),
#  PackedProtein(batch_size=1, num_atoms=[320], num_bonds=[7269], num_residues=[320]),
#  PackedProtein(batch_size=1, num_atoms=[390], num_bonds=[8481], num_residues=[390]),
#  PackedProtein(batch_size=1, num_atoms=[688], num_bonds=[15437], num_residues=[688]),
#  PackedProtein(batch_size=1, num_atoms=[898], num_bonds=[22290], num_residues=[898]),
#  PackedProtein(batch_size=1, num_atoms=[283], num_bonds=[5459], num_residues=[283]),
#  PackedProtein(batch_size=1, num_atoms=[334], num_bonds=[6229], num_residues=[334]),
#  PackedProtein(batch_size=1, num_atoms=[150], num_bonds=[3179], num_residues=[150]),
#  PackedProtein(batch_size=1, num_atoms=[418], num_bonds=[8991], num_residues=[418]),
#  PackedProtein(batch_size=1, num_atoms=[1509], num_bonds=[33196], num_residues=[1509]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5282], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[306], num_bonds=[5782], num_residues=[306]),
#  PackedProtein(batch_size=1, num_atoms=[2382], num_bonds=[50643], num_residues=[2382]),
#  PackedProtein(batch_size=1, num_atoms=[1014], num_bonds=[22689], num_residues=[1014]),
#  PackedProtein(batch_size=1, num_atoms=[2102], num_bonds=[49519], num_residues=[2102]),
#  PackedProtein(batch_size=1, num_atoms=[607], num_bonds=[12628], num_residues=[607]),
#  PackedProtein(batch_size=1, num_atoms=[232], num_bonds=[4964], num_residues=[232]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[16329], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[570], num_bonds=[11535], num_residues=[570]),
#  PackedProtein(batch_size=1, num_atoms=[337], num_bonds=[6369], num_residues=[337]),
#  PackedProtein(batch_size=1, num_atoms=[258], num_bonds=[5687], num_residues=[258]),
#  PackedProtein(batch_size=1, num_atoms=[288], num_bonds=[5506], num_residues=[288]),
#  PackedProtein(batch_size=1, num_atoms=[1556], num_bonds=[41118], num_residues=[1556]),
#  PackedProtein(batch_size=1, num_atoms=[692], num_bonds=[15310], num_residues=[692]),
#  PackedProtein(batch_size=1, num_atoms=[692], num_bonds=[15111], num_residues=[692]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2033], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[551], num_bonds=[12795], num_residues=[551]),
#  PackedProtein(batch_size=1, num_atoms=[497], num_bonds=[10461], num_residues=[497]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[16307], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[357], num_bonds=[7665], num_residues=[357]),
#  PackedProtein(batch_size=1, num_atoms=[274], num_bonds=[5352], num_residues=[274]),
#  PackedProtein(batch_size=1, num_atoms=[1868], num_bonds=[42869], num_residues=[1868]),
#  PackedProtein(batch_size=1, num_atoms=[4044], num_bonds=[94625], num_residues=[4044]),
#  PackedProtein(batch_size=1, num_atoms=[303], num_bonds=[6514], num_residues=[303]),
#  PackedProtein(batch_size=1, num_atoms=[246], num_bonds=[5656], num_residues=[246]),
#  PackedProtein(batch_size=1, num_atoms=[2598], num_bonds=[59782], num_residues=[2598]),
#  PackedProtein(batch_size=1, num_atoms=[892], num_bonds=[19516], num_residues=[892]),
#  PackedProtein(batch_size=1, num_atoms=[1287], num_bonds=[28023], num_residues=[1287]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5640], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[147], num_bonds=[2697], num_residues=[147]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5706], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[254], num_bonds=[5545], num_residues=[254]),
#  PackedProtein(batch_size=1, num_atoms=[178], num_bonds=[3268], num_residues=[178]),
#  PackedProtein(batch_size=1, num_atoms=[124], num_bonds=[1799], num_residues=[124]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[1795], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[1789], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[252], num_bonds=[4265], num_residues=[252]),
#  PackedProtein(batch_size=1, num_atoms=[210], num_bonds=[4225], num_residues=[210]),
#  PackedProtein(batch_size=1, num_atoms=[332], num_bonds=[6638], num_residues=[332]),
#  PackedProtein(batch_size=1, num_atoms=[1724], num_bonds=[40064], num_residues=[1724]),
#  PackedProtein(batch_size=1, num_atoms=[179], num_bonds=[3255], num_residues=[179]),
#  PackedProtein(batch_size=1, num_atoms=[961], num_bonds=[22219], num_residues=[961]),
#  PackedProtein(batch_size=1, num_atoms=[2100], num_bonds=[49511], num_residues=[2100]),
#  PackedProtein(batch_size=1, num_atoms=[197], num_bonds=[4021], num_residues=[197]),
#  PackedProtein(batch_size=1, num_atoms=[124], num_bonds=[2479], num_residues=[124]),
#  PackedProtein(batch_size=1, num_atoms=[1666], num_bonds=[40456], num_residues=[1666]),
#  PackedProtein(batch_size=1, num_atoms=[525], num_bonds=[11515], num_residues=[525]),
#  PackedProtein(batch_size=1, num_atoms=[307], num_bonds=[6787], num_residues=[307]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7689], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[728], num_bonds=[16175], num_residues=[728]),
#  PackedProtein(batch_size=1, num_atoms=[330], num_bonds=[7461], num_residues=[330]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2030], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[262], num_bonds=[5642], num_residues=[262]),
#  PackedProtein(batch_size=1, num_atoms=[678], num_bonds=[17123], num_residues=[678]),
#  PackedProtein(batch_size=1, num_atoms=[4060], num_bonds=[94551], num_residues=[4060]),
#  PackedProtein(batch_size=1, num_atoms=[138], num_bonds=[2891], num_residues=[138]),
#  PackedProtein(batch_size=1, num_atoms=[105], num_bonds=[2052], num_residues=[105]),
#  PackedProtein(batch_size=1, num_atoms=[2100], num_bonds=[51180], num_residues=[2100]),
#  PackedProtein(batch_size=1, num_atoms=[1314], num_bonds=[30150], num_residues=[1314]),
#  PackedProtein(batch_size=1, num_atoms=[263], num_bonds=[5666], num_residues=[263]),
#  PackedProtein(batch_size=1, num_atoms=[1152], num_bonds=[24472], num_residues=[1152]),
#  PackedProtein(batch_size=1, num_atoms=[283], num_bonds=[5528], num_residues=[283]),
#  PackedProtein(batch_size=1, num_atoms=[644], num_bonds=[14934], num_residues=[644]),
#  PackedProtein(batch_size=1, num_atoms=[544], num_bonds=[11060], num_residues=[544]),
#  PackedProtein(batch_size=1, num_atoms=[208], num_bonds=[4048], num_residues=[208]),
#  PackedProtein(batch_size=1, num_atoms=[124], num_bonds=[2463], num_residues=[124]),
#  PackedProtein(batch_size=1, num_atoms=[1618], num_bonds=[32560], num_residues=[1618]),
#  PackedProtein(batch_size=1, num_atoms=[2598], num_bonds=[59569], num_residues=[2598]),
#  PackedProtein(batch_size=1, num_atoms=[262], num_bonds=[5745], num_residues=[262]),
#  PackedProtein(batch_size=1, num_atoms=[426], num_bonds=[7856], num_residues=[426]),
#  PackedProtein(batch_size=1, num_atoms=[329], num_bonds=[7450], num_residues=[329]),
#  PackedProtein(batch_size=1, num_atoms=[389], num_bonds=[8814], num_residues=[389]),
#  PackedProtein(batch_size=1, num_atoms=[105], num_bonds=[2002], num_residues=[105]),
#  PackedProtein(batch_size=1, num_atoms=[1488], num_bonds=[28261], num_residues=[1488]),
#  PackedProtein(batch_size=1, num_atoms=[426], num_bonds=[7770], num_residues=[426]),
#  PackedProtein(batch_size=1, num_atoms=[528], num_bonds=[10174], num_residues=[528]),
#  PackedProtein(batch_size=1, num_atoms=[426], num_bonds=[7837], num_residues=[426]),
#  PackedProtein(batch_size=1, num_atoms=[265], num_bonds=[4951], num_residues=[265]),
#  PackedProtein(batch_size=1, num_atoms=[238], num_bonds=[4843], num_residues=[238]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2056], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[338], num_bonds=[6790], num_residues=[338]),
#  PackedProtein(batch_size=1, num_atoms=[942], num_bonds=[21137], num_residues=[942]),
#  PackedProtein(batch_size=1, num_atoms=[1032], num_bonds=[22924], num_residues=[1032]),
#  PackedProtein(batch_size=1, num_atoms=[274], num_bonds=[5365], num_residues=[274]),
#  PackedProtein(batch_size=1, num_atoms=[866], num_bonds=[17906], num_residues=[866]),
#  PackedProtein(batch_size=1, num_atoms=[1624], num_bonds=[32828], num_residues=[1624]),
#  PackedProtein(batch_size=1, num_atoms=[942], num_bonds=[21301], num_residues=[942]),
#  PackedProtein(batch_size=1, num_atoms=[414], num_bonds=[9374], num_residues=[414]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[1113], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2001], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[536], num_bonds=[12966], num_residues=[536]),
#  PackedProtein(batch_size=1, num_atoms=[1620], num_bonds=[32732], num_residues=[1620]),
#  PackedProtein(batch_size=1, num_atoms=[304], num_bonds=[5800], num_residues=[304]),
#  PackedProtein(batch_size=1, num_atoms=[564], num_bonds=[11341], num_residues=[564]),
#  PackedProtein(batch_size=1, num_atoms=[335], num_bonds=[6275], num_residues=[335]),
#  PackedProtein(batch_size=1, num_atoms=[307], num_bonds=[6914], num_residues=[307]),
#  PackedProtein(batch_size=1, num_atoms=[492], num_bonds=[9549], num_residues=[492]),
#  PackedProtein(batch_size=1, num_atoms=[792], num_bonds=[17054], num_residues=[792]),
#  PackedProtein(batch_size=1, num_atoms=[223], num_bonds=[5204], num_residues=[223]),
#  PackedProtein(batch_size=1, num_atoms=[497], num_bonds=[11163], num_residues=[497]),
#  PackedProtein(batch_size=1, num_atoms=[98], num_bonds=[1788], num_residues=[98]),
#  PackedProtein(batch_size=1, num_atoms=[330], num_bonds=[7467], num_residues=[330]),
#  PackedProtein(batch_size=1, num_atoms=[344], num_bonds=[7208], num_residues=[344]),
#  PackedProtein(batch_size=1, num_atoms=[371], num_bonds=[8130], num_residues=[371]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[886], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[152], num_bonds=[2661], num_residues=[152]),
#  PackedProtein(batch_size=1, num_atoms=[426], num_bonds=[7957], num_residues=[426]),
#  PackedProtein(batch_size=1, num_atoms=[329], num_bonds=[7452], num_residues=[329]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5230], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5163], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5147], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5170], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2027], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[554], num_bonds=[11085], num_residues=[554]),
#  PackedProtein(batch_size=1, num_atoms=[1620], num_bonds=[33050], num_residues=[1620]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7659], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[245], num_bonds=[4390], num_residues=[245]),
#  PackedProtein(batch_size=1, num_atoms=[764], num_bonds=[16223], num_residues=[764]),
#  PackedProtein(batch_size=1, num_atoms=[262], num_bonds=[5646], num_residues=[262]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5200], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[438], num_bonds=[9381], num_residues=[438]),
#  PackedProtein(batch_size=1, num_atoms=[593], num_bonds=[13695], num_residues=[593]),
#  PackedProtein(batch_size=1, num_atoms=[492], num_bonds=[10300], num_residues=[492]),
#  PackedProtein(batch_size=1, num_atoms=[1653], num_bonds=[38532], num_residues=[1653]),
#  PackedProtein(batch_size=1, num_atoms=[496], num_bonds=[10587], num_residues=[496]),
#  PackedProtein(batch_size=1, num_atoms=[854], num_bonds=[20697], num_residues=[854]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7681], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[939], num_bonds=[21212], num_residues=[939]),
#  PackedProtein(batch_size=1, num_atoms=[4060], num_bonds=[94944], num_residues=[4060]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5664], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[147], num_bonds=[2707], num_residues=[147]),
#  PackedProtein(batch_size=1, num_atoms=[621], num_bonds=[11415], num_residues=[621]),
#  PackedProtein(batch_size=1, num_atoms=[156], num_bonds=[2902], num_residues=[156]),
#  PackedProtein(batch_size=1, num_atoms=[156], num_bonds=[2904], num_residues=[156]),
#  PackedProtein(batch_size=1, num_atoms=[430], num_bonds=[7572], num_residues=[430]),
#  PackedProtein(batch_size=1, num_atoms=[542], num_bonds=[11524], num_residues=[542]),
#  PackedProtein(batch_size=1, num_atoms=[267], num_bonds=[5134], num_residues=[267]),
#  PackedProtein(batch_size=1, num_atoms=[416], num_bonds=[8530], num_residues=[416]),
#  PackedProtein(batch_size=1, num_atoms=[291], num_bonds=[6644], num_residues=[291]),
#  PackedProtein(batch_size=1, num_atoms=[284], num_bonds=[5467], num_residues=[284]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5218], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[390], num_bonds=[8467], num_residues=[390]),
#  PackedProtein(batch_size=1, num_atoms=[265], num_bonds=[4965], num_residues=[265]),
#  PackedProtein(batch_size=1, num_atoms=[287], num_bonds=[5755], num_residues=[287]),
#  PackedProtein(batch_size=1, num_atoms=[447], num_bonds=[9506], num_residues=[447]),
#  PackedProtein(batch_size=1, num_atoms=[395], num_bonds=[9886], num_residues=[395]),
#  PackedProtein(batch_size=1, num_atoms=[239], num_bonds=[5601], num_residues=[239]),
#  PackedProtein(batch_size=1, num_atoms=[532], num_bonds=[12287], num_residues=[532]),
#  PackedProtein(batch_size=1, num_atoms=[188], num_bonds=[3294], num_residues=[188]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[16307], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[124], num_bonds=[1873], num_residues=[124]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7776], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[522], num_bonds=[10418], num_residues=[522]),
#  PackedProtein(batch_size=1, num_atoms=[524], num_bonds=[10584], num_residues=[524]),
#  PackedProtein(batch_size=1, num_atoms=[864], num_bonds=[20968], num_residues=[864]),
#  PackedProtein(batch_size=1, num_atoms=[407], num_bonds=[8928], num_residues=[407]),
#  PackedProtein(batch_size=1, num_atoms=[105], num_bonds=[1978], num_residues=[105]),
#  PackedProtein(batch_size=1, num_atoms=[316], num_bonds=[6084], num_residues=[316]),
#  PackedProtein(batch_size=1, num_atoms=[212], num_bonds=[4279], num_residues=[212]),
#  PackedProtein(batch_size=1, num_atoms=[498], num_bonds=[9829], num_residues=[498]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5261], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[85], num_bonds=[1600], num_residues=[85]),
#  PackedProtein(batch_size=1, num_atoms=[246], num_bonds=[4099], num_residues=[246]),
#  PackedProtein(batch_size=1, num_atoms=[522], num_bonds=[11400], num_residues=[522]),
#  PackedProtein(batch_size=1, num_atoms=[792], num_bonds=[16696], num_residues=[792]),
#  PackedProtein(batch_size=1, num_atoms=[993], num_bonds=[21944], num_residues=[993]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[1678], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[4032], num_bonds=[80232], num_residues=[4032]),
#  PackedProtein(batch_size=1, num_atoms=[4032], num_bonds=[80304], num_residues=[4032]),
#  PackedProtein(batch_size=1, num_atoms=[427], num_bonds=[9875], num_residues=[427]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5276], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[1329], num_bonds=[27916], num_residues=[1329]),
#  PackedProtein(batch_size=1, num_atoms=[2658], num_bonds=[57024], num_residues=[2658]),
#  PackedProtein(batch_size=1, num_atoms=[463], num_bonds=[9687], num_residues=[463]),
#  PackedProtein(batch_size=1, num_atoms=[320], num_bonds=[7270], num_residues=[320]),
#  PackedProtein(batch_size=1, num_atoms=[764], num_bonds=[16295], num_residues=[764]),
#  PackedProtein(batch_size=1, num_atoms=[296], num_bonds=[6083], num_residues=[296]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2048], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[115], num_bonds=[1734], num_residues=[115]),
#  PackedProtein(batch_size=1, num_atoms=[1314], num_bonds=[29433], num_residues=[1314]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5669], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5685], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[642], num_bonds=[15234], num_residues=[642]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[827], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[505], num_bonds=[9596], num_residues=[505]),
#  PackedProtein(batch_size=1, num_atoms=[264], num_bonds=[5029], num_residues=[264]),
#  PackedProtein(batch_size=1, num_atoms=[540], num_bonds=[11463], num_residues=[540]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5253], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[546], num_bonds=[10562], num_residues=[546]),
#  PackedProtein(batch_size=1, num_atoms=[515], num_bonds=[11187], num_residues=[515]),
#  PackedProtein(batch_size=1, num_atoms=[672], num_bonds=[14083], num_residues=[672]),
#  PackedProtein(batch_size=1, num_atoms=[126], num_bonds=[2007], num_residues=[126]),
#  PackedProtein(batch_size=1, num_atoms=[1509], num_bonds=[33118], num_residues=[1509]),
#  PackedProtein(batch_size=1, num_atoms=[380], num_bonds=[8495], num_residues=[380]),
#  PackedProtein(batch_size=1, num_atoms=[511], num_bonds=[10040], num_residues=[511]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5261], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[4324], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[213], num_bonds=[4331], num_residues=[213]),
#  PackedProtein(batch_size=1, num_atoms=[493], num_bonds=[9635], num_residues=[493]),
#  PackedProtein(batch_size=1, num_atoms=[492], num_bonds=[9587], num_residues=[492]),
#  PackedProtein(batch_size=1, num_atoms=[471], num_bonds=[10777], num_residues=[471]),
#  PackedProtein(batch_size=1, num_atoms=[1371], num_bonds=[29119], num_residues=[1371]),
#  PackedProtein(batch_size=1, num_atoms=[537], num_bonds=[11177], num_residues=[537]),
#  PackedProtein(batch_size=1, num_atoms=[267], num_bonds=[5141], num_residues=[267]),
#  PackedProtein(batch_size=1, num_atoms=[296], num_bonds=[6276], num_residues=[296]),
#  PackedProtein(batch_size=1, num_atoms=[515], num_bonds=[11140], num_residues=[515]),
#  PackedProtein(batch_size=1, num_atoms=[361], num_bonds=[7377], num_residues=[361]),
#  PackedProtein(batch_size=1, num_atoms=[2728], num_bonds=[62496], num_residues=[2728]),
#  PackedProtein(batch_size=1, num_atoms=[2772], num_bonds=[58905], num_residues=[2772]),
#  PackedProtein(batch_size=1, num_atoms=[1072], num_bonds=[23254], num_residues=[1072]),
#  PackedProtein(batch_size=1, num_atoms=[90], num_bonds=[1368], num_residues=[90]),
#  PackedProtein(batch_size=1, num_atoms=[377], num_bonds=[8455], num_residues=[377]),
#  PackedProtein(batch_size=1, num_atoms=[1016], num_bonds=[22804], num_residues=[1016]),
#  PackedProtein(batch_size=1, num_atoms=[378], num_bonds=[8501], num_residues=[378]),
#  PackedProtein(batch_size=1, num_atoms=[370], num_bonds=[8270], num_residues=[370]),
#  PackedProtein(batch_size=1, num_atoms=[606], num_bonds=[12604], num_residues=[606]),
#  PackedProtein(batch_size=1, num_atoms=[606], num_bonds=[12664], num_residues=[606]),
#  PackedProtein(batch_size=1, num_atoms=[607], num_bonds=[12465], num_residues=[607]),
#  PackedProtein(batch_size=1, num_atoms=[607], num_bonds=[12523], num_residues=[607]),
#  PackedProtein(batch_size=1, num_atoms=[180], num_bonds=[3100], num_residues=[180]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7749], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[379], num_bonds=[8509], num_residues=[379]),
#  PackedProtein(batch_size=1, num_atoms=[1535], num_bonds=[30644], num_residues=[1535]),
#  PackedProtein(batch_size=1, num_atoms=[924], num_bonds=[20434], num_residues=[924]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5681], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5692], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5701], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[1872], num_bonds=[37276], num_residues=[1872]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7737], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[351], num_bonds=[7528], num_residues=[351]),
#  PackedProtein(batch_size=1, num_atoms=[711], num_bonds=[15678], num_residues=[711]),
#  PackedProtein(batch_size=1, num_atoms=[812], num_bonds=[16398], num_residues=[812]),
#  PackedProtein(batch_size=1, num_atoms=[838], num_bonds=[16974], num_residues=[838]),
#  PackedProtein(batch_size=1, num_atoms=[806], num_bonds=[16434], num_residues=[806]),
#  PackedProtein(batch_size=1, num_atoms=[410], num_bonds=[7716], num_residues=[410]),
#  PackedProtein(batch_size=1, num_atoms=[195], num_bonds=[3999], num_residues=[195]),
#  PackedProtein(batch_size=1, num_atoms=[228], num_bonds=[5253], num_residues=[228]),
#  PackedProtein(batch_size=1, num_atoms=[251], num_bonds=[5866], num_residues=[251]),
#  PackedProtein(batch_size=1, num_atoms=[1350], num_bonds=[31592], num_residues=[1350]),
#  PackedProtein(batch_size=1, num_atoms=[188], num_bonds=[3293], num_residues=[188]),
#  PackedProtein(batch_size=1, num_atoms=[547], num_bonds=[10558], num_residues=[547]),
#  PackedProtein(batch_size=1, num_atoms=[613], num_bonds=[13171], num_residues=[613]),
#  PackedProtein(batch_size=1, num_atoms=[1069], num_bonds=[22763], num_residues=[1069]),
#  PackedProtein(batch_size=1, num_atoms=[233], num_bonds=[4711], num_residues=[233]),
#  PackedProtein(batch_size=1, num_atoms=[438], num_bonds=[9332], num_residues=[438]),
#  PackedProtein(batch_size=1, num_atoms=[157], num_bonds=[3101], num_residues=[157]),
#  PackedProtein(batch_size=1, num_atoms=[1557], num_bonds=[41971], num_residues=[1557]),
#  PackedProtein(batch_size=1, num_atoms=[214], num_bonds=[4301], num_residues=[214]),
#  PackedProtein(batch_size=1, num_atoms=[2856], num_bonds=[66104], num_residues=[2856]),
#  PackedProtein(batch_size=1, num_atoms=[188], num_bonds=[4281], num_residues=[188]),
#  PackedProtein(batch_size=1, num_atoms=[261], num_bonds=[4905], num_residues=[261]),
#  PackedProtein(batch_size=1, num_atoms=[125], num_bonds=[2578], num_residues=[125]),
#  PackedProtein(batch_size=1, num_atoms=[514], num_bonds=[10253], num_residues=[514]),
#  PackedProtein(batch_size=1, num_atoms=[370], num_bonds=[7899], num_residues=[370]),
#  PackedProtein(batch_size=1, num_atoms=[522], num_bonds=[10242], num_residues=[522]),
#  PackedProtein(batch_size=1, num_atoms=[472], num_bonds=[11000], num_residues=[472]),
#  PackedProtein(batch_size=1, num_atoms=[185], num_bonds=[3285], num_residues=[185]),
#  PackedProtein(batch_size=1, num_atoms=[314], num_bonds=[7002], num_residues=[314]),
#  PackedProtein(batch_size=1, num_atoms=[258], num_bonds=[5099], num_residues=[258]),
#  PackedProtein(batch_size=1, num_atoms=[320], num_bonds=[7294], num_residues=[320]),
#  PackedProtein(batch_size=1, num_atoms=[510], num_bonds=[11323], num_residues=[510]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1296], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[558], num_bonds=[11280], num_residues=[558]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7714], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[617], num_bonds=[11365], num_residues=[617]),
#  PackedProtein(batch_size=1, num_atoms=[502], num_bonds=[9943], num_residues=[502]),
#  PackedProtein(batch_size=1, num_atoms=[493], num_bonds=[9680], num_residues=[493]),
#  PackedProtein(batch_size=1, num_atoms=[410], num_bonds=[8528], num_residues=[410]),
#  PackedProtein(batch_size=1, num_atoms=[383], num_bonds=[9255], num_residues=[383]),
#  PackedProtein(batch_size=1, num_atoms=[121], num_bonds=[2120], num_residues=[121]),
#  PackedProtein(batch_size=1, num_atoms=[1270], num_bonds=[29532], num_residues=[1270]),
#  PackedProtein(batch_size=1, num_atoms=[607], num_bonds=[12618], num_residues=[607]),
#  PackedProtein(batch_size=1, num_atoms=[828], num_bonds=[16778], num_residues=[828]),
#  PackedProtein(batch_size=1, num_atoms=[265], num_bonds=[4969], num_residues=[265]),
#  PackedProtein(batch_size=1, num_atoms=[528], num_bonds=[10416], num_residues=[528]),
#  PackedProtein(batch_size=1, num_atoms=[297], num_bonds=[5854], num_residues=[297]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5186], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[301], num_bonds=[5746], num_residues=[301]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[7675], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[620], num_bonds=[11453], num_residues=[620]),
#  PackedProtein(batch_size=1, num_atoms=[659], num_bonds=[15731], num_residues=[659]),
#  PackedProtein(batch_size=1, num_atoms=[228], num_bonds=[5257], num_residues=[228]),
#  PackedProtein(batch_size=1, num_atoms=[227], num_bonds=[4546], num_residues=[227]),
#  PackedProtein(batch_size=1, num_atoms=[343], num_bonds=[7403], num_residues=[343]),
#  PackedProtein(batch_size=1, num_atoms=[390], num_bonds=[8467], num_residues=[390]),
#  PackedProtein(batch_size=1, num_atoms=[592], num_bonds=[13229], num_residues=[592]),
#  PackedProtein(batch_size=1, num_atoms=[425], num_bonds=[8953], num_residues=[425]),
#  PackedProtein(batch_size=1, num_atoms=[248], num_bonds=[5041], num_residues=[248]),
#  PackedProtein(batch_size=1, num_atoms=[337], num_bonds=[6310], num_residues=[337]),
#  PackedProtein(batch_size=1, num_atoms=[884], num_bonds=[19523], num_residues=[884]),
#  PackedProtein(batch_size=1, num_atoms=[276], num_bonds=[6073], num_residues=[276]),
#  PackedProtein(batch_size=1, num_atoms=[792], num_bonds=[16676], num_residues=[792]),
#  PackedProtein(batch_size=1, num_atoms=[398], num_bonds=[7867], num_residues=[398]),
#  PackedProtein(batch_size=1, num_atoms=[394], num_bonds=[8629], num_residues=[394]),
#  PackedProtein(batch_size=1, num_atoms=[461], num_bonds=[9783], num_residues=[461]),
#  PackedProtein(batch_size=1, num_atoms=[446], num_bonds=[9509], num_residues=[446]),
#  PackedProtein(batch_size=1, num_atoms=[274], num_bonds=[5343], num_residues=[274]),
#  PackedProtein(batch_size=1, num_atoms=[698], num_bonds=[13648], num_residues=[698]),
#  PackedProtein(batch_size=1, num_atoms=[607], num_bonds=[12616], num_residues=[607]),
#  PackedProtein(batch_size=1, num_atoms=[161], num_bonds=[3242], num_residues=[161]),
#  PackedProtein(batch_size=1, num_atoms=[271], num_bonds=[5377], num_residues=[271]),
#  PackedProtein(batch_size=1, num_atoms=[177], num_bonds=[3414], num_residues=[177]),
#  PackedProtein(batch_size=1, num_atoms=[162], num_bonds=[3320], num_residues=[162]),
#  PackedProtein(batch_size=1, num_atoms=[1212], num_bonds=[25115], num_residues=[1212]),
#  PackedProtein(batch_size=1, num_atoms=[129], num_bonds=[2480], num_residues=[129]),
#  PackedProtein(batch_size=1, num_atoms=[273], num_bonds=[4494], num_residues=[273]),
#  PackedProtein(batch_size=1, num_atoms=[87], num_bonds=[1218], num_residues=[87]),
#  PackedProtein(batch_size=1, num_atoms=[95], num_bonds=[1600], num_residues=[95]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[992], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[334], num_bonds=[6747], num_residues=[334]),
#  PackedProtein(batch_size=1, num_atoms=[656], num_bonds=[15615], num_residues=[656]),
#  PackedProtein(batch_size=1, num_atoms=[606], num_bonds=[12590], num_residues=[606]),
#  PackedProtein(batch_size=1, num_atoms=[604], num_bonds=[13102], num_residues=[604]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5663], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5608], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[267], num_bonds=[5082], num_residues=[267]),
#  PackedProtein(batch_size=1, num_atoms=[136], num_bonds=[2899], num_residues=[136]),
#  PackedProtein(batch_size=1, num_atoms=[461], num_bonds=[9728], num_residues=[461]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5281], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[993], num_bonds=[22143], num_residues=[993]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5262], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[394], num_bonds=[8783], num_residues=[394]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[2409], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5634], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[489], num_bonds=[11572], num_residues=[489]),
#  PackedProtein(batch_size=1, num_atoms=[138], num_bonds=[2938], num_residues=[138]),
#  PackedProtein(batch_size=1, num_atoms=[493], num_bonds=[9628], num_residues=[493]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5702], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[904], num_bonds=[21901], num_residues=[904]),
#  PackedProtein(batch_size=1, num_atoms=[133], num_bonds=[2409], num_residues=[133]),
#  PackedProtein(batch_size=1, num_atoms=[297], num_bonds=[5595], num_residues=[297]),
#  PackedProtein(batch_size=1, num_atoms=[281], num_bonds=[6183], num_residues=[281]),
#  PackedProtein(batch_size=1, num_atoms=[1209], num_bonds=[25379], num_residues=[1209]),
#  PackedProtein(batch_size=1, num_atoms=[245], num_bonds=[5695], num_residues=[245]),
# ...
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1132], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[166], num_bonds=[3237], num_residues=[166]),
#  PackedProtein(batch_size=1, num_atoms=[1602], num_bonds=[36952], num_residues=[1602]),
#  PackedProtein(batch_size=1, num_atoms=[373], num_bonds=[8680], num_residues=[373]),
#  PackedProtein(batch_size=1, num_atoms=[1317], num_bonds=[30203], num_residues=[1317]),
#  PackedProtein(batch_size=1, num_atoms=[1318], num_bonds=[30240], num_residues=[1318]),
#  PackedProtein(batch_size=1, num_atoms=[314], num_bonds=[7339], num_residues=[314]),
#  PackedProtein(batch_size=1, num_atoms=[475], num_bonds=[9461], num_residues=[475]),
#  PackedProtein(batch_size=1, num_atoms=[376], num_bonds=[6903], num_residues=[376]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[1796], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[241], num_bonds=[5707], num_residues=[241]),
#  PackedProtein(batch_size=1, num_atoms=[363], num_bonds=[6633], num_residues=[363]),
#  PackedProtein(batch_size=1, num_atoms=[472], num_bonds=[11041], num_residues=[472]),
#  PackedProtein(batch_size=1, num_atoms=[299], num_bonds=[5688], num_residues=[299]),
#  PackedProtein(batch_size=1, num_atoms=[636], num_bonds=[12464], num_residues=[636]),
#  PackedProtein(batch_size=1, num_atoms=[378], num_bonds=[7804], num_residues=[378]),
#  PackedProtein(batch_size=1, num_atoms=[480], num_bonds=[11367], num_residues=[480]),
#  PackedProtein(batch_size=1, num_atoms=[113], num_bonds=[2181], num_residues=[113]),
#  PackedProtein(batch_size=1, num_atoms=[181], num_bonds=[3781], num_residues=[181]),
#  PackedProtein(batch_size=1, num_atoms=[229], num_bonds=[5012], num_residues=[229]),
#  PackedProtein(batch_size=1, num_atoms=[437], num_bonds=[9322], num_residues=[437]),
#  PackedProtein(batch_size=1, num_atoms=[437], num_bonds=[9309], num_residues=[437]),
#  PackedProtein(batch_size=1, num_atoms=[119], num_bonds=[2332], num_residues=[119]),
#  PackedProtein(batch_size=1, num_atoms=[1015], num_bonds=[22951], num_residues=[1015]),
#  PackedProtein(batch_size=1, num_atoms=[469], num_bonds=[11242], num_residues=[469]),
#  PackedProtein(batch_size=1, num_atoms=[145], num_bonds=[2856], num_residues=[145]),
#  PackedProtein(batch_size=1, num_atoms=[220], num_bonds=[4504], num_residues=[220]),
#  PackedProtein(batch_size=1, num_atoms=[99], num_bonds=[1896], num_residues=[99]),
#  PackedProtein(batch_size=1, num_atoms=[119], num_bonds=[2117], num_residues=[119]),
#  PackedProtein(batch_size=1, num_atoms=[998], num_bonds=[22276], num_residues=[998]),
#  PackedProtein(batch_size=1, num_atoms=[515], num_bonds=[11199], num_residues=[515]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[607], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[1646], num_bonds=[33246], num_residues=[1646]),
#  PackedProtein(batch_size=1, num_atoms=[1662], num_bonds=[33844], num_residues=[1662]),
#  PackedProtein(batch_size=1, num_atoms=[1662], num_bonds=[33790], num_residues=[1662]),
#  PackedProtein(batch_size=1, num_atoms=[458], num_bonds=[11064], num_residues=[458]),
#  PackedProtein(batch_size=1, num_atoms=[879], num_bonds=[19677], num_residues=[879]),
#  PackedProtein(batch_size=1, num_atoms=[258], num_bonds=[5013], num_residues=[258]),
#  PackedProtein(batch_size=1, num_atoms=[133], num_bonds=[2575], num_residues=[133]),
#  PackedProtein(batch_size=1, num_atoms=[405], num_bonds=[8267], num_residues=[405]),
#  PackedProtein(batch_size=1, num_atoms=[565], num_bonds=[11385], num_residues=[565]),
#  PackedProtein(batch_size=1, num_atoms=[562], num_bonds=[11359], num_residues=[562]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[2399], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[771], num_bonds=[18351], num_residues=[771]),
#  PackedProtein(batch_size=1, num_atoms=[914], num_bonds=[19238], num_residues=[914]),
#  PackedProtein(batch_size=1, num_atoms=[258], num_bonds=[5696], num_residues=[258]),
#  PackedProtein(batch_size=1, num_atoms=[208], num_bonds=[4081], num_residues=[208]),
#  PackedProtein(batch_size=1, num_atoms=[117], num_bonds=[2553], num_residues=[117]),
#  PackedProtein(batch_size=1, num_atoms=[581], num_bonds=[8111], num_residues=[581]),
#  PackedProtein(batch_size=1, num_atoms=[581], num_bonds=[8622], num_residues=[581]),
#  PackedProtein(batch_size=1, num_atoms=[210], num_bonds=[4073], num_residues=[210]),
#  PackedProtein(batch_size=1, num_atoms=[2111], num_bonds=[47515], num_residues=[2111]),
#  PackedProtein(batch_size=1, num_atoms=[1653], num_bonds=[38603], num_residues=[1653]),
#  PackedProtein(batch_size=1, num_atoms=[338], num_bonds=[5943], num_residues=[338]),
#  PackedProtein(batch_size=1, num_atoms=[4032], num_bonds=[79872], num_residues=[4032]),
#  PackedProtein(batch_size=1, num_atoms=[4032], num_bonds=[79272], num_residues=[4032]),
#  PackedProtein(batch_size=1, num_atoms=[525], num_bonds=[10870], num_residues=[525]),
#  PackedProtein(batch_size=1, num_atoms=[182], num_bonds=[3226], num_residues=[182]),
#  PackedProtein(batch_size=1, num_atoms=[337], num_bonds=[6277], num_residues=[337]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[1048], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[121], num_bonds=[1942], num_residues=[121]),
#  PackedProtein(batch_size=1, num_atoms=[708], num_bonds=[15827], num_residues=[708]),
#  PackedProtein(batch_size=1, num_atoms=[218], num_bonds=[3969], num_residues=[218]),
#  PackedProtein(batch_size=1, num_atoms=[72], num_bonds=[869], num_residues=[72]),
#  PackedProtein(batch_size=1, num_atoms=[225], num_bonds=[4560], num_residues=[225]),
#  PackedProtein(batch_size=1, num_atoms=[222], num_bonds=[4558], num_residues=[222]),
#  PackedProtein(batch_size=1, num_atoms=[265], num_bonds=[4997], num_residues=[265]),
#  PackedProtein(batch_size=1, num_atoms=[87], num_bonds=[1261], num_residues=[87]),
#  PackedProtein(batch_size=1, num_atoms=[1568], num_bonds=[41810], num_residues=[1568]),
#  PackedProtein(batch_size=1, num_atoms=[416], num_bonds=[7353], num_residues=[416]),
#  PackedProtein(batch_size=1, num_atoms=[976], num_bonds=[19527], num_residues=[976]),
#  PackedProtein(batch_size=1, num_atoms=[4216], num_bonds=[91968], num_residues=[4216]),
#  PackedProtein(batch_size=1, num_atoms=[2736], num_bonds=[57931], num_residues=[2736]),
#  PackedProtein(batch_size=1, num_atoms=[357], num_bonds=[8043], num_residues=[357]),
#  PackedProtein(batch_size=1, num_atoms=[238], num_bonds=[5543], num_residues=[238]),
#  PackedProtein(batch_size=1, num_atoms=[993], num_bonds=[21257], num_residues=[993]),
#  PackedProtein(batch_size=1, num_atoms=[681], num_bonds=[12971], num_residues=[681]),
#  PackedProtein(batch_size=1, num_atoms=[124], num_bonds=[2467], num_residues=[124]),
#  PackedProtein(batch_size=1, num_atoms=[426], num_bonds=[9245], num_residues=[426]),
#  PackedProtein(batch_size=1, num_atoms=[1557], num_bonds=[42336], num_residues=[1557]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5672], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[214], num_bonds=[4041], num_residues=[214]),
#  PackedProtein(batch_size=1, num_atoms=[506], num_bonds=[9195], num_residues=[506]),
#  PackedProtein(batch_size=1, num_atoms=[188], num_bonds=[3299], num_residues=[188]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[6208], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[240], num_bonds=[5569], num_residues=[240]),
#  PackedProtein(batch_size=1, num_atoms=[83], num_bonds=[1190], num_residues=[83]),
#  PackedProtein(batch_size=1, num_atoms=[684], num_bonds=[13536], num_residues=[684]),
#  PackedProtein(batch_size=1, num_atoms=[4216], num_bonds=[92136], num_residues=[4216]),
#  PackedProtein(batch_size=1, num_atoms=[145], num_bonds=[2875], num_residues=[145]),
#  PackedProtein(batch_size=1, num_atoms=[211], num_bonds=[4125], num_residues=[211]),
#  PackedProtein(batch_size=1, num_atoms=[327], num_bonds=[6244], num_residues=[327]),
#  PackedProtein(batch_size=1, num_atoms=[348], num_bonds=[7331], num_residues=[348]),
#  PackedProtein(batch_size=1, num_atoms=[257], num_bonds=[5673], num_residues=[257]),
#  PackedProtein(batch_size=1, num_atoms=[154], num_bonds=[3509], num_residues=[154]),
#  PackedProtein(batch_size=1, num_atoms=[900], num_bonds=[19582], num_residues=[900]),
#  PackedProtein(batch_size=1, num_atoms=[606], num_bonds=[12613], num_residues=[606]),
#  PackedProtein(batch_size=1, num_atoms=[386], num_bonds=[6616], num_residues=[386]),
#  PackedProtein(batch_size=1, num_atoms=[267], num_bonds=[5016], num_residues=[267]),
#  PackedProtein(batch_size=1, num_atoms=[498], num_bonds=[10351], num_residues=[498]),
#  PackedProtein(batch_size=1, num_atoms=[268], num_bonds=[5157], num_residues=[268]),
#  PackedProtein(batch_size=1, num_atoms=[998], num_bonds=[22272], num_residues=[998]),
#  PackedProtein(batch_size=1, num_atoms=[998], num_bonds=[22250], num_residues=[998]),
#  PackedProtein(batch_size=1, num_atoms=[111], num_bonds=[2217], num_residues=[111]),
#  PackedProtein(batch_size=1, num_atoms=[898], num_bonds=[22255], num_residues=[898]),
#  PackedProtein(batch_size=1, num_atoms=[637], num_bonds=[13473], num_residues=[637]),
#  PackedProtein(batch_size=1, num_atoms=[115], num_bonds=[2479], num_residues=[115]),
#  PackedProtein(batch_size=1, num_atoms=[1014], num_bonds=[22819], num_residues=[1014]),
#  PackedProtein(batch_size=1, num_atoms=[792], num_bonds=[16970], num_residues=[792]),
#  PackedProtein(batch_size=1, num_atoms=[1088], num_bonds=[23772], num_residues=[1088]),
#  PackedProtein(batch_size=1, num_atoms=[431], num_bonds=[8985], num_residues=[431]),
#  PackedProtein(batch_size=1, num_atoms=[230], num_bonds=[5611], num_residues=[230]),
#  PackedProtein(batch_size=1, num_atoms=[476], num_bonds=[9958], num_residues=[476]),
#  PackedProtein(batch_size=1, num_atoms=[285], num_bonds=[6045], num_residues=[285]),
#  PackedProtein(batch_size=1, num_atoms=[570], num_bonds=[12611], num_residues=[570]),
#  PackedProtein(batch_size=1, num_atoms=[560], num_bonds=[12587], num_residues=[560]),
#  PackedProtein(batch_size=1, num_atoms=[500], num_bonds=[11114], num_residues=[500]),
#  PackedProtein(batch_size=1, num_atoms=[130], num_bonds=[1957], num_residues=[130]),
#  PackedProtein(batch_size=1, num_atoms=[840], num_bonds=[21221], num_residues=[840]),
#  PackedProtein(batch_size=1, num_atoms=[88], num_bonds=[1091], num_residues=[88]),
#  PackedProtein(batch_size=1, num_atoms=[377], num_bonds=[7694], num_residues=[377]),
#  PackedProtein(batch_size=1, num_atoms=[660], num_bonds=[15388], num_residues=[660]),
#  PackedProtein(batch_size=1, num_atoms=[4044], num_bonds=[94723], num_residues=[4044]),
#  PackedProtein(batch_size=1, num_atoms=[104], num_bonds=[2064], num_residues=[104]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5699], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[578], num_bonds=[12002], num_residues=[578]),
#  PackedProtein(batch_size=1, num_atoms=[332], num_bonds=[5862], num_residues=[332]),
#  PackedProtein(batch_size=1, num_atoms=[183], num_bonds=[3431], num_residues=[183]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[1796], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[242], num_bonds=[4861], num_residues=[242]),
#  PackedProtein(batch_size=1, num_atoms=[670], num_bonds=[12224], num_residues=[670]),
#  PackedProtein(batch_size=1, num_atoms=[1644], num_bonds=[38669], num_residues=[1644]),
#  PackedProtein(batch_size=1, num_atoms=[220], num_bonds=[4529], num_residues=[220]),
#  PackedProtein(batch_size=1, num_atoms=[219], num_bonds=[4950], num_residues=[219]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[2412], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[472], num_bonds=[9994], num_residues=[472]),
#  PackedProtein(batch_size=1, num_atoms=[546], num_bonds=[10455], num_residues=[546]),
#  PackedProtein(batch_size=1, num_atoms=[930], num_bonds=[19358], num_residues=[930]),
#  PackedProtein(batch_size=1, num_atoms=[369], num_bonds=[9076], num_residues=[369]),
#  PackedProtein(batch_size=1, num_atoms=[374], num_bonds=[7180], num_residues=[374]),
#  PackedProtein(batch_size=1, num_atoms=[224], num_bonds=[5201], num_residues=[224]),
#  PackedProtein(batch_size=1, num_atoms=[189], num_bonds=[3319], num_residues=[189]),
#  PackedProtein(batch_size=1, num_atoms=[328], num_bonds=[6737], num_residues=[328]),
#  PackedProtein(batch_size=1, num_atoms=[330], num_bonds=[5824], num_residues=[330]),
#  PackedProtein(batch_size=1, num_atoms=[188], num_bonds=[3319], num_residues=[188]),
#  PackedProtein(batch_size=1, num_atoms=[448], num_bonds=[8700], num_residues=[448]),
#  PackedProtein(batch_size=1, num_atoms=[3168], num_bonds=[65814], num_residues=[3168]),
#  PackedProtein(batch_size=1, num_atoms=[138], num_bonds=[2856], num_residues=[138]),
#  PackedProtein(batch_size=1, num_atoms=[209], num_bonds=[4087], num_residues=[209]),
#  PackedProtein(batch_size=1, num_atoms=[485], num_bonds=[9871], num_residues=[485]),
#  PackedProtein(batch_size=1, num_atoms=[713], num_bonds=[15735], num_residues=[713]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[5261], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[1658], num_bonds=[34354], num_residues=[1658]),
#  PackedProtein(batch_size=1, num_atoms=[566], num_bonds=[11473], num_residues=[566]),
#  PackedProtein(batch_size=1, num_atoms=[674], num_bonds=[15042], num_residues=[674]),
#  PackedProtein(batch_size=1, num_atoms=[284], num_bonds=[5903], num_residues=[284]),
#  PackedProtein(batch_size=1, num_atoms=[495], num_bonds=[10487], num_residues=[495]),
#  PackedProtein(batch_size=1, num_atoms=[275], num_bonds=[6113], num_residues=[275]),
#  PackedProtein(batch_size=1, num_atoms=[672], num_bonds=[14332], num_residues=[672]),
#  PackedProtein(batch_size=1, num_atoms=[462], num_bonds=[8914], num_residues=[462]),
#  PackedProtein(batch_size=1, num_atoms=[542], num_bonds=[11146], num_residues=[542]),
#  PackedProtein(batch_size=1, num_atoms=[1016], num_bonds=[23071], num_residues=[1016]),
#  PackedProtein(batch_size=1, num_atoms=[1620], num_bonds=[32760], num_residues=[1620]),
#  PackedProtein(batch_size=1, num_atoms=[829], num_bonds=[19365], num_residues=[829]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5661], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[337], num_bonds=[6403], num_residues=[337]),
#  PackedProtein(batch_size=1, num_atoms=[268], num_bonds=[5191], num_residues=[268]),
#  PackedProtein(batch_size=1, num_atoms=[559], num_bonds=[12294], num_residues=[559]),
#  PackedProtein(batch_size=1, num_atoms=[325], num_bonds=[6257], num_residues=[325]),
#  PackedProtein(batch_size=1, num_atoms=[244], num_bonds=[5598], num_residues=[244]),
#  PackedProtein(batch_size=1, num_atoms=[692], num_bonds=[13451], num_residues=[692]),
#  PackedProtein(batch_size=1, num_atoms=[184], num_bonds=[3803], num_residues=[184]),
#  PackedProtein(batch_size=1, num_atoms=[240], num_bonds=[5588], num_residues=[240]),
#  PackedProtein(batch_size=1, num_atoms=[331], num_bonds=[7401], num_residues=[331]),
#  PackedProtein(batch_size=1, num_atoms=[138], num_bonds=[2897], num_residues=[138]),
#  PackedProtein(batch_size=1, num_atoms=[782], num_bonds=[17209], num_residues=[782]),
#  PackedProtein(batch_size=1, num_atoms=[107], num_bonds=[2145], num_residues=[107]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[607], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[515], num_bonds=[10889], num_residues=[515]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[2025], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[1088], num_bonds=[23796], num_residues=[1088]),
#  PackedProtein(batch_size=1, num_atoms=[490], num_bonds=[10437], num_residues=[490]),
#  PackedProtein(batch_size=1, num_atoms=[1094], num_bonds=[22466], num_residues=[1094]),
#  PackedProtein(batch_size=1, num_atoms=[1094], num_bonds=[22444], num_residues=[1094]),
#  PackedProtein(batch_size=1, num_atoms=[807], num_bonds=[20536], num_residues=[807]),
#  PackedProtein(batch_size=1, num_atoms=[807], num_bonds=[20580], num_residues=[807]),
#  ...]

# %%
len(output_list)
# Out:
# 19404

# %%
sequence_model = models.ESM(path="../../../result/model_pth/ESM/", model="ESM-2_650M")

# %%
def esmProcess(esmModel, curProtein, pklName):
    """
    curProtein: list of packedProtein 
    pklName: the pkl name to store the protein
    """
    output = esmModel(curProtein, curProtein.residue_feature)
    curProtein.residue_feature = output['residue_feature']
    curProtein.mol_feature = output['graph_feature']
    protein_pkl = '../../../data/dta-datasets/PDBbind/esm/gearnetesm_' + pklName + '.pkl'
    with utils.smart_open(protein_pkl, "wb") as fout:
        pickle.dump(curProtein, fout)

# %%
indexes = range(0,1000)   # len(transform_list)
indexes = tqdm(indexes, "ESM Computing ......")
for index in indexes:
    curProtein = output_list[index]
    esmProcess(sequence_model, curProtein, str(index))
# Out:
# ESM Computing ......:   0%|          | 0/1000 [00:00<?, ?it/s]d:\miniconda3\envs\torchdrug\lib\site-packages\torchdrug\models\esm.py:122: UserWarning: ESM can only encode proteins within 1022 residues. Truncate the input to fit into ESM.
#   warnings.warn("ESM can only encode proteins within %d residues. Truncate the input to fit into ESM."
# ESM Computing ......:   0%|          | 2/1000 [00:34<4:45:57, 17.19s/it]
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# d:\Code\CurrentWork\Demo\DTA_Work\script\notebook\DatasetBuilding\PDBbindESM.ipynb Cell 9' in <cell line: 3>()
#
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000008?line=2'>3</a> for index in indexes:
#
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000008?line=3'>4</a>     curProtein = output_list[index]
#
# ----> <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000008?line=4'>5</a>     esmProcess(sequence_model, curProtein, str(index))
#
#
#
# d:\Code\CurrentWork\Demo\DTA_Work\script\notebook\DatasetBuilding\PDBbindESM.ipynb Cell 8' in esmProcess(esmModel, curProtein, pklName)
#
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000007?line=0'>1</a> def esmProcess(esmModel, curProtein, pklName):
#
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000007?line=1'>2</a>     """
#
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000007?line=2'>3</a>     curProtein: list of packedProtein
#
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000007?line=3'>4</a>     pklName: the pkl name to store the protein
#
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000007?line=4'>5</a>     """
#
# ----> <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000007?line=5'>6</a>     output = esmModel(curProtein, curProtein.residue_feature)
#
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000007?line=6'>7</a>     curProtein.residue_feature = output['residue_feature']
#
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000007?line=7'>8</a>     curProtein.mol_feature = output['graph_feature']
#
#
#
# File d:\miniconda3\envs\torchdrug\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#
#    1191 # this function, and just call forward.
#
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
#
# -> 1194     return forward_call(*input, **kwargs)
#
#    1195 # Do not call functions when jit is used
#
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
#
#
# File d:\miniconda3\envs\torchdrug\lib\site-packages\torchdrug\models\esm.py:139, in EvolutionaryScaleModeling.forward(self, graph, input, all_loss, metric)
#
#     136     input, size_ext = functional._extend(input, size_ext, eos, torch.ones_like(size_ext))
#
#     137 input = functional.variadic_to_padded(input, size_ext, value=self.alphabet.padding_idx)[0]  # (batch_size, max_residues)
#
# --> 139 output = self.model(input, repr_layers=[33])
#
#     140 residue_feature = output["representations"][33]
#
#     141 # output = self.model(input, repr_layers=[12])  # for esm2-35M contains 12 layers
#
#     142 # residue_feature = output["representations"][12]
#
#
#
# File d:\miniconda3\envs\torchdrug\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#
#    1191 # this function, and just call forward.
#
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
#
# -> 1194     return forward_call(*input, **kwargs)
#
#    1195 # Do not call functions when jit is used
#
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
#
#
# File d:\miniconda3\envs\torchdrug\lib\site-packages\esm\model\esm2.py:112, in ESM2.forward(self, tokens, repr_layers, need_head_weights, return_contacts)
#
#     109     padding_mask = None
#
#     111 for layer_idx, layer in enumerate(self.layers):
#
# --> 112     x, attn = layer(
#
#     113         x,
#
#     114         self_attn_padding_mask=padding_mask,
#
#     115         need_head_weights=need_head_weights,
#
#     116     )
#
#     117     if (layer_idx + 1) in repr_layers:
#
#     118         hidden_representations[layer_idx + 1] = x.transpose(0, 1)
#
#
#
# File d:\miniconda3\envs\torchdrug\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#
#    1191 # this function, and just call forward.
#
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
#
# -> 1194     return forward_call(*input, **kwargs)
#
#    1195 # Do not call functions when jit is used
#
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
#
#
# File d:\miniconda3\envs\torchdrug\lib\site-packages\esm\modules.py:140, in TransformerLayer.forward(self, x, self_attn_mask, self_attn_padding_mask, need_head_weights)
#
#     138 x = gelu(self.fc1(x))
#
#     139 x = self.fc2(x)
#
# --> 140 x = residual + x
#
#     142 return x, attn
#
#
#
# KeyboardInterrupt:

# %% [markdown]
# Read all pkl and aggreate into the new list

# %%
import pickle
import torch
from tqdm import tqdm
from torchdrug import utils, transforms, data, models, layers

# %%
protein_pkl = '../../../data/dta-datasets/PDBbind/gearnet_pocket_Protein.pkl'
with utils.smart_open(protein_pkl, "rb") as fin:
    output_list = pickle.load(fin)

# %%
len(output_list)
# Out:
# 9018

# %%
output_list
# Out:
# [PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[501], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[22], num_bonds=[246], num_residues=[22]),
#  PackedProtein(batch_size=1, num_atoms=[29], num_bonds=[347], num_residues=[29]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[713], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[73], num_bonds=[1106], num_residues=[73]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[588], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[73], num_bonds=[1131], num_residues=[73]),
#  PackedProtein(batch_size=1, num_atoms=[34], num_bonds=[552], num_residues=[34]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[340], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[834], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[653], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[632], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[594], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[821], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[876], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[16], num_bonds=[174], num_residues=[16]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[710], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[604], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[626], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[503], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[705], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[779], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[704], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[566], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[685], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[725], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[610], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[715], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[848], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[766], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[637], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[830], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[785], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[689], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[675], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[885], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[554], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1030], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[1193], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[683], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[769], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[772], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[721], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[527], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[784], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[927], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[521], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[705], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[482], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[606], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[779], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[497], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[863], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1080], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[690], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[707], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[759], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[698], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[819], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[595], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[851], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[762], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[735], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[78], num_bonds=[1493], num_residues=[78]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[534], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[625], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[650], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[685], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[609], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[632], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[648], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[630], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[639], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[650], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[646], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[364], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[544], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[590], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[522], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[581], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[799], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[590], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[447], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[803], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[604], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[644], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[708], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[494], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[736], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[725], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[1007], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[932], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[840], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[770], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[782], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[510], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[829], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[857], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[999], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[805], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[757], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[879], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[717], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[573], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[864], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[784], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[934], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[779], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[975], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[909], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[751], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[785], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[776], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[853], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[730], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[784], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[937], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[980], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[748], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1010], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[108], num_bonds=[1641], num_residues=[108]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1000], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[746], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[543], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[636], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[701], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[694], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[585], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[399], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[540], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[479], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[72], num_bonds=[1082], num_residues=[72]),
#  PackedProtein(batch_size=1, num_atoms=[21], num_bonds=[225], num_residues=[21]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[895], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[759], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[709], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[567], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[555], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[805], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[860], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[705], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[807], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[635], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[670], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[947], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[92], num_bonds=[1313], num_residues=[92]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[801], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[736], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[586], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[610], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1142], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[801], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[733], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[876], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[751], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[731], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[762], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[701], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[1053], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[74], num_bonds=[1147], num_residues=[74]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[737], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[19], num_bonds=[217], num_residues=[19]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[614], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[494], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[553], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[25], num_bonds=[293], num_residues=[25]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[636], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[729], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[536], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[799], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[839], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[839], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[664], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[580], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[887], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[949], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1281], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[721], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1229], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1285], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[561], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[528], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[784], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1089], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[993], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[572], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[594], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[956], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[792], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[932], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1102], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[1014], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1159], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[581], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[728], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[937], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[919], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[748], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[532], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[466], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[114], num_bonds=[2303], num_residues=[114]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1025], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[1022], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1086], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1046], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[985], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[118], num_bonds=[2421], num_residues=[118]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[974], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[112], num_bonds=[2239], num_residues=[112]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[515], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[881], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[1150], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[23], num_bonds=[328], num_residues=[23]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[1042], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[935], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[885], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[647], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[950], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[881], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[926], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[74], num_bonds=[1170], num_residues=[74]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[977], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[722], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[630], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[693], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[637], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[674], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[910], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[105], num_bonds=[1777], num_residues=[105]),
#  PackedProtein(batch_size=1, num_atoms=[116], num_bonds=[2325], num_residues=[116]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[499], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[888], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[879], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[538], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[692], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[30], num_bonds=[439], num_residues=[30]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[543], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[444], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1088], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1313], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[914], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[871], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1179], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[794], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[707], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1058], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1052], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1059], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1089], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[650], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[663], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[738], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[572], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[668], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[827], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[726], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[1157], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[640], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[521], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[697], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[823], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[940], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[950], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1005], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1103], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[761], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[956], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[780], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[592], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[679], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[591], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[580], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[565], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[88], num_bonds=[1535], num_residues=[88]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[978], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[985], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1241], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[803], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[941], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[859], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[802], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[730], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[642], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[996], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[904], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[813], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1243], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1129], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[773], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[775], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[663], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[722], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[813], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1047], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[561], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[668], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[850], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1183], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[886], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[617], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[618], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[738], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[626], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[779], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[660], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[1249], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[744], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[859], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[862], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[916], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1074], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[903], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[454], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[623], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[560], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[627], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[879], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[656], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[982], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[597], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[616], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[744], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[664], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[725], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[759], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[879], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[814], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[734], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[689], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1031], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[649], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[755], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[17], num_bonds=[195], num_residues=[17]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[597], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[567], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[518], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[646], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[645], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1012], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[592], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[724], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[12], num_bonds=[111], num_residues=[12]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1107], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[950], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[651], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[985], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[691], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[719], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[615], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[701], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[870], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[860], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[911], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[847], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[745], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[915], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[747], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1102], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[1040], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[80], num_bonds=[1395], num_residues=[80]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[710], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1072], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[649], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[660], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[654], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[662], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[774], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[565], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[778], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[477], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[607], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[18], num_bonds=[242], num_residues=[18]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1096], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[73], num_bonds=[1164], num_residues=[73]),
#  PackedProtein(batch_size=1, num_atoms=[28], num_bonds=[307], num_residues=[28]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[570], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1061], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[597], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[719], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[512], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[682], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1007], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[108], num_bonds=[1722], num_residues=[108]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1259], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[844], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[756], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[913], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[813], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[520], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[22], num_bonds=[282], num_residues=[22]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[890], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[834], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[78], num_bonds=[1201], num_residues=[78]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[886], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[1048], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[489], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[823], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1184], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[798], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[759], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[597], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[883], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[904], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[802], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[719], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[864], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[785], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[529], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1236], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[631], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[636], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[626], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[557], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[704], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[602], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[697], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[1012], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[1022], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[1044], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[24], num_bonds=[362], num_residues=[24]),
#  PackedProtein(batch_size=1, num_atoms=[24], num_bonds=[369], num_residues=[24]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[900], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[871], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[517], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[73], num_bonds=[1205], num_residues=[73]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[409], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[456], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[86], num_bonds=[1216], num_residues=[86]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[1101], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1235], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[72], num_bonds=[1331], num_residues=[72]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[970], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[1067], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1086], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[983], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[1185], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1086], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1130], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1163], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[72], num_bonds=[1342], num_residues=[72]),
#  PackedProtein(batch_size=1, num_atoms=[29], num_bonds=[333], num_residues=[29]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[940], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[841], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[718], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1074], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[24], num_bonds=[261], num_residues=[24]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[707], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[840], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[719], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[990], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[695], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[576], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1171], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[872], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[910], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[511], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[660], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[796], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[92], num_bonds=[1691], num_residues=[92]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[947], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[873], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[81], num_bonds=[1284], num_residues=[81]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[852], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1070], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[464], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1455], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[869], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[805], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[880], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[693], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[25], num_bonds=[385], num_residues=[25]),
#  PackedProtein(batch_size=1, num_atoms=[26], num_bonds=[405], num_residues=[26]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1200], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[908], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[909], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[579], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[658], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[799], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[796], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[719], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[710], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[984], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[781], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[495], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[878], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[611], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[924], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[782], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[938], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[90], num_bonds=[1689], num_residues=[90]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[561], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[655], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[555], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[729], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[612], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[648], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[816], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[946], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[698], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[671], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[735], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[821], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[565], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[467], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1366], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[521], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[831], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[959], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1529], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[488], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[505], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[623], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[683], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[909], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[438], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[882], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[615], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[798], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1174], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[590], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[664], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[962], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[756], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[854], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1187], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1026], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[1032], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1088], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[880], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1120], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[1052], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[726], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[651], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[653], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[896], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[795], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[820], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[817], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[753], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[848], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[806], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[904], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[885], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[753], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[806], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[857], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[860], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[843], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[85], num_bonds=[1636], num_residues=[85]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[621], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1267], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[724], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[674], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[950], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[730], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[780], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1038], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[1281], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[81], num_bonds=[1525], num_residues=[81]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[999], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[113], num_bonds=[1764], num_residues=[113]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1236], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[811], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[816], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[790], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1524], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[555], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[615], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[666], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[646], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[755], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[721], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[492], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[476], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[650], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[258], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[284], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[650], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[622], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[1060], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1040], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[546], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[465], num_residues=[35]),
# ...
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[310], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[16], num_bonds=[186], num_residues=[16]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[479], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[763], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[663], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[693], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[500], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[662], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[746], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[877], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[925], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[30], num_bonds=[434], num_residues=[30]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[783], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[839], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[818], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[29], num_bonds=[415], num_residues=[29]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[773], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[799], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[850], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[544], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[729], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[888], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[857], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[581], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[779], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[773], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[858], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[729], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[894], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[349], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[956], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[885], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[752], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[867], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[895], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[861], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[870], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[853], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[982], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[1202], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1063], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[1010], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[899], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[30], num_bonds=[407], num_residues=[30]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[636], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[932], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[697], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[588], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[804], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[535], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[694], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[820], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[767], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[994], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[728], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[875], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[912], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[924], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1268], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1002], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[1226], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[921], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[955], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[642], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[748], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[918], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[630], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[698], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[440], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[535], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[679], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[650], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[582], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[630], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[637], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[34], num_bonds=[550], num_residues=[34]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[828], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[499], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[451], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[935], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[723], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1156], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1083], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[910], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[31], num_bonds=[432], num_residues=[31]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[386], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[564], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[996], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[605], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[904], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[686], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1082], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[919], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1396], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[814], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1087], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[87], num_bonds=[1325], num_residues=[87]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1111], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[871], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[871], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[999], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[944], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1042], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1019], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[837], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[953], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[1187], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1137], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[26], num_bonds=[394], num_residues=[26]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[764], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[844], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[585], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[813], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[922], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1097], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[116], num_bonds=[2444], num_residues=[116]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[868], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[741], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[854], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[977], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[847], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1105], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[632], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[781], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[795], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[792], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[851], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[798], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[698], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[453], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[836], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[768], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[650], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[26], num_bonds=[367], num_residues=[26]),
#  PackedProtein(batch_size=1, num_atoms=[28], num_bonds=[392], num_residues=[28]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[644], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[583], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[21], num_bonds=[249], num_residues=[21]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[550], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[23], num_bonds=[290], num_residues=[23]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[966], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[640], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[870], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[479], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[826], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[313], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[74], num_bonds=[1129], num_residues=[74]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[876], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[675], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[23], num_bonds=[334], num_residues=[23]),
#  PackedProtein(batch_size=1, num_atoms=[16], num_bonds=[208], num_residues=[16]),
#  PackedProtein(batch_size=1, num_atoms=[25], num_bonds=[361], num_residues=[25]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[765], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[819], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1005], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[23], num_bonds=[314], num_residues=[23]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[905], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1090], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[548], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[773], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[519], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[608], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1013], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[604], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[651], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[794], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1148], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[74], num_bonds=[1282], num_residues=[74]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1096], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[1214], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[542], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[809], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[977], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[801], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1028], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[931], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[835], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[890], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[88], num_bonds=[1729], num_residues=[88]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[551], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[81], num_bonds=[1573], num_residues=[81]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1082], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[946], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[563], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[675], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[655], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[558], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[566], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[891], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[866], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[630], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1097], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[776], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[28], num_bonds=[343], num_residues=[28]),
#  ...]

# %%
indexes = range(len(output_list)) # len(output_list)
indexes = tqdm(indexes, "ESM Combining ...")
for index in indexes: 
    # read each esm protein from pkl file
    curProtein = output_list[index]
    protein_pkl = '../../../data/dta-datasets/PDBbind/esm/gearnetesm_'+str(index)+'.pkl'
    with utils.smart_open(protein_pkl, "rb") as fin:
        output_protein = pickle.load(fin)
    output_list[index].residue_feature = output_protein.residue_feature
# Out:
# ESM Combining ...: 100%|██████████| 9018/9018 [02:35<00:00, 57.88it/s]

# %%
output_list[8866].residue_feature.shape
# Out:
# torch.Size([29, 1280])

# %%
len(output_list)
# Out:
# 9018

# %%
protein_pkl = '../../../data/dta-datasets/PDBbind/gearnetesm_pocket_Protein.pkl'
with utils.smart_open(protein_pkl, "wb") as fout:
    pickle.dump(output_list, fout)

# %%
indexes = range(5)   # len(transform_list)
indexes = tqdm(indexes, "ESM Computing ......")
for index in indexes:
    curProtein = transform_list[index]
    if curProtein.batch_size == 1:
        esmProcess(sequence_model, curProtein, str(index))
    else:
        for i in range(curProtein.batch_size):
            protein = data.Protein.pack([curProtein[i]])
            esmProcess(sequence_model, protein, str(index) + '-' + str(i))

# %%
indexes = range(0,1000)   # len(transform_list)
indexes = tqdm(indexes, "ESM Computing ......")
for index in indexes:
    curProtein = output_list[index]
    esmProcess(sequence_model, curProtein, str(index))
# Out:
# ESM Computing ......:   0%|          | 0/1000 [00:00<?, ?it/s]d:\miniconda3\envs\torchdrug\lib\site-packages\torchdrug\models\esm.py:122: UserWarning: ESM can only encode proteins within 1022 residues. Truncate the input to fit into ESM.
#   warnings.warn("ESM can only encode proteins within %d residues. Truncate the input to fit into ESM."
# ESM Computing ......:   0%|          | 2/1000 [00:34<4:45:57, 17.19s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Code\CurrentWork\Demo\DTA_Work\script\notebook\DatasetBuilding\PDBbindESM.ipynb Cell 9' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000008?line=2'>3</a> for index in indexes:
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000008?line=3'>4</a>     curProtein = output_list[index]
# ----> <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000008?line=4'>5</a>     esmProcess(sequence_model, curProtein, str(index))
#
# d:\Code\CurrentWork\Demo\DTA_Work\script\notebook\DatasetBuilding\PDBbindESM.ipynb Cell 8' in esmProcess(esmModel, curProtein, pklName)
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000007?line=0'>1</a> def esmProcess(esmModel, curProtein, pklName):
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000007?line=1'>2</a>     """
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000007?line=2'>3</a>     curProtein: list of packedProtein
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000007?line=3'>4</a>     pklName: the pkl name to store the protein
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000007?line=4'>5</a>     """
# ----> <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000007?line=5'>6</a>     output = esmModel(curProtein, curProtein.residue_feature)
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000007?line=6'>7</a>     curProtein.residue_feature = output['residue_feature']
#       <a href='vscode-notebook-cell:/d%3A/Code/CurrentWork/Demo/DTA_Work/script/notebook/DatasetBuilding/PDBbindESM.ipynb#ch0000007?line=7'>8</a>     curProtein.mol_feature = output['graph_feature']
#
# File d:\miniconda3\envs\torchdrug\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File d:\miniconda3\envs\torchdrug\lib\site-packages\torchdrug\models\esm.py:139, in EvolutionaryScaleModeling.forward(self, graph, input, all_loss, metric)
#     136     input, size_ext = functional._extend(input, size_ext, eos, torch.ones_like(size_ext))
#     137 input = functional.variadic_to_padded(input, size_ext, value=self.alphabet.padding_idx)[0]  # (batch_size, max_residues)
# --> 139 output = self.model(input, repr_layers=[33])
#     140 residue_feature = output["representations"][33]
#     141 # output = self.model(input, repr_layers=[12])  # for esm2-35M contains 12 layers
#     142 # residue_feature = output["representations"][12]
#
# File d:\miniconda3\envs\torchdrug\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File d:\miniconda3\envs\torchdrug\lib\site-packages\esm\model\esm2.py:112, in ESM2.forward(self, tokens, repr_layers, need_head_weights, return_contacts)
#     109     padding_mask = None
#     111 for layer_idx, layer in enumerate(self.layers):
# --> 112     x, attn = layer(
#     113         x,
#     114         self_attn_padding_mask=padding_mask,
#     115         need_head_weights=need_head_weights,
#     116     )
#     117     if (layer_idx + 1) in repr_layers:
#     118         hidden_representations[layer_idx + 1] = x.transpose(0, 1)
#
# File d:\miniconda3\envs\torchdrug\lib\site-packages\torch\nn\modules\module.py:1194, in Module._call_impl(self, *input, **kwargs)
#    1190 # If we don't have any hooks, we want to skip the rest of the logic in
#    1191 # this function, and just call forward.
#    1192 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194     return forward_call(*input, **kwargs)
#    1195 # Do not call functions when jit is used
#    1196 full_backward_hooks, non_full_backward_hooks = [], []
#
# File d:\miniconda3\envs\torchdrug\lib\site-packages\esm\modules.py:140, in TransformerLayer.forward(self, x, self_attn_mask, self_attn_padding_mask, need_head_weights)
#     138 x = gelu(self.fc1(x))
#     139 x = self.fc2(x)
# --> 140 x = residual + x
#     142 return x, attn
#
# KeyboardInterrupt:

# %%
indexes = range(0,1000)   # len(transform_list)
indexes = tqdm(indexes, "ESM Combining ...")
for index in indexes: 
    # read each esm protein from pkl file
    curProtein = output_list[index]
    curLength = curProtein.num_residue.tolist()
    if curLength <= 1022:
        protein_pkl = '../../../data/dta-datasets/Davis/esm/gearnetesm_'+str(index)+'.pkl'
        with utils.smart_open(protein_pkl, "rb") as fin:
            output_protein = pickle.load(fin)
        output_list[index].residue_feature = output_protein.residue_feature
    elif curLength <= 2044:
        for i in range(2):
            protein_pkl = '../../../data/dta-datasets/Davis/esm/gearnetesm_'+str(index)+'-'+str(i)+'.pkl'
            with utils.smart_open(protein_pkl, "rb") as fin:
                output_protein = pickle.load(fin)
            if i == 0: # the 1st part [0, 1022]
                residue_feature = output_protein.residue_feature
            else: # the 2nd part [1022, 2044]
                residue_feature = torch.cat((residue_feature, output_protein.residue_feature), dim=0)
        output_list[index].residue_feature = residue_feature
    elif curLength <= 3066:
        for i in range(3):
            protein_pkl = '../../../data/dta-datasets/Davis/esm/gearnetesm_'+str(index)+'-'+str(i)+'.pkl'
            with utils.smart_open(protein_pkl, "rb") as fin:
                output_protein = pickle.load(fin)
            if i == 0: # the 1st part [0, 1022]
                residue_feature = output_protein.residue_feature
                # print(residue_feature.shape)
            elif i == 1: # the 2nd part [1022, 2044]
                residue_feature = torch.cat((residue_feature, output_protein.residue_feature), dim=0)
                # print(residue_feature.shape)
            else: # the 3rd part [2044, length]
                residue_feature = torch.cat((residue_feature, output_protein.residue_feature), dim=0)
        print(residue_feature.shape)
        output_list[index].residue_feature = residue_feature

# %% [markdown]
# Read all pkl and aggreate into the new list

# %%
import pickle
import torch
from tqdm import tqdm
from torchdrug import utils, transforms, data, models, layers

# %%
protein_pkl = '../../../data/dta-datasets/PDBbind/gearnet_pocket_Protein.pkl'
with utils.smart_open(protein_pkl, "rb") as fin:
    output_list = pickle.load(fin)

# %%
len(output_list)
# Out:
# 9018

# %%
output_list
# Out:
# [PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[501], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[22], num_bonds=[246], num_residues=[22]),
#  PackedProtein(batch_size=1, num_atoms=[29], num_bonds=[347], num_residues=[29]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[713], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[73], num_bonds=[1106], num_residues=[73]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[588], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[73], num_bonds=[1131], num_residues=[73]),
#  PackedProtein(batch_size=1, num_atoms=[34], num_bonds=[552], num_residues=[34]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[340], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[834], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[653], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[632], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[594], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[821], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[876], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[16], num_bonds=[174], num_residues=[16]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[710], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[604], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[626], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[503], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[705], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[779], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[704], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[566], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[685], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[725], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[610], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[715], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[848], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[766], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[637], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[830], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[785], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[689], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[675], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[885], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[554], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1030], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[1193], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[683], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[769], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[772], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[721], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[527], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[784], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[927], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[521], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[705], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[482], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[606], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[779], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[497], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[863], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1080], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[690], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[707], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[759], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[698], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[819], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[595], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[851], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[762], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[735], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[78], num_bonds=[1493], num_residues=[78]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[534], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[625], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[650], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[685], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[609], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[632], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[648], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[630], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[639], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[650], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[646], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[364], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[544], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[590], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[522], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[581], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[799], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[590], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[447], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[803], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[604], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[644], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[708], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[494], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[736], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[725], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[1007], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[932], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[840], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[770], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[782], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[510], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[829], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[857], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[999], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[805], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[757], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[879], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[717], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[573], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[864], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[784], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[934], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[779], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[975], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[909], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[751], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[785], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[776], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[853], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[730], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[784], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[937], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[980], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[748], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1010], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[108], num_bonds=[1641], num_residues=[108]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1000], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[746], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[543], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[636], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[701], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[694], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[585], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[399], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[540], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[479], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[72], num_bonds=[1082], num_residues=[72]),
#  PackedProtein(batch_size=1, num_atoms=[21], num_bonds=[225], num_residues=[21]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[895], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[759], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[709], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[567], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[555], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[805], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[860], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[705], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[807], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[635], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[670], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[947], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[92], num_bonds=[1313], num_residues=[92]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[801], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[736], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[586], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[610], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1142], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[801], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[733], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[876], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[751], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[731], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[762], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[701], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[1053], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[74], num_bonds=[1147], num_residues=[74]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[737], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[19], num_bonds=[217], num_residues=[19]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[614], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[494], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[553], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[25], num_bonds=[293], num_residues=[25]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[636], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[729], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[536], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[799], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[839], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[839], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[664], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[580], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[887], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[949], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1281], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[721], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1229], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1285], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[561], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[528], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[784], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1089], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[993], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[572], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[594], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[956], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[792], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[932], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1102], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[1014], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1159], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[581], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[728], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[937], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[919], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[748], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[532], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[466], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[114], num_bonds=[2303], num_residues=[114]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1025], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[1022], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1086], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1046], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[985], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[118], num_bonds=[2421], num_residues=[118]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[974], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[112], num_bonds=[2239], num_residues=[112]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[515], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[881], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[1150], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[23], num_bonds=[328], num_residues=[23]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[1042], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[935], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[885], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[647], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[950], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[881], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[926], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[74], num_bonds=[1170], num_residues=[74]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[977], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[722], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[630], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[693], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[637], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[674], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[910], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[105], num_bonds=[1777], num_residues=[105]),
#  PackedProtein(batch_size=1, num_atoms=[116], num_bonds=[2325], num_residues=[116]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[499], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[888], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[879], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[538], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[692], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[30], num_bonds=[439], num_residues=[30]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[543], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[444], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1088], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1313], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[914], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[871], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1179], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[794], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[707], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1058], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1052], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1059], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1089], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[650], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[663], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[738], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[572], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[668], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[827], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[726], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[1157], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[640], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[521], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[697], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[823], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[940], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[950], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1005], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1103], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[761], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[956], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[780], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[592], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[679], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[591], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[580], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[565], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[88], num_bonds=[1535], num_residues=[88]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[978], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[985], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1241], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[803], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[941], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[859], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[802], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[730], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[642], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[996], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[904], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[813], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1243], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1129], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[773], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[775], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[663], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[722], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[813], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1047], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[561], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[668], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[850], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1183], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[886], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[617], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[618], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[738], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[626], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[779], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[660], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[1249], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[744], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[859], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[862], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[916], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1074], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[903], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[454], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[623], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[560], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[627], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[879], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[656], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[982], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[597], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[616], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[744], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[664], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[725], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[759], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[879], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[814], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[734], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[689], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1031], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[649], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[755], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[17], num_bonds=[195], num_residues=[17]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[597], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[567], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[518], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[646], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[645], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1012], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[592], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[724], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[12], num_bonds=[111], num_residues=[12]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1107], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[950], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[651], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[985], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[691], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[719], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[615], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[701], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[870], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[860], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[911], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[847], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[745], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[915], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[747], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1102], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[1040], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[80], num_bonds=[1395], num_residues=[80]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[710], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1072], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[649], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[660], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[654], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[662], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[774], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[565], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[778], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[477], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[607], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[18], num_bonds=[242], num_residues=[18]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1096], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[73], num_bonds=[1164], num_residues=[73]),
#  PackedProtein(batch_size=1, num_atoms=[28], num_bonds=[307], num_residues=[28]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[570], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1061], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[597], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[719], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[512], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[682], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1007], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[108], num_bonds=[1722], num_residues=[108]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1259], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[844], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[756], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[913], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[813], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[520], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[22], num_bonds=[282], num_residues=[22]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[890], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[834], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[78], num_bonds=[1201], num_residues=[78]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[886], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[1048], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[489], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[823], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1184], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[798], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[759], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[597], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[883], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[904], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[802], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[719], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[864], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[785], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[529], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1236], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[631], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[636], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[626], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[557], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[704], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[602], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[697], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[1012], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[1022], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[1044], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[24], num_bonds=[362], num_residues=[24]),
#  PackedProtein(batch_size=1, num_atoms=[24], num_bonds=[369], num_residues=[24]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[900], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[871], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[517], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[73], num_bonds=[1205], num_residues=[73]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[409], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[456], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[86], num_bonds=[1216], num_residues=[86]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[1101], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1235], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[72], num_bonds=[1331], num_residues=[72]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[970], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[1067], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1086], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[983], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[1185], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1086], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1130], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1163], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[72], num_bonds=[1342], num_residues=[72]),
#  PackedProtein(batch_size=1, num_atoms=[29], num_bonds=[333], num_residues=[29]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[940], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[841], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[718], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1074], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[24], num_bonds=[261], num_residues=[24]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[707], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[840], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[719], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[990], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[695], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[576], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1171], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[872], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[910], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[511], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[660], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[796], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[92], num_bonds=[1691], num_residues=[92]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[947], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[873], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[81], num_bonds=[1284], num_residues=[81]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[852], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1070], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[464], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1455], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[869], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[805], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[880], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[693], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[25], num_bonds=[385], num_residues=[25]),
#  PackedProtein(batch_size=1, num_atoms=[26], num_bonds=[405], num_residues=[26]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1200], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[908], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[909], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[579], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[658], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[799], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[796], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[719], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[710], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[984], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[781], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[495], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[878], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[611], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[924], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[782], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[938], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[90], num_bonds=[1689], num_residues=[90]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[561], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[655], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[555], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[729], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[612], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[648], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[816], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[946], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[698], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[671], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[735], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[821], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[565], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[467], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1366], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[521], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[831], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[959], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1529], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[488], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[505], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[623], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[683], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[909], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[438], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[882], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[615], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[798], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1174], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[590], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[664], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[962], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[756], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[854], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1187], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1026], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[1032], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1088], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[880], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1120], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[1052], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[726], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[651], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[653], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[896], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[795], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[820], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[817], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[753], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[848], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[806], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[904], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[885], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[753], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[806], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[857], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[860], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[843], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[85], num_bonds=[1636], num_residues=[85]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[621], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1267], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[724], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[674], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[950], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[730], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[780], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1038], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[1281], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[81], num_bonds=[1525], num_residues=[81]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[999], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[113], num_bonds=[1764], num_residues=[113]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1236], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[811], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[816], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[790], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1524], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[555], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[615], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[666], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[646], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[755], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[721], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[492], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[476], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[650], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[258], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[284], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[650], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[622], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[1060], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1040], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[546], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[465], num_residues=[35]),
# ...
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[310], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[16], num_bonds=[186], num_residues=[16]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[479], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[763], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[663], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[693], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[500], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[662], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[746], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[877], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[925], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[30], num_bonds=[434], num_residues=[30]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[783], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[839], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[818], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[29], num_bonds=[415], num_residues=[29]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[773], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[799], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[850], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[544], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[729], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[888], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[857], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[581], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[779], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[773], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[858], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[729], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[894], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[349], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[956], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[885], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[752], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[867], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[895], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[861], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[870], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[853], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[982], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[1202], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1063], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[1010], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[899], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[30], num_bonds=[407], num_residues=[30]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[636], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[932], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[697], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[588], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[804], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[535], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[694], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[820], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[767], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[994], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[728], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[875], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[912], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[924], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1268], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1002], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[1226], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[921], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[955], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[642], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[748], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[918], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[630], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[698], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[440], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[535], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[679], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[650], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[582], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[630], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[637], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[34], num_bonds=[550], num_residues=[34]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[828], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[499], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[451], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[935], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[723], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1156], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1083], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[910], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[31], num_bonds=[432], num_residues=[31]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[386], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[564], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[996], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[605], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[904], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[686], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1082], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[919], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1396], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[814], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1087], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[87], num_bonds=[1325], num_residues=[87]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1111], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[871], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[871], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[999], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[944], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1042], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1019], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[837], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[953], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[1187], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1137], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[26], num_bonds=[394], num_residues=[26]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[764], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[844], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[585], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[813], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[922], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1097], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[116], num_bonds=[2444], num_residues=[116]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[868], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[741], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[854], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[977], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[847], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1105], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[632], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[781], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[795], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[792], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[851], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[798], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[698], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[453], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[836], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[768], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[650], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[26], num_bonds=[367], num_residues=[26]),
#  PackedProtein(batch_size=1, num_atoms=[28], num_bonds=[392], num_residues=[28]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[644], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[583], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[21], num_bonds=[249], num_residues=[21]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[550], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[23], num_bonds=[290], num_residues=[23]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[966], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[640], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[870], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[479], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[826], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[313], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[74], num_bonds=[1129], num_residues=[74]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[876], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[675], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[23], num_bonds=[334], num_residues=[23]),
#  PackedProtein(batch_size=1, num_atoms=[16], num_bonds=[208], num_residues=[16]),
#  PackedProtein(batch_size=1, num_atoms=[25], num_bonds=[361], num_residues=[25]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[765], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[819], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1005], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[23], num_bonds=[314], num_residues=[23]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[905], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1090], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[548], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[773], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[519], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[608], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1013], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[604], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[651], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[794], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1148], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[74], num_bonds=[1282], num_residues=[74]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1096], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[1214], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[542], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[809], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[977], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[801], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1028], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[931], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[835], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[890], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[88], num_bonds=[1729], num_residues=[88]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[551], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[81], num_bonds=[1573], num_residues=[81]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1082], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[946], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[563], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[675], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[655], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[558], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[566], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[891], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[866], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[630], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1097], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[776], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[28], num_bonds=[343], num_residues=[28]),
#  ...]

# %%
indexes = range(len(output_list)) # len(output_list)
indexes = tqdm(indexes, "ESM Combining ...")
for index in indexes: 
    # read each esm protein from pkl file
    curProtein = output_list[index]
    protein_pkl = '../../../data/dta-datasets/PDBbind/esm/gearnetesm_'+str(index)+'.pkl'
    with utils.smart_open(protein_pkl, "rb") as fin:
        output_protein = pickle.load(fin)
    output_list[index].residue_feature = output_protein.residue_feature
# Out:
# ESM Combining ...: 100%|██████████| 9018/9018 [02:35<00:00, 57.88it/s]

# %%
output_list[8866].residue_feature.shape
# Out:
# torch.Size([29, 1280])

# %%
len(output_list)
# Out:
# 9018

# %%
protein_pkl = '../../../data/dta-datasets/PDBbind/gearnetesm_pocket_Protein.pkl'
with utils.smart_open(protein_pkl, "wb") as fout:
    pickle.dump(output_list, fout)

# %% [markdown]
# #### GearNet Pocket Construction

# %%
import pickle
from tqdm import tqdm
from torchdrug import utils, transforms, data, models, layers

# %%
protein_pkl = '../../../data/dta-datasets/PDBbind/gearnet_pocket_Protein.pkl'
with utils.smart_open(protein_pkl, "rb") as fin:
    output_list = pickle.load(fin)

# %%
output_list
# Out:
# [PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[501], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[22], num_bonds=[246], num_residues=[22]),
#  PackedProtein(batch_size=1, num_atoms=[29], num_bonds=[347], num_residues=[29]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[713], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[73], num_bonds=[1106], num_residues=[73]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[588], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[73], num_bonds=[1131], num_residues=[73]),
#  PackedProtein(batch_size=1, num_atoms=[34], num_bonds=[552], num_residues=[34]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[340], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[834], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[653], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[632], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[594], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[821], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[876], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[16], num_bonds=[174], num_residues=[16]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[710], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[604], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[626], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[503], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[705], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[779], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[704], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[566], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[685], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[725], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[610], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[715], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[848], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[766], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[637], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[830], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[785], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[689], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[675], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[885], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[554], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1030], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[1193], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[683], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[769], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[772], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[721], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[527], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[784], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[927], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[521], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[705], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[482], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[606], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[779], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[497], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[863], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1080], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[690], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[707], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[759], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[698], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[819], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[595], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[851], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[762], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[735], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[78], num_bonds=[1493], num_residues=[78]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[534], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[625], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[650], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[685], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[609], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[632], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[648], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[630], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[639], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[650], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[646], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[364], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[544], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[590], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[522], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[581], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[799], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[590], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[447], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[803], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[604], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[644], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[708], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[494], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[736], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[725], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[1007], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[932], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[840], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[770], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[782], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[510], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[829], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[857], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[999], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[805], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[757], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[879], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[717], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[573], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[864], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[784], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[934], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[779], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[975], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[909], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[751], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[785], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[776], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[853], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[730], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[784], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[937], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[980], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[748], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1010], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[108], num_bonds=[1641], num_residues=[108]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1000], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[746], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[543], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[636], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[701], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[694], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[585], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[399], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[540], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[479], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[72], num_bonds=[1082], num_residues=[72]),
#  PackedProtein(batch_size=1, num_atoms=[21], num_bonds=[225], num_residues=[21]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[895], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[759], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[709], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[567], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[555], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[805], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[860], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[705], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[807], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[635], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[670], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[947], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[92], num_bonds=[1313], num_residues=[92]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[801], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[736], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[586], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[610], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1142], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[801], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[733], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[876], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[751], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[731], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[762], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[701], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[1053], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[74], num_bonds=[1147], num_residues=[74]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[737], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[19], num_bonds=[217], num_residues=[19]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[614], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[494], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[553], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[25], num_bonds=[293], num_residues=[25]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[636], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[729], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[536], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[799], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[839], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[839], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[664], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[580], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[887], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[949], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1281], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[721], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1229], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1285], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[561], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[528], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[784], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1089], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[993], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[572], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[594], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[956], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[792], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[932], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1102], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[1014], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1159], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[581], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[728], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[937], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[919], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[748], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[532], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[466], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[114], num_bonds=[2303], num_residues=[114]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1025], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[1022], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1086], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1046], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[985], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[118], num_bonds=[2421], num_residues=[118]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[974], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[112], num_bonds=[2239], num_residues=[112]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[515], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[881], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[1150], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[23], num_bonds=[328], num_residues=[23]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[1042], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[935], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[885], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[647], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[950], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[881], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[926], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[74], num_bonds=[1170], num_residues=[74]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[977], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[722], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[630], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[693], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[637], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[674], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[910], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[105], num_bonds=[1777], num_residues=[105]),
#  PackedProtein(batch_size=1, num_atoms=[116], num_bonds=[2325], num_residues=[116]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[499], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[888], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[879], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[538], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[692], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[30], num_bonds=[439], num_residues=[30]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[543], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[444], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1088], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1313], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[914], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[871], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1179], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[794], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[707], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1058], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1052], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1059], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1089], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[650], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[663], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[738], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[572], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[668], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[827], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[726], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[1157], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[640], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[521], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[697], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[823], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[940], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[950], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1005], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1103], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[761], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[956], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[780], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[592], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[679], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[591], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[580], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[565], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[88], num_bonds=[1535], num_residues=[88]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[978], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[985], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1241], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[803], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[941], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[859], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[802], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[730], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[642], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[996], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[904], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[813], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1243], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1129], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[773], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[775], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[663], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[722], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[813], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1047], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[561], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[668], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[850], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1183], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[886], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[617], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[618], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[738], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[626], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[779], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[660], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[1249], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[744], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[859], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[862], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[916], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1074], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[903], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[454], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[623], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[560], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[627], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[879], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[656], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[982], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[597], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[616], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[744], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[664], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[725], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[759], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[879], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[814], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[734], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[689], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1031], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[649], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[755], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[17], num_bonds=[195], num_residues=[17]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[597], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[567], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[518], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[646], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[645], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1012], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[592], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[724], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[12], num_bonds=[111], num_residues=[12]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1107], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[950], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[651], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[985], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[691], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[719], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[615], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[701], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[870], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[860], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[911], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[847], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[745], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[915], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[747], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1102], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[1040], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[80], num_bonds=[1395], num_residues=[80]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[710], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1072], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[649], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[660], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[654], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[662], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[774], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[565], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[778], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[477], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[607], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[18], num_bonds=[242], num_residues=[18]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1096], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[73], num_bonds=[1164], num_residues=[73]),
#  PackedProtein(batch_size=1, num_atoms=[28], num_bonds=[307], num_residues=[28]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[570], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1061], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[597], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[719], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[512], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[682], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1007], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[108], num_bonds=[1722], num_residues=[108]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1259], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[844], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[756], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[913], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[813], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[520], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[22], num_bonds=[282], num_residues=[22]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[890], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[834], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[78], num_bonds=[1201], num_residues=[78]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[886], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[1048], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[489], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[823], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1184], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[798], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[759], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[597], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[883], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[904], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[802], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[719], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[864], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[785], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[529], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1236], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[631], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[636], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[626], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[557], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[704], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[602], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[697], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[1012], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[1022], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[1044], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[24], num_bonds=[362], num_residues=[24]),
#  PackedProtein(batch_size=1, num_atoms=[24], num_bonds=[369], num_residues=[24]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[900], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[871], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[517], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[73], num_bonds=[1205], num_residues=[73]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[409], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[456], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[86], num_bonds=[1216], num_residues=[86]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[1101], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1235], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[72], num_bonds=[1331], num_residues=[72]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[970], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[1067], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1086], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[983], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[1185], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1086], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1130], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1163], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[72], num_bonds=[1342], num_residues=[72]),
#  PackedProtein(batch_size=1, num_atoms=[29], num_bonds=[333], num_residues=[29]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[940], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[841], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[718], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1074], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[24], num_bonds=[261], num_residues=[24]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[707], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[840], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[719], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[990], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[695], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[576], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1171], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[872], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[910], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[511], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[660], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[796], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[92], num_bonds=[1691], num_residues=[92]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[947], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[873], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[81], num_bonds=[1284], num_residues=[81]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[852], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1070], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[464], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1455], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[869], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[805], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[880], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[693], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[25], num_bonds=[385], num_residues=[25]),
#  PackedProtein(batch_size=1, num_atoms=[26], num_bonds=[405], num_residues=[26]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1200], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[908], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[909], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[579], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[658], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[799], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[796], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[719], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[710], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[984], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[781], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[495], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[878], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[611], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[924], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[782], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[938], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[90], num_bonds=[1689], num_residues=[90]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[561], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[655], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[555], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[729], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[612], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[648], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[816], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[946], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[698], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[671], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[735], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[821], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[565], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[467], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1366], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[521], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[831], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[959], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1529], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[488], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[505], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[623], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[683], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[909], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[438], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[882], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[615], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[798], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1174], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[590], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[664], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[962], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[756], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[854], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1187], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1026], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[1032], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1088], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[880], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1120], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[1052], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[726], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[651], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[653], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[896], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[795], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[820], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[817], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[753], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[848], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[806], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[904], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[885], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[753], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[806], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[857], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[860], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[843], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[85], num_bonds=[1636], num_residues=[85]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[621], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1267], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[724], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[674], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[950], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[730], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[780], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1038], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[1281], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[81], num_bonds=[1525], num_residues=[81]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[999], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[113], num_bonds=[1764], num_residues=[113]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1236], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[811], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[816], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[790], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1524], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[555], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[615], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[666], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[646], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[755], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[721], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[492], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[476], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[650], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[258], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[284], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[650], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[622], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[1060], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1040], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[546], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[465], num_residues=[35]),
# ...
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[310], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[16], num_bonds=[186], num_residues=[16]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[479], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[763], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[663], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[693], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[500], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[662], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[746], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[877], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[925], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[30], num_bonds=[434], num_residues=[30]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[783], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[839], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[818], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[29], num_bonds=[415], num_residues=[29]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[773], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[799], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[850], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[544], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[729], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[888], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[857], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[581], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[779], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[773], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[858], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[729], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[894], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[349], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[956], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[885], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[752], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[867], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[895], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[861], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[870], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[853], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[982], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[1202], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1063], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[1010], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[899], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[30], num_bonds=[407], num_residues=[30]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[636], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[932], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[697], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[588], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[804], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[535], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[694], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[820], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[767], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[994], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[728], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[875], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[912], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[924], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1268], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1002], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[1226], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[921], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[955], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[642], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[748], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[918], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[630], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[698], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[440], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[535], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[679], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[650], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[582], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[630], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[637], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[34], num_bonds=[550], num_residues=[34]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[828], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[499], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[451], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[935], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[723], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1156], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1083], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[910], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[31], num_bonds=[432], num_residues=[31]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[386], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[564], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[996], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[605], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[904], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[686], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1082], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[919], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1396], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[814], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1087], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[87], num_bonds=[1325], num_residues=[87]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1111], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[871], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[871], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[999], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[944], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1042], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1019], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[837], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[953], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[1187], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1137], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[26], num_bonds=[394], num_residues=[26]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[764], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[844], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[585], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[813], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[922], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1097], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[116], num_bonds=[2444], num_residues=[116]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[868], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[741], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[854], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[977], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[847], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1105], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[632], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[781], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[795], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[792], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[851], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[798], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[698], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[453], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[836], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[768], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[650], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[26], num_bonds=[367], num_residues=[26]),
#  PackedProtein(batch_size=1, num_atoms=[28], num_bonds=[392], num_residues=[28]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[644], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[583], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[21], num_bonds=[249], num_residues=[21]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[550], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[23], num_bonds=[290], num_residues=[23]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[966], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[640], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[870], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[479], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[826], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[313], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[74], num_bonds=[1129], num_residues=[74]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[876], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[675], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[23], num_bonds=[334], num_residues=[23]),
#  PackedProtein(batch_size=1, num_atoms=[16], num_bonds=[208], num_residues=[16]),
#  PackedProtein(batch_size=1, num_atoms=[25], num_bonds=[361], num_residues=[25]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[765], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[819], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1005], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[23], num_bonds=[314], num_residues=[23]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[905], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1090], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[548], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[773], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[519], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[608], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1013], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[604], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[651], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[794], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1148], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[74], num_bonds=[1282], num_residues=[74]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1096], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[1214], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[542], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[809], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[977], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[801], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1028], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[931], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[835], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[890], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[88], num_bonds=[1729], num_residues=[88]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[551], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[81], num_bonds=[1573], num_residues=[81]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1082], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[946], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[563], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[675], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[655], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[558], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[566], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[891], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[866], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[630], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1097], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[776], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[28], num_bonds=[343], num_residues=[28]),
#  ...]

# %%
len(output_list)
# Out:
# 9018

# %%
sequence_model = models.ESM(path="../../../result/model_pth/ESM/", model="ESM-2_650M")

# %%
def esmProcess(esmModel, curProtein, pklName):
    """
    curProtein: list of packedProtein 
    pklName: the pkl name to store the protein
    """
    output = esmModel(curProtein, curProtein.residue_feature)
    curProtein.residue_feature = output['residue_feature']
    curProtein.mol_feature = output['graph_feature']
    protein_pkl = '../../../data/dta-datasets/PDBbind/esm/gearnetesm_' + pklName + '.pkl'
    with utils.smart_open(protein_pkl, "wb") as fout:
        pickle.dump(curProtein, fout)

# %%
indexes = range(8000,9018)   # len(transform_list)
indexes = tqdm(indexes, "ESM Computing ......")
for index in indexes:
    curProtein = output_list[index]
    esmProcess(sequence_model, curProtein, str(index))
# Out:
# ESM Computing ......: 100%|██████████| 1018/1018 [34:12<00:00,  2.02s/it]

# %% [markdown]
# Read all pkl and aggreate into the new list

# %%
import pickle
import torch
from tqdm import tqdm
from torchdrug import utils, transforms, data, models, layers

# %%
protein_pkl = '../../../data/dta-datasets/PDBbind/gearnet_pocket_Protein.pkl'
with utils.smart_open(protein_pkl, "rb") as fin:
    output_list = pickle.load(fin)

# %%
len(output_list)
# Out:
# 9018

# %%
output_list
# Out:
# [PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[501], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[22], num_bonds=[246], num_residues=[22]),
#  PackedProtein(batch_size=1, num_atoms=[29], num_bonds=[347], num_residues=[29]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[713], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[73], num_bonds=[1106], num_residues=[73]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[588], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[73], num_bonds=[1131], num_residues=[73]),
#  PackedProtein(batch_size=1, num_atoms=[34], num_bonds=[552], num_residues=[34]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[340], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[834], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[653], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[632], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[594], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[821], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[876], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[16], num_bonds=[174], num_residues=[16]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[710], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[604], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[626], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[503], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[705], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[779], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[704], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[566], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[685], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[725], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[610], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[715], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[848], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[766], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[637], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[830], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[785], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[689], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[675], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[885], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[554], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1030], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[1193], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[683], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[769], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[772], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[721], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[527], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[784], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[927], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[521], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[705], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[482], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[606], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[779], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[497], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[863], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1080], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[690], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[707], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[759], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[698], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[819], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[595], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[851], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[762], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[735], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[78], num_bonds=[1493], num_residues=[78]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[534], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[625], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[650], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[685], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[609], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[632], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[648], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[630], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[639], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[650], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[646], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[364], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[544], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[590], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[522], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[581], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[799], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[590], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[447], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[803], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[604], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[644], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[708], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[494], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[736], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[725], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[1007], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[932], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[840], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[770], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[782], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[510], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[829], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[857], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[999], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[805], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[757], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[879], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[717], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[573], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[864], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[784], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[934], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[779], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[975], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[909], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[751], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[785], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[776], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[853], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[730], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[784], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[937], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[980], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[748], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1010], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[108], num_bonds=[1641], num_residues=[108]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1000], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[746], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[543], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[636], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[701], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[694], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[585], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[399], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[540], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[479], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[72], num_bonds=[1082], num_residues=[72]),
#  PackedProtein(batch_size=1, num_atoms=[21], num_bonds=[225], num_residues=[21]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[895], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[759], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[709], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[567], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[555], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[805], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[860], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[705], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[807], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[635], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[670], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[947], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[92], num_bonds=[1313], num_residues=[92]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[801], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[736], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[586], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[610], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1142], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[801], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[733], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[876], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[751], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[731], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[762], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[701], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[1053], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[74], num_bonds=[1147], num_residues=[74]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[737], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[19], num_bonds=[217], num_residues=[19]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[614], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[494], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[553], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[25], num_bonds=[293], num_residues=[25]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[636], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[729], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[536], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[799], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[839], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[839], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[664], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[580], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[887], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[949], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1281], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[721], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1229], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1285], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[561], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[528], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[784], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1089], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[993], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[572], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[594], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[956], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[792], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[932], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1102], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[1014], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1159], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[581], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[728], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[937], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[919], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[748], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[532], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[466], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[114], num_bonds=[2303], num_residues=[114]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1025], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[1022], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1086], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1046], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[985], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[118], num_bonds=[2421], num_residues=[118]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[974], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[112], num_bonds=[2239], num_residues=[112]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[515], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[881], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[1150], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[23], num_bonds=[328], num_residues=[23]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[1042], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[935], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[885], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[647], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[950], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[881], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[926], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[74], num_bonds=[1170], num_residues=[74]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[977], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[722], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[630], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[693], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[637], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[674], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[910], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[105], num_bonds=[1777], num_residues=[105]),
#  PackedProtein(batch_size=1, num_atoms=[116], num_bonds=[2325], num_residues=[116]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[499], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[888], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[879], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[538], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[692], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[30], num_bonds=[439], num_residues=[30]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[543], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[444], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1088], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1313], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[914], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[871], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1179], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[794], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[707], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1058], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1052], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1059], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1089], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[650], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[663], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[738], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[572], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[668], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[827], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[726], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[1157], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[640], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[521], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[697], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[823], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[940], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[950], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1005], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1103], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[761], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[956], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[780], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[592], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[679], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[591], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[580], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[565], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[88], num_bonds=[1535], num_residues=[88]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[978], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[985], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1241], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[803], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[941], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[859], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[802], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[730], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[642], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[996], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[904], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[813], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1243], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1129], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[773], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[775], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[663], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[722], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[813], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1047], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[561], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[668], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[850], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1183], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[886], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[617], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[618], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[738], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[626], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[779], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[660], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[1249], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[744], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[859], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[862], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[916], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1074], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[903], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[454], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[623], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[560], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[627], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[879], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[656], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[982], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[597], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[616], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[744], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[664], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[725], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[759], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[879], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[814], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[734], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[689], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1031], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[649], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[755], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[17], num_bonds=[195], num_residues=[17]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[597], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[567], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[518], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[646], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[645], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1012], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[592], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[724], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[12], num_bonds=[111], num_residues=[12]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1107], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[950], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[651], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[985], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[691], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[719], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[615], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[701], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[870], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[860], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[911], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[847], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[745], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[915], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[747], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1102], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[1040], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[80], num_bonds=[1395], num_residues=[80]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[710], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1072], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[649], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[660], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[654], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[662], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[774], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[565], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[778], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[477], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[607], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[18], num_bonds=[242], num_residues=[18]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1096], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[73], num_bonds=[1164], num_residues=[73]),
#  PackedProtein(batch_size=1, num_atoms=[28], num_bonds=[307], num_residues=[28]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[570], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1061], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[597], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[719], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[512], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[682], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1007], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[108], num_bonds=[1722], num_residues=[108]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1259], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[844], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[756], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[913], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[813], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[520], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[22], num_bonds=[282], num_residues=[22]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[890], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[834], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[78], num_bonds=[1201], num_residues=[78]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[886], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[1048], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[489], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[823], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1184], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[798], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[759], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[597], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[883], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[904], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[802], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[719], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[864], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[785], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[529], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1236], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[631], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[636], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[626], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[557], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[704], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[602], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[697], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[1012], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[1022], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[1044], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[24], num_bonds=[362], num_residues=[24]),
#  PackedProtein(batch_size=1, num_atoms=[24], num_bonds=[369], num_residues=[24]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[900], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[871], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[517], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[73], num_bonds=[1205], num_residues=[73]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[409], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[456], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[86], num_bonds=[1216], num_residues=[86]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[1101], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1235], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[72], num_bonds=[1331], num_residues=[72]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[970], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[1067], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1086], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[983], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[1185], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1086], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1130], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1163], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[72], num_bonds=[1342], num_residues=[72]),
#  PackedProtein(batch_size=1, num_atoms=[29], num_bonds=[333], num_residues=[29]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[940], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[841], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[718], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1074], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[24], num_bonds=[261], num_residues=[24]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[707], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[840], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[719], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[990], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[695], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[576], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1171], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[872], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[910], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[511], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[660], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[796], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[92], num_bonds=[1691], num_residues=[92]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[947], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[873], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[81], num_bonds=[1284], num_residues=[81]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[852], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1070], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[464], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1455], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[869], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[805], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[880], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[693], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[25], num_bonds=[385], num_residues=[25]),
#  PackedProtein(batch_size=1, num_atoms=[26], num_bonds=[405], num_residues=[26]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[1200], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[908], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[909], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[579], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[658], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[799], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[796], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[719], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[710], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[984], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[781], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[495], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[878], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[611], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[924], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[782], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[938], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[90], num_bonds=[1689], num_residues=[90]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[561], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[655], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[555], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[729], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[612], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[648], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[816], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[946], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[698], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[671], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[735], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[821], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[565], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[467], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1366], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[521], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[831], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[959], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1529], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[488], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[505], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[623], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[683], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[909], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[438], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[882], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[615], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[798], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1174], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[590], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[664], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[962], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[756], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[854], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1187], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1026], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[1032], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1088], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[880], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1120], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[1052], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[726], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[651], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[653], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[896], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[795], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[820], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[817], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[753], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[848], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[806], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[904], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[885], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[753], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[806], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[857], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[860], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[843], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[85], num_bonds=[1636], num_residues=[85]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[621], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1267], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[724], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[674], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[950], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[730], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[780], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1038], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[1281], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[81], num_bonds=[1525], num_residues=[81]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[999], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[113], num_bonds=[1764], num_residues=[113]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1236], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[811], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[816], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[790], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1524], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[555], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[615], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[666], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[646], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[755], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[721], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[492], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[476], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[650], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[258], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[284], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[650], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[622], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[1060], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1040], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[546], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[465], num_residues=[35]),
# ...
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[310], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[16], num_bonds=[186], num_residues=[16]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[479], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[763], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[663], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[693], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[500], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[662], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[746], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[877], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[925], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[30], num_bonds=[434], num_residues=[30]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[783], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[839], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[818], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[29], num_bonds=[415], num_residues=[29]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[773], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[799], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[850], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[544], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[729], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[888], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[857], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[581], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[779], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[773], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[858], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[729], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[894], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[32], num_bonds=[349], num_residues=[32]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[956], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[885], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[752], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[867], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[895], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[861], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[870], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[853], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[982], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[1202], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1063], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[1010], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[899], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[30], num_bonds=[407], num_residues=[30]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[636], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[932], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[697], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[588], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[804], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[535], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[694], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[56], num_bonds=[820], num_residues=[56]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[767], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[994], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[728], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[875], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[912], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[924], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1268], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1002], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[1226], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[921], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[955], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[642], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[748], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[918], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[630], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[698], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[440], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[36], num_bonds=[535], num_residues=[36]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[679], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[650], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[582], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[630], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[637], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[34], num_bonds=[550], num_residues=[34]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[828], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[499], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[451], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[935], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[723], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1156], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1083], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[910], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[31], num_bonds=[432], num_residues=[31]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[386], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[564], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[996], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[605], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[904], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[686], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1082], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[919], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1396], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[814], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[1087], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[87], num_bonds=[1325], num_residues=[87]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1111], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[871], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[871], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[999], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[944], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1042], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1019], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[837], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[953], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[1187], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1137], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[26], num_bonds=[394], num_residues=[26]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[764], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[844], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[585], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[813], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[922], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1097], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[116], num_bonds=[2444], num_residues=[116]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[868], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[741], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[854], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[977], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[847], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[1105], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[632], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[781], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[795], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[792], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[851], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[798], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[698], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[453], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[836], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[768], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[650], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[26], num_bonds=[367], num_residues=[26]),
#  PackedProtein(batch_size=1, num_atoms=[28], num_bonds=[392], num_residues=[28]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[644], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[43], num_bonds=[583], num_residues=[43]),
#  PackedProtein(batch_size=1, num_atoms=[21], num_bonds=[249], num_residues=[21]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[550], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[23], num_bonds=[290], num_residues=[23]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[966], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[40], num_bonds=[640], num_residues=[40]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[870], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[33], num_bonds=[479], num_residues=[33]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[826], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[27], num_bonds=[313], num_residues=[27]),
#  PackedProtein(batch_size=1, num_atoms=[74], num_bonds=[1129], num_residues=[74]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[876], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[675], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[23], num_bonds=[334], num_residues=[23]),
#  PackedProtein(batch_size=1, num_atoms=[16], num_bonds=[208], num_residues=[16]),
#  PackedProtein(batch_size=1, num_atoms=[25], num_bonds=[361], num_residues=[25]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[765], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[819], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[1005], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[23], num_bonds=[314], num_residues=[23]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[905], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[1090], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[548], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[773], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[519], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[608], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1013], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[604], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[651], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[794], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1148], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[74], num_bonds=[1282], num_residues=[74]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[1096], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[1214], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[39], num_bonds=[542], num_residues=[39]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[809], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[977], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[801], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1028], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[931], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[54], num_bonds=[835], num_residues=[54]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[890], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[88], num_bonds=[1729], num_residues=[88]),
#  PackedProtein(batch_size=1, num_atoms=[37], num_bonds=[551], num_residues=[37]),
#  PackedProtein(batch_size=1, num_atoms=[81], num_bonds=[1573], num_residues=[81]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[1082], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[946], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[45], num_bonds=[563], num_residues=[45]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[675], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[655], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[46], num_bonds=[558], num_residues=[46]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[566], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[891], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[53], num_bonds=[866], num_residues=[53]),
#  PackedProtein(batch_size=1, num_atoms=[42], num_bonds=[630], num_residues=[42]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[1097], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[776], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[28], num_bonds=[343], num_residues=[28]),
#  ...]

# %%
indexes = range(len(output_list)) # len(output_list)
indexes = tqdm(indexes, "ESM Combining ...")
for index in indexes: 
    # read each esm protein from pkl file
    curProtein = output_list[index]
    protein_pkl = '../../../data/dta-datasets/PDBbind/esm/gearnetesm_'+str(index)+'.pkl'
    with utils.smart_open(protein_pkl, "rb") as fin:
        output_protein = pickle.load(fin)
    output_list[index].residue_feature = output_protein.residue_feature
# Out:
# ESM Combining ...: 100%|██████████| 9018/9018 [02:35<00:00, 57.88it/s]

# %%
output_list[8866].residue_feature.shape
# Out:
# torch.Size([29, 1280])

# %%
len(output_list)
# Out:
# 9018

# %%
protein_pkl = '../../../data/dta-datasets/PDBbind/gearnetesm_pocket_Protein.pkl'
with utils.smart_open(protein_pkl, "wb") as fout:
    pickle.dump(output_list, fout)
