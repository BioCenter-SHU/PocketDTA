# %% [markdown]
# # ESM for Protein Residue Embedding

# %% [markdown]
# #### GearNet Protein Construction without ESM

# %%
import pickle
from tqdm import tqdm
from torchdrug import utils, transforms, data, models, layers
# Out:
# No CUDA runtime is found, using CUDA_HOME='C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.7'

# %%
protein_pkl = '../../../data/dta-datasets/KIBA/pocket_Protein.pkl'
with utils.smart_open(protein_pkl, "rb") as fin:
    protein_list = pickle.load(fin)

# %%
protein_list
# Out:
# [Protein(num_atom=586, num_bond=1118, num_residue=73),
#  Protein(num_atom=435, num_bond=836, num_residue=55),
#  Protein(num_atom=2491, num_bond=4812, num_residue=302),
#  Protein(num_atom=1079, num_bond=2072, num_residue=133),
#  Protein(num_atom=541, num_bond=1038, num_residue=65),
#  Protein(num_atom=719, num_bond=1384, num_residue=87),
#  Protein(num_atom=917, num_bond=1754, num_residue=113),
#  Protein(num_atom=545, num_bond=1040, num_residue=65),
#  Protein(num_atom=598, num_bond=1132, num_residue=76),
#  Protein(num_atom=1042, num_bond=1996, num_residue=131),
#  Protein(num_atom=596, num_bond=1130, num_residue=74),
#  Protein(num_atom=933, num_bond=1792, num_residue=114),
#  Protein(num_atom=545, num_bond=1036, num_residue=69),
#  Protein(num_atom=67, num_bond=128, num_residue=7),
#  Protein(num_atom=580, num_bond=1116, num_residue=67),
#  Protein(num_atom=1057, num_bond=2054, num_residue=125),
#  Protein(num_atom=2841, num_bond=5518, num_residue=340),
#  Protein(num_atom=1007, num_bond=1914, num_residue=122),
#  Protein(num_atom=1340, num_bond=2580, num_residue=169),
#  Protein(num_atom=1407, num_bond=2696, num_residue=180),
#  Protein(num_atom=1136, num_bond=2184, num_residue=141),
#  Protein(num_atom=1276, num_bond=2482, num_residue=155),
#  Protein(num_atom=464, num_bond=878, num_residue=64),
#  Protein(num_atom=473, num_bond=896, num_residue=62),
#  Protein(num_atom=1495, num_bond=2886, num_residue=184),
#  Protein(num_atom=1713, num_bond=3278, num_residue=219),
#  Protein(num_atom=903, num_bond=1744, num_residue=109),
#  Protein(num_atom=1510, num_bond=2898, num_residue=188),
#  Protein(num_atom=1090, num_bond=2132, num_residue=129),
#  Protein(num_atom=1250, num_bond=2408, num_residue=156),
#  Protein(num_atom=1708, num_bond=3310, num_residue=208),
#  Protein(num_atom=1188, num_bond=2268, num_residue=144),
#  Protein(num_atom=965, num_bond=1864, num_residue=115),
#  Protein(num_atom=879, num_bond=1678, num_residue=108),
#  Protein(num_atom=364, num_bond=684, num_residue=44),
#  Protein(num_atom=456, num_bond=856, num_residue=57),
#  Protein(num_atom=1170, num_bond=2270, num_residue=141),
#  Protein(num_atom=1076, num_bond=2076, num_residue=132),
#  Protein(num_atom=667, num_bond=1266, num_residue=82),
#  Protein(num_atom=911, num_bond=1762, num_residue=108),
#  Protein(num_atom=1377, num_bond=2620, num_residue=174),
#  Protein(num_atom=2084, num_bond=4054, num_residue=256),
#  Protein(num_atom=651, num_bond=1244, num_residue=79),
#  Protein(num_atom=3127, num_bond=6052, num_residue=380),
#  Protein(num_atom=924, num_bond=1780, num_residue=110),
#  Protein(num_atom=1156, num_bond=2246, num_residue=138),
#  Protein(num_atom=845, num_bond=1616, num_residue=101),
#  Protein(num_atom=371, num_bond=688, num_residue=47),
#  Protein(num_atom=535, num_bond=1002, num_residue=68),
#  Protein(num_atom=452, num_bond=870, num_residue=58),
#  Protein(num_atom=993, num_bond=1902, num_residue=123),
#  Protein(num_atom=954, num_bond=1836, num_residue=114),
#  Protein(num_atom=399, num_bond=750, num_residue=51),
#  Protein(num_atom=920, num_bond=1786, num_residue=106),
#  Protein(num_atom=456, num_bond=858, num_residue=55),
#  Protein(num_atom=1512, num_bond=2926, num_residue=185),
#  Protein(num_atom=576, num_bond=1108, num_residue=68),
#  Protein(num_atom=810, num_bond=1554, num_residue=98),
#  Protein(num_atom=533, num_bond=1044, num_residue=61),
#  Protein(num_atom=735, num_bond=1402, num_residue=92),
#  Protein(num_atom=629, num_bond=1184, num_residue=81),
#  Protein(num_atom=665, num_bond=1244, num_residue=87),
#  Protein(num_atom=611, num_bond=1176, num_residue=73),
#  Protein(num_atom=546, num_bond=1054, num_residue=66),
#  Protein(num_atom=660, num_bond=1266, num_residue=82),
#  Protein(num_atom=2759, num_bond=5334, num_residue=335),
#  Protein(num_atom=1525, num_bond=2966, num_residue=185),
#  Protein(num_atom=639, num_bond=1246, num_residue=77),
#  Protein(num_atom=605, num_bond=1172, num_residue=72),
#  Protein(num_atom=614, num_bond=1172, num_residue=77),
#  Protein(num_atom=625, num_bond=1196, num_residue=74),
#  Protein(num_atom=1121, num_bond=2152, num_residue=136),
#  Protein(num_atom=695, num_bond=1318, num_residue=89),
#  Protein(num_atom=977, num_bond=1888, num_residue=123),
#  Protein(num_atom=3524, num_bond=6874, num_residue=433),
#  Protein(num_atom=538, num_bond=1024, num_residue=69),
#  Protein(num_atom=787, num_bond=1512, num_residue=100),
#  Protein(num_atom=527, num_bond=1008, num_residue=66),
#  Protein(num_atom=659, num_bond=1260, num_residue=83),
#  Protein(num_atom=1015, num_bond=1930, num_residue=124),
#  Protein(num_atom=1117, num_bond=2114, num_residue=136),
#  Protein(num_atom=1140, num_bond=2186, num_residue=140),
#  Protein(num_atom=632, num_bond=1206, num_residue=80),
#  Protein(num_atom=1029, num_bond=1994, num_residue=123),
#  Protein(num_atom=763, num_bond=1448, num_residue=96),
#  Protein(num_atom=415, num_bond=800, num_residue=52),
#  Protein(num_atom=1250, num_bond=2454, num_residue=149),
#  Protein(num_atom=2482, num_bond=4812, num_residue=294),
#  Protein(num_atom=2510, num_bond=4858, num_residue=305),
#  Protein(num_atom=4410, num_bond=8414, num_residue=527),
#  Protein(num_atom=662, num_bond=1264, num_residue=83),
#  Protein(num_atom=1137, num_bond=2204, num_residue=141),
#  Protein(num_atom=835, num_bond=1612, num_residue=102),
#  Protein(num_atom=1257, num_bond=2434, num_residue=155),
#  Protein(num_atom=1233, num_bond=2366, num_residue=150),
#  Protein(num_atom=666, num_bond=1266, num_residue=84),
#  Protein(num_atom=459, num_bond=848, num_residue=58),
#  Protein(num_atom=336, num_bond=652, num_residue=44),
#  Protein(num_atom=585, num_bond=1122, num_residue=72),
#  Protein(num_atom=2556, num_bond=4926, num_residue=307),
#  Protein(num_atom=475, num_bond=902, num_residue=59),
#  Protein(num_atom=1138, num_bond=2228, num_residue=135),
#  Protein(num_atom=589, num_bond=1128, num_residue=76),
#  Protein(num_atom=661, num_bond=1278, num_residue=77),
#  Protein(num_atom=681, num_bond=1298, num_residue=82),
#  Protein(num_atom=357, num_bond=676, num_residue=47),
#  Protein(num_atom=779, num_bond=1526, num_residue=95),
#  Protein(num_atom=776, num_bond=1476, num_residue=99),
#  Protein(num_atom=397, num_bond=764, num_residue=48),
#  Protein(num_atom=986, num_bond=1896, num_residue=118),
#  Protein(num_atom=621, num_bond=1178, num_residue=78),
#  Protein(num_atom=1531, num_bond=2940, num_residue=189),
#  Protein(num_atom=526, num_bond=1024, num_residue=62),
#  Protein(num_atom=845, num_bond=1636, num_residue=101),
#  Protein(num_atom=572, num_bond=1090, num_residue=70),
#  Protein(num_atom=822, num_bond=1568, num_residue=100),
#  Protein(num_atom=2670, num_bond=5210, num_residue=325),
#  Protein(num_atom=439, num_bond=832, num_residue=57),
#  Protein(num_atom=1049, num_bond=2004, num_residue=125),
#  Protein(num_atom=951, num_bond=1842, num_residue=124),
#  Protein(num_atom=395, num_bond=752, num_residue=51),
#  Protein(num_atom=467, num_bond=876, num_residue=59),
#  Protein(num_atom=602, num_bond=1162, num_residue=71),
#  Protein(num_atom=734, num_bond=1418, num_residue=89),
#  Protein(num_atom=799, num_bond=1544, num_residue=98),
#  Protein(num_atom=279, num_bond=526, num_residue=35),
#  Protein(num_atom=377, num_bond=726, num_residue=44),
#  Protein(num_atom=453, num_bond=874, num_residue=58),
#  Protein(num_atom=6636, num_bond=12724, num_residue=797),
#  Protein(num_atom=544, num_bond=1036, num_residue=69),
#  Protein(num_atom=195, num_bond=372, num_residue=26),
#  Protein(num_atom=509, num_bond=978, num_residue=63),
#  Protein(num_atom=1735, num_bond=3368, num_residue=211),
#  Protein(num_atom=898, num_bond=1734, num_residue=112),
#  Protein(num_atom=1329, num_bond=2528, num_residue=169),
#  Protein(num_atom=592, num_bond=1140, num_residue=75),
#  Protein(num_atom=975, num_bond=1864, num_residue=120),
#  Protein(num_atom=675, num_bond=1290, num_residue=85),
#  Protein(num_atom=1599, num_bond=3084, num_residue=194),
#  Protein(num_atom=1251, num_bond=2404, num_residue=149),
#  Protein(num_atom=1336, num_bond=2590, num_residue=164),
#  Protein(num_atom=1189, num_bond=2304, num_residue=144),
#  Protein(num_atom=992, num_bond=1908, num_residue=119),
#  Protein(num_atom=729, num_bond=1408, num_residue=92),
#  Protein(num_atom=635, num_bond=1218, num_residue=77),
#  Protein(num_atom=1159, num_bond=2264, num_residue=137),
#  Protein(num_atom=1516, num_bond=2948, num_residue=187),
#  Protein(num_atom=646, num_bond=1242, num_residue=78),
#  Protein(num_atom=529, num_bond=1018, num_residue=67),
#  Protein(num_atom=609, num_bond=1176, num_residue=76),
#  Protein(num_atom=573, num_bond=1096, num_residue=74),
#  Protein(num_atom=679, num_bond=1296, num_residue=84),
#  Protein(num_atom=1264, num_bond=2416, num_residue=156),
#  Protein(num_atom=1069, num_bond=2048, num_residue=130),
#  Protein(num_atom=974, num_bond=1868, num_residue=119),
#  Protein(num_atom=770, num_bond=1456, num_residue=95),
#  Protein(num_atom=912, num_bond=1736, num_residue=113),
#  Protein(num_atom=453, num_bond=874, num_residue=57),
#  Protein(num_atom=507, num_bond=980, num_residue=60),
#  Protein(num_atom=1388, num_bond=2678, num_residue=173),
#  Protein(num_atom=903, num_bond=1742, num_residue=113),
#  Protein(num_atom=1011, num_bond=1912, num_residue=130),
#  Protein(num_atom=1221, num_bond=2362, num_residue=143),
#  Protein(num_atom=1115, num_bond=2168, num_residue=133),
#  Protein(num_atom=194, num_bond=372, num_residue=25),
#  Protein(num_atom=659, num_bond=1258, num_residue=83),
#  Protein(num_atom=1138, num_bond=2168, num_residue=139),
#  Protein(num_atom=1492, num_bond=2864, num_residue=184),
#  Protein(num_atom=1436, num_bond=2760, num_residue=179),
#  Protein(num_atom=656, num_bond=1248, num_residue=81),
#  Protein(num_atom=1370, num_bond=2642, num_residue=164),
#  Protein(num_atom=956, num_bond=1826, num_residue=116),
#  Protein(num_atom=1184, num_bond=2248, num_residue=143),
#  Protein(num_atom=737, num_bond=1418, num_residue=90),
#  Protein(num_atom=710, num_bond=1352, num_residue=88),
#  Protein(num_atom=806, num_bond=1550, num_residue=106),
#  Protein(num_atom=897, num_bond=1754, num_residue=103),
#  Protein(num_atom=628, num_bond=1194, num_residue=77),
#  Protein(num_atom=3659, num_bond=7044, num_residue=444),
#  Protein(num_atom=2015, num_bond=3860, num_residue=254),
#  Protein(num_atom=862, num_bond=1648, num_residue=106),
#  Protein(num_atom=1317, num_bond=2510, num_residue=164),
#  Protein(num_atom=385, num_bond=732, num_residue=47),
#  Protein(num_atom=923, num_bond=1794, num_residue=114),
#  Protein(num_atom=762, num_bond=1464, num_residue=96),
#  Protein(num_atom=979, num_bond=1888, num_residue=124),
#  Protein(num_atom=790, num_bond=1514, num_residue=95),
#  Protein(num_atom=1169, num_bond=2234, num_residue=146),
#  Protein(num_atom=561, num_bond=1072, num_residue=69),
#  Protein(num_atom=377, num_bond=704, num_residue=50),
#  Protein(num_atom=859, num_bond=1628, num_residue=103),
#  Protein(num_atom=377, num_bond=708, num_residue=48),
#  Protein(num_atom=1180, num_bond=2264, num_residue=150),
#  Protein(num_atom=596, num_bond=1136, num_residue=76),
#  Protein(num_atom=1017, num_bond=1940, num_residue=123),
#  Protein(num_atom=1535, num_bond=2962, num_residue=186),
#  Protein(num_atom=626, num_bond=1198, num_residue=79),
#  Protein(num_atom=852, num_bond=1668, num_residue=102),
#  Protein(num_atom=385, num_bond=738, num_residue=49),
#  Protein(num_atom=1220, num_bond=2326, num_residue=146),
#  Protein(num_atom=1025, num_bond=1956, num_residue=124),
#  Protein(num_atom=593, num_bond=1124, num_residue=73),
#  Protein(num_atom=321, num_bond=620, num_residue=38),
#  Protein(num_atom=325, num_bond=606, num_residue=41),
#  Protein(num_atom=879, num_bond=1692, num_residue=107),
#  Protein(num_atom=727, num_bond=1384, num_residue=86),
#  Protein(num_atom=689, num_bond=1306, num_residue=88),
#  Protein(num_atom=494, num_bond=950, num_residue=59),
#  Protein(num_atom=560, num_bond=1084, num_residue=69),
#  Protein(num_atom=281, num_bond=532, num_residue=38),
#  Protein(num_atom=536, num_bond=1030, num_residue=66),
#  Protein(num_atom=711, num_bond=1358, num_residue=88),
#  Protein(num_atom=821, num_bond=1582, num_residue=101),
#  Protein(num_atom=382, num_bond=722, num_residue=51),
#  Protein(num_atom=494, num_bond=940, num_residue=64),
#  Protein(num_atom=639, num_bond=1230, num_residue=82),
#  Protein(num_atom=847, num_bond=1624, num_residue=102),
#  Protein(num_atom=862, num_bond=1652, num_residue=109),
#  Protein(num_atom=378, num_bond=714, num_residue=47),
#  Protein(num_atom=921, num_bond=1766, num_residue=116),
#  Protein(num_atom=669, num_bond=1280, num_residue=79),
#  Protein(num_atom=821, num_bond=1576, num_residue=104),
#  Protein(num_atom=1640, num_bond=3180, num_residue=195),
#  Protein(num_atom=779, num_bond=1488, num_residue=96),
#  Protein(num_atom=705, num_bond=1338, num_residue=85),
#  Protein(num_atom=446, num_bond=852, num_residue=57),
#  Protein(num_atom=52, num_bond=102, num_residue=5),
#  Protein(num_atom=1503, num_bond=2914, num_residue=183),
#  Protein(num_atom=339, num_bond=644, num_residue=44)]

# %%
graph_construction_model = layers.GraphConstruction(node_layers=[layers.geometry.AlphaCarbonNode()], 
                                                    edge_layers=[layers.geometry.SpatialEdge(radius=10.0, min_distance=5),
                                                                 layers.geometry.KNNEdge(k=10, min_distance=5),
                                                                 layers.geometry.SequentialEdge(max_distance=2)],
                                                    edge_feature="gearnet")

# %%
output_list = []
for protein in protein_list:
    graph = data.Protein.pack([protein])
    transGraph = graph_construction_model(graph)
    output_list.append(transGraph)

# %%
len(output_list)
# Out:
# 229

# %%
protein_view = transforms.ProteinView(view="residue", keys="graph1")

# %%
transform_list = []
for protein in output_list:
    item = {"graph1": protein}
    transform_list.append(protein_view(item)['graph1'])

# %%
transform_list
# Out:
# [PackedProtein(batch_size=1, num_atoms=[73], num_bonds=[1020], num_residues=[73]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[826], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[302], num_bonds=[4540], num_residues=[302]),
#  PackedProtein(batch_size=1, num_atoms=[133], num_bonds=[1951], num_residues=[133]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[759], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[87], num_bonds=[1294], num_residues=[87]),
#  PackedProtein(batch_size=1, num_atoms=[113], num_bonds=[1643], num_residues=[113]),
#  PackedProtein(batch_size=1, num_atoms=[65], num_bonds=[956], num_residues=[65]),
#  PackedProtein(batch_size=1, num_atoms=[76], num_bonds=[1075], num_residues=[76]),
#  PackedProtein(batch_size=1, num_atoms=[131], num_bonds=[1919], num_residues=[131]),
#  PackedProtein(batch_size=1, num_atoms=[74], num_bonds=[1115], num_residues=[74]),
#  PackedProtein(batch_size=1, num_atoms=[114], num_bonds=[1679], num_residues=[114]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[961], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[7], num_bonds=[37], num_residues=[7]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[852], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[125], num_bonds=[1837], num_residues=[125]),
#  PackedProtein(batch_size=1, num_atoms=[340], num_bonds=[5241], num_residues=[340]),
#  PackedProtein(batch_size=1, num_atoms=[122], num_bonds=[1637], num_residues=[122]),
#  PackedProtein(batch_size=1, num_atoms=[169], num_bonds=[2534], num_residues=[169]),
#  PackedProtein(batch_size=1, num_atoms=[180], num_bonds=[2729], num_residues=[180]),
#  PackedProtein(batch_size=1, num_atoms=[141], num_bonds=[1914], num_residues=[141]),
#  PackedProtein(batch_size=1, num_atoms=[155], num_bonds=[2137], num_residues=[155]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[963], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[873], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[184], num_bonds=[2634], num_residues=[184]),
#  PackedProtein(batch_size=1, num_atoms=[219], num_bonds=[3136], num_residues=[219]),
#  PackedProtein(batch_size=1, num_atoms=[109], num_bonds=[1546], num_residues=[109]),
#  PackedProtein(batch_size=1, num_atoms=[188], num_bonds=[2618], num_residues=[188]),
#  PackedProtein(batch_size=1, num_atoms=[129], num_bonds=[1887], num_residues=[129]),
#  PackedProtein(batch_size=1, num_atoms=[156], num_bonds=[2344], num_residues=[156]),
#  PackedProtein(batch_size=1, num_atoms=[208], num_bonds=[3104], num_residues=[208]),
#  PackedProtein(batch_size=1, num_atoms=[144], num_bonds=[1972], num_residues=[144]),
#  PackedProtein(batch_size=1, num_atoms=[115], num_bonds=[1563], num_residues=[115]),
#  PackedProtein(batch_size=1, num_atoms=[108], num_bonds=[1520], num_residues=[108]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[630], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[738], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[141], num_bonds=[1985], num_residues=[141]),
#  PackedProtein(batch_size=1, num_atoms=[132], num_bonds=[1970], num_residues=[132]),
#  PackedProtein(batch_size=1, num_atoms=[82], num_bonds=[1033], num_residues=[82]),
#  PackedProtein(batch_size=1, num_atoms=[108], num_bonds=[1553], num_residues=[108]),
#  PackedProtein(batch_size=1, num_atoms=[174], num_bonds=[2532], num_residues=[174]),
#  PackedProtein(batch_size=1, num_atoms=[256], num_bonds=[3927], num_residues=[256]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1014], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[380], num_bonds=[5669], num_residues=[380]),
#  PackedProtein(batch_size=1, num_atoms=[110], num_bonds=[1588], num_residues=[110]),
#  PackedProtein(batch_size=1, num_atoms=[138], num_bonds=[1964], num_residues=[138]),
#  PackedProtein(batch_size=1, num_atoms=[101], num_bonds=[1498], num_residues=[101]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[633], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[951], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[835], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[1716], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[114], num_bonds=[1560], num_residues=[114]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[612], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[1564], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[55], num_bonds=[657], num_residues=[55]),
#  PackedProtein(batch_size=1, num_atoms=[185], num_bonds=[2771], num_residues=[185]),
#  PackedProtein(batch_size=1, num_atoms=[68], num_bonds=[909], num_residues=[68]),
#  PackedProtein(batch_size=1, num_atoms=[98], num_bonds=[1221], num_residues=[98]),
#  PackedProtein(batch_size=1, num_atoms=[61], num_bonds=[916], num_residues=[61]),
#  PackedProtein(batch_size=1, num_atoms=[92], num_bonds=[1252], num_residues=[92]),
#  PackedProtein(batch_size=1, num_atoms=[81], num_bonds=[1102], num_residues=[81]),
#  PackedProtein(batch_size=1, num_atoms=[87], num_bonds=[1163], num_residues=[87]),
#  PackedProtein(batch_size=1, num_atoms=[73], num_bonds=[1010], num_residues=[73]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[876], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[82], num_bonds=[1161], num_residues=[82]),
#  PackedProtein(batch_size=1, num_atoms=[335], num_bonds=[5202], num_residues=[335]),
#  PackedProtein(batch_size=1, num_atoms=[185], num_bonds=[2884], num_residues=[185]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1107], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[72], num_bonds=[1005], num_residues=[72]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1093], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[74], num_bonds=[1072], num_residues=[74]),
#  PackedProtein(batch_size=1, num_atoms=[136], num_bonds=[1885], num_residues=[136]),
#  PackedProtein(batch_size=1, num_atoms=[89], num_bonds=[1090], num_residues=[89]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[1776], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[433], num_bonds=[7051], num_residues=[433]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[994], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[100], num_bonds=[1342], num_residues=[100]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[937], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[83], num_bonds=[1118], num_residues=[83]),
#  PackedProtein(batch_size=1, num_atoms=[124], num_bonds=[1841], num_residues=[124]),
#  PackedProtein(batch_size=1, num_atoms=[136], num_bonds=[1767], num_residues=[136]),
#  PackedProtein(batch_size=1, num_atoms=[140], num_bonds=[1924], num_residues=[140]),
#  PackedProtein(batch_size=1, num_atoms=[80], num_bonds=[1206], num_residues=[80]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[1628], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[96], num_bonds=[1403], num_residues=[96]),
#  PackedProtein(batch_size=1, num_atoms=[52], num_bonds=[763], num_residues=[52]),
#  PackedProtein(batch_size=1, num_atoms=[149], num_bonds=[2301], num_residues=[149]),
#  PackedProtein(batch_size=1, num_atoms=[294], num_bonds=[4490], num_residues=[294]),
#  PackedProtein(batch_size=1, num_atoms=[305], num_bonds=[4691], num_residues=[305]),
#  PackedProtein(batch_size=1, num_atoms=[527], num_bonds=[7077], num_residues=[527]),
#  PackedProtein(batch_size=1, num_atoms=[83], num_bonds=[1151], num_residues=[83]),
#  PackedProtein(batch_size=1, num_atoms=[141], num_bonds=[2045], num_residues=[141]),
#  PackedProtein(batch_size=1, num_atoms=[102], num_bonds=[1427], num_residues=[102]),
#  PackedProtein(batch_size=1, num_atoms=[155], num_bonds=[2121], num_residues=[155]),
#  PackedProtein(batch_size=1, num_atoms=[150], num_bonds=[2086], num_residues=[150]),
#  PackedProtein(batch_size=1, num_atoms=[84], num_bonds=[1166], num_residues=[84]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[790], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[630], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[72], num_bonds=[939], num_residues=[72]),
#  PackedProtein(batch_size=1, num_atoms=[307], num_bonds=[4723], num_residues=[307]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[851], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[135], num_bonds=[1977], num_residues=[135]),
#  PackedProtein(batch_size=1, num_atoms=[76], num_bonds=[1035], num_residues=[76]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1021], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[82], num_bonds=[1089], num_residues=[82]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[641], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[95], num_bonds=[1376], num_residues=[95]),
#  PackedProtein(batch_size=1, num_atoms=[99], num_bonds=[1493], num_residues=[99]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[659], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[118], num_bonds=[1601], num_residues=[118]),
#  PackedProtein(batch_size=1, num_atoms=[78], num_bonds=[972], num_residues=[78]),
#  PackedProtein(batch_size=1, num_atoms=[189], num_bonds=[2813], num_residues=[189]),
#  PackedProtein(batch_size=1, num_atoms=[62], num_bonds=[742], num_residues=[62]),
#  PackedProtein(batch_size=1, num_atoms=[101], num_bonds=[1586], num_residues=[101]),
#  PackedProtein(batch_size=1, num_atoms=[70], num_bonds=[966], num_residues=[70]),
#  PackedProtein(batch_size=1, num_atoms=[100], num_bonds=[1441], num_residues=[100]),
#  PackedProtein(batch_size=1, num_atoms=[325], num_bonds=[5131], num_residues=[325]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[830], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[125], num_bonds=[1839], num_residues=[125]),
#  PackedProtein(batch_size=1, num_atoms=[124], num_bonds=[1879], num_residues=[124]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[637], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[806], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[71], num_bonds=[884], num_residues=[71]),
#  PackedProtein(batch_size=1, num_atoms=[89], num_bonds=[1277], num_residues=[89]),
#  PackedProtein(batch_size=1, num_atoms=[98], num_bonds=[1172], num_residues=[98]),
#  PackedProtein(batch_size=1, num_atoms=[35], num_bonds=[439], num_residues=[35]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[589], num_residues=[44]),
#  PackedProtein(batch_size=1, num_atoms=[58], num_bonds=[822], num_residues=[58]),
#  PackedProtein(batch_size=1, num_atoms=[797], num_bonds=[14895], num_residues=[797]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[933], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[26], num_bonds=[297], num_residues=[26]),
#  PackedProtein(batch_size=1, num_atoms=[63], num_bonds=[894], num_residues=[63]),
#  PackedProtein(batch_size=1, num_atoms=[211], num_bonds=[3366], num_residues=[211]),
#  PackedProtein(batch_size=1, num_atoms=[112], num_bonds=[1772], num_residues=[112]),
#  PackedProtein(batch_size=1, num_atoms=[169], num_bonds=[2523], num_residues=[169]),
#  PackedProtein(batch_size=1, num_atoms=[75], num_bonds=[1048], num_residues=[75]),
#  PackedProtein(batch_size=1, num_atoms=[120], num_bonds=[1771], num_residues=[120]),
#  PackedProtein(batch_size=1, num_atoms=[85], num_bonds=[1219], num_residues=[85]),
#  PackedProtein(batch_size=1, num_atoms=[194], num_bonds=[2805], num_residues=[194]),
#  PackedProtein(batch_size=1, num_atoms=[149], num_bonds=[2040], num_residues=[149]),
#  PackedProtein(batch_size=1, num_atoms=[164], num_bonds=[2492], num_residues=[164]),
#  PackedProtein(batch_size=1, num_atoms=[144], num_bonds=[2247], num_residues=[144]),
#  PackedProtein(batch_size=1, num_atoms=[119], num_bonds=[1740], num_residues=[119]),
#  PackedProtein(batch_size=1, num_atoms=[92], num_bonds=[1248], num_residues=[92]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[945], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[137], num_bonds=[1991], num_residues=[137]),
#  PackedProtein(batch_size=1, num_atoms=[187], num_bonds=[2767], num_residues=[187]),
#  PackedProtein(batch_size=1, num_atoms=[78], num_bonds=[966], num_residues=[78]),
#  PackedProtein(batch_size=1, num_atoms=[67], num_bonds=[855], num_residues=[67]),
#  PackedProtein(batch_size=1, num_atoms=[76], num_bonds=[1114], num_residues=[76]),
#  PackedProtein(batch_size=1, num_atoms=[74], num_bonds=[1114], num_residues=[74]),
#  PackedProtein(batch_size=1, num_atoms=[84], num_bonds=[1262], num_residues=[84]),
#  PackedProtein(batch_size=1, num_atoms=[156], num_bonds=[2303], num_residues=[156]),
#  PackedProtein(batch_size=1, num_atoms=[130], num_bonds=[1897], num_residues=[130]),
#  PackedProtein(batch_size=1, num_atoms=[119], num_bonds=[1750], num_residues=[119]),
#  PackedProtein(batch_size=1, num_atoms=[95], num_bonds=[1276], num_residues=[95]),
#  PackedProtein(batch_size=1, num_atoms=[113], num_bonds=[1638], num_residues=[113]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[880], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[60], num_bonds=[852], num_residues=[60]),
#  PackedProtein(batch_size=1, num_atoms=[173], num_bonds=[2568], num_residues=[173]),
#  PackedProtein(batch_size=1, num_atoms=[113], num_bonds=[1639], num_residues=[113]),
#  PackedProtein(batch_size=1, num_atoms=[130], num_bonds=[1841], num_residues=[130]),
#  PackedProtein(batch_size=1, num_atoms=[143], num_bonds=[1941], num_residues=[143]),
#  PackedProtein(batch_size=1, num_atoms=[133], num_bonds=[2065], num_residues=[133]),
#  PackedProtein(batch_size=1, num_atoms=[25], num_bonds=[344], num_residues=[25]),
#  PackedProtein(batch_size=1, num_atoms=[83], num_bonds=[1008], num_residues=[83]),
#  PackedProtein(batch_size=1, num_atoms=[139], num_bonds=[1831], num_residues=[139]),
#  PackedProtein(batch_size=1, num_atoms=[184], num_bonds=[2695], num_residues=[184]),
#  PackedProtein(batch_size=1, num_atoms=[179], num_bonds=[2625], num_residues=[179]),
#  PackedProtein(batch_size=1, num_atoms=[81], num_bonds=[1126], num_residues=[81]),
#  PackedProtein(batch_size=1, num_atoms=[164], num_bonds=[2316], num_residues=[164]),
#  PackedProtein(batch_size=1, num_atoms=[116], num_bonds=[1594], num_residues=[116]),
#  PackedProtein(batch_size=1, num_atoms=[143], num_bonds=[1895], num_residues=[143]),
#  PackedProtein(batch_size=1, num_atoms=[90], num_bonds=[1330], num_residues=[90]),
#  PackedProtein(batch_size=1, num_atoms=[88], num_bonds=[1187], num_residues=[88]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[1509], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[103], num_bonds=[1457], num_residues=[103]),
#  PackedProtein(batch_size=1, num_atoms=[77], num_bonds=[1034], num_residues=[77]),
#  PackedProtein(batch_size=1, num_atoms=[444], num_bonds=[6152], num_residues=[444]),
#  PackedProtein(batch_size=1, num_atoms=[254], num_bonds=[3929], num_residues=[254]),
#  PackedProtein(batch_size=1, num_atoms=[106], num_bonds=[1564], num_residues=[106]),
#  PackedProtein(batch_size=1, num_atoms=[164], num_bonds=[2575], num_residues=[164]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[637], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[114], num_bonds=[1615], num_residues=[114]),
#  PackedProtein(batch_size=1, num_atoms=[96], num_bonds=[1276], num_residues=[96]),
#  PackedProtein(batch_size=1, num_atoms=[124], num_bonds=[1730], num_residues=[124]),
#  PackedProtein(batch_size=1, num_atoms=[95], num_bonds=[1410], num_residues=[95]),
#  PackedProtein(batch_size=1, num_atoms=[146], num_bonds=[2224], num_residues=[146]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[1044], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[50], num_bonds=[627], num_residues=[50]),
#  PackedProtein(batch_size=1, num_atoms=[103], num_bonds=[1503], num_residues=[103]),
#  PackedProtein(batch_size=1, num_atoms=[48], num_bonds=[662], num_residues=[48]),
#  PackedProtein(batch_size=1, num_atoms=[150], num_bonds=[2211], num_residues=[150]),
#  PackedProtein(batch_size=1, num_atoms=[76], num_bonds=[1215], num_residues=[76]),
#  PackedProtein(batch_size=1, num_atoms=[123], num_bonds=[1807], num_residues=[123]),
#  PackedProtein(batch_size=1, num_atoms=[186], num_bonds=[2476], num_residues=[186]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[1011], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[102], num_bonds=[1476], num_residues=[102]),
#  PackedProtein(batch_size=1, num_atoms=[49], num_bonds=[596], num_residues=[49]),
#  PackedProtein(batch_size=1, num_atoms=[146], num_bonds=[1993], num_residues=[146]),
#  PackedProtein(batch_size=1, num_atoms=[124], num_bonds=[1836], num_residues=[124]),
#  PackedProtein(batch_size=1, num_atoms=[73], num_bonds=[891], num_residues=[73]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[498], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[41], num_bonds=[482], num_residues=[41]),
#  PackedProtein(batch_size=1, num_atoms=[107], num_bonds=[1455], num_residues=[107]),
#  PackedProtein(batch_size=1, num_atoms=[86], num_bonds=[1103], num_residues=[86]),
#  PackedProtein(batch_size=1, num_atoms=[88], num_bonds=[1199], num_residues=[88]),
#  PackedProtein(batch_size=1, num_atoms=[59], num_bonds=[868], num_residues=[59]),
#  PackedProtein(batch_size=1, num_atoms=[69], num_bonds=[940], num_residues=[69]),
#  PackedProtein(batch_size=1, num_atoms=[38], num_bonds=[539], num_residues=[38]),
#  PackedProtein(batch_size=1, num_atoms=[66], num_bonds=[855], num_residues=[66]),
#  PackedProtein(batch_size=1, num_atoms=[88], num_bonds=[1154], num_residues=[88]),
#  PackedProtein(batch_size=1, num_atoms=[101], num_bonds=[1323], num_residues=[101]),
#  PackedProtein(batch_size=1, num_atoms=[51], num_bonds=[721], num_residues=[51]),
#  PackedProtein(batch_size=1, num_atoms=[64], num_bonds=[916], num_residues=[64]),
#  PackedProtein(batch_size=1, num_atoms=[82], num_bonds=[1206], num_residues=[82]),
#  PackedProtein(batch_size=1, num_atoms=[102], num_bonds=[1430], num_residues=[102]),
#  PackedProtein(batch_size=1, num_atoms=[109], num_bonds=[1662], num_residues=[109]),
#  PackedProtein(batch_size=1, num_atoms=[47], num_bonds=[650], num_residues=[47]),
#  PackedProtein(batch_size=1, num_atoms=[116], num_bonds=[1665], num_residues=[116]),
#  PackedProtein(batch_size=1, num_atoms=[79], num_bonds=[962], num_residues=[79]),
#  PackedProtein(batch_size=1, num_atoms=[104], num_bonds=[1456], num_residues=[104]),
#  PackedProtein(batch_size=1, num_atoms=[195], num_bonds=[2683], num_residues=[195]),
#  PackedProtein(batch_size=1, num_atoms=[96], num_bonds=[1350], num_residues=[96]),
#  PackedProtein(batch_size=1, num_atoms=[85], num_bonds=[1124], num_residues=[85]),
#  PackedProtein(batch_size=1, num_atoms=[57], num_bonds=[803], num_residues=[57]),
#  PackedProtein(batch_size=1, num_atoms=[5], num_bonds=[19], num_residues=[5]),
#  PackedProtein(batch_size=1, num_atoms=[183], num_bonds=[2604], num_residues=[183]),
#  PackedProtein(batch_size=1, num_atoms=[44], num_bonds=[591], num_residues=[44])]

# %%
protein_pkl = '../../../data/dta-datasets/KIBA/gearnet_pocket_Protein.pkl'
with utils.smart_open(protein_pkl, "wb") as fout:
    pickle.dump(transform_list, fout)

# %% [markdown]
# #### GearNet Protein Construction

# %%
import pickle
from tqdm import tqdm
from torchdrug import utils, transforms, data, models, layers

# %%
protein_pkl = '../../../data/dta-datasets/KIBA/pdb_Protein.pkl'
with utils.smart_open(protein_pkl, "rb") as fin:
    protein_list = pickle.load(fin)

# %%
protein_list
# Out:
# [Protein(num_atom=3454, num_bond=7092, num_residue=431),
#  Protein(num_atom=4481, num_bond=9122, num_residue=574),
#  Protein(num_atom=8396, num_bond=17184, num_residue=1044),
#  Protein(num_atom=5776, num_bond=11822, num_residue=725),
#  Protein(num_atom=7660, num_bond=15664, num_residue=970),
#  Protein(num_atom=3829, num_bond=7834, num_residue=476),
#  Protein(num_atom=6066, num_bond=12346, num_residue=756),
#  Protein(num_atom=3228, num_bond=6604, num_residue=403),
#  Protein(num_atom=5783, num_bond=11792, num_residue=740),
#  Protein(num_atom=5932, num_bond=12108, num_residue=745),
#  Protein(num_atom=2964, num_bond=6066, num_residue=365),
#  Protein(num_atom=4453, num_bond=9134, num_residue=556),
#  Protein(num_atom=3702, num_bond=7522, num_residue=454),
#  Protein(num_atom=2136, num_bond=4386, num_residue=272),
#  Protein(num_atom=4620, num_bond=9458, num_residue=588),
#  Protein(num_atom=5222, num_bond=10662, num_residue=661),
#  Protein(num_atom=9192, num_bond=18812, num_residue=1132),
#  Protein(num_atom=11278, num_bond=22884, num_residue=1388),
#  Protein(num_atom=6324, num_bond=12920, num_residue=802),
#  Protein(num_atom=6033, num_bond=12336, num_residue=772),
#  Protein(num_atom=7050, num_bond=14426, num_residue=890),
#  Protein(num_atom=9996, num_bond=20386, num_residue=1239),
#  Protein(num_atom=4506, num_bond=9230, num_residue=591),
#  Protein(num_atom=4282, num_bond=8734, num_residue=543),
#  Protein(num_atom=8643, num_bond=17678, num_residue=1130),
#  Protein(num_atom=9392, num_bond=19228, num_residue=1210),
#  Protein(num_atom=5130, num_bond=10500, num_residue=648),
#  Protein(num_atom=9661, num_bond=19856, num_residue=1255),
#  Protein(num_atom=6155, num_bond=12626, num_residue=796),
#  Protein(num_atom=5522, num_bond=11362, num_residue=697),
#  Protein(num_atom=5401, num_bond=11074, num_residue=671),
#  Protein(num_atom=10981, num_bond=22534, num_residue=1382),
#  Protein(num_atom=4088, num_bond=8388, num_residue=509),
#  Protein(num_atom=4279, num_bond=8762, num_residue=537),
#  Protein(num_atom=2405, num_bond=4920, num_residue=297),
#  Protein(num_atom=6581, num_bond=13430, num_residue=822),
#  Protein(num_atom=7607, num_bond=15616, num_residue=972),
#  Protein(num_atom=4280, num_bond=8772, num_residue=543),
#  Protein(num_atom=4124, num_bond=8440, num_residue=512),
#  Protein(num_atom=8740, num_bond=17924, num_residue=1114),
#  Protein(num_atom=10860, num_bond=22258, num_residue=1367),
#  Protein(num_atom=10929, num_bond=22394, num_residue=1390),
#  Protein(num_atom=4188, num_bond=8580, num_residue=526),
#  Protein(num_atom=18612, num_bond=38200, num_residue=2347),
#  Protein(num_atom=8716, num_bond=17840, num_residue=1106),
#  Protein(num_atom=4186, num_bond=8582, num_residue=529),
#  Protein(num_atom=7725, num_bond=15830, num_residue=976),
#  Protein(num_atom=2519, num_bond=5170, num_residue=313),
#  Protein(num_atom=6446, num_bond=13208, num_residue=822),
#  Protein(num_atom=2376, num_bond=4874, num_residue=303),
#  Protein(num_atom=4214, num_bond=8632, num_residue=536),
#  Protein(num_atom=5936, num_bond=12138, num_residue=766),
#  Protein(num_atom=3269, num_bond=6696, num_residue=406),
#  Protein(num_atom=8623, num_bond=17616, num_residue=1089),
#  Protein(num_atom=6637, num_bond=13490, num_residue=822),
#  Protein(num_atom=5393, num_bond=11060, num_residue=672),
#  Protein(num_atom=2872, num_bond=5890, num_residue=351),
#  Protein(num_atom=10584, num_bond=21626, num_residue=1338),
#  Protein(num_atom=2911, num_bond=5970, num_residue=350),
#  Protein(num_atom=6456, num_bond=13222, num_residue=821),
#  Protein(num_atom=6193, num_bond=12704, num_residue=802),
#  Protein(num_atom=6163, num_bond=12616, num_residue=806),
#  Protein(num_atom=2858, num_bond=5860, num_residue=351),
#  Protein(num_atom=2874, num_bond=5892, num_residue=351),
#  Protein(num_atom=4158, num_bond=8514, num_residue=525),
#  Protein(num_atom=9355, num_bond=19118, num_residue=1154),
#  Protein(num_atom=5466, num_bond=11190, num_residue=683),
#  Protein(num_atom=2398, num_bond=4920, num_residue=298),
#  Protein(num_atom=3036, num_bond=6210, num_residue=379),
#  Protein(num_atom=5927, num_bond=12066, num_residue=753),
#  Protein(num_atom=2915, num_bond=5970, num_residue=360),
#  Protein(num_atom=7603, num_bond=15590, num_residue=976),
#  Protein(num_atom=8232, num_bond=16830, num_residue=1055),
#  Protein(num_atom=6440, num_bond=13224, num_residue=864),
#  Protein(num_atom=9409, num_bond=19324, num_residue=1187),
#  Protein(num_atom=5027, num_bond=10272, num_residue=646),
#  Protein(num_atom=6913, num_bond=14202, num_residue=894),
#  Protein(num_atom=3919, num_bond=8024, num_residue=480),
#  Protein(num_atom=3925, num_bond=8038, num_residue=481),
#  Protein(num_atom=4763, num_bond=9730, num_residue=590),
#  Protein(num_atom=10740, num_bond=22000, num_residue=1363),
#  Protein(num_atom=10643, num_bond=21752, num_residue=1356),
#  Protein(num_atom=3121, num_bond=6372, num_residue=400),
#  Protein(num_atom=7935, num_bond=16276, num_residue=993),
#  Protein(num_atom=3564, num_bond=7288, num_residue=450),
#  Protein(num_atom=3717, num_bond=7600, num_residue=467),
#  Protein(num_atom=4791, num_bond=9810, num_residue=596),
#  Protein(num_atom=8722, num_bond=17846, num_residue=1068),
#  Protein(num_atom=8633, num_bond=17652, num_residue=1070),
#  Protein(num_atom=20287, num_bond=41398, num_residue=2549),
#  Protein(num_atom=3973, num_bond=8136, num_residue=507),
#  Protein(num_atom=9023, num_bond=18462, num_residue=1182),
#  Protein(num_atom=4110, num_bond=8424, num_residue=505),
#  Protein(num_atom=4905, num_bond=10058, num_residue=619),
#  Protein(num_atom=5075, num_bond=10384, num_residue=635),
#  Protein(num_atom=3385, num_bond=6914, num_residue=427),
#  Protein(num_atom=3376, num_bond=6894, num_residue=424),
#  Protein(num_atom=2738, num_bond=5594, num_residue=337),
#  Protein(num_atom=3328, num_bond=6796, num_residue=415),
#  Protein(num_atom=8906, num_bond=18228, num_residue=1102),
#  Protein(num_atom=3202, num_bond=6574, num_residue=400),
#  Protein(num_atom=3755, num_bond=7716, num_residue=464),
#  Protein(num_atom=3330, num_bond=6794, num_residue=416),
#  Protein(num_atom=4035, num_bond=8272, num_residue=484),
#  Protein(num_atom=4241, num_bond=8690, num_residue=499),
#  Protein(num_atom=3591, num_bond=7352, num_residue=483),
#  Protein(num_atom=3292, num_bond=6738, num_residue=420),
#  Protein(num_atom=2751, num_bond=5630, num_residue=346),
#  Protein(num_atom=3007, num_bond=6140, num_residue=372),
#  Protein(num_atom=4062, num_bond=8326, num_residue=505),
#  Protein(num_atom=5389, num_bond=11080, num_residue=712),
#  Protein(num_atom=5899, num_bond=12070, num_residue=740),
#  Protein(num_atom=5493, num_bond=11258, num_residue=675),
#  Protein(num_atom=2895, num_bond=5962, num_residue=358),
#  Protein(num_atom=3631, num_bond=7368, num_residue=445),
#  Protein(num_atom=6636, num_bond=13502, num_residue=841),
#  Protein(num_atom=8801, num_bond=18040, num_residue=1124),
#  Protein(num_atom=2630, num_bond=5370, num_residue=334),
#  Protein(num_atom=4804, num_bond=9822, num_residue=603),
#  Protein(num_atom=5087, num_bond=10428, num_residue=647),
#  Protein(num_atom=2951, num_bond=6032, num_residue=367),
#  Protein(num_atom=3688, num_bond=7532, num_residue=464),
#  Protein(num_atom=2651, num_bond=5414, num_residue=331),
#  Protein(num_atom=4376, num_bond=8948, num_residue=552),
#  Protein(num_atom=7611, num_bond=15600, num_residue=987),
#  Protein(num_atom=1752, num_bond=3606, num_residue=215),
#  Protein(num_atom=3182, num_bond=6534, num_residue=391),
#  Protein(num_atom=3342, num_bond=6842, num_residue=415),
#  Protein(num_atom=32960, num_bond=67292, num_residue=4128),
#  Protein(num_atom=8574, num_bond=17570, num_residue=1104),
#  Protein(num_atom=2600, num_bond=5310, num_residue=326),
#  Protein(num_atom=2346, num_bond=4804, num_residue=292),
#  Protein(num_atom=5876, num_bond=12000, num_residue=737),
#  Protein(num_atom=3048, num_bond=6224, num_residue=393),
#  Protein(num_atom=8835, num_bond=18102, num_residue=1124),
#  Protein(num_atom=7307, num_bond=15016, num_residue=954),
#  Protein(num_atom=5739, num_bond=11762, num_residue=706),
#  Protein(num_atom=4001, num_bond=8178, num_residue=509),
#  Protein(num_atom=10709, num_bond=22030, num_residue=1400),
#  Protein(num_atom=8378, num_bond=17132, num_residue=1052),
#  Protein(num_atom=4754, num_bond=9726, num_residue=592),
#  Protein(num_atom=5449, num_bond=11150, num_residue=676),
#  Protein(num_atom=5368, num_bond=11004, num_residue=659),
#  Protein(num_atom=6809, num_bond=13954, num_residue=890),
#  Protein(num_atom=8067, num_bond=16628, num_residue=1038),
#  Protein(num_atom=5061, num_bond=10380, num_residue=620),
#  Protein(num_atom=6446, num_bond=13224, num_residue=820),
#  Protein(num_atom=7754, num_bond=15892, num_residue=999),
#  Protein(num_atom=4499, num_bond=9200, num_residue=559),
#  Protein(num_atom=4254, num_bond=8672, num_residue=545),
#  Protein(num_atom=4074, num_bond=8316, num_residue=524),
#  Protein(num_atom=3943, num_bond=8040, num_residue=491),
#  Protein(num_atom=6155, num_bond=12552, num_residue=762),
#  Protein(num_atom=11093, num_bond=22508, num_residue=1354),
#  Protein(num_atom=5111, num_bond=10470, num_residue=666),
#  Protein(num_atom=4402, num_bond=8994, num_residue=558),
#  Protein(num_atom=3966, num_bond=8118, num_residue=499),
#  Protein(num_atom=6017, num_bond=12332, num_residue=763),
#  Protein(num_atom=3656, num_bond=7512, num_residue=451),
#  Protein(num_atom=5373, num_bond=10968, num_residue=671),
#  Protein(num_atom=2906, num_bond=5942, num_residue=370),
#  Protein(num_atom=5660, num_bond=11540, num_residue=716),
#  Protein(num_atom=8131, num_bond=16606, num_residue=1009),
#  Protein(num_atom=5242, num_bond=10708, num_residue=651),
#  Protein(num_atom=2393, num_bond=4890, num_residue=307),
#  Protein(num_atom=3470, num_bond=7110, num_residue=436),
#  Protein(num_atom=7137, num_bond=14594, num_residue=912),
#  Protein(num_atom=10291, num_bond=21140, num_residue=1308),
#  Protein(num_atom=5830, num_bond=11934, num_residue=735),
#  Protein(num_atom=2913, num_bond=5962, num_residue=364),
#  Protein(num_atom=6640, num_bond=13610, num_residue=839),
#  Protein(num_atom=7312, num_bond=14914, num_residue=942),
#  Protein(num_atom=7874, num_bond=16050, num_residue=984),
#  Protein(num_atom=2907, num_bond=5946, num_residue=360),
#  Protein(num_atom=3651, num_bond=7442, num_residue=473),
#  Protein(num_atom=6534, num_bond=13446, num_residue=847),
#  Protein(num_atom=6467, num_bond=13272, num_residue=822),
#  Protein(num_atom=3016, num_bond=6168, num_residue=382),
#  Protein(num_atom=20070, num_bond=40872, num_residue=2527),
#  Protein(num_atom=13836, num_bond=28154, num_residue=1732),
#  Protein(num_atom=6174, num_bond=12596, num_residue=788),
#  Protein(num_atom=8140, num_bond=16572, num_residue=1001),
#  Protein(num_atom=2529, num_bond=5174, num_residue=326),
#  Protein(num_atom=3017, num_bond=6156, num_residue=385),
#  Protein(num_atom=3805, num_bond=7764, num_residue=473),
#  Protein(num_atom=10543, num_bond=21568, num_residue=1332),
#  Protein(num_atom=4886, num_bond=10020, num_residue=616),
#  Protein(num_atom=5988, num_bond=12278, num_residue=778),
#  Protein(num_atom=2768, num_bond=5672, num_residue=344),
#  Protein(num_atom=2532, num_bond=5172, num_residue=322),
#  Protein(num_atom=5799, num_bond=11854, num_residue=752),
#  Protein(num_atom=2873, num_bond=5854, num_residue=358),
#  Protein(num_atom=10027, num_bond=20484, num_residue=1323),
#  Protein(num_atom=4537, num_bond=9268, num_residue=588),
#  Protein(num_atom=5221, num_bond=10646, num_residue=655),
#  Protein(num_atom=10876, num_bond=22196, num_residue=1374),
#  Protein(num_atom=3601, num_bond=7344, num_residue=465),
#  Protein(num_atom=4006, num_bond=8224, num_residue=502),
#  Protein(num_atom=2919, num_bond=5964, num_residue=367),
#  Protein(num_atom=6795, num_bond=13908, num_residue=878),
#  Protein(num_atom=7301, num_bond=14950, num_residue=926),
#  Protein(num_atom=10004, num_bond=20242, num_residue=1235),
#  Protein(num_atom=9202, num_bond=18864, num_residue=1198),
#  Protein(num_atom=3842, num_bond=7900, num_residue=488),
#  Protein(num_atom=5050, num_bond=10360, num_residue=646),
#  Protein(num_atom=4045, num_bond=8296, num_residue=481),
#  Protein(num_atom=3641, num_bond=7438, num_residue=465),
#  Protein(num_atom=2908, num_bond=5974, num_residue=367),
#  Protein(num_atom=2504, num_bond=5136, num_residue=313),
#  Protein(num_atom=3415, num_bond=6992, num_residue=422),
#  Protein(num_atom=4199, num_bond=8596, num_residue=520),
#  Protein(num_atom=3615, num_bond=7368, num_residue=460),
#  Protein(num_atom=6416, num_bond=13142, num_residue=800),
#  Protein(num_atom=2412, num_bond=4976, num_residue=311),
#  Protein(num_atom=3271, num_bond=6666, num_residue=416),
#  Protein(num_atom=4103, num_bond=8446, num_residue=527),
#  Protein(num_atom=6419, num_bond=13090, num_residue=816),
#  Protein(num_atom=3769, num_bond=7736, num_residue=482),
#  Protein(num_atom=3266, num_bond=6648, num_residue=414),
#  Protein(num_atom=3820, num_bond=7818, num_residue=489),
#  Protein(num_atom=4444, num_bond=9100, num_residue=569),
#  Protein(num_atom=5880, num_bond=11998, num_residue=729),
#  Protein(num_atom=12397, num_bond=25454, num_residue=1620),
#  Protein(num_atom=3810, num_bond=7798, num_residue=478),
#  Protein(num_atom=3923, num_bond=8030, num_residue=479),
#  Protein(num_atom=4873, num_bond=10014, num_residue=629),
#  Protein(num_atom=2143, num_bond=4406, num_residue=270),
#  Protein(num_atom=6684, num_bond=13694, num_residue=846),
#  Protein(num_atom=3614, num_bond=7392, num_residue=447)]

# %% [markdown]
# As the ESM model limit the input length with max 1022. The excess part will be truncated, but we can not tell which part is more import. So if the length is between [1023, 2044] two embedding will be added, [2044, 3066] will get three and so on.

# %%
graph_construction_model = layers.GraphConstruction(node_layers=[layers.geometry.AlphaCarbonNode()], 
                                                    edge_layers=[layers.geometry.SpatialEdge(radius=10.0, min_distance=5),
                                                                 layers.geometry.KNNEdge(k=10, min_distance=5),
                                                                 layers.geometry.SequentialEdge(max_distance=2)],
                                                    edge_feature="gearnet")

# %% [markdown]
# For loop for all 229 protein with different length.

# %%
output_list = []
for protein in protein_list:
    print(protein)
    curLength = protein.num_residue.tolist()
    if curLength <= 1022:
        graph = data.Protein.pack([protein])
        transGraph = graph_construction_model(graph)
        output_list.append(transGraph)
    elif curLength <= 2044:
        mask1 = list(range(1022))
        mask2 = list(range(1022, curLength))
        part1 = protein.subresidue(mask1)
        part2 = protein.subresidue(mask2)
        graph = data.Protein.pack([part1, part2])
        transGraph = graph_construction_model(graph)
        output_list.append(transGraph)
    elif curLength <= 3066:
        mask1 = list(range(1022))
        mask2 = list(range(1022, 2044))
        mask3 = list(range(2044, curLength))
        part1 = protein.subresidue(mask1)
        part2 = protein.subresidue(mask2)
        part3 = protein.subresidue(mask3)
        graph = data.Protein.pack([part1, part2, part3])
        transGraph = graph_construction_model(graph)
        output_list.append(transGraph)
    elif curLength <= 5110:
        mask1 = list(range(1022))
        mask2 = list(range(1022, 2044))
        mask3 = list(range(2044, 3066))
        mask4 = list(range(3066, 4088))
        mask5 = list(range(4088, curLength))
        part1 = protein.subresidue(mask1)
        part2 = protein.subresidue(mask2)
        part3 = protein.subresidue(mask3)
        part4 = protein.subresidue(mask4)
        part5 = protein.subresidue(mask5)
        graph = data.Protein.pack([part1, part2, part3, part4, part5])
        transGraph = graph_construction_model(graph)
        output_list.append(transGraph)
    else :
        raise ValueError("Error with to long residue")
# Out:
# Protein(num_atom=3454, num_bond=7092, num_residue=431)
# Protein(num_atom=4481, num_bond=9122, num_residue=574)
# Protein(num_atom=8396, num_bond=17184, num_residue=1044)
# Protein(num_atom=5776, num_bond=11822, num_residue=725)
# Protein(num_atom=7660, num_bond=15664, num_residue=970)
# Protein(num_atom=3829, num_bond=7834, num_residue=476)
# Protein(num_atom=6066, num_bond=12346, num_residue=756)
# Protein(num_atom=3228, num_bond=6604, num_residue=403)
# Protein(num_atom=5783, num_bond=11792, num_residue=740)
# Protein(num_atom=5932, num_bond=12108, num_residue=745)
# Protein(num_atom=2964, num_bond=6066, num_residue=365)
# Protein(num_atom=4453, num_bond=9134, num_residue=556)
# Protein(num_atom=3702, num_bond=7522, num_residue=454)
# Protein(num_atom=2136, num_bond=4386, num_residue=272)
# Protein(num_atom=4620, num_bond=9458, num_residue=588)
# Protein(num_atom=5222, num_bond=10662, num_residue=661)
# Protein(num_atom=9192, num_bond=18812, num_residue=1132)
# Protein(num_atom=11278, num_bond=22884, num_residue=1388)
# Protein(num_atom=6324, num_bond=12920, num_residue=802)
# Protein(num_atom=6033, num_bond=12336, num_residue=772)
# Protein(num_atom=7050, num_bond=14426, num_residue=890)
# Protein(num_atom=9996, num_bond=20386, num_residue=1239)
# Protein(num_atom=4506, num_bond=9230, num_residue=591)
# Protein(num_atom=4282, num_bond=8734, num_residue=543)
# Protein(num_atom=8643, num_bond=17678, num_residue=1130)
# Protein(num_atom=9392, num_bond=19228, num_residue=1210)
# Protein(num_atom=5130, num_bond=10500, num_residue=648)
# Protein(num_atom=9661, num_bond=19856, num_residue=1255)
# Protein(num_atom=6155, num_bond=12626, num_residue=796)
# Protein(num_atom=5522, num_bond=11362, num_residue=697)
# Protein(num_atom=5401, num_bond=11074, num_residue=671)
# Protein(num_atom=10981, num_bond=22534, num_residue=1382)
# Protein(num_atom=4088, num_bond=8388, num_residue=509)
# Protein(num_atom=4279, num_bond=8762, num_residue=537)
# Protein(num_atom=2405, num_bond=4920, num_residue=297)
# Protein(num_atom=6581, num_bond=13430, num_residue=822)
# Protein(num_atom=7607, num_bond=15616, num_residue=972)
# Protein(num_atom=4280, num_bond=8772, num_residue=543)
# Protein(num_atom=4124, num_bond=8440, num_residue=512)
# Protein(num_atom=8740, num_bond=17924, num_residue=1114)
# Protein(num_atom=10860, num_bond=22258, num_residue=1367)
# Protein(num_atom=10929, num_bond=22394, num_residue=1390)
# Protein(num_atom=4188, num_bond=8580, num_residue=526)
# Protein(num_atom=18612, num_bond=38200, num_residue=2347)
# Protein(num_atom=8716, num_bond=17840, num_residue=1106)
# Protein(num_atom=4186, num_bond=8582, num_residue=529)
# Protein(num_atom=7725, num_bond=15830, num_residue=976)
# Protein(num_atom=2519, num_bond=5170, num_residue=313)
# Protein(num_atom=6446, num_bond=13208, num_residue=822)
# Protein(num_atom=2376, num_bond=4874, num_residue=303)
# Protein(num_atom=4214, num_bond=8632, num_residue=536)
# Protein(num_atom=5936, num_bond=12138, num_residue=766)
# Protein(num_atom=3269, num_bond=6696, num_residue=406)
# Protein(num_atom=8623, num_bond=17616, num_residue=1089)
# Protein(num_atom=6637, num_bond=13490, num_residue=822)
# Protein(num_atom=5393, num_bond=11060, num_residue=672)
# Protein(num_atom=2872, num_bond=5890, num_residue=351)
# Protein(num_atom=10584, num_bond=21626, num_residue=1338)
# Protein(num_atom=2911, num_bond=5970, num_residue=350)
# Protein(num_atom=6456, num_bond=13222, num_residue=821)
# Protein(num_atom=6193, num_bond=12704, num_residue=802)
# Protein(num_atom=6163, num_bond=12616, num_residue=806)
# Protein(num_atom=2858, num_bond=5860, num_residue=351)
# Protein(num_atom=2874, num_bond=5892, num_residue=351)
# Protein(num_atom=4158, num_bond=8514, num_residue=525)
# Protein(num_atom=9355, num_bond=19118, num_residue=1154)
# Protein(num_atom=5466, num_bond=11190, num_residue=683)
# Protein(num_atom=2398, num_bond=4920, num_residue=298)
# Protein(num_atom=3036, num_bond=6210, num_residue=379)
# Protein(num_atom=5927, num_bond=12066, num_residue=753)
# Protein(num_atom=2915, num_bond=5970, num_residue=360)
# Protein(num_atom=7603, num_bond=15590, num_residue=976)
# Protein(num_atom=8232, num_bond=16830, num_residue=1055)
# Protein(num_atom=6440, num_bond=13224, num_residue=864)
# Protein(num_atom=9409, num_bond=19324, num_residue=1187)
# Protein(num_atom=5027, num_bond=10272, num_residue=646)
# Protein(num_atom=6913, num_bond=14202, num_residue=894)
# Protein(num_atom=3919, num_bond=8024, num_residue=480)
# Protein(num_atom=3925, num_bond=8038, num_residue=481)
# Protein(num_atom=4763, num_bond=9730, num_residue=590)
# Protein(num_atom=10740, num_bond=22000, num_residue=1363)
# Protein(num_atom=10643, num_bond=21752, num_residue=1356)
# Protein(num_atom=3121, num_bond=6372, num_residue=400)
# Protein(num_atom=7935, num_bond=16276, num_residue=993)
# Protein(num_atom=3564, num_bond=7288, num_residue=450)
# Protein(num_atom=3717, num_bond=7600, num_residue=467)
# Protein(num_atom=4791, num_bond=9810, num_residue=596)
# Protein(num_atom=8722, num_bond=17846, num_residue=1068)
# Protein(num_atom=8633, num_bond=17652, num_residue=1070)
# Protein(num_atom=20287, num_bond=41398, num_residue=2549)
# Protein(num_atom=3973, num_bond=8136, num_residue=507)
# Protein(num_atom=9023, num_bond=18462, num_residue=1182)
# Protein(num_atom=4110, num_bond=8424, num_residue=505)
# Protein(num_atom=4905, num_bond=10058, num_residue=619)
# Protein(num_atom=5075, num_bond=10384, num_residue=635)
# Protein(num_atom=3385, num_bond=6914, num_residue=427)
# Protein(num_atom=3376, num_bond=6894, num_residue=424)
# Protein(num_atom=2738, num_bond=5594, num_residue=337)
# Protein(num_atom=3328, num_bond=6796, num_residue=415)
# Protein(num_atom=8906, num_bond=18228, num_residue=1102)
# Protein(num_atom=3202, num_bond=6574, num_residue=400)
# Protein(num_atom=3755, num_bond=7716, num_residue=464)
# Protein(num_atom=3330, num_bond=6794, num_residue=416)
# Protein(num_atom=4035, num_bond=8272, num_residue=484)
# Protein(num_atom=4241, num_bond=8690, num_residue=499)
# Protein(num_atom=3591, num_bond=7352, num_residue=483)
# Protein(num_atom=3292, num_bond=6738, num_residue=420)
# Protein(num_atom=2751, num_bond=5630, num_residue=346)
# Protein(num_atom=3007, num_bond=6140, num_residue=372)
# Protein(num_atom=4062, num_bond=8326, num_residue=505)
# Protein(num_atom=5389, num_bond=11080, num_residue=712)
# Protein(num_atom=5899, num_bond=12070, num_residue=740)
# Protein(num_atom=5493, num_bond=11258, num_residue=675)
# Protein(num_atom=2895, num_bond=5962, num_residue=358)
# Protein(num_atom=3631, num_bond=7368, num_residue=445)
# Protein(num_atom=6636, num_bond=13502, num_residue=841)
# Protein(num_atom=8801, num_bond=18040, num_residue=1124)
# Protein(num_atom=2630, num_bond=5370, num_residue=334)
# Protein(num_atom=4804, num_bond=9822, num_residue=603)
# Protein(num_atom=5087, num_bond=10428, num_residue=647)
# Protein(num_atom=2951, num_bond=6032, num_residue=367)
# Protein(num_atom=3688, num_bond=7532, num_residue=464)
# Protein(num_atom=2651, num_bond=5414, num_residue=331)
# Protein(num_atom=4376, num_bond=8948, num_residue=552)
# Protein(num_atom=7611, num_bond=15600, num_residue=987)
# Protein(num_atom=1752, num_bond=3606, num_residue=215)
# Protein(num_atom=3182, num_bond=6534, num_residue=391)
# Protein(num_atom=3342, num_bond=6842, num_residue=415)
# Protein(num_atom=32960, num_bond=67292, num_residue=4128)
# Protein(num_atom=8574, num_bond=17570, num_residue=1104)
# Protein(num_atom=2600, num_bond=5310, num_residue=326)
# Protein(num_atom=2346, num_bond=4804, num_residue=292)
# Protein(num_atom=5876, num_bond=12000, num_residue=737)
# Protein(num_atom=3048, num_bond=6224, num_residue=393)
# Protein(num_atom=8835, num_bond=18102, num_residue=1124)
# Protein(num_atom=7307, num_bond=15016, num_residue=954)
# Protein(num_atom=5739, num_bond=11762, num_residue=706)
# Protein(num_atom=4001, num_bond=8178, num_residue=509)
# Protein(num_atom=10709, num_bond=22030, num_residue=1400)
# Protein(num_atom=8378, num_bond=17132, num_residue=1052)
# Protein(num_atom=4754, num_bond=9726, num_residue=592)
# Protein(num_atom=5449, num_bond=11150, num_residue=676)
# Protein(num_atom=5368, num_bond=11004, num_residue=659)
# Protein(num_atom=6809, num_bond=13954, num_residue=890)
# Protein(num_atom=8067, num_bond=16628, num_residue=1038)
# Protein(num_atom=5061, num_bond=10380, num_residue=620)
# Protein(num_atom=6446, num_bond=13224, num_residue=820)
# Protein(num_atom=7754, num_bond=15892, num_residue=999)
# Protein(num_atom=4499, num_bond=9200, num_residue=559)
# Protein(num_atom=4254, num_bond=8672, num_residue=545)
# Protein(num_atom=4074, num_bond=8316, num_residue=524)
# Protein(num_atom=3943, num_bond=8040, num_residue=491)
# Protein(num_atom=6155, num_bond=12552, num_residue=762)
# Protein(num_atom=11093, num_bond=22508, num_residue=1354)
# Protein(num_atom=5111, num_bond=10470, num_residue=666)
# Protein(num_atom=4402, num_bond=8994, num_residue=558)
# Protein(num_atom=3966, num_bond=8118, num_residue=499)
# Protein(num_atom=6017, num_bond=12332, num_residue=763)
# Protein(num_atom=3656, num_bond=7512, num_residue=451)
# Protein(num_atom=5373, num_bond=10968, num_residue=671)
# Protein(num_atom=2906, num_bond=5942, num_residue=370)
# Protein(num_atom=5660, num_bond=11540, num_residue=716)
# Protein(num_atom=8131, num_bond=16606, num_residue=1009)
# Protein(num_atom=5242, num_bond=10708, num_residue=651)
# Protein(num_atom=2393, num_bond=4890, num_residue=307)
# Protein(num_atom=3470, num_bond=7110, num_residue=436)
# Protein(num_atom=7137, num_bond=14594, num_residue=912)
# Protein(num_atom=10291, num_bond=21140, num_residue=1308)
# Protein(num_atom=5830, num_bond=11934, num_residue=735)
# Protein(num_atom=2913, num_bond=5962, num_residue=364)
# Protein(num_atom=6640, num_bond=13610, num_residue=839)
# Protein(num_atom=7312, num_bond=14914, num_residue=942)
# Protein(num_atom=7874, num_bond=16050, num_residue=984)
# Protein(num_atom=2907, num_bond=5946, num_residue=360)
# Protein(num_atom=3651, num_bond=7442, num_residue=473)
# Protein(num_atom=6534, num_bond=13446, num_residue=847)
# Protein(num_atom=6467, num_bond=13272, num_residue=822)
# Protein(num_atom=3016, num_bond=6168, num_residue=382)
# Protein(num_atom=20070, num_bond=40872, num_residue=2527)
# Protein(num_atom=13836, num_bond=28154, num_residue=1732)
# Protein(num_atom=6174, num_bond=12596, num_residue=788)
# Protein(num_atom=8140, num_bond=16572, num_residue=1001)
# Protein(num_atom=2529, num_bond=5174, num_residue=326)
# Protein(num_atom=3017, num_bond=6156, num_residue=385)
# Protein(num_atom=3805, num_bond=7764, num_residue=473)
# Protein(num_atom=10543, num_bond=21568, num_residue=1332)
# Protein(num_atom=4886, num_bond=10020, num_residue=616)
# Protein(num_atom=5988, num_bond=12278, num_residue=778)
# Protein(num_atom=2768, num_bond=5672, num_residue=344)
# Protein(num_atom=2532, num_bond=5172, num_residue=322)
# Protein(num_atom=5799, num_bond=11854, num_residue=752)
# Protein(num_atom=2873, num_bond=5854, num_residue=358)
# Protein(num_atom=10027, num_bond=20484, num_residue=1323)
# Protein(num_atom=4537, num_bond=9268, num_residue=588)
# Protein(num_atom=5221, num_bond=10646, num_residue=655)
# Protein(num_atom=10876, num_bond=22196, num_residue=1374)
# Protein(num_atom=3601, num_bond=7344, num_residue=465)
# Protein(num_atom=4006, num_bond=8224, num_residue=502)
# Protein(num_atom=2919, num_bond=5964, num_residue=367)
# Protein(num_atom=6795, num_bond=13908, num_residue=878)
# Protein(num_atom=7301, num_bond=14950, num_residue=926)
# Protein(num_atom=10004, num_bond=20242, num_residue=1235)
# Protein(num_atom=9202, num_bond=18864, num_residue=1198)
# Protein(num_atom=3842, num_bond=7900, num_residue=488)
# Protein(num_atom=5050, num_bond=10360, num_residue=646)
# Protein(num_atom=4045, num_bond=8296, num_residue=481)
# Protein(num_atom=3641, num_bond=7438, num_residue=465)
# Protein(num_atom=2908, num_bond=5974, num_residue=367)
# Protein(num_atom=2504, num_bond=5136, num_residue=313)
# Protein(num_atom=3415, num_bond=6992, num_residue=422)
# Protein(num_atom=4199, num_bond=8596, num_residue=520)
# Protein(num_atom=3615, num_bond=7368, num_residue=460)
# Protein(num_atom=6416, num_bond=13142, num_residue=800)
# Protein(num_atom=2412, num_bond=4976, num_residue=311)
# Protein(num_atom=3271, num_bond=6666, num_residue=416)
# Protein(num_atom=4103, num_bond=8446, num_residue=527)
# Protein(num_atom=6419, num_bond=13090, num_residue=816)
# Protein(num_atom=3769, num_bond=7736, num_residue=482)
# Protein(num_atom=3266, num_bond=6648, num_residue=414)
# Protein(num_atom=3820, num_bond=7818, num_residue=489)
# Protein(num_atom=4444, num_bond=9100, num_residue=569)
# Protein(num_atom=5880, num_bond=11998, num_residue=729)
# Protein(num_atom=12397, num_bond=25454, num_residue=1620)
# Protein(num_atom=3810, num_bond=7798, num_residue=478)
# Protein(num_atom=3923, num_bond=8030, num_residue=479)
# Protein(num_atom=4873, num_bond=10014, num_residue=629)
# Protein(num_atom=2143, num_bond=4406, num_residue=270)
# Protein(num_atom=6684, num_bond=13694, num_residue=846)
# Protein(num_atom=3614, num_bond=7392, num_residue=447)

# %%
output_list
# Out:
# [PackedProtein(batch_size=1, num_atoms=[431], num_bonds=[7507], num_residues=[431]),
#  PackedProtein(batch_size=1, num_atoms=[574], num_bonds=[8301], num_residues=[574]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 22], num_bonds=[19103, 220], num_residues=[1022, 22]),
#  PackedProtein(batch_size=1, num_atoms=[725], num_bonds=[11806], num_residues=[725]),
#  PackedProtein(batch_size=1, num_atoms=[970], num_bonds=[13888], num_residues=[970]),
#  PackedProtein(batch_size=1, num_atoms=[476], num_bonds=[8081], num_residues=[476]),
#  PackedProtein(batch_size=1, num_atoms=[756], num_bonds=[12719], num_residues=[756]),
#  PackedProtein(batch_size=1, num_atoms=[403], num_bonds=[6331], num_residues=[403]),
#  PackedProtein(batch_size=1, num_atoms=[740], num_bonds=[11870], num_residues=[740]),
#  PackedProtein(batch_size=1, num_atoms=[745], num_bonds=[12311], num_residues=[745]),
#  PackedProtein(batch_size=1, num_atoms=[365], num_bonds=[6814], num_residues=[365]),
#  PackedProtein(batch_size=1, num_atoms=[556], num_bonds=[9386], num_residues=[556]),
#  PackedProtein(batch_size=1, num_atoms=[454], num_bonds=[7409], num_residues=[454]),
#  PackedProtein(batch_size=1, num_atoms=[272], num_bonds=[3534], num_residues=[272]),
#  PackedProtein(batch_size=1, num_atoms=[588], num_bonds=[8956], num_residues=[588]),
#  PackedProtein(batch_size=1, num_atoms=[661], num_bonds=[8488], num_residues=[661]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 110], num_bonds=[19011, 1627], num_residues=[1022, 110]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 366], num_bonds=[14509, 5332], num_residues=[1022, 366]),
#  PackedProtein(batch_size=1, num_atoms=[802], num_bonds=[13976], num_residues=[802]),
#  PackedProtein(batch_size=1, num_atoms=[772], num_bonds=[14059], num_residues=[772]),
#  PackedProtein(batch_size=1, num_atoms=[890], num_bonds=[14404], num_residues=[890]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 217], num_bonds=[12859, 4504], num_residues=[1022, 217]),
#  PackedProtein(batch_size=1, num_atoms=[591], num_bonds=[8296], num_residues=[591]),
#  PackedProtein(batch_size=1, num_atoms=[543], num_bonds=[8702], num_residues=[543]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 108], num_bonds=[13040, 1465], num_residues=[1022, 108]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 188], num_bonds=[20274, 1330], num_residues=[1022, 188]),
#  PackedProtein(batch_size=1, num_atoms=[648], num_bonds=[9628], num_residues=[648]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 233], num_bonds=[20391, 1667], num_residues=[1022, 233]),
#  PackedProtein(batch_size=1, num_atoms=[796], num_bonds=[14606], num_residues=[796]),
#  PackedProtein(batch_size=1, num_atoms=[697], num_bonds=[13228], num_residues=[697]),
#  PackedProtein(batch_size=1, num_atoms=[671], num_bonds=[12841], num_residues=[671]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 360], num_bonds=[19038, 6152], num_residues=[1022, 360]),
#  PackedProtein(batch_size=1, num_atoms=[509], num_bonds=[9040], num_residues=[509]),
#  PackedProtein(batch_size=1, num_atoms=[537], num_bonds=[9484], num_residues=[537]),
#  PackedProtein(batch_size=1, num_atoms=[297], num_bonds=[5545], num_residues=[297]),
#  PackedProtein(batch_size=1, num_atoms=[822], num_bonds=[13442], num_residues=[822]),
#  PackedProtein(batch_size=1, num_atoms=[972], num_bonds=[18216], num_residues=[972]),
#  PackedProtein(batch_size=1, num_atoms=[543], num_bonds=[9533], num_residues=[543]),
#  PackedProtein(batch_size=1, num_atoms=[512], num_bonds=[9075], num_residues=[512]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 92], num_bonds=[19185, 658], num_residues=[1022, 92]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 345], num_bonds=[19140, 5419], num_residues=[1022, 345]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 368], num_bonds=[20854, 6491], num_residues=[1022, 368]),
#  PackedProtein(batch_size=1, num_atoms=[526], num_bonds=[9277], num_residues=[526]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 303], num_bonds=[20642, 19768, 4228], num_residues=[1022, 1022, 303]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 84], num_bonds=[18237, 602], num_residues=[1022, 84]),
#  PackedProtein(batch_size=1, num_atoms=[529], num_bonds=[9475], num_residues=[529]),
#  PackedProtein(batch_size=1, num_atoms=[976], num_bonds=[18002], num_residues=[976]),
#  PackedProtein(batch_size=1, num_atoms=[313], num_bonds=[5712], num_residues=[313]),
#  PackedProtein(batch_size=1, num_atoms=[822], num_bonds=[13483], num_residues=[822]),
#  PackedProtein(batch_size=1, num_atoms=[303], num_bonds=[5566], num_residues=[303]),
#  PackedProtein(batch_size=1, num_atoms=[536], num_bonds=[9506], num_residues=[536]),
#  PackedProtein(batch_size=1, num_atoms=[766], num_bonds=[11016], num_residues=[766]),
#  PackedProtein(batch_size=1, num_atoms=[406], num_bonds=[6561], num_residues=[406]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 67], num_bonds=[18635, 483], num_residues=[1022, 67]),
#  PackedProtein(batch_size=1, num_atoms=[822], num_bonds=[13206], num_residues=[822]),
#  PackedProtein(batch_size=1, num_atoms=[672], num_bonds=[12833], num_residues=[672]),
#  PackedProtein(batch_size=1, num_atoms=[351], num_bonds=[6645], num_residues=[351]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 316], num_bonds=[18762, 3573], num_residues=[1022, 316]),
#  PackedProtein(batch_size=1, num_atoms=[350], num_bonds=[6507], num_residues=[350]),
#  PackedProtein(batch_size=1, num_atoms=[821], num_bonds=[13519], num_residues=[821]),
#  PackedProtein(batch_size=1, num_atoms=[802], num_bonds=[13379], num_residues=[802]),
#  PackedProtein(batch_size=1, num_atoms=[806], num_bonds=[13515], num_residues=[806]),
#  PackedProtein(batch_size=1, num_atoms=[351], num_bonds=[6624], num_residues=[351]),
#  PackedProtein(batch_size=1, num_atoms=[351], num_bonds=[6629], num_residues=[351]),
#  PackedProtein(batch_size=1, num_atoms=[525], num_bonds=[7991], num_residues=[525]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 132], num_bonds=[19101, 2056], num_residues=[1022, 132]),
#  PackedProtein(batch_size=1, num_atoms=[683], num_bonds=[12816], num_residues=[683]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5562], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[379], num_bonds=[6989], num_residues=[379]),
#  PackedProtein(batch_size=1, num_atoms=[753], num_bonds=[10524], num_residues=[753]),
#  PackedProtein(batch_size=1, num_atoms=[360], num_bonds=[6666], num_residues=[360]),
#  PackedProtein(batch_size=1, num_atoms=[976], num_bonds=[18766], num_residues=[976]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 33], num_bonds=[19187, 245], num_residues=[1022, 33]),
#  PackedProtein(batch_size=1, num_atoms=[864], num_bonds=[16788], num_residues=[864]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 165], num_bonds=[18441, 2573], num_residues=[1022, 165]),
#  PackedProtein(batch_size=1, num_atoms=[646], num_bonds=[8424], num_residues=[646]),
#  PackedProtein(batch_size=1, num_atoms=[894], num_bonds=[15699], num_residues=[894]),
#  PackedProtein(batch_size=1, num_atoms=[480], num_bonds=[8833], num_residues=[480]),
#  PackedProtein(batch_size=1, num_atoms=[481], num_bonds=[8855], num_residues=[481]),
#  PackedProtein(batch_size=1, num_atoms=[590], num_bonds=[10368], num_residues=[590]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 341], num_bonds=[18602, 4121], num_residues=[1022, 341]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 334], num_bonds=[18667, 3898], num_residues=[1022, 334]),
#  PackedProtein(batch_size=1, num_atoms=[400], num_bonds=[6787], num_residues=[400]),
#  PackedProtein(batch_size=1, num_atoms=[993], num_bonds=[17735], num_residues=[993]),
#  PackedProtein(batch_size=1, num_atoms=[450], num_bonds=[8976], num_residues=[450]),
#  PackedProtein(batch_size=1, num_atoms=[467], num_bonds=[7722], num_residues=[467]),
#  PackedProtein(batch_size=1, num_atoms=[596], num_bonds=[10318], num_residues=[596]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 46], num_bonds=[19392, 542], num_residues=[1022, 46]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 48], num_bonds=[18891, 521], num_residues=[1022, 48]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 505], num_bonds=[16207, 15927, 8267], num_residues=[1022, 1022, 505]),
#  PackedProtein(batch_size=1, num_atoms=[507], num_bonds=[9353], num_residues=[507]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 160], num_bonds=[13235, 2067], num_residues=[1022, 160]),
#  PackedProtein(batch_size=1, num_atoms=[505], num_bonds=[9324], num_residues=[505]),
#  PackedProtein(batch_size=1, num_atoms=[619], num_bonds=[11592], num_residues=[619]),
#  PackedProtein(batch_size=1, num_atoms=[635], num_bonds=[11623], num_residues=[635]),
#  PackedProtein(batch_size=1, num_atoms=[427], num_bonds=[7405], num_residues=[427]),
#  PackedProtein(batch_size=1, num_atoms=[424], num_bonds=[7287], num_residues=[424]),
#  PackedProtein(batch_size=1, num_atoms=[337], num_bonds=[5862], num_residues=[337]),
#  PackedProtein(batch_size=1, num_atoms=[415], num_bonds=[6559], num_residues=[415]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 80], num_bonds=[18890, 898], num_residues=[1022, 80]),
#  PackedProtein(batch_size=1, num_atoms=[400], num_bonds=[6478], num_residues=[400]),
#  PackedProtein(batch_size=1, num_atoms=[464], num_bonds=[7427], num_residues=[464]),
#  PackedProtein(batch_size=1, num_atoms=[416], num_bonds=[6659], num_residues=[416]),
#  PackedProtein(batch_size=1, num_atoms=[484], num_bonds=[7933], num_residues=[484]),
#  PackedProtein(batch_size=1, num_atoms=[499], num_bonds=[7671], num_residues=[499]),
#  PackedProtein(batch_size=1, num_atoms=[483], num_bonds=[7716], num_residues=[483]),
#  PackedProtein(batch_size=1, num_atoms=[420], num_bonds=[7597], num_residues=[420]),
#  PackedProtein(batch_size=1, num_atoms=[346], num_bonds=[6157], num_residues=[346]),
#  PackedProtein(batch_size=1, num_atoms=[372], num_bonds=[6727], num_residues=[372]),
#  PackedProtein(batch_size=1, num_atoms=[505], num_bonds=[8981], num_residues=[505]),
#  PackedProtein(batch_size=1, num_atoms=[712], num_bonds=[10003], num_residues=[712]),
#  PackedProtein(batch_size=1, num_atoms=[740], num_bonds=[13442], num_residues=[740]),
#  PackedProtein(batch_size=1, num_atoms=[675], num_bonds=[11330], num_residues=[675]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[6470], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[445], num_bonds=[6711], num_residues=[445]),
#  PackedProtein(batch_size=1, num_atoms=[841], num_bonds=[9798], num_residues=[841]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 102], num_bonds=[19706, 1152], num_residues=[1022, 102]),
#  PackedProtein(batch_size=1, num_atoms=[334], num_bonds=[5968], num_residues=[334]),
#  PackedProtein(batch_size=1, num_atoms=[603], num_bonds=[10867], num_residues=[603]),
#  PackedProtein(batch_size=1, num_atoms=[647], num_bonds=[11064], num_residues=[647]),
#  PackedProtein(batch_size=1, num_atoms=[367], num_bonds=[6712], num_residues=[367]),
#  PackedProtein(batch_size=1, num_atoms=[464], num_bonds=[7518], num_residues=[464]),
#  PackedProtein(batch_size=1, num_atoms=[331], num_bonds=[5805], num_residues=[331]),
#  PackedProtein(batch_size=1, num_atoms=[552], num_bonds=[8694], num_residues=[552]),
#  PackedProtein(batch_size=1, num_atoms=[987], num_bonds=[19005], num_residues=[987]),
#  PackedProtein(batch_size=1, num_atoms=[215], num_bonds=[3518], num_residues=[215]),
#  PackedProtein(batch_size=1, num_atoms=[391], num_bonds=[6806], num_residues=[391]),
#  PackedProtein(batch_size=1, num_atoms=[415], num_bonds=[6661], num_residues=[415]),
#  PackedProtein(batch_size=5, num_atoms=[1022, 1022, 1022, 1022, 40], num_bonds=[16592, 16611, 15667, 17355, 454], num_residues=[1022, 1022, 1022, 1022, 40]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 82], num_bonds=[12180, 592], num_residues=[1022, 82]),
#  PackedProtein(batch_size=1, num_atoms=[326], num_bonds=[5834], num_residues=[326]),
#  PackedProtein(batch_size=1, num_atoms=[292], num_bonds=[5562], num_residues=[292]),
#  PackedProtein(batch_size=1, num_atoms=[737], num_bonds=[13651], num_residues=[737]),
#  PackedProtein(batch_size=1, num_atoms=[393], num_bonds=[6880], num_residues=[393]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 102], num_bonds=[20777, 1446], num_residues=[1022, 102]),
#  PackedProtein(batch_size=1, num_atoms=[954], num_bonds=[11860], num_residues=[954]),
#  PackedProtein(batch_size=1, num_atoms=[706], num_bonds=[12588], num_residues=[706]),
#  PackedProtein(batch_size=1, num_atoms=[509], num_bonds=[8889], num_residues=[509]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 378], num_bonds=[21165, 6291], num_residues=[1022, 378]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 30], num_bonds=[15660, 290], num_residues=[1022, 30]),
#  PackedProtein(batch_size=1, num_atoms=[592], num_bonds=[10314], num_residues=[592]),
#  PackedProtein(batch_size=1, num_atoms=[676], num_bonds=[12577], num_residues=[676]),
#  PackedProtein(batch_size=1, num_atoms=[659], num_bonds=[12491], num_residues=[659]),
#  PackedProtein(batch_size=1, num_atoms=[890], num_bonds=[15585], num_residues=[890]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 16], num_bonds=[13401, 138], num_residues=[1022, 16]),
#  PackedProtein(batch_size=1, num_atoms=[620], num_bonds=[11930], num_residues=[620]),
#  PackedProtein(batch_size=1, num_atoms=[820], num_bonds=[15086], num_residues=[820]),
#  PackedProtein(batch_size=1, num_atoms=[999], num_bonds=[16532], num_residues=[999]),
#  PackedProtein(batch_size=1, num_atoms=[559], num_bonds=[8750], num_residues=[559]),
#  PackedProtein(batch_size=1, num_atoms=[545], num_bonds=[8492], num_residues=[545]),
#  PackedProtein(batch_size=1, num_atoms=[524], num_bonds=[8170], num_residues=[524]),
#  PackedProtein(batch_size=1, num_atoms=[491], num_bonds=[7644], num_residues=[491]),
#  PackedProtein(batch_size=1, num_atoms=[762], num_bonds=[13492], num_residues=[762]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 332], num_bonds=[13922, 5076], num_residues=[1022, 332]),
#  PackedProtein(batch_size=1, num_atoms=[666], num_bonds=[10331], num_residues=[666]),
#  PackedProtein(batch_size=1, num_atoms=[558], num_bonds=[9694], num_residues=[558]),
#  PackedProtein(batch_size=1, num_atoms=[499], num_bonds=[8964], num_residues=[499]),
#  PackedProtein(batch_size=1, num_atoms=[763], num_bonds=[10044], num_residues=[763]),
#  PackedProtein(batch_size=1, num_atoms=[451], num_bonds=[8854], num_residues=[451]),
#  PackedProtein(batch_size=1, num_atoms=[671], num_bonds=[12735], num_residues=[671]),
#  PackedProtein(batch_size=1, num_atoms=[370], num_bonds=[6325], num_residues=[370]),
#  PackedProtein(batch_size=1, num_atoms=[716], num_bonds=[12650], num_residues=[716]),
#  PackedProtein(batch_size=1, num_atoms=[1009], num_bonds=[15967], num_residues=[1009]),
#  PackedProtein(batch_size=1, num_atoms=[651], num_bonds=[10054], num_residues=[651]),
#  PackedProtein(batch_size=1, num_atoms=[307], num_bonds=[3819], num_residues=[307]),
#  PackedProtein(batch_size=1, num_atoms=[436], num_bonds=[7367], num_residues=[436]),
#  PackedProtein(batch_size=1, num_atoms=[912], num_bonds=[14686], num_residues=[912]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 286], num_bonds=[20644, 2019], num_residues=[1022, 286]),
#  PackedProtein(batch_size=1, num_atoms=[735], num_bonds=[13346], num_residues=[735]),
#  PackedProtein(batch_size=1, num_atoms=[364], num_bonds=[6704], num_residues=[364]),
#  PackedProtein(batch_size=1, num_atoms=[839], num_bonds=[15104], num_residues=[839]),
#  PackedProtein(batch_size=1, num_atoms=[942], num_bonds=[14856], num_residues=[942]),
#  PackedProtein(batch_size=1, num_atoms=[984], num_bonds=[15296], num_residues=[984]),
#  PackedProtein(batch_size=1, num_atoms=[360], num_bonds=[6672], num_residues=[360]),
#  PackedProtein(batch_size=1, num_atoms=[473], num_bonds=[7051], num_residues=[473]),
#  PackedProtein(batch_size=1, num_atoms=[847], num_bonds=[11050], num_residues=[847]),
#  PackedProtein(batch_size=1, num_atoms=[822], num_bonds=[14832], num_residues=[822]),
#  PackedProtein(batch_size=1, num_atoms=[382], num_bonds=[6487], num_residues=[382]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 483], num_bonds=[16697, 20175, 9679], num_residues=[1022, 1022, 483]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 710], num_bonds=[14102, 12627], num_residues=[1022, 710]),
#  PackedProtein(batch_size=1, num_atoms=[788], num_bonds=[10982], num_residues=[788]),
#  PackedProtein(batch_size=1, num_atoms=[1001], num_bonds=[14108], num_residues=[1001]),
#  PackedProtein(batch_size=1, num_atoms=[326], num_bonds=[5684], num_residues=[326]),
#  PackedProtein(batch_size=1, num_atoms=[385], num_bonds=[6369], num_residues=[385]),
#  PackedProtein(batch_size=1, num_atoms=[473], num_bonds=[7902], num_residues=[473]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 310], num_bonds=[11522, 6394], num_residues=[1022, 310]),
#  PackedProtein(batch_size=1, num_atoms=[616], num_bonds=[9457], num_residues=[616]),
#  PackedProtein(batch_size=1, num_atoms=[778], num_bonds=[11101], num_residues=[778]),
#  PackedProtein(batch_size=1, num_atoms=[344], num_bonds=[5873], num_residues=[344]),
#  PackedProtein(batch_size=1, num_atoms=[322], num_bonds=[5793], num_residues=[322]),
#  PackedProtein(batch_size=1, num_atoms=[752], num_bonds=[10697], num_residues=[752]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[6201], num_residues=[358]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 301], num_bonds=[11745, 4883], num_residues=[1022, 301]),
#  PackedProtein(batch_size=1, num_atoms=[588], num_bonds=[8282], num_residues=[588]),
#  PackedProtein(batch_size=1, num_atoms=[655], num_bonds=[10090], num_residues=[655]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 352], num_bonds=[16651, 4391], num_residues=[1022, 352]),
#  PackedProtein(batch_size=1, num_atoms=[465], num_bonds=[7283], num_residues=[465]),
#  PackedProtein(batch_size=1, num_atoms=[502], num_bonds=[7687], num_residues=[502]),
#  PackedProtein(batch_size=1, num_atoms=[367], num_bonds=[6029], num_residues=[367]),
#  PackedProtein(batch_size=1, num_atoms=[878], num_bonds=[14382], num_residues=[878]),
#  PackedProtein(batch_size=1, num_atoms=[926], num_bonds=[10790], num_residues=[926]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 213], num_bonds=[12248, 2409], num_residues=[1022, 213]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 176], num_bonds=[12112, 1246], num_residues=[1022, 176]),
#  PackedProtein(batch_size=1, num_atoms=[488], num_bonds=[8758], num_residues=[488]),
#  PackedProtein(batch_size=1, num_atoms=[646], num_bonds=[10960], num_residues=[646]),
#  PackedProtein(batch_size=1, num_atoms=[481], num_bonds=[7736], num_residues=[481]),
#  PackedProtein(batch_size=1, num_atoms=[465], num_bonds=[7174], num_residues=[465]),
#  PackedProtein(batch_size=1, num_atoms=[367], num_bonds=[6821], num_residues=[367]),
#  PackedProtein(batch_size=1, num_atoms=[313], num_bonds=[5352], num_residues=[313]),
#  PackedProtein(batch_size=1, num_atoms=[422], num_bonds=[6734], num_residues=[422]),
#  PackedProtein(batch_size=1, num_atoms=[520], num_bonds=[8398], num_residues=[520]),
#  PackedProtein(batch_size=1, num_atoms=[460], num_bonds=[8082], num_residues=[460]),
#  PackedProtein(batch_size=1, num_atoms=[800], num_bonds=[11655], num_residues=[800]),
#  PackedProtein(batch_size=1, num_atoms=[311], num_bonds=[5731], num_residues=[311]),
#  PackedProtein(batch_size=1, num_atoms=[416], num_bonds=[7026], num_residues=[416]),
#  PackedProtein(batch_size=1, num_atoms=[527], num_bonds=[8311], num_residues=[527]),
#  PackedProtein(batch_size=1, num_atoms=[816], num_bonds=[12161], num_residues=[816]),
#  PackedProtein(batch_size=1, num_atoms=[482], num_bonds=[7788], num_residues=[482]),
#  PackedProtein(batch_size=1, num_atoms=[414], num_bonds=[6518], num_residues=[414]),
#  PackedProtein(batch_size=1, num_atoms=[489], num_bonds=[7300], num_residues=[489]),
#  PackedProtein(batch_size=1, num_atoms=[569], num_bonds=[7616], num_residues=[569]),
#  PackedProtein(batch_size=1, num_atoms=[729], num_bonds=[12771], num_residues=[729]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 598], num_bonds=[20544, 8605], num_residues=[1022, 598]),
#  PackedProtein(batch_size=1, num_atoms=[478], num_bonds=[8866], num_residues=[478]),
#  PackedProtein(batch_size=1, num_atoms=[479], num_bonds=[8772], num_residues=[479]),
#  PackedProtein(batch_size=1, num_atoms=[629], num_bonds=[8804], num_residues=[629]),
#  PackedProtein(batch_size=1, num_atoms=[270], num_bonds=[3519], num_residues=[270]),
#  PackedProtein(batch_size=1, num_atoms=[846], num_bonds=[15166], num_residues=[846]),
#  PackedProtein(batch_size=1, num_atoms=[447], num_bonds=[6904], num_residues=[447])]

# %%
len(output_list)
# Out:
# 229

# %%
protein_view = transforms.ProteinView(view="residue", keys="graph1")

# %%
transform_list = []
for protein in output_list:
    item = {"graph1": protein}
    transform_list.append(protein_view(item)['graph1'])

# %%
transform_list
# Out:
# [PackedProtein(batch_size=1, num_atoms=[431], num_bonds=[7507], num_residues=[431]),
#  PackedProtein(batch_size=1, num_atoms=[574], num_bonds=[8301], num_residues=[574]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 22], num_bonds=[19103, 220], num_residues=[1022, 22]),
#  PackedProtein(batch_size=1, num_atoms=[725], num_bonds=[11806], num_residues=[725]),
#  PackedProtein(batch_size=1, num_atoms=[970], num_bonds=[13888], num_residues=[970]),
#  PackedProtein(batch_size=1, num_atoms=[476], num_bonds=[8081], num_residues=[476]),
#  PackedProtein(batch_size=1, num_atoms=[756], num_bonds=[12719], num_residues=[756]),
#  PackedProtein(batch_size=1, num_atoms=[403], num_bonds=[6331], num_residues=[403]),
#  PackedProtein(batch_size=1, num_atoms=[740], num_bonds=[11870], num_residues=[740]),
#  PackedProtein(batch_size=1, num_atoms=[745], num_bonds=[12311], num_residues=[745]),
#  PackedProtein(batch_size=1, num_atoms=[365], num_bonds=[6814], num_residues=[365]),
#  PackedProtein(batch_size=1, num_atoms=[556], num_bonds=[9386], num_residues=[556]),
#  PackedProtein(batch_size=1, num_atoms=[454], num_bonds=[7409], num_residues=[454]),
#  PackedProtein(batch_size=1, num_atoms=[272], num_bonds=[3534], num_residues=[272]),
#  PackedProtein(batch_size=1, num_atoms=[588], num_bonds=[8956], num_residues=[588]),
#  PackedProtein(batch_size=1, num_atoms=[661], num_bonds=[8488], num_residues=[661]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 110], num_bonds=[19011, 1627], num_residues=[1022, 110]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 366], num_bonds=[14509, 5332], num_residues=[1022, 366]),
#  PackedProtein(batch_size=1, num_atoms=[802], num_bonds=[13976], num_residues=[802]),
#  PackedProtein(batch_size=1, num_atoms=[772], num_bonds=[14059], num_residues=[772]),
#  PackedProtein(batch_size=1, num_atoms=[890], num_bonds=[14404], num_residues=[890]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 217], num_bonds=[12859, 4504], num_residues=[1022, 217]),
#  PackedProtein(batch_size=1, num_atoms=[591], num_bonds=[8296], num_residues=[591]),
#  PackedProtein(batch_size=1, num_atoms=[543], num_bonds=[8702], num_residues=[543]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 108], num_bonds=[13040, 1465], num_residues=[1022, 108]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 188], num_bonds=[20274, 1330], num_residues=[1022, 188]),
#  PackedProtein(batch_size=1, num_atoms=[648], num_bonds=[9628], num_residues=[648]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 233], num_bonds=[20391, 1667], num_residues=[1022, 233]),
#  PackedProtein(batch_size=1, num_atoms=[796], num_bonds=[14606], num_residues=[796]),
#  PackedProtein(batch_size=1, num_atoms=[697], num_bonds=[13228], num_residues=[697]),
#  PackedProtein(batch_size=1, num_atoms=[671], num_bonds=[12841], num_residues=[671]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 360], num_bonds=[19038, 6152], num_residues=[1022, 360]),
#  PackedProtein(batch_size=1, num_atoms=[509], num_bonds=[9040], num_residues=[509]),
#  PackedProtein(batch_size=1, num_atoms=[537], num_bonds=[9484], num_residues=[537]),
#  PackedProtein(batch_size=1, num_atoms=[297], num_bonds=[5545], num_residues=[297]),
#  PackedProtein(batch_size=1, num_atoms=[822], num_bonds=[13442], num_residues=[822]),
#  PackedProtein(batch_size=1, num_atoms=[972], num_bonds=[18216], num_residues=[972]),
#  PackedProtein(batch_size=1, num_atoms=[543], num_bonds=[9533], num_residues=[543]),
#  PackedProtein(batch_size=1, num_atoms=[512], num_bonds=[9075], num_residues=[512]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 92], num_bonds=[19185, 658], num_residues=[1022, 92]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 345], num_bonds=[19140, 5419], num_residues=[1022, 345]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 368], num_bonds=[20854, 6491], num_residues=[1022, 368]),
#  PackedProtein(batch_size=1, num_atoms=[526], num_bonds=[9277], num_residues=[526]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 303], num_bonds=[20642, 19768, 4228], num_residues=[1022, 1022, 303]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 84], num_bonds=[18237, 602], num_residues=[1022, 84]),
#  PackedProtein(batch_size=1, num_atoms=[529], num_bonds=[9475], num_residues=[529]),
#  PackedProtein(batch_size=1, num_atoms=[976], num_bonds=[18002], num_residues=[976]),
#  PackedProtein(batch_size=1, num_atoms=[313], num_bonds=[5712], num_residues=[313]),
#  PackedProtein(batch_size=1, num_atoms=[822], num_bonds=[13483], num_residues=[822]),
#  PackedProtein(batch_size=1, num_atoms=[303], num_bonds=[5566], num_residues=[303]),
#  PackedProtein(batch_size=1, num_atoms=[536], num_bonds=[9506], num_residues=[536]),
#  PackedProtein(batch_size=1, num_atoms=[766], num_bonds=[11016], num_residues=[766]),
#  PackedProtein(batch_size=1, num_atoms=[406], num_bonds=[6561], num_residues=[406]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 67], num_bonds=[18635, 483], num_residues=[1022, 67]),
#  PackedProtein(batch_size=1, num_atoms=[822], num_bonds=[13206], num_residues=[822]),
#  PackedProtein(batch_size=1, num_atoms=[672], num_bonds=[12833], num_residues=[672]),
#  PackedProtein(batch_size=1, num_atoms=[351], num_bonds=[6645], num_residues=[351]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 316], num_bonds=[18762, 3573], num_residues=[1022, 316]),
#  PackedProtein(batch_size=1, num_atoms=[350], num_bonds=[6507], num_residues=[350]),
#  PackedProtein(batch_size=1, num_atoms=[821], num_bonds=[13519], num_residues=[821]),
#  PackedProtein(batch_size=1, num_atoms=[802], num_bonds=[13379], num_residues=[802]),
#  PackedProtein(batch_size=1, num_atoms=[806], num_bonds=[13515], num_residues=[806]),
#  PackedProtein(batch_size=1, num_atoms=[351], num_bonds=[6624], num_residues=[351]),
#  PackedProtein(batch_size=1, num_atoms=[351], num_bonds=[6629], num_residues=[351]),
#  PackedProtein(batch_size=1, num_atoms=[525], num_bonds=[7991], num_residues=[525]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 132], num_bonds=[19101, 2056], num_residues=[1022, 132]),
#  PackedProtein(batch_size=1, num_atoms=[683], num_bonds=[12816], num_residues=[683]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5562], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[379], num_bonds=[6989], num_residues=[379]),
#  PackedProtein(batch_size=1, num_atoms=[753], num_bonds=[10524], num_residues=[753]),
#  PackedProtein(batch_size=1, num_atoms=[360], num_bonds=[6666], num_residues=[360]),
#  PackedProtein(batch_size=1, num_atoms=[976], num_bonds=[18766], num_residues=[976]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 33], num_bonds=[19187, 245], num_residues=[1022, 33]),
#  PackedProtein(batch_size=1, num_atoms=[864], num_bonds=[16788], num_residues=[864]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 165], num_bonds=[18441, 2573], num_residues=[1022, 165]),
#  PackedProtein(batch_size=1, num_atoms=[646], num_bonds=[8424], num_residues=[646]),
#  PackedProtein(batch_size=1, num_atoms=[894], num_bonds=[15699], num_residues=[894]),
#  PackedProtein(batch_size=1, num_atoms=[480], num_bonds=[8833], num_residues=[480]),
#  PackedProtein(batch_size=1, num_atoms=[481], num_bonds=[8855], num_residues=[481]),
#  PackedProtein(batch_size=1, num_atoms=[590], num_bonds=[10368], num_residues=[590]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 341], num_bonds=[18602, 4121], num_residues=[1022, 341]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 334], num_bonds=[18667, 3898], num_residues=[1022, 334]),
#  PackedProtein(batch_size=1, num_atoms=[400], num_bonds=[6787], num_residues=[400]),
#  PackedProtein(batch_size=1, num_atoms=[993], num_bonds=[17735], num_residues=[993]),
#  PackedProtein(batch_size=1, num_atoms=[450], num_bonds=[8976], num_residues=[450]),
#  PackedProtein(batch_size=1, num_atoms=[467], num_bonds=[7722], num_residues=[467]),
#  PackedProtein(batch_size=1, num_atoms=[596], num_bonds=[10318], num_residues=[596]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 46], num_bonds=[19392, 542], num_residues=[1022, 46]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 48], num_bonds=[18891, 521], num_residues=[1022, 48]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 505], num_bonds=[16207, 15927, 8267], num_residues=[1022, 1022, 505]),
#  PackedProtein(batch_size=1, num_atoms=[507], num_bonds=[9353], num_residues=[507]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 160], num_bonds=[13235, 2067], num_residues=[1022, 160]),
#  PackedProtein(batch_size=1, num_atoms=[505], num_bonds=[9324], num_residues=[505]),
#  PackedProtein(batch_size=1, num_atoms=[619], num_bonds=[11592], num_residues=[619]),
#  PackedProtein(batch_size=1, num_atoms=[635], num_bonds=[11623], num_residues=[635]),
#  PackedProtein(batch_size=1, num_atoms=[427], num_bonds=[7405], num_residues=[427]),
#  PackedProtein(batch_size=1, num_atoms=[424], num_bonds=[7287], num_residues=[424]),
#  PackedProtein(batch_size=1, num_atoms=[337], num_bonds=[5862], num_residues=[337]),
#  PackedProtein(batch_size=1, num_atoms=[415], num_bonds=[6559], num_residues=[415]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 80], num_bonds=[18890, 898], num_residues=[1022, 80]),
#  PackedProtein(batch_size=1, num_atoms=[400], num_bonds=[6478], num_residues=[400]),
#  PackedProtein(batch_size=1, num_atoms=[464], num_bonds=[7427], num_residues=[464]),
#  PackedProtein(batch_size=1, num_atoms=[416], num_bonds=[6659], num_residues=[416]),
#  PackedProtein(batch_size=1, num_atoms=[484], num_bonds=[7933], num_residues=[484]),
#  PackedProtein(batch_size=1, num_atoms=[499], num_bonds=[7671], num_residues=[499]),
#  PackedProtein(batch_size=1, num_atoms=[483], num_bonds=[7716], num_residues=[483]),
#  PackedProtein(batch_size=1, num_atoms=[420], num_bonds=[7597], num_residues=[420]),
#  PackedProtein(batch_size=1, num_atoms=[346], num_bonds=[6157], num_residues=[346]),
#  PackedProtein(batch_size=1, num_atoms=[372], num_bonds=[6727], num_residues=[372]),
#  PackedProtein(batch_size=1, num_atoms=[505], num_bonds=[8981], num_residues=[505]),
#  PackedProtein(batch_size=1, num_atoms=[712], num_bonds=[10003], num_residues=[712]),
#  PackedProtein(batch_size=1, num_atoms=[740], num_bonds=[13442], num_residues=[740]),
#  PackedProtein(batch_size=1, num_atoms=[675], num_bonds=[11330], num_residues=[675]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[6470], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[445], num_bonds=[6711], num_residues=[445]),
#  PackedProtein(batch_size=1, num_atoms=[841], num_bonds=[9798], num_residues=[841]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 102], num_bonds=[19706, 1152], num_residues=[1022, 102]),
#  PackedProtein(batch_size=1, num_atoms=[334], num_bonds=[5968], num_residues=[334]),
#  PackedProtein(batch_size=1, num_atoms=[603], num_bonds=[10867], num_residues=[603]),
#  PackedProtein(batch_size=1, num_atoms=[647], num_bonds=[11064], num_residues=[647]),
#  PackedProtein(batch_size=1, num_atoms=[367], num_bonds=[6712], num_residues=[367]),
#  PackedProtein(batch_size=1, num_atoms=[464], num_bonds=[7518], num_residues=[464]),
#  PackedProtein(batch_size=1, num_atoms=[331], num_bonds=[5805], num_residues=[331]),
#  PackedProtein(batch_size=1, num_atoms=[552], num_bonds=[8694], num_residues=[552]),
#  PackedProtein(batch_size=1, num_atoms=[987], num_bonds=[19005], num_residues=[987]),
#  PackedProtein(batch_size=1, num_atoms=[215], num_bonds=[3518], num_residues=[215]),
#  PackedProtein(batch_size=1, num_atoms=[391], num_bonds=[6806], num_residues=[391]),
#  PackedProtein(batch_size=1, num_atoms=[415], num_bonds=[6661], num_residues=[415]),
#  PackedProtein(batch_size=5, num_atoms=[1022, 1022, 1022, 1022, 40], num_bonds=[16592, 16611, 15667, 17355, 454], num_residues=[1022, 1022, 1022, 1022, 40]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 82], num_bonds=[12180, 592], num_residues=[1022, 82]),
#  PackedProtein(batch_size=1, num_atoms=[326], num_bonds=[5834], num_residues=[326]),
#  PackedProtein(batch_size=1, num_atoms=[292], num_bonds=[5562], num_residues=[292]),
#  PackedProtein(batch_size=1, num_atoms=[737], num_bonds=[13651], num_residues=[737]),
#  PackedProtein(batch_size=1, num_atoms=[393], num_bonds=[6880], num_residues=[393]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 102], num_bonds=[20777, 1446], num_residues=[1022, 102]),
#  PackedProtein(batch_size=1, num_atoms=[954], num_bonds=[11860], num_residues=[954]),
#  PackedProtein(batch_size=1, num_atoms=[706], num_bonds=[12588], num_residues=[706]),
#  PackedProtein(batch_size=1, num_atoms=[509], num_bonds=[8889], num_residues=[509]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 378], num_bonds=[21165, 6291], num_residues=[1022, 378]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 30], num_bonds=[15660, 290], num_residues=[1022, 30]),
#  PackedProtein(batch_size=1, num_atoms=[592], num_bonds=[10314], num_residues=[592]),
#  PackedProtein(batch_size=1, num_atoms=[676], num_bonds=[12577], num_residues=[676]),
#  PackedProtein(batch_size=1, num_atoms=[659], num_bonds=[12491], num_residues=[659]),
#  PackedProtein(batch_size=1, num_atoms=[890], num_bonds=[15585], num_residues=[890]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 16], num_bonds=[13401, 138], num_residues=[1022, 16]),
#  PackedProtein(batch_size=1, num_atoms=[620], num_bonds=[11930], num_residues=[620]),
#  PackedProtein(batch_size=1, num_atoms=[820], num_bonds=[15086], num_residues=[820]),
#  PackedProtein(batch_size=1, num_atoms=[999], num_bonds=[16532], num_residues=[999]),
#  PackedProtein(batch_size=1, num_atoms=[559], num_bonds=[8750], num_residues=[559]),
#  PackedProtein(batch_size=1, num_atoms=[545], num_bonds=[8492], num_residues=[545]),
#  PackedProtein(batch_size=1, num_atoms=[524], num_bonds=[8170], num_residues=[524]),
#  PackedProtein(batch_size=1, num_atoms=[491], num_bonds=[7644], num_residues=[491]),
#  PackedProtein(batch_size=1, num_atoms=[762], num_bonds=[13492], num_residues=[762]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 332], num_bonds=[13922, 5076], num_residues=[1022, 332]),
#  PackedProtein(batch_size=1, num_atoms=[666], num_bonds=[10331], num_residues=[666]),
#  PackedProtein(batch_size=1, num_atoms=[558], num_bonds=[9694], num_residues=[558]),
#  PackedProtein(batch_size=1, num_atoms=[499], num_bonds=[8964], num_residues=[499]),
#  PackedProtein(batch_size=1, num_atoms=[763], num_bonds=[10044], num_residues=[763]),
#  PackedProtein(batch_size=1, num_atoms=[451], num_bonds=[8854], num_residues=[451]),
#  PackedProtein(batch_size=1, num_atoms=[671], num_bonds=[12735], num_residues=[671]),
#  PackedProtein(batch_size=1, num_atoms=[370], num_bonds=[6325], num_residues=[370]),
#  PackedProtein(batch_size=1, num_atoms=[716], num_bonds=[12650], num_residues=[716]),
#  PackedProtein(batch_size=1, num_atoms=[1009], num_bonds=[15967], num_residues=[1009]),
#  PackedProtein(batch_size=1, num_atoms=[651], num_bonds=[10054], num_residues=[651]),
#  PackedProtein(batch_size=1, num_atoms=[307], num_bonds=[3819], num_residues=[307]),
#  PackedProtein(batch_size=1, num_atoms=[436], num_bonds=[7367], num_residues=[436]),
#  PackedProtein(batch_size=1, num_atoms=[912], num_bonds=[14686], num_residues=[912]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 286], num_bonds=[20644, 2019], num_residues=[1022, 286]),
#  PackedProtein(batch_size=1, num_atoms=[735], num_bonds=[13346], num_residues=[735]),
#  PackedProtein(batch_size=1, num_atoms=[364], num_bonds=[6704], num_residues=[364]),
#  PackedProtein(batch_size=1, num_atoms=[839], num_bonds=[15104], num_residues=[839]),
#  PackedProtein(batch_size=1, num_atoms=[942], num_bonds=[14856], num_residues=[942]),
#  PackedProtein(batch_size=1, num_atoms=[984], num_bonds=[15296], num_residues=[984]),
#  PackedProtein(batch_size=1, num_atoms=[360], num_bonds=[6672], num_residues=[360]),
#  PackedProtein(batch_size=1, num_atoms=[473], num_bonds=[7051], num_residues=[473]),
#  PackedProtein(batch_size=1, num_atoms=[847], num_bonds=[11050], num_residues=[847]),
#  PackedProtein(batch_size=1, num_atoms=[822], num_bonds=[14832], num_residues=[822]),
#  PackedProtein(batch_size=1, num_atoms=[382], num_bonds=[6487], num_residues=[382]),
#  PackedProtein(batch_size=3, num_atoms=[1022, 1022, 483], num_bonds=[16697, 20175, 9679], num_residues=[1022, 1022, 483]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 710], num_bonds=[14102, 12627], num_residues=[1022, 710]),
#  PackedProtein(batch_size=1, num_atoms=[788], num_bonds=[10982], num_residues=[788]),
#  PackedProtein(batch_size=1, num_atoms=[1001], num_bonds=[14108], num_residues=[1001]),
#  PackedProtein(batch_size=1, num_atoms=[326], num_bonds=[5684], num_residues=[326]),
#  PackedProtein(batch_size=1, num_atoms=[385], num_bonds=[6369], num_residues=[385]),
#  PackedProtein(batch_size=1, num_atoms=[473], num_bonds=[7902], num_residues=[473]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 310], num_bonds=[11522, 6394], num_residues=[1022, 310]),
#  PackedProtein(batch_size=1, num_atoms=[616], num_bonds=[9457], num_residues=[616]),
#  PackedProtein(batch_size=1, num_atoms=[778], num_bonds=[11101], num_residues=[778]),
#  PackedProtein(batch_size=1, num_atoms=[344], num_bonds=[5873], num_residues=[344]),
#  PackedProtein(batch_size=1, num_atoms=[322], num_bonds=[5793], num_residues=[322]),
#  PackedProtein(batch_size=1, num_atoms=[752], num_bonds=[10697], num_residues=[752]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[6201], num_residues=[358]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 301], num_bonds=[11745, 4883], num_residues=[1022, 301]),
#  PackedProtein(batch_size=1, num_atoms=[588], num_bonds=[8282], num_residues=[588]),
#  PackedProtein(batch_size=1, num_atoms=[655], num_bonds=[10090], num_residues=[655]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 352], num_bonds=[16651, 4391], num_residues=[1022, 352]),
#  PackedProtein(batch_size=1, num_atoms=[465], num_bonds=[7283], num_residues=[465]),
#  PackedProtein(batch_size=1, num_atoms=[502], num_bonds=[7687], num_residues=[502]),
#  PackedProtein(batch_size=1, num_atoms=[367], num_bonds=[6029], num_residues=[367]),
#  PackedProtein(batch_size=1, num_atoms=[878], num_bonds=[14382], num_residues=[878]),
#  PackedProtein(batch_size=1, num_atoms=[926], num_bonds=[10790], num_residues=[926]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 213], num_bonds=[12248, 2409], num_residues=[1022, 213]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 176], num_bonds=[12112, 1246], num_residues=[1022, 176]),
#  PackedProtein(batch_size=1, num_atoms=[488], num_bonds=[8758], num_residues=[488]),
#  PackedProtein(batch_size=1, num_atoms=[646], num_bonds=[10960], num_residues=[646]),
#  PackedProtein(batch_size=1, num_atoms=[481], num_bonds=[7736], num_residues=[481]),
#  PackedProtein(batch_size=1, num_atoms=[465], num_bonds=[7174], num_residues=[465]),
#  PackedProtein(batch_size=1, num_atoms=[367], num_bonds=[6821], num_residues=[367]),
#  PackedProtein(batch_size=1, num_atoms=[313], num_bonds=[5352], num_residues=[313]),
#  PackedProtein(batch_size=1, num_atoms=[422], num_bonds=[6734], num_residues=[422]),
#  PackedProtein(batch_size=1, num_atoms=[520], num_bonds=[8398], num_residues=[520]),
#  PackedProtein(batch_size=1, num_atoms=[460], num_bonds=[8082], num_residues=[460]),
#  PackedProtein(batch_size=1, num_atoms=[800], num_bonds=[11655], num_residues=[800]),
#  PackedProtein(batch_size=1, num_atoms=[311], num_bonds=[5731], num_residues=[311]),
#  PackedProtein(batch_size=1, num_atoms=[416], num_bonds=[7026], num_residues=[416]),
#  PackedProtein(batch_size=1, num_atoms=[527], num_bonds=[8311], num_residues=[527]),
#  PackedProtein(batch_size=1, num_atoms=[816], num_bonds=[12161], num_residues=[816]),
#  PackedProtein(batch_size=1, num_atoms=[482], num_bonds=[7788], num_residues=[482]),
#  PackedProtein(batch_size=1, num_atoms=[414], num_bonds=[6518], num_residues=[414]),
#  PackedProtein(batch_size=1, num_atoms=[489], num_bonds=[7300], num_residues=[489]),
#  PackedProtein(batch_size=1, num_atoms=[569], num_bonds=[7616], num_residues=[569]),
#  PackedProtein(batch_size=1, num_atoms=[729], num_bonds=[12771], num_residues=[729]),
#  PackedProtein(batch_size=2, num_atoms=[1022, 598], num_bonds=[20544, 8605], num_residues=[1022, 598]),
#  PackedProtein(batch_size=1, num_atoms=[478], num_bonds=[8866], num_residues=[478]),
#  PackedProtein(batch_size=1, num_atoms=[479], num_bonds=[8772], num_residues=[479]),
#  PackedProtein(batch_size=1, num_atoms=[629], num_bonds=[8804], num_residues=[629]),
#  PackedProtein(batch_size=1, num_atoms=[270], num_bonds=[3519], num_residues=[270]),
#  PackedProtein(batch_size=1, num_atoms=[846], num_bonds=[15166], num_residues=[846]),
#  PackedProtein(batch_size=1, num_atoms=[447], num_bonds=[6904], num_residues=[447])]

# %%
sequence_model = models.ESM(path="../../../result/model_pth/ESM/", model="ESM-2_650M")

# %%
def esmProcess(esmModel, curProtein, pklName):
    """
    curProtein: list of packedProtein 
    pklName: the pkl name to store the protein
    """
    output = esmModel(curProtein, curProtein.residue_feature)
    curProtein.residue_feature = output['residue_feature']
    # print(curProtein.residue_feature.shape)
    protein_pkl = '../../../data/dta-datasets/KIBA/esm/gearnetesm_' + pklName + '.pkl'
    with utils.smart_open(protein_pkl, "wb") as fout:
        pickle.dump(curProtein, fout)

# %% [markdown]
# - P53779(index:121)
# - P78527(index:128)
# - Q5S007(index:130)

# %%
transform_list[178]
# Out:
# PackedProtein(batch_size=3, num_atoms=[1022, 1022, 483], num_bonds=[16697, 20175, 9679], num_residues=[1022, 1022, 483])

# %%
indexes = range(178, 179)  # len(transform_list)
indexes = tqdm(indexes, "ESM Computing ......")
for index in indexes:
    curProtein = transform_list[index]
    if curProtein.batch_size == 1:
        esmProcess(sequence_model, curProtein, str(index))
    else:
        for i in range(curProtein.batch_size):
            protein = data.Protein.pack([curProtein[i]])
            esmProcess(sequence_model, protein, str(index) + '_' + str(i))
# Out:
# ESM Computing ......: 100%|██████████| 1/1 [00:19<00:00, 19.05s/it]

# %% [markdown]
# Read all pkl and aggreate into the new list

# %%
import pickle
from tqdm import tqdm
from torchdrug import utils, transforms, data, layers

# %%
protein_pkl = '../../../data/dta-datasets/KIBA/pdb_Protein.pkl'
with utils.smart_open(protein_pkl, "rb") as fin:
    protein_list = pickle.load(fin)

# %%
protein_list
# Out:
# [Protein(num_atom=3454, num_bond=7092, num_residue=431),
#  Protein(num_atom=4481, num_bond=9122, num_residue=574),
#  Protein(num_atom=8396, num_bond=17184, num_residue=1044),
#  Protein(num_atom=5776, num_bond=11822, num_residue=725),
#  Protein(num_atom=7660, num_bond=15664, num_residue=970),
#  Protein(num_atom=3829, num_bond=7834, num_residue=476),
#  Protein(num_atom=6066, num_bond=12346, num_residue=756),
#  Protein(num_atom=3228, num_bond=6604, num_residue=403),
#  Protein(num_atom=5783, num_bond=11792, num_residue=740),
#  Protein(num_atom=5932, num_bond=12108, num_residue=745),
#  Protein(num_atom=2964, num_bond=6066, num_residue=365),
#  Protein(num_atom=4453, num_bond=9134, num_residue=556),
#  Protein(num_atom=3702, num_bond=7522, num_residue=454),
#  Protein(num_atom=2136, num_bond=4386, num_residue=272),
#  Protein(num_atom=4620, num_bond=9458, num_residue=588),
#  Protein(num_atom=5222, num_bond=10662, num_residue=661),
#  Protein(num_atom=9192, num_bond=18812, num_residue=1132),
#  Protein(num_atom=11278, num_bond=22884, num_residue=1388),
#  Protein(num_atom=6324, num_bond=12920, num_residue=802),
#  Protein(num_atom=6033, num_bond=12336, num_residue=772),
#  Protein(num_atom=7050, num_bond=14426, num_residue=890),
#  Protein(num_atom=9996, num_bond=20386, num_residue=1239),
#  Protein(num_atom=4506, num_bond=9230, num_residue=591),
#  Protein(num_atom=4282, num_bond=8734, num_residue=543),
#  Protein(num_atom=8643, num_bond=17678, num_residue=1130),
#  Protein(num_atom=9392, num_bond=19228, num_residue=1210),
#  Protein(num_atom=5130, num_bond=10500, num_residue=648),
#  Protein(num_atom=9661, num_bond=19856, num_residue=1255),
#  Protein(num_atom=6155, num_bond=12626, num_residue=796),
#  Protein(num_atom=5522, num_bond=11362, num_residue=697),
#  Protein(num_atom=5401, num_bond=11074, num_residue=671),
#  Protein(num_atom=10981, num_bond=22534, num_residue=1382),
#  Protein(num_atom=4088, num_bond=8388, num_residue=509),
#  Protein(num_atom=4279, num_bond=8762, num_residue=537),
#  Protein(num_atom=2405, num_bond=4920, num_residue=297),
#  Protein(num_atom=6581, num_bond=13430, num_residue=822),
#  Protein(num_atom=7607, num_bond=15616, num_residue=972),
#  Protein(num_atom=4280, num_bond=8772, num_residue=543),
#  Protein(num_atom=4124, num_bond=8440, num_residue=512),
#  Protein(num_atom=8740, num_bond=17924, num_residue=1114),
#  Protein(num_atom=10860, num_bond=22258, num_residue=1367),
#  Protein(num_atom=10929, num_bond=22394, num_residue=1390),
#  Protein(num_atom=4188, num_bond=8580, num_residue=526),
#  Protein(num_atom=18612, num_bond=38200, num_residue=2347),
#  Protein(num_atom=8716, num_bond=17840, num_residue=1106),
#  Protein(num_atom=4186, num_bond=8582, num_residue=529),
#  Protein(num_atom=7725, num_bond=15830, num_residue=976),
#  Protein(num_atom=2519, num_bond=5170, num_residue=313),
#  Protein(num_atom=6446, num_bond=13208, num_residue=822),
#  Protein(num_atom=2376, num_bond=4874, num_residue=303),
#  Protein(num_atom=4214, num_bond=8632, num_residue=536),
#  Protein(num_atom=5936, num_bond=12138, num_residue=766),
#  Protein(num_atom=3269, num_bond=6696, num_residue=406),
#  Protein(num_atom=8623, num_bond=17616, num_residue=1089),
#  Protein(num_atom=6637, num_bond=13490, num_residue=822),
#  Protein(num_atom=5393, num_bond=11060, num_residue=672),
#  Protein(num_atom=2872, num_bond=5890, num_residue=351),
#  Protein(num_atom=10584, num_bond=21626, num_residue=1338),
#  Protein(num_atom=2911, num_bond=5970, num_residue=350),
#  Protein(num_atom=6456, num_bond=13222, num_residue=821),
#  Protein(num_atom=6193, num_bond=12704, num_residue=802),
#  Protein(num_atom=6163, num_bond=12616, num_residue=806),
#  Protein(num_atom=2858, num_bond=5860, num_residue=351),
#  Protein(num_atom=2874, num_bond=5892, num_residue=351),
#  Protein(num_atom=4158, num_bond=8514, num_residue=525),
#  Protein(num_atom=9355, num_bond=19118, num_residue=1154),
#  Protein(num_atom=5466, num_bond=11190, num_residue=683),
#  Protein(num_atom=2398, num_bond=4920, num_residue=298),
#  Protein(num_atom=3036, num_bond=6210, num_residue=379),
#  Protein(num_atom=5927, num_bond=12066, num_residue=753),
#  Protein(num_atom=2915, num_bond=5970, num_residue=360),
#  Protein(num_atom=7603, num_bond=15590, num_residue=976),
#  Protein(num_atom=8232, num_bond=16830, num_residue=1055),
#  Protein(num_atom=6440, num_bond=13224, num_residue=864),
#  Protein(num_atom=9409, num_bond=19324, num_residue=1187),
#  Protein(num_atom=5027, num_bond=10272, num_residue=646),
#  Protein(num_atom=6913, num_bond=14202, num_residue=894),
#  Protein(num_atom=3919, num_bond=8024, num_residue=480),
#  Protein(num_atom=3925, num_bond=8038, num_residue=481),
#  Protein(num_atom=4763, num_bond=9730, num_residue=590),
#  Protein(num_atom=10740, num_bond=22000, num_residue=1363),
#  Protein(num_atom=10643, num_bond=21752, num_residue=1356),
#  Protein(num_atom=3121, num_bond=6372, num_residue=400),
#  Protein(num_atom=7935, num_bond=16276, num_residue=993),
#  Protein(num_atom=3564, num_bond=7288, num_residue=450),
#  Protein(num_atom=3717, num_bond=7600, num_residue=467),
#  Protein(num_atom=4791, num_bond=9810, num_residue=596),
#  Protein(num_atom=8722, num_bond=17846, num_residue=1068),
#  Protein(num_atom=8633, num_bond=17652, num_residue=1070),
#  Protein(num_atom=20287, num_bond=41398, num_residue=2549),
#  Protein(num_atom=3973, num_bond=8136, num_residue=507),
#  Protein(num_atom=9023, num_bond=18462, num_residue=1182),
#  Protein(num_atom=4110, num_bond=8424, num_residue=505),
#  Protein(num_atom=4905, num_bond=10058, num_residue=619),
#  Protein(num_atom=5075, num_bond=10384, num_residue=635),
#  Protein(num_atom=3385, num_bond=6914, num_residue=427),
#  Protein(num_atom=3376, num_bond=6894, num_residue=424),
#  Protein(num_atom=2738, num_bond=5594, num_residue=337),
#  Protein(num_atom=3328, num_bond=6796, num_residue=415),
#  Protein(num_atom=8906, num_bond=18228, num_residue=1102),
#  Protein(num_atom=3202, num_bond=6574, num_residue=400),
#  Protein(num_atom=3755, num_bond=7716, num_residue=464),
#  Protein(num_atom=3330, num_bond=6794, num_residue=416),
#  Protein(num_atom=4035, num_bond=8272, num_residue=484),
#  Protein(num_atom=4241, num_bond=8690, num_residue=499),
#  Protein(num_atom=3591, num_bond=7352, num_residue=483),
#  Protein(num_atom=3292, num_bond=6738, num_residue=420),
#  Protein(num_atom=2751, num_bond=5630, num_residue=346),
#  Protein(num_atom=3007, num_bond=6140, num_residue=372),
#  Protein(num_atom=4062, num_bond=8326, num_residue=505),
#  Protein(num_atom=5389, num_bond=11080, num_residue=712),
#  Protein(num_atom=5899, num_bond=12070, num_residue=740),
#  Protein(num_atom=5493, num_bond=11258, num_residue=675),
#  Protein(num_atom=2895, num_bond=5962, num_residue=358),
#  Protein(num_atom=3631, num_bond=7368, num_residue=445),
#  Protein(num_atom=6636, num_bond=13502, num_residue=841),
#  Protein(num_atom=8801, num_bond=18040, num_residue=1124),
#  Protein(num_atom=2630, num_bond=5370, num_residue=334),
#  Protein(num_atom=4804, num_bond=9822, num_residue=603),
#  Protein(num_atom=5087, num_bond=10428, num_residue=647),
#  Protein(num_atom=2951, num_bond=6032, num_residue=367),
#  Protein(num_atom=3688, num_bond=7532, num_residue=464),
#  Protein(num_atom=2651, num_bond=5414, num_residue=331),
#  Protein(num_atom=4376, num_bond=8948, num_residue=552),
#  Protein(num_atom=7611, num_bond=15600, num_residue=987),
#  Protein(num_atom=1752, num_bond=3606, num_residue=215),
#  Protein(num_atom=3182, num_bond=6534, num_residue=391),
#  Protein(num_atom=3342, num_bond=6842, num_residue=415),
#  Protein(num_atom=32960, num_bond=67292, num_residue=4128),
#  Protein(num_atom=8574, num_bond=17570, num_residue=1104),
#  Protein(num_atom=2600, num_bond=5310, num_residue=326),
#  Protein(num_atom=2346, num_bond=4804, num_residue=292),
#  Protein(num_atom=5876, num_bond=12000, num_residue=737),
#  Protein(num_atom=3048, num_bond=6224, num_residue=393),
#  Protein(num_atom=8835, num_bond=18102, num_residue=1124),
#  Protein(num_atom=7307, num_bond=15016, num_residue=954),
#  Protein(num_atom=5739, num_bond=11762, num_residue=706),
#  Protein(num_atom=4001, num_bond=8178, num_residue=509),
#  Protein(num_atom=10709, num_bond=22030, num_residue=1400),
#  Protein(num_atom=8378, num_bond=17132, num_residue=1052),
#  Protein(num_atom=4754, num_bond=9726, num_residue=592),
#  Protein(num_atom=5449, num_bond=11150, num_residue=676),
#  Protein(num_atom=5368, num_bond=11004, num_residue=659),
#  Protein(num_atom=6809, num_bond=13954, num_residue=890),
#  Protein(num_atom=8067, num_bond=16628, num_residue=1038),
#  Protein(num_atom=5061, num_bond=10380, num_residue=620),
#  Protein(num_atom=6446, num_bond=13224, num_residue=820),
#  Protein(num_atom=7754, num_bond=15892, num_residue=999),
#  Protein(num_atom=4499, num_bond=9200, num_residue=559),
#  Protein(num_atom=4254, num_bond=8672, num_residue=545),
#  Protein(num_atom=4074, num_bond=8316, num_residue=524),
#  Protein(num_atom=3943, num_bond=8040, num_residue=491),
#  Protein(num_atom=6155, num_bond=12552, num_residue=762),
#  Protein(num_atom=11093, num_bond=22508, num_residue=1354),
#  Protein(num_atom=5111, num_bond=10470, num_residue=666),
#  Protein(num_atom=4402, num_bond=8994, num_residue=558),
#  Protein(num_atom=3966, num_bond=8118, num_residue=499),
#  Protein(num_atom=6017, num_bond=12332, num_residue=763),
#  Protein(num_atom=3656, num_bond=7512, num_residue=451),
#  Protein(num_atom=5373, num_bond=10968, num_residue=671),
#  Protein(num_atom=2906, num_bond=5942, num_residue=370),
#  Protein(num_atom=5660, num_bond=11540, num_residue=716),
#  Protein(num_atom=8131, num_bond=16606, num_residue=1009),
#  Protein(num_atom=5242, num_bond=10708, num_residue=651),
#  Protein(num_atom=2393, num_bond=4890, num_residue=307),
#  Protein(num_atom=3470, num_bond=7110, num_residue=436),
#  Protein(num_atom=7137, num_bond=14594, num_residue=912),
#  Protein(num_atom=10291, num_bond=21140, num_residue=1308),
#  Protein(num_atom=5830, num_bond=11934, num_residue=735),
#  Protein(num_atom=2913, num_bond=5962, num_residue=364),
#  Protein(num_atom=6640, num_bond=13610, num_residue=839),
#  Protein(num_atom=7312, num_bond=14914, num_residue=942),
#  Protein(num_atom=7874, num_bond=16050, num_residue=984),
#  Protein(num_atom=2907, num_bond=5946, num_residue=360),
#  Protein(num_atom=3651, num_bond=7442, num_residue=473),
#  Protein(num_atom=6534, num_bond=13446, num_residue=847),
#  Protein(num_atom=6467, num_bond=13272, num_residue=822),
#  Protein(num_atom=3016, num_bond=6168, num_residue=382),
#  Protein(num_atom=20070, num_bond=40872, num_residue=2527),
#  Protein(num_atom=13836, num_bond=28154, num_residue=1732),
#  Protein(num_atom=6174, num_bond=12596, num_residue=788),
#  Protein(num_atom=8140, num_bond=16572, num_residue=1001),
#  Protein(num_atom=2529, num_bond=5174, num_residue=326),
#  Protein(num_atom=3017, num_bond=6156, num_residue=385),
#  Protein(num_atom=3805, num_bond=7764, num_residue=473),
#  Protein(num_atom=10543, num_bond=21568, num_residue=1332),
#  Protein(num_atom=4886, num_bond=10020, num_residue=616),
#  Protein(num_atom=5988, num_bond=12278, num_residue=778),
#  Protein(num_atom=2768, num_bond=5672, num_residue=344),
#  Protein(num_atom=2532, num_bond=5172, num_residue=322),
#  Protein(num_atom=5799, num_bond=11854, num_residue=752),
#  Protein(num_atom=2873, num_bond=5854, num_residue=358),
#  Protein(num_atom=10027, num_bond=20484, num_residue=1323),
#  Protein(num_atom=4537, num_bond=9268, num_residue=588),
#  Protein(num_atom=5221, num_bond=10646, num_residue=655),
#  Protein(num_atom=10876, num_bond=22196, num_residue=1374),
#  Protein(num_atom=3601, num_bond=7344, num_residue=465),
#  Protein(num_atom=4006, num_bond=8224, num_residue=502),
#  Protein(num_atom=2919, num_bond=5964, num_residue=367),
#  Protein(num_atom=6795, num_bond=13908, num_residue=878),
#  Protein(num_atom=7301, num_bond=14950, num_residue=926),
#  Protein(num_atom=10004, num_bond=20242, num_residue=1235),
#  Protein(num_atom=9202, num_bond=18864, num_residue=1198),
#  Protein(num_atom=3842, num_bond=7900, num_residue=488),
#  Protein(num_atom=5050, num_bond=10360, num_residue=646),
#  Protein(num_atom=4045, num_bond=8296, num_residue=481),
#  Protein(num_atom=3641, num_bond=7438, num_residue=465),
#  Protein(num_atom=2908, num_bond=5974, num_residue=367),
#  Protein(num_atom=2504, num_bond=5136, num_residue=313),
#  Protein(num_atom=3415, num_bond=6992, num_residue=422),
#  Protein(num_atom=4199, num_bond=8596, num_residue=520),
#  Protein(num_atom=3615, num_bond=7368, num_residue=460),
#  Protein(num_atom=6416, num_bond=13142, num_residue=800),
#  Protein(num_atom=2412, num_bond=4976, num_residue=311),
#  Protein(num_atom=3271, num_bond=6666, num_residue=416),
#  Protein(num_atom=4103, num_bond=8446, num_residue=527),
#  Protein(num_atom=6419, num_bond=13090, num_residue=816),
#  Protein(num_atom=3769, num_bond=7736, num_residue=482),
#  Protein(num_atom=3266, num_bond=6648, num_residue=414),
#  Protein(num_atom=3820, num_bond=7818, num_residue=489),
#  Protein(num_atom=4444, num_bond=9100, num_residue=569),
#  Protein(num_atom=5880, num_bond=11998, num_residue=729),
#  Protein(num_atom=12397, num_bond=25454, num_residue=1620),
#  Protein(num_atom=3810, num_bond=7798, num_residue=478),
#  Protein(num_atom=3923, num_bond=8030, num_residue=479),
#  Protein(num_atom=4873, num_bond=10014, num_residue=629),
#  Protein(num_atom=2143, num_bond=4406, num_residue=270),
#  Protein(num_atom=6684, num_bond=13694, num_residue=846),
#  Protein(num_atom=3614, num_bond=7392, num_residue=447)]

# %%
graph_construction_model = layers.GraphConstruction(node_layers=[layers.geometry.AlphaCarbonNode()], 
                                                    edge_layers=[layers.geometry.SpatialEdge(radius=10.0, min_distance=5),
                                                                 layers.geometry.KNNEdge(k=10, min_distance=5),
                                                                 layers.geometry.SequentialEdge(max_distance=2)],
                                                    edge_feature="gearnet")

# %%
output_list = []
for protein in protein_list:
    graph = data.Protein.pack([protein])
    transGraph = graph_construction_model(graph)
    output_list.append(transGraph)

# %%
len(output_list)
# Out:
# 229

# %%
output_list
# Out:
# [PackedProtein(batch_size=1, num_atoms=[431], num_bonds=[7507], num_residues=[431]),
#  PackedProtein(batch_size=1, num_atoms=[574], num_bonds=[8301], num_residues=[574]),
#  PackedProtein(batch_size=1, num_atoms=[1044], num_bonds=[19549], num_residues=[1044]),
#  PackedProtein(batch_size=1, num_atoms=[725], num_bonds=[11806], num_residues=[725]),
#  PackedProtein(batch_size=1, num_atoms=[970], num_bonds=[13888], num_residues=[970]),
#  PackedProtein(batch_size=1, num_atoms=[476], num_bonds=[8081], num_residues=[476]),
#  PackedProtein(batch_size=1, num_atoms=[756], num_bonds=[12719], num_residues=[756]),
#  PackedProtein(batch_size=1, num_atoms=[403], num_bonds=[6331], num_residues=[403]),
#  PackedProtein(batch_size=1, num_atoms=[740], num_bonds=[11870], num_residues=[740]),
#  PackedProtein(batch_size=1, num_atoms=[745], num_bonds=[12311], num_residues=[745]),
#  PackedProtein(batch_size=1, num_atoms=[365], num_bonds=[6814], num_residues=[365]),
#  PackedProtein(batch_size=1, num_atoms=[556], num_bonds=[9386], num_residues=[556]),
#  PackedProtein(batch_size=1, num_atoms=[454], num_bonds=[7409], num_residues=[454]),
#  PackedProtein(batch_size=1, num_atoms=[272], num_bonds=[3534], num_residues=[272]),
#  PackedProtein(batch_size=1, num_atoms=[588], num_bonds=[8956], num_residues=[588]),
#  PackedProtein(batch_size=1, num_atoms=[661], num_bonds=[8488], num_residues=[661]),
#  PackedProtein(batch_size=1, num_atoms=[1132], num_bonds=[21304], num_residues=[1132]),
#  PackedProtein(batch_size=1, num_atoms=[1388], num_bonds=[19926], num_residues=[1388]),
#  PackedProtein(batch_size=1, num_atoms=[802], num_bonds=[13976], num_residues=[802]),
#  PackedProtein(batch_size=1, num_atoms=[772], num_bonds=[14059], num_residues=[772]),
#  PackedProtein(batch_size=1, num_atoms=[890], num_bonds=[14404], num_residues=[890]),
#  PackedProtein(batch_size=1, num_atoms=[1239], num_bonds=[17985], num_residues=[1239]),
#  PackedProtein(batch_size=1, num_atoms=[591], num_bonds=[8296], num_residues=[591]),
#  PackedProtein(batch_size=1, num_atoms=[543], num_bonds=[8702], num_residues=[543]),
#  PackedProtein(batch_size=1, num_atoms=[1130], num_bonds=[14517], num_residues=[1130]),
#  PackedProtein(batch_size=1, num_atoms=[1210], num_bonds=[21882], num_residues=[1210]),
#  PackedProtein(batch_size=1, num_atoms=[648], num_bonds=[9628], num_residues=[648]),
#  PackedProtein(batch_size=1, num_atoms=[1255], num_bonds=[22209], num_residues=[1255]),
#  PackedProtein(batch_size=1, num_atoms=[796], num_bonds=[14606], num_residues=[796]),
#  PackedProtein(batch_size=1, num_atoms=[697], num_bonds=[13228], num_residues=[697]),
#  PackedProtein(batch_size=1, num_atoms=[671], num_bonds=[12841], num_residues=[671]),
#  PackedProtein(batch_size=1, num_atoms=[1382], num_bonds=[25486], num_residues=[1382]),
#  PackedProtein(batch_size=1, num_atoms=[509], num_bonds=[9040], num_residues=[509]),
#  PackedProtein(batch_size=1, num_atoms=[537], num_bonds=[9484], num_residues=[537]),
#  PackedProtein(batch_size=1, num_atoms=[297], num_bonds=[5545], num_residues=[297]),
#  PackedProtein(batch_size=1, num_atoms=[822], num_bonds=[13442], num_residues=[822]),
#  PackedProtein(batch_size=1, num_atoms=[972], num_bonds=[18216], num_residues=[972]),
#  PackedProtein(batch_size=1, num_atoms=[543], num_bonds=[9533], num_residues=[543]),
#  PackedProtein(batch_size=1, num_atoms=[512], num_bonds=[9075], num_residues=[512]),
#  PackedProtein(batch_size=1, num_atoms=[1114], num_bonds=[19840], num_residues=[1114]),
#  PackedProtein(batch_size=1, num_atoms=[1367], num_bonds=[25306], num_residues=[1367]),
#  PackedProtein(batch_size=1, num_atoms=[1390], num_bonds=[27647], num_residues=[1390]),
#  PackedProtein(batch_size=1, num_atoms=[526], num_bonds=[9277], num_residues=[526]),
#  PackedProtein(batch_size=1, num_atoms=[2347], num_bonds=[46035], num_residues=[2347]),
#  PackedProtein(batch_size=1, num_atoms=[1106], num_bonds=[18888], num_residues=[1106]),
#  PackedProtein(batch_size=1, num_atoms=[529], num_bonds=[9475], num_residues=[529]),
#  PackedProtein(batch_size=1, num_atoms=[976], num_bonds=[18002], num_residues=[976]),
#  PackedProtein(batch_size=1, num_atoms=[313], num_bonds=[5712], num_residues=[313]),
#  PackedProtein(batch_size=1, num_atoms=[822], num_bonds=[13483], num_residues=[822]),
#  PackedProtein(batch_size=1, num_atoms=[303], num_bonds=[5566], num_residues=[303]),
#  PackedProtein(batch_size=1, num_atoms=[536], num_bonds=[9506], num_residues=[536]),
#  PackedProtein(batch_size=1, num_atoms=[766], num_bonds=[11016], num_residues=[766]),
#  PackedProtein(batch_size=1, num_atoms=[406], num_bonds=[6561], num_residues=[406]),
#  PackedProtein(batch_size=1, num_atoms=[1089], num_bonds=[19104], num_residues=[1089]),
#  PackedProtein(batch_size=1, num_atoms=[822], num_bonds=[13206], num_residues=[822]),
#  PackedProtein(batch_size=1, num_atoms=[672], num_bonds=[12833], num_residues=[672]),
#  PackedProtein(batch_size=1, num_atoms=[351], num_bonds=[6645], num_residues=[351]),
#  PackedProtein(batch_size=1, num_atoms=[1338], num_bonds=[23262], num_residues=[1338]),
#  PackedProtein(batch_size=1, num_atoms=[350], num_bonds=[6507], num_residues=[350]),
#  PackedProtein(batch_size=1, num_atoms=[821], num_bonds=[13519], num_residues=[821]),
#  PackedProtein(batch_size=1, num_atoms=[802], num_bonds=[13379], num_residues=[802]),
#  PackedProtein(batch_size=1, num_atoms=[806], num_bonds=[13515], num_residues=[806]),
#  PackedProtein(batch_size=1, num_atoms=[351], num_bonds=[6624], num_residues=[351]),
#  PackedProtein(batch_size=1, num_atoms=[351], num_bonds=[6629], num_residues=[351]),
#  PackedProtein(batch_size=1, num_atoms=[525], num_bonds=[7991], num_residues=[525]),
#  PackedProtein(batch_size=1, num_atoms=[1154], num_bonds=[21753], num_residues=[1154]),
#  PackedProtein(batch_size=1, num_atoms=[683], num_bonds=[12816], num_residues=[683]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5562], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[379], num_bonds=[6989], num_residues=[379]),
#  PackedProtein(batch_size=1, num_atoms=[753], num_bonds=[10524], num_residues=[753]),
#  PackedProtein(batch_size=1, num_atoms=[360], num_bonds=[6666], num_residues=[360]),
#  PackedProtein(batch_size=1, num_atoms=[976], num_bonds=[18766], num_residues=[976]),
#  PackedProtein(batch_size=1, num_atoms=[1055], num_bonds=[19426], num_residues=[1055]),
#  PackedProtein(batch_size=1, num_atoms=[864], num_bonds=[16788], num_residues=[864]),
#  PackedProtein(batch_size=1, num_atoms=[1187], num_bonds=[22079], num_residues=[1187]),
#  PackedProtein(batch_size=1, num_atoms=[646], num_bonds=[8424], num_residues=[646]),
#  PackedProtein(batch_size=1, num_atoms=[894], num_bonds=[15699], num_residues=[894]),
#  PackedProtein(batch_size=1, num_atoms=[480], num_bonds=[8833], num_residues=[480]),
#  PackedProtein(batch_size=1, num_atoms=[481], num_bonds=[8855], num_residues=[481]),
#  PackedProtein(batch_size=1, num_atoms=[590], num_bonds=[10368], num_residues=[590]),
#  PackedProtein(batch_size=1, num_atoms=[1363], num_bonds=[23651], num_residues=[1363]),
#  PackedProtein(batch_size=1, num_atoms=[1356], num_bonds=[23708], num_residues=[1356]),
#  PackedProtein(batch_size=1, num_atoms=[400], num_bonds=[6787], num_residues=[400]),
#  PackedProtein(batch_size=1, num_atoms=[993], num_bonds=[17735], num_residues=[993]),
#  PackedProtein(batch_size=1, num_atoms=[450], num_bonds=[8976], num_residues=[450]),
#  PackedProtein(batch_size=1, num_atoms=[467], num_bonds=[7722], num_residues=[467]),
#  PackedProtein(batch_size=1, num_atoms=[596], num_bonds=[10318], num_residues=[596]),
#  PackedProtein(batch_size=1, num_atoms=[1068], num_bonds=[20206], num_residues=[1068]),
#  PackedProtein(batch_size=1, num_atoms=[1070], num_bonds=[19959], num_residues=[1070]),
#  PackedProtein(batch_size=1, num_atoms=[2549], num_bonds=[42733], num_residues=[2549]),
#  PackedProtein(batch_size=1, num_atoms=[507], num_bonds=[9353], num_residues=[507]),
#  PackedProtein(batch_size=1, num_atoms=[1182], num_bonds=[15333], num_residues=[1182]),
#  PackedProtein(batch_size=1, num_atoms=[505], num_bonds=[9324], num_residues=[505]),
#  PackedProtein(batch_size=1, num_atoms=[619], num_bonds=[11592], num_residues=[619]),
#  PackedProtein(batch_size=1, num_atoms=[635], num_bonds=[11623], num_residues=[635]),
#  PackedProtein(batch_size=1, num_atoms=[427], num_bonds=[7405], num_residues=[427]),
#  PackedProtein(batch_size=1, num_atoms=[424], num_bonds=[7287], num_residues=[424]),
#  PackedProtein(batch_size=1, num_atoms=[337], num_bonds=[5862], num_residues=[337]),
#  PackedProtein(batch_size=1, num_atoms=[415], num_bonds=[6559], num_residues=[415]),
#  PackedProtein(batch_size=1, num_atoms=[1102], num_bonds=[20779], num_residues=[1102]),
#  PackedProtein(batch_size=1, num_atoms=[400], num_bonds=[6478], num_residues=[400]),
#  PackedProtein(batch_size=1, num_atoms=[464], num_bonds=[7427], num_residues=[464]),
#  PackedProtein(batch_size=1, num_atoms=[416], num_bonds=[6659], num_residues=[416]),
#  PackedProtein(batch_size=1, num_atoms=[484], num_bonds=[7933], num_residues=[484]),
#  PackedProtein(batch_size=1, num_atoms=[499], num_bonds=[7671], num_residues=[499]),
#  PackedProtein(batch_size=1, num_atoms=[483], num_bonds=[7716], num_residues=[483]),
#  PackedProtein(batch_size=1, num_atoms=[420], num_bonds=[7597], num_residues=[420]),
#  PackedProtein(batch_size=1, num_atoms=[346], num_bonds=[6157], num_residues=[346]),
#  PackedProtein(batch_size=1, num_atoms=[372], num_bonds=[6727], num_residues=[372]),
#  PackedProtein(batch_size=1, num_atoms=[505], num_bonds=[8981], num_residues=[505]),
#  PackedProtein(batch_size=1, num_atoms=[712], num_bonds=[10003], num_residues=[712]),
#  PackedProtein(batch_size=1, num_atoms=[740], num_bonds=[13442], num_residues=[740]),
#  PackedProtein(batch_size=1, num_atoms=[675], num_bonds=[11330], num_residues=[675]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[6470], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[445], num_bonds=[6711], num_residues=[445]),
#  PackedProtein(batch_size=1, num_atoms=[841], num_bonds=[9798], num_residues=[841]),
#  PackedProtein(batch_size=1, num_atoms=[1124], num_bonds=[21458], num_residues=[1124]),
#  PackedProtein(batch_size=1, num_atoms=[334], num_bonds=[5968], num_residues=[334]),
#  PackedProtein(batch_size=1, num_atoms=[603], num_bonds=[10867], num_residues=[603]),
#  PackedProtein(batch_size=1, num_atoms=[647], num_bonds=[11064], num_residues=[647]),
#  PackedProtein(batch_size=1, num_atoms=[367], num_bonds=[6712], num_residues=[367]),
#  PackedProtein(batch_size=1, num_atoms=[464], num_bonds=[7518], num_residues=[464]),
#  PackedProtein(batch_size=1, num_atoms=[331], num_bonds=[5805], num_residues=[331]),
#  PackedProtein(batch_size=1, num_atoms=[552], num_bonds=[8694], num_residues=[552]),
#  PackedProtein(batch_size=1, num_atoms=[987], num_bonds=[19005], num_residues=[987]),
#  PackedProtein(batch_size=1, num_atoms=[215], num_bonds=[3518], num_residues=[215]),
#  PackedProtein(batch_size=1, num_atoms=[391], num_bonds=[6806], num_residues=[391]),
#  PackedProtein(batch_size=1, num_atoms=[415], num_bonds=[6661], num_residues=[415]),
#  PackedProtein(batch_size=1, num_atoms=[4128], num_bonds=[118646], num_residues=[4128]),
#  PackedProtein(batch_size=1, num_atoms=[1104], num_bonds=[12775], num_residues=[1104]),
#  PackedProtein(batch_size=1, num_atoms=[326], num_bonds=[5834], num_residues=[326]),
#  PackedProtein(batch_size=1, num_atoms=[292], num_bonds=[5562], num_residues=[292]),
#  PackedProtein(batch_size=1, num_atoms=[737], num_bonds=[13651], num_residues=[737]),
#  PackedProtein(batch_size=1, num_atoms=[393], num_bonds=[6880], num_residues=[393]),
#  PackedProtein(batch_size=1, num_atoms=[1124], num_bonds=[22947], num_residues=[1124]),
#  PackedProtein(batch_size=1, num_atoms=[954], num_bonds=[11860], num_residues=[954]),
#  PackedProtein(batch_size=1, num_atoms=[706], num_bonds=[12588], num_residues=[706]),
#  PackedProtein(batch_size=1, num_atoms=[509], num_bonds=[8889], num_residues=[509]),
#  PackedProtein(batch_size=1, num_atoms=[1400], num_bonds=[27513], num_residues=[1400]),
#  PackedProtein(batch_size=1, num_atoms=[1052], num_bonds=[16311], num_residues=[1052]),
#  PackedProtein(batch_size=1, num_atoms=[592], num_bonds=[10314], num_residues=[592]),
#  PackedProtein(batch_size=1, num_atoms=[676], num_bonds=[12577], num_residues=[676]),
#  PackedProtein(batch_size=1, num_atoms=[659], num_bonds=[12491], num_residues=[659]),
#  PackedProtein(batch_size=1, num_atoms=[890], num_bonds=[15585], num_residues=[890]),
#  PackedProtein(batch_size=1, num_atoms=[1038], num_bonds=[13611], num_residues=[1038]),
#  PackedProtein(batch_size=1, num_atoms=[620], num_bonds=[11930], num_residues=[620]),
#  PackedProtein(batch_size=1, num_atoms=[820], num_bonds=[15086], num_residues=[820]),
#  PackedProtein(batch_size=1, num_atoms=[999], num_bonds=[16532], num_residues=[999]),
#  PackedProtein(batch_size=1, num_atoms=[559], num_bonds=[8750], num_residues=[559]),
#  PackedProtein(batch_size=1, num_atoms=[545], num_bonds=[8492], num_residues=[545]),
#  PackedProtein(batch_size=1, num_atoms=[524], num_bonds=[8170], num_residues=[524]),
#  PackedProtein(batch_size=1, num_atoms=[491], num_bonds=[7644], num_residues=[491]),
#  PackedProtein(batch_size=1, num_atoms=[762], num_bonds=[13492], num_residues=[762]),
#  PackedProtein(batch_size=1, num_atoms=[1354], num_bonds=[18988], num_residues=[1354]),
#  PackedProtein(batch_size=1, num_atoms=[666], num_bonds=[10331], num_residues=[666]),
#  PackedProtein(batch_size=1, num_atoms=[558], num_bonds=[9694], num_residues=[558]),
#  PackedProtein(batch_size=1, num_atoms=[499], num_bonds=[8964], num_residues=[499]),
#  PackedProtein(batch_size=1, num_atoms=[763], num_bonds=[10044], num_residues=[763]),
#  PackedProtein(batch_size=1, num_atoms=[451], num_bonds=[8854], num_residues=[451]),
#  PackedProtein(batch_size=1, num_atoms=[671], num_bonds=[12735], num_residues=[671]),
#  PackedProtein(batch_size=1, num_atoms=[370], num_bonds=[6325], num_residues=[370]),
#  PackedProtein(batch_size=1, num_atoms=[716], num_bonds=[12650], num_residues=[716]),
#  PackedProtein(batch_size=1, num_atoms=[1009], num_bonds=[15967], num_residues=[1009]),
#  PackedProtein(batch_size=1, num_atoms=[651], num_bonds=[10054], num_residues=[651]),
#  PackedProtein(batch_size=1, num_atoms=[307], num_bonds=[3819], num_residues=[307]),
#  PackedProtein(batch_size=1, num_atoms=[436], num_bonds=[7367], num_residues=[436]),
#  PackedProtein(batch_size=1, num_atoms=[912], num_bonds=[14686], num_residues=[912]),
#  PackedProtein(batch_size=1, num_atoms=[1308], num_bonds=[23096], num_residues=[1308]),
#  PackedProtein(batch_size=1, num_atoms=[735], num_bonds=[13346], num_residues=[735]),
#  PackedProtein(batch_size=1, num_atoms=[364], num_bonds=[6704], num_residues=[364]),
#  PackedProtein(batch_size=1, num_atoms=[839], num_bonds=[15104], num_residues=[839]),
#  PackedProtein(batch_size=1, num_atoms=[942], num_bonds=[14856], num_residues=[942]),
#  PackedProtein(batch_size=1, num_atoms=[984], num_bonds=[15296], num_residues=[984]),
#  PackedProtein(batch_size=1, num_atoms=[360], num_bonds=[6672], num_residues=[360]),
#  PackedProtein(batch_size=1, num_atoms=[473], num_bonds=[7051], num_residues=[473]),
#  PackedProtein(batch_size=1, num_atoms=[847], num_bonds=[11050], num_residues=[847]),
#  PackedProtein(batch_size=1, num_atoms=[822], num_bonds=[14832], num_residues=[822]),
#  PackedProtein(batch_size=1, num_atoms=[382], num_bonds=[6487], num_residues=[382]),
#  PackedProtein(batch_size=1, num_atoms=[2527], num_bonds=[47859], num_residues=[2527]),
#  PackedProtein(batch_size=1, num_atoms=[1732], num_bonds=[27604], num_residues=[1732]),
#  PackedProtein(batch_size=1, num_atoms=[788], num_bonds=[10982], num_residues=[788]),
#  PackedProtein(batch_size=1, num_atoms=[1001], num_bonds=[14108], num_residues=[1001]),
#  PackedProtein(batch_size=1, num_atoms=[326], num_bonds=[5684], num_residues=[326]),
#  PackedProtein(batch_size=1, num_atoms=[385], num_bonds=[6369], num_residues=[385]),
#  PackedProtein(batch_size=1, num_atoms=[473], num_bonds=[7902], num_residues=[473]),
#  PackedProtein(batch_size=1, num_atoms=[1332], num_bonds=[18281], num_residues=[1332]),
#  PackedProtein(batch_size=1, num_atoms=[616], num_bonds=[9457], num_residues=[616]),
#  PackedProtein(batch_size=1, num_atoms=[778], num_bonds=[11101], num_residues=[778]),
#  PackedProtein(batch_size=1, num_atoms=[344], num_bonds=[5873], num_residues=[344]),
#  PackedProtein(batch_size=1, num_atoms=[322], num_bonds=[5793], num_residues=[322]),
#  PackedProtein(batch_size=1, num_atoms=[752], num_bonds=[10697], num_residues=[752]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[6201], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[1323], num_bonds=[17321], num_residues=[1323]),
#  PackedProtein(batch_size=1, num_atoms=[588], num_bonds=[8282], num_residues=[588]),
#  PackedProtein(batch_size=1, num_atoms=[655], num_bonds=[10090], num_residues=[655]),
#  PackedProtein(batch_size=1, num_atoms=[1374], num_bonds=[21047], num_residues=[1374]),
#  PackedProtein(batch_size=1, num_atoms=[465], num_bonds=[7283], num_residues=[465]),
#  PackedProtein(batch_size=1, num_atoms=[502], num_bonds=[7687], num_residues=[502]),
#  PackedProtein(batch_size=1, num_atoms=[367], num_bonds=[6029], num_residues=[367]),
#  PackedProtein(batch_size=1, num_atoms=[878], num_bonds=[14382], num_residues=[878]),
#  PackedProtein(batch_size=1, num_atoms=[926], num_bonds=[10790], num_residues=[926]),
#  PackedProtein(batch_size=1, num_atoms=[1235], num_bonds=[14948], num_residues=[1235]),
#  PackedProtein(batch_size=1, num_atoms=[1198], num_bonds=[13544], num_residues=[1198]),
#  PackedProtein(batch_size=1, num_atoms=[488], num_bonds=[8758], num_residues=[488]),
#  PackedProtein(batch_size=1, num_atoms=[646], num_bonds=[10960], num_residues=[646]),
#  PackedProtein(batch_size=1, num_atoms=[481], num_bonds=[7736], num_residues=[481]),
#  PackedProtein(batch_size=1, num_atoms=[465], num_bonds=[7174], num_residues=[465]),
#  PackedProtein(batch_size=1, num_atoms=[367], num_bonds=[6821], num_residues=[367]),
#  PackedProtein(batch_size=1, num_atoms=[313], num_bonds=[5352], num_residues=[313]),
#  PackedProtein(batch_size=1, num_atoms=[422], num_bonds=[6734], num_residues=[422]),
#  PackedProtein(batch_size=1, num_atoms=[520], num_bonds=[8398], num_residues=[520]),
#  PackedProtein(batch_size=1, num_atoms=[460], num_bonds=[8082], num_residues=[460]),
#  PackedProtein(batch_size=1, num_atoms=[800], num_bonds=[11655], num_residues=[800]),
#  PackedProtein(batch_size=1, num_atoms=[311], num_bonds=[5731], num_residues=[311]),
#  PackedProtein(batch_size=1, num_atoms=[416], num_bonds=[7026], num_residues=[416]),
#  PackedProtein(batch_size=1, num_atoms=[527], num_bonds=[8311], num_residues=[527]),
#  PackedProtein(batch_size=1, num_atoms=[816], num_bonds=[12161], num_residues=[816]),
#  PackedProtein(batch_size=1, num_atoms=[482], num_bonds=[7788], num_residues=[482]),
#  PackedProtein(batch_size=1, num_atoms=[414], num_bonds=[6518], num_residues=[414]),
#  PackedProtein(batch_size=1, num_atoms=[489], num_bonds=[7300], num_residues=[489]),
#  PackedProtein(batch_size=1, num_atoms=[569], num_bonds=[7616], num_residues=[569]),
#  PackedProtein(batch_size=1, num_atoms=[729], num_bonds=[12771], num_residues=[729]),
#  PackedProtein(batch_size=1, num_atoms=[1620], num_bonds=[29287], num_residues=[1620]),
#  PackedProtein(batch_size=1, num_atoms=[478], num_bonds=[8866], num_residues=[478]),
#  PackedProtein(batch_size=1, num_atoms=[479], num_bonds=[8772], num_residues=[479]),
#  PackedProtein(batch_size=1, num_atoms=[629], num_bonds=[8804], num_residues=[629]),
#  PackedProtein(batch_size=1, num_atoms=[270], num_bonds=[3519], num_residues=[270]),
#  PackedProtein(batch_size=1, num_atoms=[846], num_bonds=[15166], num_residues=[846]),
#  PackedProtein(batch_size=1, num_atoms=[447], num_bonds=[6904], num_residues=[447])]

# %%
protein_view = transforms.ProteinView(view="residue", keys="graph1")

# %%
transform_list = []
for protein in output_list:
    item = {"graph1": protein}
    transform_list.append(protein_view(item)['graph1'])

# %%
transform_list
# Out:
# [PackedProtein(batch_size=1, num_atoms=[431], num_bonds=[7507], num_residues=[431]),
#  PackedProtein(batch_size=1, num_atoms=[574], num_bonds=[8301], num_residues=[574]),
#  PackedProtein(batch_size=1, num_atoms=[1044], num_bonds=[19549], num_residues=[1044]),
#  PackedProtein(batch_size=1, num_atoms=[725], num_bonds=[11806], num_residues=[725]),
#  PackedProtein(batch_size=1, num_atoms=[970], num_bonds=[13888], num_residues=[970]),
#  PackedProtein(batch_size=1, num_atoms=[476], num_bonds=[8081], num_residues=[476]),
#  PackedProtein(batch_size=1, num_atoms=[756], num_bonds=[12719], num_residues=[756]),
#  PackedProtein(batch_size=1, num_atoms=[403], num_bonds=[6331], num_residues=[403]),
#  PackedProtein(batch_size=1, num_atoms=[740], num_bonds=[11870], num_residues=[740]),
#  PackedProtein(batch_size=1, num_atoms=[745], num_bonds=[12311], num_residues=[745]),
#  PackedProtein(batch_size=1, num_atoms=[365], num_bonds=[6814], num_residues=[365]),
#  PackedProtein(batch_size=1, num_atoms=[556], num_bonds=[9386], num_residues=[556]),
#  PackedProtein(batch_size=1, num_atoms=[454], num_bonds=[7409], num_residues=[454]),
#  PackedProtein(batch_size=1, num_atoms=[272], num_bonds=[3534], num_residues=[272]),
#  PackedProtein(batch_size=1, num_atoms=[588], num_bonds=[8956], num_residues=[588]),
#  PackedProtein(batch_size=1, num_atoms=[661], num_bonds=[8488], num_residues=[661]),
#  PackedProtein(batch_size=1, num_atoms=[1132], num_bonds=[21304], num_residues=[1132]),
#  PackedProtein(batch_size=1, num_atoms=[1388], num_bonds=[19926], num_residues=[1388]),
#  PackedProtein(batch_size=1, num_atoms=[802], num_bonds=[13976], num_residues=[802]),
#  PackedProtein(batch_size=1, num_atoms=[772], num_bonds=[14059], num_residues=[772]),
#  PackedProtein(batch_size=1, num_atoms=[890], num_bonds=[14404], num_residues=[890]),
#  PackedProtein(batch_size=1, num_atoms=[1239], num_bonds=[17985], num_residues=[1239]),
#  PackedProtein(batch_size=1, num_atoms=[591], num_bonds=[8296], num_residues=[591]),
#  PackedProtein(batch_size=1, num_atoms=[543], num_bonds=[8702], num_residues=[543]),
#  PackedProtein(batch_size=1, num_atoms=[1130], num_bonds=[14517], num_residues=[1130]),
#  PackedProtein(batch_size=1, num_atoms=[1210], num_bonds=[21882], num_residues=[1210]),
#  PackedProtein(batch_size=1, num_atoms=[648], num_bonds=[9628], num_residues=[648]),
#  PackedProtein(batch_size=1, num_atoms=[1255], num_bonds=[22209], num_residues=[1255]),
#  PackedProtein(batch_size=1, num_atoms=[796], num_bonds=[14606], num_residues=[796]),
#  PackedProtein(batch_size=1, num_atoms=[697], num_bonds=[13228], num_residues=[697]),
#  PackedProtein(batch_size=1, num_atoms=[671], num_bonds=[12841], num_residues=[671]),
#  PackedProtein(batch_size=1, num_atoms=[1382], num_bonds=[25486], num_residues=[1382]),
#  PackedProtein(batch_size=1, num_atoms=[509], num_bonds=[9040], num_residues=[509]),
#  PackedProtein(batch_size=1, num_atoms=[537], num_bonds=[9484], num_residues=[537]),
#  PackedProtein(batch_size=1, num_atoms=[297], num_bonds=[5545], num_residues=[297]),
#  PackedProtein(batch_size=1, num_atoms=[822], num_bonds=[13442], num_residues=[822]),
#  PackedProtein(batch_size=1, num_atoms=[972], num_bonds=[18216], num_residues=[972]),
#  PackedProtein(batch_size=1, num_atoms=[543], num_bonds=[9533], num_residues=[543]),
#  PackedProtein(batch_size=1, num_atoms=[512], num_bonds=[9075], num_residues=[512]),
#  PackedProtein(batch_size=1, num_atoms=[1114], num_bonds=[19840], num_residues=[1114]),
#  PackedProtein(batch_size=1, num_atoms=[1367], num_bonds=[25306], num_residues=[1367]),
#  PackedProtein(batch_size=1, num_atoms=[1390], num_bonds=[27647], num_residues=[1390]),
#  PackedProtein(batch_size=1, num_atoms=[526], num_bonds=[9277], num_residues=[526]),
#  PackedProtein(batch_size=1, num_atoms=[2347], num_bonds=[46035], num_residues=[2347]),
#  PackedProtein(batch_size=1, num_atoms=[1106], num_bonds=[18888], num_residues=[1106]),
#  PackedProtein(batch_size=1, num_atoms=[529], num_bonds=[9475], num_residues=[529]),
#  PackedProtein(batch_size=1, num_atoms=[976], num_bonds=[18002], num_residues=[976]),
#  PackedProtein(batch_size=1, num_atoms=[313], num_bonds=[5712], num_residues=[313]),
#  PackedProtein(batch_size=1, num_atoms=[822], num_bonds=[13483], num_residues=[822]),
#  PackedProtein(batch_size=1, num_atoms=[303], num_bonds=[5566], num_residues=[303]),
#  PackedProtein(batch_size=1, num_atoms=[536], num_bonds=[9506], num_residues=[536]),
#  PackedProtein(batch_size=1, num_atoms=[766], num_bonds=[11016], num_residues=[766]),
#  PackedProtein(batch_size=1, num_atoms=[406], num_bonds=[6561], num_residues=[406]),
#  PackedProtein(batch_size=1, num_atoms=[1089], num_bonds=[19104], num_residues=[1089]),
#  PackedProtein(batch_size=1, num_atoms=[822], num_bonds=[13206], num_residues=[822]),
#  PackedProtein(batch_size=1, num_atoms=[672], num_bonds=[12833], num_residues=[672]),
#  PackedProtein(batch_size=1, num_atoms=[351], num_bonds=[6645], num_residues=[351]),
#  PackedProtein(batch_size=1, num_atoms=[1338], num_bonds=[23262], num_residues=[1338]),
#  PackedProtein(batch_size=1, num_atoms=[350], num_bonds=[6507], num_residues=[350]),
#  PackedProtein(batch_size=1, num_atoms=[821], num_bonds=[13519], num_residues=[821]),
#  PackedProtein(batch_size=1, num_atoms=[802], num_bonds=[13379], num_residues=[802]),
#  PackedProtein(batch_size=1, num_atoms=[806], num_bonds=[13515], num_residues=[806]),
#  PackedProtein(batch_size=1, num_atoms=[351], num_bonds=[6624], num_residues=[351]),
#  PackedProtein(batch_size=1, num_atoms=[351], num_bonds=[6629], num_residues=[351]),
#  PackedProtein(batch_size=1, num_atoms=[525], num_bonds=[7991], num_residues=[525]),
#  PackedProtein(batch_size=1, num_atoms=[1154], num_bonds=[21753], num_residues=[1154]),
#  PackedProtein(batch_size=1, num_atoms=[683], num_bonds=[12816], num_residues=[683]),
#  PackedProtein(batch_size=1, num_atoms=[298], num_bonds=[5562], num_residues=[298]),
#  PackedProtein(batch_size=1, num_atoms=[379], num_bonds=[6989], num_residues=[379]),
#  PackedProtein(batch_size=1, num_atoms=[753], num_bonds=[10524], num_residues=[753]),
#  PackedProtein(batch_size=1, num_atoms=[360], num_bonds=[6666], num_residues=[360]),
#  PackedProtein(batch_size=1, num_atoms=[976], num_bonds=[18766], num_residues=[976]),
#  PackedProtein(batch_size=1, num_atoms=[1055], num_bonds=[19426], num_residues=[1055]),
#  PackedProtein(batch_size=1, num_atoms=[864], num_bonds=[16788], num_residues=[864]),
#  PackedProtein(batch_size=1, num_atoms=[1187], num_bonds=[22079], num_residues=[1187]),
#  PackedProtein(batch_size=1, num_atoms=[646], num_bonds=[8424], num_residues=[646]),
#  PackedProtein(batch_size=1, num_atoms=[894], num_bonds=[15699], num_residues=[894]),
#  PackedProtein(batch_size=1, num_atoms=[480], num_bonds=[8833], num_residues=[480]),
#  PackedProtein(batch_size=1, num_atoms=[481], num_bonds=[8855], num_residues=[481]),
#  PackedProtein(batch_size=1, num_atoms=[590], num_bonds=[10368], num_residues=[590]),
#  PackedProtein(batch_size=1, num_atoms=[1363], num_bonds=[23651], num_residues=[1363]),
#  PackedProtein(batch_size=1, num_atoms=[1356], num_bonds=[23708], num_residues=[1356]),
#  PackedProtein(batch_size=1, num_atoms=[400], num_bonds=[6787], num_residues=[400]),
#  PackedProtein(batch_size=1, num_atoms=[993], num_bonds=[17735], num_residues=[993]),
#  PackedProtein(batch_size=1, num_atoms=[450], num_bonds=[8976], num_residues=[450]),
#  PackedProtein(batch_size=1, num_atoms=[467], num_bonds=[7722], num_residues=[467]),
#  PackedProtein(batch_size=1, num_atoms=[596], num_bonds=[10318], num_residues=[596]),
#  PackedProtein(batch_size=1, num_atoms=[1068], num_bonds=[20206], num_residues=[1068]),
#  PackedProtein(batch_size=1, num_atoms=[1070], num_bonds=[19959], num_residues=[1070]),
#  PackedProtein(batch_size=1, num_atoms=[2549], num_bonds=[42733], num_residues=[2549]),
#  PackedProtein(batch_size=1, num_atoms=[507], num_bonds=[9353], num_residues=[507]),
#  PackedProtein(batch_size=1, num_atoms=[1182], num_bonds=[15333], num_residues=[1182]),
#  PackedProtein(batch_size=1, num_atoms=[505], num_bonds=[9324], num_residues=[505]),
#  PackedProtein(batch_size=1, num_atoms=[619], num_bonds=[11592], num_residues=[619]),
#  PackedProtein(batch_size=1, num_atoms=[635], num_bonds=[11623], num_residues=[635]),
#  PackedProtein(batch_size=1, num_atoms=[427], num_bonds=[7405], num_residues=[427]),
#  PackedProtein(batch_size=1, num_atoms=[424], num_bonds=[7287], num_residues=[424]),
#  PackedProtein(batch_size=1, num_atoms=[337], num_bonds=[5862], num_residues=[337]),
#  PackedProtein(batch_size=1, num_atoms=[415], num_bonds=[6559], num_residues=[415]),
#  PackedProtein(batch_size=1, num_atoms=[1102], num_bonds=[20779], num_residues=[1102]),
#  PackedProtein(batch_size=1, num_atoms=[400], num_bonds=[6478], num_residues=[400]),
#  PackedProtein(batch_size=1, num_atoms=[464], num_bonds=[7427], num_residues=[464]),
#  PackedProtein(batch_size=1, num_atoms=[416], num_bonds=[6659], num_residues=[416]),
#  PackedProtein(batch_size=1, num_atoms=[484], num_bonds=[7933], num_residues=[484]),
#  PackedProtein(batch_size=1, num_atoms=[499], num_bonds=[7671], num_residues=[499]),
#  PackedProtein(batch_size=1, num_atoms=[483], num_bonds=[7716], num_residues=[483]),
#  PackedProtein(batch_size=1, num_atoms=[420], num_bonds=[7597], num_residues=[420]),
#  PackedProtein(batch_size=1, num_atoms=[346], num_bonds=[6157], num_residues=[346]),
#  PackedProtein(batch_size=1, num_atoms=[372], num_bonds=[6727], num_residues=[372]),
#  PackedProtein(batch_size=1, num_atoms=[505], num_bonds=[8981], num_residues=[505]),
#  PackedProtein(batch_size=1, num_atoms=[712], num_bonds=[10003], num_residues=[712]),
#  PackedProtein(batch_size=1, num_atoms=[740], num_bonds=[13442], num_residues=[740]),
#  PackedProtein(batch_size=1, num_atoms=[675], num_bonds=[11330], num_residues=[675]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[6470], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[445], num_bonds=[6711], num_residues=[445]),
#  PackedProtein(batch_size=1, num_atoms=[841], num_bonds=[9798], num_residues=[841]),
#  PackedProtein(batch_size=1, num_atoms=[1124], num_bonds=[21458], num_residues=[1124]),
#  PackedProtein(batch_size=1, num_atoms=[334], num_bonds=[5968], num_residues=[334]),
#  PackedProtein(batch_size=1, num_atoms=[603], num_bonds=[10867], num_residues=[603]),
#  PackedProtein(batch_size=1, num_atoms=[647], num_bonds=[11064], num_residues=[647]),
#  PackedProtein(batch_size=1, num_atoms=[367], num_bonds=[6712], num_residues=[367]),
#  PackedProtein(batch_size=1, num_atoms=[464], num_bonds=[7518], num_residues=[464]),
#  PackedProtein(batch_size=1, num_atoms=[331], num_bonds=[5805], num_residues=[331]),
#  PackedProtein(batch_size=1, num_atoms=[552], num_bonds=[8694], num_residues=[552]),
#  PackedProtein(batch_size=1, num_atoms=[987], num_bonds=[19005], num_residues=[987]),
#  PackedProtein(batch_size=1, num_atoms=[215], num_bonds=[3518], num_residues=[215]),
#  PackedProtein(batch_size=1, num_atoms=[391], num_bonds=[6806], num_residues=[391]),
#  PackedProtein(batch_size=1, num_atoms=[415], num_bonds=[6661], num_residues=[415]),
#  PackedProtein(batch_size=1, num_atoms=[4128], num_bonds=[118646], num_residues=[4128]),
#  PackedProtein(batch_size=1, num_atoms=[1104], num_bonds=[12775], num_residues=[1104]),
#  PackedProtein(batch_size=1, num_atoms=[326], num_bonds=[5834], num_residues=[326]),
#  PackedProtein(batch_size=1, num_atoms=[292], num_bonds=[5562], num_residues=[292]),
#  PackedProtein(batch_size=1, num_atoms=[737], num_bonds=[13651], num_residues=[737]),
#  PackedProtein(batch_size=1, num_atoms=[393], num_bonds=[6880], num_residues=[393]),
#  PackedProtein(batch_size=1, num_atoms=[1124], num_bonds=[22947], num_residues=[1124]),
#  PackedProtein(batch_size=1, num_atoms=[954], num_bonds=[11860], num_residues=[954]),
#  PackedProtein(batch_size=1, num_atoms=[706], num_bonds=[12588], num_residues=[706]),
#  PackedProtein(batch_size=1, num_atoms=[509], num_bonds=[8889], num_residues=[509]),
#  PackedProtein(batch_size=1, num_atoms=[1400], num_bonds=[27513], num_residues=[1400]),
#  PackedProtein(batch_size=1, num_atoms=[1052], num_bonds=[16311], num_residues=[1052]),
#  PackedProtein(batch_size=1, num_atoms=[592], num_bonds=[10314], num_residues=[592]),
#  PackedProtein(batch_size=1, num_atoms=[676], num_bonds=[12577], num_residues=[676]),
#  PackedProtein(batch_size=1, num_atoms=[659], num_bonds=[12491], num_residues=[659]),
#  PackedProtein(batch_size=1, num_atoms=[890], num_bonds=[15585], num_residues=[890]),
#  PackedProtein(batch_size=1, num_atoms=[1038], num_bonds=[13611], num_residues=[1038]),
#  PackedProtein(batch_size=1, num_atoms=[620], num_bonds=[11930], num_residues=[620]),
#  PackedProtein(batch_size=1, num_atoms=[820], num_bonds=[15086], num_residues=[820]),
#  PackedProtein(batch_size=1, num_atoms=[999], num_bonds=[16532], num_residues=[999]),
#  PackedProtein(batch_size=1, num_atoms=[559], num_bonds=[8750], num_residues=[559]),
#  PackedProtein(batch_size=1, num_atoms=[545], num_bonds=[8492], num_residues=[545]),
#  PackedProtein(batch_size=1, num_atoms=[524], num_bonds=[8170], num_residues=[524]),
#  PackedProtein(batch_size=1, num_atoms=[491], num_bonds=[7644], num_residues=[491]),
#  PackedProtein(batch_size=1, num_atoms=[762], num_bonds=[13492], num_residues=[762]),
#  PackedProtein(batch_size=1, num_atoms=[1354], num_bonds=[18988], num_residues=[1354]),
#  PackedProtein(batch_size=1, num_atoms=[666], num_bonds=[10331], num_residues=[666]),
#  PackedProtein(batch_size=1, num_atoms=[558], num_bonds=[9694], num_residues=[558]),
#  PackedProtein(batch_size=1, num_atoms=[499], num_bonds=[8964], num_residues=[499]),
#  PackedProtein(batch_size=1, num_atoms=[763], num_bonds=[10044], num_residues=[763]),
#  PackedProtein(batch_size=1, num_atoms=[451], num_bonds=[8854], num_residues=[451]),
#  PackedProtein(batch_size=1, num_atoms=[671], num_bonds=[12735], num_residues=[671]),
#  PackedProtein(batch_size=1, num_atoms=[370], num_bonds=[6325], num_residues=[370]),
#  PackedProtein(batch_size=1, num_atoms=[716], num_bonds=[12650], num_residues=[716]),
#  PackedProtein(batch_size=1, num_atoms=[1009], num_bonds=[15967], num_residues=[1009]),
#  PackedProtein(batch_size=1, num_atoms=[651], num_bonds=[10054], num_residues=[651]),
#  PackedProtein(batch_size=1, num_atoms=[307], num_bonds=[3819], num_residues=[307]),
#  PackedProtein(batch_size=1, num_atoms=[436], num_bonds=[7367], num_residues=[436]),
#  PackedProtein(batch_size=1, num_atoms=[912], num_bonds=[14686], num_residues=[912]),
#  PackedProtein(batch_size=1, num_atoms=[1308], num_bonds=[23096], num_residues=[1308]),
#  PackedProtein(batch_size=1, num_atoms=[735], num_bonds=[13346], num_residues=[735]),
#  PackedProtein(batch_size=1, num_atoms=[364], num_bonds=[6704], num_residues=[364]),
#  PackedProtein(batch_size=1, num_atoms=[839], num_bonds=[15104], num_residues=[839]),
#  PackedProtein(batch_size=1, num_atoms=[942], num_bonds=[14856], num_residues=[942]),
#  PackedProtein(batch_size=1, num_atoms=[984], num_bonds=[15296], num_residues=[984]),
#  PackedProtein(batch_size=1, num_atoms=[360], num_bonds=[6672], num_residues=[360]),
#  PackedProtein(batch_size=1, num_atoms=[473], num_bonds=[7051], num_residues=[473]),
#  PackedProtein(batch_size=1, num_atoms=[847], num_bonds=[11050], num_residues=[847]),
#  PackedProtein(batch_size=1, num_atoms=[822], num_bonds=[14832], num_residues=[822]),
#  PackedProtein(batch_size=1, num_atoms=[382], num_bonds=[6487], num_residues=[382]),
#  PackedProtein(batch_size=1, num_atoms=[2527], num_bonds=[47859], num_residues=[2527]),
#  PackedProtein(batch_size=1, num_atoms=[1732], num_bonds=[27604], num_residues=[1732]),
#  PackedProtein(batch_size=1, num_atoms=[788], num_bonds=[10982], num_residues=[788]),
#  PackedProtein(batch_size=1, num_atoms=[1001], num_bonds=[14108], num_residues=[1001]),
#  PackedProtein(batch_size=1, num_atoms=[326], num_bonds=[5684], num_residues=[326]),
#  PackedProtein(batch_size=1, num_atoms=[385], num_bonds=[6369], num_residues=[385]),
#  PackedProtein(batch_size=1, num_atoms=[473], num_bonds=[7902], num_residues=[473]),
#  PackedProtein(batch_size=1, num_atoms=[1332], num_bonds=[18281], num_residues=[1332]),
#  PackedProtein(batch_size=1, num_atoms=[616], num_bonds=[9457], num_residues=[616]),
#  PackedProtein(batch_size=1, num_atoms=[778], num_bonds=[11101], num_residues=[778]),
#  PackedProtein(batch_size=1, num_atoms=[344], num_bonds=[5873], num_residues=[344]),
#  PackedProtein(batch_size=1, num_atoms=[322], num_bonds=[5793], num_residues=[322]),
#  PackedProtein(batch_size=1, num_atoms=[752], num_bonds=[10697], num_residues=[752]),
#  PackedProtein(batch_size=1, num_atoms=[358], num_bonds=[6201], num_residues=[358]),
#  PackedProtein(batch_size=1, num_atoms=[1323], num_bonds=[17321], num_residues=[1323]),
#  PackedProtein(batch_size=1, num_atoms=[588], num_bonds=[8282], num_residues=[588]),
#  PackedProtein(batch_size=1, num_atoms=[655], num_bonds=[10090], num_residues=[655]),
#  PackedProtein(batch_size=1, num_atoms=[1374], num_bonds=[21047], num_residues=[1374]),
#  PackedProtein(batch_size=1, num_atoms=[465], num_bonds=[7283], num_residues=[465]),
#  PackedProtein(batch_size=1, num_atoms=[502], num_bonds=[7687], num_residues=[502]),
#  PackedProtein(batch_size=1, num_atoms=[367], num_bonds=[6029], num_residues=[367]),
#  PackedProtein(batch_size=1, num_atoms=[878], num_bonds=[14382], num_residues=[878]),
#  PackedProtein(batch_size=1, num_atoms=[926], num_bonds=[10790], num_residues=[926]),
#  PackedProtein(batch_size=1, num_atoms=[1235], num_bonds=[14948], num_residues=[1235]),
#  PackedProtein(batch_size=1, num_atoms=[1198], num_bonds=[13544], num_residues=[1198]),
#  PackedProtein(batch_size=1, num_atoms=[488], num_bonds=[8758], num_residues=[488]),
#  PackedProtein(batch_size=1, num_atoms=[646], num_bonds=[10960], num_residues=[646]),
#  PackedProtein(batch_size=1, num_atoms=[481], num_bonds=[7736], num_residues=[481]),
#  PackedProtein(batch_size=1, num_atoms=[465], num_bonds=[7174], num_residues=[465]),
#  PackedProtein(batch_size=1, num_atoms=[367], num_bonds=[6821], num_residues=[367]),
#  PackedProtein(batch_size=1, num_atoms=[313], num_bonds=[5352], num_residues=[313]),
#  PackedProtein(batch_size=1, num_atoms=[422], num_bonds=[6734], num_residues=[422]),
#  PackedProtein(batch_size=1, num_atoms=[520], num_bonds=[8398], num_residues=[520]),
#  PackedProtein(batch_size=1, num_atoms=[460], num_bonds=[8082], num_residues=[460]),
#  PackedProtein(batch_size=1, num_atoms=[800], num_bonds=[11655], num_residues=[800]),
#  PackedProtein(batch_size=1, num_atoms=[311], num_bonds=[5731], num_residues=[311]),
#  PackedProtein(batch_size=1, num_atoms=[416], num_bonds=[7026], num_residues=[416]),
#  PackedProtein(batch_size=1, num_atoms=[527], num_bonds=[8311], num_residues=[527]),
#  PackedProtein(batch_size=1, num_atoms=[816], num_bonds=[12161], num_residues=[816]),
#  PackedProtein(batch_size=1, num_atoms=[482], num_bonds=[7788], num_residues=[482]),
#  PackedProtein(batch_size=1, num_atoms=[414], num_bonds=[6518], num_residues=[414]),
#  PackedProtein(batch_size=1, num_atoms=[489], num_bonds=[7300], num_residues=[489]),
#  PackedProtein(batch_size=1, num_atoms=[569], num_bonds=[7616], num_residues=[569]),
#  PackedProtein(batch_size=1, num_atoms=[729], num_bonds=[12771], num_residues=[729]),
#  PackedProtein(batch_size=1, num_atoms=[1620], num_bonds=[29287], num_residues=[1620]),
#  PackedProtein(batch_size=1, num_atoms=[478], num_bonds=[8866], num_residues=[478]),
#  PackedProtein(batch_size=1, num_atoms=[479], num_bonds=[8772], num_residues=[479]),
#  PackedProtein(batch_size=1, num_atoms=[629], num_bonds=[8804], num_residues=[629]),
#  PackedProtein(batch_size=1, num_atoms=[270], num_bonds=[3519], num_residues=[270]),
#  PackedProtein(batch_size=1, num_atoms=[846], num_bonds=[15166], num_residues=[846]),
#  PackedProtein(batch_size=1, num_atoms=[447], num_bonds=[6904], num_residues=[447])]

# %% [markdown]
# Add the 1022 + other residue feature into one protein.

# %%
transform_list[43].edge_list[-10:].tolist()
# Out:
# [[2335, 2337, 6],
#  [2336, 2338, 6],
#  [2337, 2339, 6],
#  [2338, 2340, 6],
#  [2339, 2341, 6],
#  [2340, 2342, 6],
#  [2341, 2343, 6],
#  [2342, 2344, 6],
#  [2343, 2345, 6],
#  [2344, 2346, 6]]

# %%
import torch

# %%
indexes = range(len(transform_list)) 
indexes = tqdm(indexes, "ESM Combining ...")
for index in indexes: 
    # read each esm protein from pkl file
    curProtein = transform_list[index]
    curLength = curProtein.num_residue.tolist()
    if curLength <= 1022:
        protein_pkl = '../../../data/dta-datasets/KIBA/esm/gearnetesm_'+str(index)+'.pkl'
        with utils.smart_open(protein_pkl, "rb") as fin:
            output_protein = pickle.load(fin)
        transform_list[index].residue_feature = output_protein.residue_feature
    elif curLength <= 2044:
        for i in range(2):
            protein_pkl = '../../../data/dta-datasets/KIBA/esm/gearnetesm_'+str(index)+'_'+str(i)+'.pkl'
            with utils.smart_open(protein_pkl, "rb") as fin:
                output_protein = pickle.load(fin)
            if i == 0: # the 1st part [0, 1022]
                residue_feature = output_protein.residue_feature
            else: # the 2nd part [1022, 2044]
                residue_feature = torch.cat((residue_feature, output_protein.residue_feature), dim=0)
        transform_list[index].residue_feature = residue_feature
    elif curLength <= 3066:
        for i in range(3):
            protein_pkl = '../../../data/dta-datasets/KIBA/esm/gearnetesm_'+str(index)+'_'+str(i)+'.pkl'
            with utils.smart_open(protein_pkl, "rb") as fin:
                output_protein = pickle.load(fin)
            if i == 0: # the 1st part [0, 1022]
                residue_feature = output_protein.residue_feature
            else: 
                residue_feature = torch.cat((residue_feature, output_protein.residue_feature), dim=0)
        transform_list[index].residue_feature = residue_feature
    elif curLength <= 5110:
        for i in range(5):
            protein_pkl = '../../../data/dta-datasets/KIBA/esm/gearnetesm_'+str(index)+'_'+str(i)+'.pkl'
            with utils.smart_open(protein_pkl, "rb") as fin:
                output_protein = pickle.load(fin)
            if i == 0: # the 1st part [0, 1022]
                residue_feature = output_protein.residue_feature
            else: 
                residue_feature = torch.cat((residue_feature, output_protein.residue_feature), dim=0)
        # print(residue_feature.shape)
        transform_list[index].residue_feature = residue_feature
# Out:
# ESM Combining ...: 100%|██████████| 229/229 [00:07<00:00, 29.57it/s]

# %%
transform_list[128].residue_feature.shape
# Out:
# torch.Size([4128, 1280])

# %%
len(transform_list)
# Out:
# 229

# %%
protein_pkl = '../../../data/dta-datasets/KIBA/gearnetesm650m_Protein.pkl'
with utils.smart_open(protein_pkl, "wb") as fout:
    pickle.dump(transform_list, fout)
